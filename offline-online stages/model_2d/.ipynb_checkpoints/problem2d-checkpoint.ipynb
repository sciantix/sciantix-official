# %% [markdown]
# ## **REFERENCE FULL ORDER PROBLEM**

# %% [markdown]
# #### LOAD LIBRARIES

# %%
# Import libraries:
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import itertools
import time
import os
import sys

# Import user defined libraries:
from FreeFEM import FFmatrix_fread, FFvector_fread

# %% [markdown]
# #### DEFINE REFERENCE PROBLEM PARAMETERS

# %%
## Define universal constants:
N_AVOG = 6.022141E+23  # [-]
N_BOLT = 1.380649E-23  # [-]

# Define geometrical parameters:
RADIUS = 1.00E-05  # [m]
LENGTH = 1.00E-03  # [m]

# Define fission rate:
FISSION_RATE = 3.00E+19 

# Define sources intensity:
SOURCE_T = FISSION_RATE * 7.27E-18  # [K/s]
SOURCE_C = FISSION_RATE * 0.24E+00  # [atm / (m^3 s)]

# Define temperatur diffusion coefficient and forcing dimensionless group:
ALPHA_T = 5.00E-07                        # [m^2 / s]
GAMMA_T = SOURCE_T * LENGTH**2 / ALPHA_T  # [ - ]
                       
# Define reference temperature, concentration and linear diffusion parameters:
T_BC, T_IC = 2.00E+03, 2.00E+03  # [K]
C_BC, C_IC = 0.00E+00, 0.00E+00  # [atm / m^3]

# Define forcing dimensionless group:
GAMMA_T = SOURCE_T * LENGTH**2 / ALPHA_T

# Define final time, time increment:
TIME_FINAL = 1.00E+07  # [s]
TIME_DELTA = 1.00E+04  # [s]

# Compute number of iterations:
N_ITER = int(TIME_FINAL / TIME_DELTA)  # [-]

# Define function evaluating the concentration diffusion coefficient at given z coordinated provided the problem parameters:
def ALPHA_C(ZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE):
    return 7.60E-10 * np.exp(- 4.86E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) + \
           5.64E-25 * np.exp(- 1.91E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) * np.sqrt(FISSION_RATE) + \
           8.00E-40 * FISSION_RATE

# %% [markdown]
# #### IDENTIFY DIRICHLET DOFS AND INTERNAL DOFS

# %%
# Load coordinates:
coordinates_Px = FFvector_fread('vv_cc_Px.btxt')
coordinates_Pq = FFvector_fread('vv_cc_Pq.btxt')

# Identify degrees of freedom of the Px and Pq spaces:
sFO_Px = coordinates_Px.shape[0]
sFO_Pq = coordinates_Pq.shape[0]

# Define vector of all Px indeces:
mask_all = np.arange(sFO_Px, dtype=int)

# Identify indeces of the top, bottom and middle boundaries in Px:
mask_inf_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_sup_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.ones((sFO_Px)))]
mask_mid_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_ext_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.ones((sFO_Px)))]

# Identify indeces of the Dirichlet b.c. for the temperature and concentration field:
mask_bc_T = np.fromiter(set(mask_sup_bc), int)
mask_bc_C = np.fromiter(set(mask_sup_bc) | set(mask_ext_bc) | set(mask_inf_bc), int)

# Identify indeces of the interior for the temperature and concentration field:
mask_in_T = [ii for ii in mask_all if ii not in mask_bc_T]
mask_in_C = [ii for ii in mask_all if ii not in mask_bc_C]

# %%
sFO_Px
# Out:
# 10201

# %% [markdown]
# #### DEFINE FINITE ELEMENT ESSENTIALS

# %%
# Import mass matrices on the Px and on the Pq space:
mass_Px = FFmatrix_fread('ww_mm_Px.btxt')
mass_Pq = FFmatrix_fread('ww_mm_Pq.btxt')
mass_Pm = FFmatrix_fread('ww_uu_Px_Pq.btxt')

# Extract integration weights and diagonal matrix with their inverse:
weights_Pq = mass_Pq.diagonal()
project_Pq = sparse.diags(np.reciprocal(weights_Pq))

# Import map from Px to Pq and to the dx, dy, dz derivative evaluated in Pq:
PxtoPquu_C = project_Pq.dot(FFmatrix_fread('ww_uu_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdx_C = project_Pq.dot(FFmatrix_fread('ww_dx_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdy_C = project_Pq.dot(FFmatrix_fread('ww_dy_Px_Pq.btxt')[:, mask_in_C])

# Define weights for the integration in polar coordinates:
polar_weights_Pq = np.multiply(coordinates_Pq[:, 0], weights_Pq)

# Compute volume of the domain:
volume = np.dot(np.ones(sFO_Pq), polar_weights_Pq)

# Assemble mass matrix and projected forcing term:
forc_C = PxtoPquu_C.T.dot(polar_weights_Pq[:, None])
mass_C = PxtoPquu_C.T.dot(PxtoPquu_C.multiply(polar_weights_Pq[:, None]))
inte_C = PxtoPquu_C.T.dot(polar_weights_Pq) / volume

# Assemble a function assembling the stiffness matrix at a given time:
stiff_C = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / RADIUS**2 * polar_weights_Pq[:, None])) + \
          PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / LENGTH**2 * polar_weights_Pq[:, None]))

# %% [markdown]
# #### IMPLEMENT FULLY IMPLICID FORWARD EULER FOR THE CONCENTRATION ONLY

# %%
# Initialise temperature and concentration solution containing the deviation from the initial condition:
sol_new_C = np.zeros((sFO_Px, N_ITER+1)) 

# Integrate using forward Euler up to the final time:
for ii in range(N_ITER):
    cur_time = ii * TIME_DELTA

    # Print current iteration and average temperature and concentration:
    print('Current time:', cur_time, 's')
    print('Average concentration:', inte_C @ sol_new_C[mask_in_C, ii], 'atm/m^3\n')

    # Assemble current left-hand-side and right-hand-side
    cur_lhs = mass_C + TIME_DELTA * stiff_C
    cur_rhs = mass_C.dot(sol_new_C[mask_in_C, ii:ii+1]) + TIME_DELTA * (SOURCE_C * forc_C)

    # Compute perturbation from the initial temperature and concentration in the interior of the domain:
    sol_new_C[mask_in_C, ii+1], _ = linalg.bicgstab(cur_lhs, cur_rhs)

# Print final time and final average temperature and concentration:
#
# Current time: 360000.0 s
# Average concentration: 1.0542488338565464e+24 atm/m^3
#
# Current time: 370000.0 s
# Average concentration: 1.0683628800918038e+24 atm/m^3
#
# Current time: 380000.0 s
# Average concentration: 1.0820539968698695e+24 atm/m^3
#
# Current time: 390000.0 s
# Average concentration: 1.0953383002061153e+24 atm/m^3
#
# Current time: 400000.0 s
# Average concentration: 1.1082305137548221e+24 atm/m^3
#
# Current time: 410000.0 s
# Average concentration: 1.1207454366930008e+24 atm/m^3
#
# Current time: 420000.0 s
# Average concentration: 1.1328966138690564e+24 atm/m^3
#
# Current time: 430000.0 s
# Average concentration: 1.1446969785421924e+24 atm/m^3
#
# Current time: 440000.0 s
# Average concentration: 1.156159306852595e+24 atm/m^3
#
# Current time: 450000.0 s
# Average concentration: 1.1672953673501471e+24 atm/m^3
#
# Current time: 460000.0 s
# Average concentration: 1.178116612195941e+24 atm/m^3
#
# Current time: 470000.0 s
# Average concentration: 1.1886344635651813e+24 atm/m^3
#
# Current time: 480000.0 s
# Average concentration: 1.198859110949656e+24 atm/m^3
#
# Current time: 490000.0 s
# Average concentration: 1.2088010065892942e+24 atm/m^3
#
# Current time: 500000.0 s
# Average concentration: 1.2184702523599307e+24 atm/m^3
#
# Current time: 510000.0 s
# Average concentration: 1.227875537750326e+24 atm/m^3
#
# Current time: 520000.0 s
# Average concentration: 1.237026145500973e+24 atm/m^3
#
# Current time: 530000.0 s
# Average concentration: 1.2459301056411866e+24 atm/m^3
#
# Current time: 540000.0 s
# Average concentration: 1.2545961298589612e+24 atm/m^3
#
# Current time: 550000.0 s
# Average concentration: 1.2630319408171185e+24 atm/m^3
#
# Current time: 560000.0 s
# Average concentration: 1.2712446844892838e+24 atm/m^3
#
# Current time: 570000.0 s
# Average concentration: 1.2792426752327984e+24 atm/m^3
#
# Current time: 580000.0 s
# Average concentration: 1.2870319540231498e+24 atm/m^3
#
# Current time: 590000.0 s
# Average concentration: 1.2946199461530267e+24 atm/m^3
#
# Current time: 600000.0 s
# Average concentration: 1.3020125650642228e+24 atm/m^3
#
# Current time: 610000.0 s
# Average concentration: 1.3092159752842592e+24 atm/m^3
#
# Current time: 620000.0 s
# Average concentration: 1.3162366467924717e+24 atm/m^3
#
# Current time: 630000.0 s
# Average concentration: 1.3230800334289982e+24 atm/m^3
#
# Current time: 640000.0 s
# Average concentration: 1.3297520339231095e+24 atm/m^3
#
# Current time: 650000.0 s
# Average concentration: 1.3362574526104652e+24 atm/m^3
#
# Current time: 660000.0 s
# Average concentration: 1.3426014810092836e+24 atm/m^3
#
# Current time: 670000.0 s
# Average concentration: 1.348789317487361e+24 atm/m^3
#
# Current time: 680000.0 s
# Average concentration: 1.3548257187956424e+24 atm/m^3
#
# Current time: 690000.0 s
# Average concentration: 1.360714833633052e+24 atm/m^3
#
# Current time: 700000.0 s
# Average concentration: 1.3664617720290308e+24 atm/m^3
#
# Current time: 710000.0 s
# Average concentration: 1.372070120667512e+24 atm/m^3
#
# Current time: 720000.0 s
# Current time: 1090000.0 s
# Average concentration: 1.5128541132901403e+24 atm/m^3
#
# Current time: 1100000.0 s
# Average concentration: 1.5152248594369523e+24 atm/m^3
#
# Current time: 1110000.0 s
# Average concentration: 1.5175481462958877e+24 atm/m^3
#
# Current time: 1120000.0 s
# Average concentration: 1.5198253717221023e+24 atm/m^3
#
# Current time: 1130000.0 s
# Average concentration: 1.5220575683179774e+24 atm/m^3
#
# Current time: 1140000.0 s
# Average concentration: 1.524244913905901e+24 atm/m^3
#
# Current time: 1150000.0 s
# Average concentration: 1.526389191927385e+24 atm/m^3
#
# Current time: 1160000.0 s
# Average concentration: 1.528491639609634e+24 atm/m^3
#
# Current time: 1170000.0 s
# Average concentration: 1.5305523185052904e+24 atm/m^3
#
# Current time: 1180000.0 s
# Average concentration: 1.5325723817760492e+24 atm/m^3
#
# Current time: 1190000.0 s
# Average concentration: 1.5345537403497208e+24 atm/m^3
#
# Current time: 1200000.0 s
# Average concentration: 1.536496072817469e+24 atm/m^3
#
# Current time: 1210000.0 s
# Average concentration: 1.5384011992696782e+24 atm/m^3
#
# Current time: 1220000.0 s
# Average concentration: 1.5402690483074815e+24 atm/m^3
#
# Current time: 1230000.0 s
# Average concentration: 1.542101473936155e+24 atm/m^3
#
# Current time: 1240000.0 s
# Average concentration: 1.5438984127541476e+24 atm/m^3
#
# Current time: 1250000.0 s
# Average concentration: 1.5456608929327157e+24 atm/m^3
#
# Current time: 1260000.0 s
# Average concentration: 1.5473901339154226e+24 atm/m^3
#
# Current time: 1270000.0 s
# Average concentration: 1.5490857090021234e+24 atm/m^3
#
# Current time: 1280000.0 s
# Average concentration: 1.5507492410979618e+24 atm/m^3
#
# Current time: 1290000.0 s
# Average concentration: 1.552381394485149e+24 atm/m^3
#
# Current time: 1300000.0 s
# Average concentration: 1.553983007811453e+24 atm/m^3
#
# Current time: 1310000.0 s
# Average concentration: 1.5555542879040225e+24 atm/m^3
#
# Current time: 1320000.0 s
# Average concentration: 1.5570958280883944e+24 atm/m^3
#
# Current time: 1330000.0 s
# Average concentration: 1.5586083456008472e+24 atm/m^3
#
# Current time: 1340000.0 s
# Average concentration: 1.560092553652847e+24 atm/m^3
#
# Current time: 1350000.0 s
# Average concentration: 1.5615492004781764e+24 atm/m^3
#
# Current time: 1360000.0 s
# Average concentration: 1.562978703562847e+24 atm/m^3
#
# Current time: 1370000.0 s
# Average concentration: 1.5643818923025928e+24 atm/m^3
#
# Current time: 1380000.0 s
# Average concentration: 1.5657590861160168e+24 atm/m^3
#
# Current time: 1390000.0 s
# Average concentration: 1.567110784890831e+24 atm/m^3
#
# Current time: 1400000.0 s
# Average concentration: 1.5684377212079633e+24 atm/m^3
#
# Current time: 1410000.0 s
# Average concentration: 1.5697405241820026e+24 atm/m^3
#
# Current time: 1420000.0 s
# Average concentration: 1.5710196052996523e+24 atm/m^3
#
# Current time: 1430000.0 s
# Average concentration: 1.5722750018101781e+24 atm/m^3
#
# Current time: 1440000.0 s
# Average concentration: 1.5735077125951809e+24 atm/m^3
#
# Current time: 1450000.0 s
# Average concentration: 1.5747175779762487e+24 atm/m^3
#
# Current time: 1460000.0 s
# Average concentration: 1.575905713210618e+24 atm/m^3
#
# Current time: 1470000.0 s
# Average concentration: 1.5770723758486368e+24 atm/m^3
#
# Current time: 1480000.0 s
# Average concentration: 1.578218045533394e+24 atm/m^3
#
# Current time: 1490000.0 s
# Average concentration: 1.57934349077041e+24 atm/m^3
#
# Current time: 1500000.0 s
# Average concentration: 1.580448342520248e+24 atm/m^3
#
# Current time: 1510000.0 s
# Average concentration: 1.5815339462848592e+24 atm/m^3
#
# Current time: 1520000.0 s
# Average concentration: 1.5825995602605966e+24 atm/m^3
#
# Current time: 1530000.0 s
# Average concentration: 1.5836459630776226e+24 atm/m^3
#
# Current time: 1540000.0 s
# Average concentration: 1.5846739949295197e+24 atm/m^3
#
# Current time: 1550000.0 s
# Average concentration: 1.5856840556606897e+24 atm/m^3
#
# Current time: 1560000.0 s
# Average concentration: 1.586675879161262e+24 atm/m^3
#
# Current time: 1570000.0 s
# Average concentration: 1.5876502770983326e+24 atm/m^3
#
# Current time: 1580000.0 s
# Average concentration: 1.5886071036309136e+24 atm/m^3
#
# Current time: 1590000.0 s
# Average concentration: 1.5895469481832733e+24 atm/m^3
#
# Current time: 1600000.0 s
# Average concentration: 1.5904702446733244e+24 atm/m^3
#
# Current time: 1610000.0 s
# Average concentration: 1.5913771651884842e+24 atm/m^3
#
# Current time: 1620000.0 s
# Average concentration: 1.5922684148558102e+24 atm/m^3
#
# Current time: 1630000.0 s
# Average concentration: 1.5931438611630764e+24 atm/m^3
#
# Current time: 1640000.0 s
# Average concentration: 1.59400437545733e+24 atm/m^3
#
# Current time: 1650000.0 s
# Average concentration: 1.5948495641153664e+24 atm/m^3
#
# Current time: 1660000.0 s
# Average concentration: 1.5956799889089806e+24 atm/m^3
#
# Current time: 1670000.0 s
# Average concentration: 1.5964962833753983e+24 atm/m^3
#
# Current time: 1680000.0 s
# Average concentration: 1.5972981054093351e+24 atm/m^3
#
# Current time: 1690000.0 s
# Average concentration: 1.5980861601448856e+24 atm/m^3
#
# Current time: 1700000.0 s
# Average concentration: 1.5988603328953195e+24 atm/m^3
#
# Current time: 1710000.0 s
# Average concentration: 1.5996219027077747e+24 atm/m^3
#
# Current time: 1720000.0 s
# Average concentration: 1.6003700583139998e+24 atm/m^3
#
# Current time: 1730000.0 s
# Average concentration: 1.601105005153372e+24 atm/m^3
#
# Current time: 1740000.0 s
# Average concentration: 1.6018272074895543e+24 atm/m^3
#
# Current time: 1750000.0 s
# Average concentration: 1.6025372129884304e+24 atm/m^3
#
# Current time: 1760000.0 s
# Average concentration: 1.603234989411402e+24 atm/m^3
#
# Current time: 1770000.0 s
# Average concentration: 1.60392117810481e+24 atm/m^3
#
# Current time: 1780000.0 s
# Average concentration: 1.6045952799020306e+24 atm/m^3
#
# Current time: 1790000.0 s
# Average concentration: 1.6052580667660002e+24 atm/m^3
#
# Current time: 1800000.0 s
# Average concentration: 1.6059096949313714e+24 atm/m^3
#
# Average concentration: 1.6459677220253557e+24 atm/m^3
#
# Final time: 10000000.0 s
# Average concentration: 1.6459677733235297e+24 atm/m^3

# %%
field = sol_new_C[:, -1] / volume
#field = np.hstack((field, field))
coord_x = np.hstack((coordinates_Px[:, 0]))#, - coordinates_Px[:, 0]))
coord_y = np.hstack((coordinates_Px[:, 1]))#,   coordinates_Px[:, 1]))

max_tick = np.max(field)
tick_step = max_tick / 10

plt.figure(figsize=(8, 6))
contour = plt.tricontourf(coord_x, coord_y, field, 400, cmap='RdBu_r', vmin=0, vmax = max_tick)
cbar = plt.colorbar(contour, ticks=np.arange(0, max_tick, tick_step))       # Usa '%.2f' per due cifre decimali
cbar.ax.tick_params(labelsize=13)  # Dimensione del testo della colorbar
cbar.set_label('Concentration  [atm/m$^3$]', fontsize=14)
 
    
#plt.ylim((1-2e-2, 1))
plt.tick_params(axis="y", labelsize=13)
plt.tick_params(axis='x', labelsize=13)
plt.xlabel('Radius  [ - ]',fontsize=14)
plt.ylabel('Length  [ - ]',fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.savefig('FOM_xz.pdf', bbox_inches='tight')
# Out:
# /Users/fabs/anaconda3/lib/python3.11/site-packages/matplotlib/tri/_triangulation.py:181: RuntimeWarning: invalid value encountered in cast
#   triangles = np.asarray(triangles, dtype=np.int32)

# %% [markdown]
# ## **REDUCED BASIS MODEL CONSTRUCTION**

# %% [markdown]
# #### DEFINE PARAMETERS TRAINING SET

# %%
# Define size of the training parameter set:
sTR = 10000

# Define parameters ranges:
MIN_FR, MAX_FR = 2.00E+19, 3.00E+19 
MIN_BC, MAX_BC = 1.75E+03, 2.25E+03
MIN_LL, MAX_LL = 0.75E-3, 1.25E-3
MIN_RR, MAX_RR = 0.75E-5, 1.25E-5
MIN_GG, MAX_GG = (7.27E-18 / 5.00E-07) * MIN_FR * MIN_LL**2, (7.27E-18 / 5.00E-07) * MAX_FR * MAX_LL**2

# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_GG = (7.27E-18 / 5.00E-07) * LIST_FR * LIST_LL**2

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TRAINING = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TRAINING[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# %% [markdown]
# #### CONSTRUCT AN AFFINE DECOMPOSITION FOR THE CONCENTRATION DIFFUSION COEFFICIENTS

# %%
# Compress the training set using singular value decomposition:
UU, SS, VV = np.linalg.svd(TRAINING @ TRAINING.T, full_matrices=False)
NN = np.sum(np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))]) > 1e-6) + 1

# Construct 1D and 3D basis for the concentration diffusion coefficient:
BASIS_D_1D = UU[:, :NN]
BASIS_D_2D = ZZ_1Dto2D @ BASIS_D_1D

# Use a greedy algorithm to identify the points (indeces) to interpolate the exact concentration coefficients:
INT_COO = [np.argmax(np.abs(BASIS_D_1D[:, 0]))]
for ii in range(1, NN):
    INT_COO.append(np.argmax(np.abs(BASIS_D_1D[:, ii] - BASIS_D_1D[:, :ii] @ np.linalg.solve(BASIS_D_1D[INT_COO, :ii],  BASIS_D_1D[INT_COO, ii]))))

# Extrat the z coordinates associated with the selected indeces:
INT_COO = np.array(INT_COO)
INT_CZZ = np.array([ZZ[INT_COO[ii]] for ii in range(NN)])

# Define interpolation operator mapping from the diffusion coefficient evaluated in the interpolation points to the linear combination coefficients:
mapDAtoCO = np.linalg.solve(BASIS_D_1D[INT_COO, :], np.eye(NN))

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TRAINING - BASIS_D_1D @ mapDAtoCO @ TRAINING[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TRAINING, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
# Out:
# 3.869957140835533e-07

# %%
#guardiamo la missing energy del termine non-affine -> queste basi ridotte dopo le usiamo per davvero
cmap = plt.get_cmap('RdBu')
color = cmap(0.9)
 
missing = np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))])
fig, (ax1) = plt.subplots(1, figsize=(4,5))
ax1.set_yscale('log')
ax1.plot(range(1,26), missing[:25], '-o')
ax1.tick_params(axis="y", which='both',labelsize=13,  width=1)
ax1.tick_params(axis='x', labelsize=13,  width=1)
ax1.set_xlabel('Number of DEIM modes',fontsize=14)
ax1.set_ylabel('Missing energy',fontsize=14)
ax1.axvspan(1, NN, color='gray', alpha=0.2)
ax1.set_xlim([0,25])
ax1.set_ylim([1e-7, 1])
ax1.grid(visible=True, which='both', linewidth=1, alpha=0.7)
plt.savefig('Missing energy.pdf', bbox_inches='tight')

# %% [markdown]
# #### ASSEMBLE AFFINELY DECOMPOSED STIFFNESS MATRICES AND COMPUTE THEIR COERCIVITY CONSTANTS

# %%
# Define two mass matrices respectively linked to the regularity of the solution and of its time derivative:
Y_mass = stiff_C
X_mass = mass_C

# Initialise array for the partial stiffness matrices and for their coercivity constants:
list_basis_stiff_C = np.array([sparse.csr_matrix((mass_C.shape)) for ii in range(2*NN)])
list_coerc_stiff_C = np.zeros((2*NN))

# Iterate over the selected basis for the diffusion coefficient field
for ii in range(NN):

    # Assemble the radial and axial partial stiffness matrices associated with the basis of the diffusivity:
    list_basis_stiff_C[00+ii] = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))
    list_basis_stiff_C[NN+ii] = PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))

    # Compute the sign of the axial and radial partial stiffness matrices:
    tsign_dz_C = np.sign(list_basis_stiff_C[NN + ii].trace())
    tsign_dr_C = np.sign(list_basis_stiff_C[00 + ii].trace())

    # Compute the coercivity constant of the axial and radial partial stiffness matrices:
    list_coerc_stiff_C[NN+ii] = tsign_dz_C / linalg.eigsh(Y_mass, k=1, M=tsign_dz_C * list_basis_stiff_C[NN+ii], which='LM', return_eigenvectors=False)[0]
    list_coerc_stiff_C[00+ii] = tsign_dr_C / linalg.eigsh(Y_mass, k=1, M=tsign_dr_C * list_basis_stiff_C[00+ii], which='LM', return_eigenvectors=False)[0]

# %% [markdown]
# #### COMPUTE THE INTERPOLATION COEFFICIENTS AND THE COERCIVITY COEFFICIENTS FOR ALL THE PARAMETERS

# %%
# Compute hte interpolation coefficients and the coercivity coefficients for the parameters in the training set:
list_inter_coef = np.empty((sTR, 2*NN))
list_coerc_coef = np.empty((sTR))

# Iterate over the training set:
for ii in range(sTR):
    cur_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

    # Compute the interpolation coefficients for the radial and axial partial stiffness matrices:
    list_inter_coef[ii, NN:] = cur_coef / LIST_LL[ii]**2
    list_inter_coef[ii, :NN] = cur_coef / LIST_RR[ii]**2

    # Compute a lower bound for the coercivity constants:
    list_coerc_coef[ii] = np.dot(list_coerc_stiff_C, list_inter_coef[ii, :])

# Compute interpolation and coercivity coeffientrs for the reference parameters:
cur_inter_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE)
cur_inter_coef = np.hstack((cur_inter_coef / RADIUS**2, cur_inter_coef / LENGTH**2))
cur_coerc_coef = np.dot(list_coerc_stiff_C, cur_inter_coef)

# %% [markdown]
# #### COMPUTE THE POD MODES OF THE REFERENCE SOLUTION

# %%
# Compute the singular value decomposition of the gramian matrix:
AA, GG, BB = np.linalg.svd(sol_new_C[mask_in_C, :].T @ Y_mass @ sol_new_C[mask_in_C, :], full_matrices=False)

# Compute total Y-energy of the training set:
Y_energy = np.sum([Y_mass.dot(sol_new_C[mask_in_C, ii]).dot(sol_new_C[mask_in_C, ii]) for ii in range(N_ITER+1)])

# Determine number of POD modes to retain:
sRB_C = np.sum([np.sqrt(np.sum(GG[ii:]) / Y_energy) > 1e-4 for ii in range(len(GG))])

# Assemble POD modes for the concentration field at the reference parameters:
BASIS_C_2D = sol_new_C[mask_in_C, :] @ AA[:, :sRB_C] @ np.diag(np.reciprocal(np.sqrt(GG[:sRB_C])))

# %% [markdown]
# #### ASSEMBLE REDUCED MATRICES (LATER MUST BE CODED AS THE METHOD OF A CLASS)

# %%
# Project the Y- and X-mass matrices on the reduced basis space:
Y_mass_RB = BASIS_C_2D.T @ Y_mass @ BASIS_C_2D
X_mass_RB = BASIS_C_2D.T @ X_mass @ BASIS_C_2D

# Compute Rietz representer and projection of the forcing term:
forc_C_rietz_RB = linalg.spsolve(Y_mass, forc_C)
forc_C_proje_RB = BASIS_C_2D.T @ forc_C

# Compute Rietz representer and projection of the mass matrix tested versus the POD basis functions: 
mass_C_right_RB = mass_C @ BASIS_C_2D
mass_C_rietz_RB = linalg.spsolve(Y_mass, mass_C_right_RB)
mass_C_proje_RB = BASIS_C_2D.T @ mass_C_right_RB

# Compute the Rietz representer and projection of all the partial stiffness matrices from the affine decomposition:
list_basis_stiff_C_right_RB = np.array([list_basis_stiff_C[ii] @ BASIS_C_2D for ii in range(2*NN)])
list_basis_stiff_C_rietz_RB = np.array([linalg.spsolve(Y_mass, list_basis_stiff_C_right_RB[ii]) for ii in range(2*NN)])
list_basis_stiff_C_proje_RB = np.array([BASIS_C_2D.T @ list_basis_stiff_C_right_RB[ii] for ii in range(2*NN)])

# Pre-assemble the scalar and vector terms for the residual energy computation:
DD_pr_bb = (forc_C_rietz_RB.T @ forc_C) * (SOURCE_C * SOURCE_C)
DD_pr_bm = (forc_C_rietz_RB.T @ mass_C_right_RB) * (- 2 * SOURCE_C / TIME_DELTA)
DD_pr_mm = (mass_C_rietz_RB.T @ mass_C_right_RB) * (  1 / (TIME_DELTA * TIME_DELTA))

# Pre-assemble all the tensor terms for the residual energy computation:
DD_pr_ab = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ forc_C_rietz_RB for ii in range(2*NN)]) * (-2 * SOURCE_C)
DD_pr_am = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ mass_C_rietz_RB for ii in range(2*NN)]) * ( 2 / TIME_DELTA)
DD_pr_aa = np.array([[list_basis_stiff_C_right_RB[ii, :, :].T @ list_basis_stiff_C_rietz_RB[jj, :, :] for ii in range(2*NN)] for jj in range(2*NN)])

# Compute the weights for the integration of the reduced basis solutions:
weights_RB = np.ones((sFO_Px)) @ mass_Px[:, mask_in_C] @ BASIS_C_2D

# %% [markdown]
# #### COMPUTE REDUCED BASIS SOLUTION

# %%
# Assemble current reduced basis stiffness matrix:
stiff_C_proje_RB = np.tensordot(cur_inter_coef, list_basis_stiff_C_proje_RB, axes=[0, 0])
stiff_C_exact_RB = BASIS_C_2D.T @ stiff_C @ BASIS_C_2D

# Assemble current stiffness cross term for the computation of the residual energy:
cur_DD_pr_ab = np.tensordot(cur_inter_coef, DD_pr_ab, axes=[0, 0])
cur_DD_pr_am = np.tensordot(cur_inter_coef, DD_pr_am, axes=[0, 0])
cur_DD_pr_aa = np.tensordot(cur_inter_coef, np.tensordot(cur_inter_coef, DD_pr_aa, axes=[0, 0]), axes=[0, 0])

# Initialise reduced basis concentration solution:
sol_new_C_RB = np.zeros((sRB_C, N_ITER+1))
sol_new_C_FO = np.zeros((len(mask_in_C), N_ITER+1))

# Initialise errors and errors estimators:
energy_residual = np.empty((N_ITER))
energy_solution = np.empty((N_ITER))
energy_toterror = np.empty((N_ITER))

#
inte_C_RB = inte_C @ BASIS_C_2D

# Integrate using forward Euler up to the final time:
verbose = True
for ii in range(N_ITER):
    cur_time = ii * TIME_DELTA

    # Print current iteration and average temperature and concentration:
    if verbose:
        print('Current time:', cur_time, 's')
        print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, ii], 'atm/m^3\n')

    # Assemble current left-hand-side and right-hand-side
    cur_lhs_RB = mass_C_proje_RB + TIME_DELTA * stiff_C_proje_RB
    cur_rhs_RB = mass_C_proje_RB.dot(sol_new_C_RB[:, ii:ii+1]) + TIME_DELTA * SOURCE_C * forc_C_proje_RB

    # Compute concentration in the interior of the domain:
    sol_new_C_RB[:, ii+1] = np.linalg.solve(cur_lhs_RB, cur_rhs_RB)[:, 0]
    sol_new_C_FO[:, ii+1] = BASIS_C_2D @ sol_new_C_RB[:, ii+1]
    
    # Compute partial errors and error bounds:
    energy_toterror[ii] = TIME_DELTA * stiff_C.dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1]).dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1])
    energy_solution[ii] = TIME_DELTA * stiff_C_proje_RB.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1])
    energy_residual[ii] = TIME_DELTA * (DD_pr_bb[0] + DD_pr_bm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        DD_pr_mm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        cur_DD_pr_ab.dot(sol_new_C_RB[:, ii+1]) + cur_DD_pr_aa.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1]) +\
                                        cur_DD_pr_am.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1]))

# Print current iteration and average temperature and concentration:
if verbose: 
    print('Final time:', N_ITER * TIME_DELTA, 's')
    print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, -1], 'atm/m^3\n\n')

# Add final term energies:
energy_solution[-1] += mass_C_proje_RB.dot(sol_new_C_RB[:, -1]).dot(sol_new_C_RB[:, -1])
energy_toterror[-1] += mass_C.dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1]).dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1])

# Print errors and error bounds:
print('Error bound:', np.sqrt(np.sum(energy_residual) / np.sum(energy_solution) / cur_coerc_coef) )
print('Error exact:', np.sqrt(np.sum(energy_toterror) / np.sum(energy_solution)) )
# Out:
# Current time: 0.0 s
# Average concentration: 0.0 atm/m^3
#
# Current time: 10000.0 s
# Average concentration: 6.0788190881668644e+22 atm/m^3
#
# Current time: 20000.0 s
# Average concentration: 1.162916962638536e+23 atm/m^3
#
# Current time: 30000.0 s
# Average concentration: 1.6794069014676912e+23 atm/m^3
#
# Current time: 40000.0 s
# Average concentration: 2.1648378214004132e+23 atm/m^3
# Average concentration: 1.581535271181484e+24 atm/m^3
#
# Current time: 1520000.0 s
# Average concentration: 1.5826008739228908e+24 atm/m^3
#
# Current time: 1530000.0 s
# Average concentration: 1.583647441064256e+24 atm/m^3
#
# Current time: 1540000.0 s
# Average concentration: 1.58467535130266e+24 atm/m^3
#
# Current time: 1550000.0 s
# Average concentration: 1.585684974662873e+24 atm/m^3
#
# Current time: 1560000.0 s
# Average concentration: 1.5866766727313251e+24 atm/m^3
#
# Current time: 1570000.0 s
# Average concentration: 1.5876507988826375e+24 atm/m^3
#
# Current time: 1580000.0 s
# Average concentration: 1.5886076984989841e+24 atm/m^3
#
# Current time: 1590000.0 s
# Average concentration: 1.5895477091825582e+24 atm/m^3
#
# Current time: 1600000.0 s
# Average concentration: 1.5904711609613805e+24 atm/m^3
#
# Current time: 1610000.0 s
# Average concentration: 1.5913783764886937e+24 atm/m^3
#
# Current time: 1620000.0 s
# Average concentration: 1.592269671236179e+24 atm/m^3
#
# Current time: 1630000.0 s
# Average concentration: 1.5931453536812032e+24 atm/m^3
#
# Current time: 1640000.0 s
# Average concentration: 1.5940057254883287e+24 atm/m^3
#
# Current time: 1650000.0 s
# Average concentration: 1.5948510816852684e+24 atm/m^3
#
# Current time: 1660000.0 s
# Average concentration: 1.5956817108335027e+24 atm/m^3
#
# Current time: 1670000.0 s
# Average concentration: 1.596497895193723e+24 atm/m^3
#
# Current time: 1680000.0 s
# Average concentration: 1.5972999108863107e+24 atm/m^3
#
# Current time: 1690000.0 s
# Average concentration: 1.5980880280469967e+24 atm/m^3
#
# Current time: 1700000.0 s
# Average concentration: 1.5988625109778913e+24 atm/m^3
#
# Current time: 1710000.0 s
# Average concentration: 1.599623618294027e+24 atm/m^3
#
# Current time: 1720000.0 s
# Average concentration: 1.6003716030655815e+24 atm/m^3
#
# Current time: 1730000.0 s
# Average concentration: 1.6011067129559247e+24 atm/m^3
#
# Current time: 1740000.0 s
# Average concentration: 1.6018291903556276e+24 atm/m^3
#
# Current time: 1750000.0 s
# Average concentration: 1.6025392725125712e+24 atm/m^3
#
# Current time: 1760000.0 s
# Average concentration: 1.603237191658298e+24 atm/m^3
#
# Current time: 1770000.0 s
# Average concentration: 1.6039231751307147e+24 atm/m^3
#
# Current time: 1780000.0 s
# Average concentration: 1.6045974454932822e+24 atm/m^3
#
# Current time: 1790000.0 s
# Average concentration: 1.6052602206508017e+24 atm/m^3
#
# Current time: 1800000.0 s
# Average concentration: 1.6059117139619187e+24 atm/m^3
#
# Current time: 1810000.0 s
# Average concentration: 1.6065521343484413e+24 atm/m^3
#
# Current time: 1820000.0 s
# Average concentration: 1.6071816864015823e+24 atm/m^3
#
# Current time: 1830000.0 s
# Average concentration: 1.6078005704852377e+24 atm/m^3
#
# Current time: 1840000.0 s
# Average concentration: 1.608408982836376e+24 atm/m^3
#
# Current time: 1850000.0 s
# Average concentration: 1.6090071156626487e+24 atm/m^3
#
# Current time: 1860000.0 s
# Average concentration: 1.609595157237302e+24 atm/m^3
#
# Current time: 1870000.0 s
# Average concentration: 1.6456734433631127e+24 atm/m^3
#
# Current time: 5120000.0 s
# Average concentration: 1.6456776205992268e+24 atm/m^3
#
# Current time: 5130000.0 s
# Average concentration: 1.645681738538797e+24 atm/m^3
#
# Current time: 5140000.0 s
# Average concentration: 1.6456857980345138e+24 atm/m^3
#
# Current time: 5150000.0 s
# Average concentration: 1.6456897999266018e+24 atm/m^3
#
# Current time: 5160000.0 s
# Average concentration: 1.6456937450430106e+24 atm/m^3
#
# Current time: 5170000.0 s
# Average concentration: 1.6456976341995974e+24 atm/m^3
#
# Current time: 5180000.0 s
# Average concentration: 1.6457014682003025e+24 atm/m^3
#
# Current time: 5190000.0 s
# Average concentration: 1.6457052478373323e+24 atm/m^3
#
# Current time: 5200000.0 s
# Average concentration: 1.6457089738913324e+24 atm/m^3
#
# Current time: 5210000.0 s
# Average concentration: 1.6457126471315566e+24 atm/m^3
#
# Current time: 5220000.0 s
# Average concentration: 1.6457162683160427e+24 atm/m^3
#
# Current time: 5230000.0 s
# Average concentration: 1.6457198381917727e+24 atm/m^3
#
# Current time: 5240000.0 s
# Average concentration: 1.645723357494841e+24 atm/m^3
#
# Current time: 5250000.0 s
# Average concentration: 1.6457268269506173e+24 atm/m^3
#
# Current time: 5260000.0 s
# Average concentration: 1.6457302472739025e+24 atm/m^3
#
# Current time: 5270000.0 s
# Average concentration: 1.645733619169087e+24 atm/m^3
#
# Current time: 5280000.0 s
# Average concentration: 1.645736943330306e+24 atm/m^3
#
# Current time: 5290000.0 s
# Average concentration: 1.6457402204415919e+24 atm/m^3
#
# Current time: 5300000.0 s
# Average concentration: 1.6457434511770215e+24 atm/m^3
#
# Current time: 5310000.0 s
# Average concentration: 1.6457466362008705e+24 atm/m^3
#
# Current time: 5320000.0 s
# Average concentration: 1.6457497761677487e+24 atm/m^3
#
# Current time: 5330000.0 s
# Average concentration: 1.6457528717227512e+24 atm/m^3
#
# Current time: 5340000.0 s
# Average concentration: 1.6457559235015988e+24 atm/m^3
#
# Current time: 5350000.0 s
# Average concentration: 1.64575893213077e+24 atm/m^3
#
# Current time: 5360000.0 s
# Average concentration: 1.645761898227647e+24 atm/m^3
#
# Current time: 5370000.0 s
# Average concentration: 1.6457648224006448e+24 atm/m^3
#
# Current time: 5380000.0 s
# Average concentration: 1.6457677052493442e+24 atm/m^3
#
# Current time: 5390000.0 s
# Average concentration: 1.6457705473646254e+24 atm/m^3
#
# Current time: 5400000.0 s
# Average concentration: 1.645773349328791e+24 atm/m^3
#
# Current time: 5410000.0 s
# Average concentration: 1.645776111715702e+24 atm/m^3
#
# Current time: 5420000.0 s
# Average concentration: 1.6457788350908908e+24 atm/m^3
#
# Current time: 5430000.0 s
# Average concentration: 1.645781520011694e+24 atm/m^3
#
# Current time: 5440000.0 s
# Average concentration: 1.6457841670273698e+24 atm/m^3
#
# Current time: 5450000.0 s
# Average concentration: 1.6457867766792154e+24 atm/m^3
#
# Current time: 5460000.0 s
# Average concentration: 1.6457893495006868e+24 atm/m^3
#
# Current time: 5470000.0 s
# Average concentration: 1.6458628901387982e+24 atm/m^3
#
# Current time: 5840000.0 s
# Average concentration: 1.645864391738409e+24 atm/m^3
#
# Current time: 5850000.0 s
# Average concentration: 1.6458658722705952e+24 atm/m^3
#
# Current time: 5860000.0 s
# Average concentration: 1.645867332033829e+24 atm/m^3
#
# Current time: 5870000.0 s
# Average concentration: 1.645868771322306e+24 atm/m^3
#
# Current time: 5880000.0 s
# Average concentration: 1.6458701904259992e+24 atm/m^3
#
# Current time: 5890000.0 s
# Average concentration: 1.6458715896307286e+24 atm/m^3
#
# Current time: 5900000.0 s
# Average concentration: 1.6458729692182142e+24 atm/m^3
#
# Current time: 5910000.0 s
# Average concentration: 1.6458743294661412e+24 atm/m^3
#
# Current time: 5920000.0 s
# Average concentration: 1.6458756706482175e+24 atm/m^3
#
# Current time: 5930000.0 s
# Average concentration: 1.645876993034228e+24 atm/m^3
#
# Current time: 5940000.0 s
# Average concentration: 1.6458782968900937e+24 atm/m^3
#
# Current time: 5950000.0 s
# Average concentration: 1.6458795824779326e+24 atm/m^3
#
# Current time: 5960000.0 s
# ...
#
# Current time: 8040000.0 s
# Average concentration: 1.6459657399191968e+24 atm/m^3
#
# Current time: 8050000.0 s
# Average concentration: 1.6459658085115994e+24 atm/m^3
#
# Current time: 8060000.0 s
# Average concentration: 1.645965876161137e+24 atm/m^3
#
# Current time: 8070000.0 s
# Average concentration: 1.6459659428808246e+24 atm/m^3
#
# Current time: 8080000.0 s
# Average concentration: 1.6459660086834949e+24 atm/m^3
#
# Current time: 8090000.0 s
# Average concentration: 1.6459660735818015e+24 atm/m^3
#
# Current time: 8100000.0 s
# Average concentration: 1.6459661375882246e+24 atm/m^3
#
# Current time: 8110000.0 s
# Average concentration: 1.645966200715072e+24 atm/m^3
#
# Current time: 8120000.0 s
# Average concentration: 1.6459662629744776e+24 atm/m^3
#
# Current time: 8130000.0 s
# Average concentration: 1.6459663243784074e+24 atm/m^3
#
# Current time: 8140000.0 s
# Average concentration: 1.6459663849386647e+24 atm/m^3
#
# Current time: 8150000.0 s
# Average concentration: 1.6459664446668846e+24 atm/m^3
#
# Current time: 8160000.0 s
# Average concentration: 1.645966503574547e+24 atm/m^3
#
# Current time: 8170000.0 s
# Average concentration: 1.6459665616729657e+24 atm/m^3
#
# Current time: 8180000.0 s
# Average concentration: 1.645966618973304e+24 atm/m^3
#
# Current time: 8190000.0 s
# Average concentration: 1.6459666754865663e+24 atm/m^3
#
# Current time: 8200000.0 s
# Average concentration: 1.645966731223605e+24 atm/m^3
#
# Current time: 8210000.0 s
# Average concentration: 1.645966786195124e+24 atm/m^3
#
# Current time: 8220000.0 s
# Average concentration: 1.6459668404116776e+24 atm/m^3
#
# Current time: 8230000.0 s
# Average concentration: 1.6459668938836725e+24 atm/m^3
#
# Current time: 8240000.0 s
# Average concentration: 1.6459669466213746e+24 atm/m^3
#
# Current time: 8250000.0 s
# Average concentration: 1.6459669986349058e+24 atm/m^3
#
# Current time: 8260000.0 s
# Average concentration: 1.6459670499342443e+24 atm/m^3
#
# Current time: 8270000.0 s
# Average concentration: 1.6459671005292363e+24 atm/m^3
#
# Current time: 8280000.0 s
# Average concentration: 1.6459671504295907e+24 atm/m^3
#
# Current time: 8290000.0 s
# Average concentration: 1.6459671996448768e+24 atm/m^3
#
# Current time: 8300000.0 s
# Average concentration: 1.645967248184535e+24 atm/m^3
#
# Current time: 8310000.0 s
# Average concentration: 1.6459672960578756e+24 atm/m^3
#
# Current time: 8320000.0 s
# Average concentration: 1.6459673432740778e+24 atm/m^3
#
# Current time: 8330000.0 s
# Average concentration: 1.6459673898421965e+24 atm/m^3
#
# Current time: 8340000.0 s
# Average concentration: 1.6459674357711592e+24 atm/m^3
#
# Current time: 8350000.0 s
# Average concentration: 1.64596748106977e+24 atm/m^3
#
# Current time: 8360000.0 s
# Average concentration: 1.6459675257467128e+24 atm/m^3
#
# Current time: 8370000.0 s
# Average concentration: 1.6459675698105478e+24 atm/m^3
#
# Current time: 8380000.0 s
# Average concentration: 1.6459676132697217e+24 atm/m^3
#
# Current time: 8390000.0 s
# Average concentration: 1.645967656132559e+24 atm/m^3
#
# Current time: 8400000.0 s
# Average concentration: 1.6459676984072733e+24 atm/m^3
#
# Current time: 8410000.0 s
# Average concentration: 1.6459677401019617e+24 atm/m^3
#
# Current time: 8420000.0 s
# Average concentration: 1.6459677812246127e+24 atm/m^3
#
# Current time: 8430000.0 s
# Average concentration: 1.6459678217830986e+24 atm/m^3
#
# Current time: 8440000.0 s
# Average concentration: 1.6459678617851905e+24 atm/m^3
#
# Current time: 8450000.0 s
# Average concentration: 1.6459679012385435e+24 atm/m^3
#
# Current time: 8460000.0 s
# Average concentration: 1.6459679401507155e+24 atm/m^3
#
# Current time: 8470000.0 s
# Average concentration: 1.6459679785291515e+24 atm/m^3
#
# Current time: 8480000.0 s
# Average concentration: 1.645968016381201e+24 atm/m^3
#
# Current time: 8490000.0 s
# Average concentration: 1.6459680537141077e+24 atm/m^3
#
# Current time: 8500000.0 s
# Average concentration: 1.6459680905350142e+24 atm/m^3
#
# Current time: 8510000.0 s
# Average concentration: 1.6459681268509677e+24 atm/m^3
#
# Current time: 8520000.0 s
# Average concentration: 1.6459681626689172e+24 atm/m^3
#
# Current time: 8530000.0 s
# Average concentration: 1.645968197995714e+24 atm/m^3
#
# Current time: 8540000.0 s
# Average concentration: 1.6459682328381164e+24 atm/m^3
#
# Current time: 8550000.0 s
# Average concentration: 1.6459682672027876e+24 atm/m^3
#
# Current time: 8560000.0 s
# Average concentration: 1.6459683010962997e+24 atm/m^3
#
# Current time: 8570000.0 s
# Average concentration: 1.645968334525134e+24 atm/m^3
#
# Current time: 8580000.0 s
# Average concentration: 1.6459683674956845e+24 atm/m^3
#
# Current time: 8590000.0 s
# Average concentration: 1.6459684000142515e+24 atm/m^3
#
# Current time: 8600000.0 s
# Average concentration: 1.6459684320870537e+24 atm/m^3
#
# Current time: 8610000.0 s
# Average concentration: 1.6459684637202207e+24 atm/m^3
#
# Current time: 8620000.0 s
# Average concentration: 1.6459684949197983e+24 atm/m^3
#
# Current time: 8630000.0 s
# Average concentration: 1.645968525691749e+24 atm/m^3
#
# Current time: 8640000.0 s
# Average concentration: 1.6459685560419517e+24 atm/m^3
#
# Current time: 8650000.0 s
# Average concentration: 1.645968585976207e+24 atm/m^3
#
# Current time: 8660000.0 s
# Average concentration: 1.6459686155002334e+24 atm/m^3
#
# Current time: 8670000.0 s
# Average concentration: 1.6459686446196693e+24 atm/m^3
#
# Current time: 8680000.0 s
# Average concentration: 1.6459686733400788e+24 atm/m^3
#
# Current time: 8690000.0 s
# Average concentration: 1.6459687016669464e+24 atm/m^3
#
# Current time: 8700000.0 s
# Average concentration: 1.645968729605681e+24 atm/m^3
#
# Current time: 8710000.0 s
# Average concentration: 1.6459687571616178e+24 atm/m^3
#
# Current time: 8720000.0 s
# Average concentration: 1.645968784340018e+24 atm/m^3
#
# Current time: 8730000.0 s
# Average concentration: 1.6459688111460692e+24 atm/m^3
#
# Current time: 8740000.0 s
# Average concentration: 1.6459688375848917e+24 atm/m^3
#
# Current time: 8750000.0 s
# Average concentration: 1.6459688636615277e+24 atm/m^3
#
# Current time: 8760000.0 s
# Average concentration: 1.645968889380956e+24 atm/m^3
#
# Current time: 8770000.0 s
# Average concentration: 1.645968914748085e+24 atm/m^3
#
# Current time: 8780000.0 s
# Average concentration: 1.645968939767754e+24 atm/m^3
#
# Current time: 8790000.0 s
# Average concentration: 1.6459689644447373e+24 atm/m^3
#
# Current time: 8800000.0 s
# Average concentration: 1.6459689887837433e+24 atm/m^3
#
# Current time: 8810000.0 s
# Average concentration: 1.6459690127894148e+24 atm/m^3
#
# Current time: 8820000.0 s
# Average concentration: 1.6459690364663306e+24 atm/m^3
#
# Current time: 8830000.0 s
# Average concentration: 1.6459690598190044e+24 atm/m^3
#
# Current time: 8840000.0 s
# Average concentration: 1.6459690828518926e+24 atm/m^3
#
# Current time: 8850000.0 s
# Average concentration: 1.645969105569385e+24 atm/m^3
#
# Current time: 8860000.0 s
# Average concentration: 1.6459691279758157e+24 atm/m^3
#
# Current time: 8870000.0 s
# Average concentration: 1.6459691500754524e+24 atm/m^3
#
# Current time: 8880000.0 s
# Average concentration: 1.6459691718725113e+24 atm/m^3
#
# Current time: 8890000.0 s
# Average concentration: 1.6459691933711467e+24 atm/m^3
#
# Current time: 8900000.0 s
# Average concentration: 1.6459692145754542e+24 atm/m^3
#
# Current time: 8910000.0 s
# Average concentration: 1.6459692354894788e+24 atm/m^3
#
# Current time: 8920000.0 s
# Average concentration: 1.6459692561172017e+24 atm/m^3
#
# Current time: 8930000.0 s
# Average concentration: 1.6459692764625565e+24 atm/m^3
#
# Current time: 8940000.0 s
# Average concentration: 1.6459692965294168e+24 atm/m^3
#
# Current time: 8950000.0 s
# Average concentration: 1.645969316321607e+24 atm/m^3
#
# Current time: 8960000.0 s
# Average concentration: 1.6459693358428975e+24 atm/m^3
#
# Current time: 8970000.0 s
# Average concentration: 1.6459693550970066e+24 atm/m^3
#
# Current time: 8980000.0 s
# Average concentration: 1.6459693740876002e+24 atm/m^3
#
# Current time: 8990000.0 s
# Average concentration: 1.6459693928182972e+24 atm/m^3
#
# Current time: 9000000.0 s
# Average concentration: 1.6459694112926615e+24 atm/m^3
#
# Current time: 9010000.0 s
# Average concentration: 1.645969429514213e+24 atm/m^3
#
# Current time: 9020000.0 s
# Average concentration: 1.645969447486419e+24 atm/m^3
#
# Current time: 9030000.0 s
# Average concentration: 1.645969465212702e+24 atm/m^3
#
# Current time: 9040000.0 s
# Average concentration: 1.6459694826964367e+24 atm/m^3
#
# Current time: 9050000.0 s
# Average concentration: 1.6459694999409505e+24 atm/m^3
#
# Current time: 9060000.0 s
# Average concentration: 1.6459695169495238e+24 atm/m^3
#
# Current time: 9070000.0 s
# Average concentration: 1.6459695337253965e+24 atm/m^3
#
# Current time: 9080000.0 s
# Average concentration: 1.6459695502717583e+24 atm/m^3
#
# Current time: 9090000.0 s
# Average concentration: 1.6459695665917595e+24 atm/m^3
#
# Current time: 9100000.0 s
# Average concentration: 1.6459695826885031e+24 atm/m^3
#
# Current time: 9110000.0 s
# Average concentration: 1.645969598565052e+24 atm/m^3
#
# Current time: 9120000.0 s
# Average concentration: 1.6459696142244264e+24 atm/m^3
#
# Current time: 9130000.0 s
# Average concentration: 1.645969629669606e+24 atm/m^3
#
# Current time: 9140000.0 s
# Average concentration: 1.6459696449035265e+24 atm/m^3
#
# Current time: 9150000.0 s
# Average concentration: 1.645969659929086e+24 atm/m^3
#
# Current time: 9160000.0 s
# Average concentration: 1.6459696747491407e+24 atm/m^3
#
# Current time: 9170000.0 s
# Average concentration: 1.6459696893665095e+24 atm/m^3
#
# Current time: 9180000.0 s
# Average concentration: 1.645969703783972e+24 atm/m^3
#
# Current time: 9190000.0 s
# Average concentration: 1.6459697180042672e+24 atm/m^3
#
# Current time: 9200000.0 s
# Average concentration: 1.6459697320301003e+24 atm/m^3
#
# Current time: 9210000.0 s
# Average concentration: 1.645969745864137e+24 atm/m^3
#
# Current time: 9220000.0 s
# Average concentration: 1.645969759509006e+24 atm/m^3
#
# Current time: 9230000.0 s
# Average concentration: 1.6459697729673003e+24 atm/m^3
#
# Current time: 9240000.0 s
# Average concentration: 1.6459697862415796e+24 atm/m^3
#
# Current time: 9250000.0 s
# Average concentration: 1.645969799334363e+24 atm/m^3
#
# Current time: 9260000.0 s
# Average concentration: 1.6459698122481405e+24 atm/m^3
#
# Current time: 9270000.0 s
# Average concentration: 1.6459698249853642e+24 atm/m^3
#
# Current time: 9280000.0 s
# Average concentration: 1.645969837548455e+24 atm/m^3
#
# Current time: 9290000.0 s
# Average concentration: 1.6459698499397993e+24 atm/m^3
#
# Current time: 9300000.0 s
# Average concentration: 1.6459698621617483e+24 atm/m^3
#
# Current time: 9310000.0 s
# Average concentration: 1.645969874216628e+24 atm/m^3
#
# Current time: 9320000.0 s
# Average concentration: 1.6459698861067233e+24 atm/m^3
#
# Current time: 9330000.0 s
# Average concentration: 1.6459698978342945e+24 atm/m^3
#
# Current time: 9340000.0 s
# Average concentration: 1.645969909401568e+24 atm/m^3
#
# Current time: 9350000.0 s
# Average concentration: 1.645969920810739e+24 atm/m^3
#
# Current time: 9360000.0 s
# Average concentration: 1.6459699320639748e+24 atm/m^3
#
# Current time: 9370000.0 s
# Average concentration: 1.6459699431634118e+24 atm/m^3
#
# Current time: 9380000.0 s
# Average concentration: 1.645969954111157e+24 atm/m^3
#
# Current time: 9390000.0 s
# Average concentration: 1.645969964909287e+24 atm/m^3
#
# Current time: 9400000.0 s
# Average concentration: 1.6459699755598532e+24 atm/m^3
#
# Current time: 9410000.0 s
# Average concentration: 1.6459699860648743e+24 atm/m^3
#
# Current time: 9420000.0 s
# Average concentration: 1.6459699964263473e+24 atm/m^3
#
# Current time: 9430000.0 s
# Average concentration: 1.6459700066462362e+24 atm/m^3
#
# Current time: 9440000.0 s
# Average concentration: 1.6459700167264794e+24 atm/m^3
#
# Current time: 9450000.0 s
# Average concentration: 1.6459700266689918e+24 atm/m^3
#
# Current time: 9460000.0 s
# Average concentration: 1.6459700364756578e+24 atm/m^3
#
# Current time: 9470000.0 s
# Average concentration: 1.645970046148337e+24 atm/m^3
#
# Current time: 9480000.0 s
# Average concentration: 1.645970055688866e+24 atm/m^3
#
# Current time: 9490000.0 s
# Average concentration: 1.6459700650990527e+24 atm/m^3
#
# Current time: 9500000.0 s
# Average concentration: 1.6459700743806842e+24 atm/m^3
#
# Current time: 9510000.0 s
# Average concentration: 1.6459700835355173e+24 atm/m^3
#
# Current time: 9520000.0 s
# Average concentration: 1.6459700925652923e+24 atm/m^3
#
# Current time: 9530000.0 s
# Average concentration: 1.6459701014717176e+24 atm/m^3
#
# Current time: 9540000.0 s
# Average concentration: 1.6459701102564838e+24 atm/m^3
#
# Current time: 9550000.0 s
# Average concentration: 1.6459701189212557e+24 atm/m^3
#
# Current time: 9560000.0 s
# Average concentration: 1.6459701274676761e+24 atm/m^3
#
# Current time: 9570000.0 s
# Average concentration: 1.6459701358973658e+24 atm/m^3
#
# Current time: 9580000.0 s
# Average concentration: 1.6459701442119216e+24 atm/m^3
# Current time: 9590000.0 s
# Average concentration: 1.64597015241292e+24 atm/m^3
#
# Current time: 9600000.0 s
# Average concentration: 1.645970160501914e+24 atm/m^3
#
# Current time: 9610000.0 s
# Average concentration: 1.6459701684804375e+24 atm/m^3
#
# Current time: 9620000.0 s
# Average concentration: 1.6459701763500027e+24 atm/m^3
#
# Current time: 9630000.0 s
# Average concentration: 1.6459701841121006e+24 atm/m^3
#
# Current time: 9640000.0 s
# Average concentration: 1.6459701917682025e+24 atm/m^3
#
# Current time: 9650000.0 s
# Average concentration: 1.6459701993197565e+24 atm/m^3
#
# Current time: 9660000.0 s
# Average concentration: 1.6459702067681957e+24 atm/m^3
#
# Current time: 9670000.0 s
# Average concentration: 1.6459702141149313e+24 atm/m^3
#
# Current time: 9680000.0 s
# Average concentration: 1.6459702213613534e+24 atm/m^3
#
# Current time: 9690000.0 s
# Average concentration: 1.6459702285088348e+24 atm/m^3
#
# Current time: 9700000.0 s
# Average concentration: 1.64597023555873e+24 atm/m^3
#
# Current time: 9710000.0 s
# Average concentration: 1.645970242512372e+24 atm/m^3
#
# Current time: 9720000.0 s
# Average concentration: 1.6459702493710793e+24 atm/m^3
#
# Current time: 9730000.0 s
# Average concentration: 1.645970256136151e+24 atm/m^3
#
# Current time: 9740000.0 s
# Average concentration: 1.6459702628088685e+24 atm/m^3
#
# Current time: 9750000.0 s
# Average concentration: 1.6459702693904925e+24 atm/m^3
#
# Current time: 9760000.0 s
# Average concentration: 1.6459702758822717e+24 atm/m^3
#
# Current time: 9770000.0 s
# Average concentration: 1.6459702822854347e+24 atm/m^3
#
# Current time: 9780000.0 s
# Average concentration: 1.6459702886011914e+24 atm/m^3
#
# Current time: 9790000.0 s
# Average concentration: 1.6459702948307392e+24 atm/m^3
#
# Current time: 9800000.0 s
# Average concentration: 1.645970300975257e+24 atm/m^3
#
# Current time: 9810000.0 s
# Average concentration: 1.645970307035907e+24 atm/m^3
#
# Current time: 9820000.0 s
# Average concentration: 1.6459703130138376e+24 atm/m^3
#
# Current time: 9830000.0 s
# Average concentration: 1.6459703189101772e+24 atm/m^3
#
# Current time: 9840000.0 s
# Average concentration: 1.6459703247260456e+24 atm/m^3
#
# Current time: 9850000.0 s
# Average concentration: 1.6459703304625405e+24 atm/m^3
#
# Current time: 9860000.0 s
# Average concentration: 1.645970336120747e+24 atm/m^3
#
# Current time: 9870000.0 s
# Average concentration: 1.645970341701736e+24 atm/m^3
#
# Current time: 9880000.0 s
# Average concentration: 1.6459703472065632e+24 atm/m^3
#
# Current time: 9890000.0 s
# Average concentration: 1.6459703526362707e+24 atm/m^3
#
# Current time: 9900000.0 s
# Average concentration: 1.6459703579918856e+24 atm/m^3
#
# Current time: 9910000.0 s
# Average concentration: 1.6459703632744197e+24 atm/m^3
#
# Current time: 9920000.0 s
# Average concentration: 1.6459703684848737e+24 atm/m^3
#
# Current time: 9930000.0 s
# Average concentration: 1.6459703736242313e+24 atm/m^3
#
# Current time: 9940000.0 s
# Average concentration: 1.6459703786934653e+24 atm/m^3
#
# Current time: 9950000.0 s
# Average concentration: 1.6459703836935341e+24 atm/m^3
#
# Current time: 9960000.0 s
# Average concentration: 1.6459703886253842e+24 atm/m^3
#
# Current time: 9970000.0 s
# Average concentration: 1.6459703934899468e+24 atm/m^3
#
# Current time: 9980000.0 s
# Average concentration: 1.64597039828814e+24 atm/m^3
#
# Current time: 9990000.0 s
# Average concentration: 1.645970403020874e+24 atm/m^3
#
# Final time: 10000000.0 s
# Average concentration: 1.6459704076890432e+24 atm/m^3
#
#
# Error bound: 0.0015354412865471903
# Error exact: 0.0006425782335814767

# %% [markdown]
# #### SAVE ESSENTIAL FILES

# %%
# Save essentail files:
np.save('model_files/FF_FO.npy', forc_C)
np.save('model_files/XX_FO.npy', np.array([mass_C]))
np.save('model_files/YY_FO.npy', np.array([stiff_C]))
np.save('model_files/KK_FO.npy', list_basis_stiff_C)
np.save('model_files/CC_FO.npy', list_coerc_stiff_C)
np.save('model_files/ZZ_FO.npy', INT_CZZ)
np.save('model_files/II_FO.npy', mapDAtoCO)
np.save('model_files/AA_FO.npy', inte_C)

# %%
# Import libraries:
import numpy as np
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import time
import sys

# Import user defined libraries:
from solver_class import FiniteElementCylinderSolver, ReducedBasisCylinderSolver

# %%
# Define size of the training parameter set:
sTR = 10000

# Define parameters ranges:
MIN_FR, MAX_FR = 2.00E+19, 3.00E+19 
MIN_BC, MAX_BC = 1.75E+03, 2.25E+03
MIN_LL, MAX_LL = 0.75E-3, 1.25E-3
MIN_RR, MAX_RR = 0.75E-5, 1.25E-5

# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))

# %%
# Define reference parameters:
cur_FY = 2.40E-01
cur_FR = 3.00E+19 
cur_BC = 2.00E+03
cur_LL = 1.00E-03
cur_RR = 1.00E-05
cur_dt = 1.00E+04

# Define empty basis functions matrix and empty list of error bounds:
cur_basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
cur_err_bounds = np.empty((sTR))

# Enter reduced basis space loop:
new_sRB = np.inf
while new_sRB > 0:

    # Assemble full order model and compute full order solution associated with the current parameter selection:
    solver_FO = FiniteElementCylinderSolver()
    solver_FO.assemble(RADIUS=cur_RR, LENGTH=cur_LL, F_RATE=cur_FR, F_YIELD=cur_FY, T_BC=cur_BC, dt=cur_dt)
    solution_FO = solver_FO.solve(n_steps=1000, verbose=False)

    # Compute orthogonal complement to the basis function and solution energy:
    orthogonal_FO = solution_FO - cur_basis @ np.linalg.solve(cur_basis.T @ solver_FO.XX_FO @ cur_basis, cur_basis.T @ solver_FO.XX_FO @ solution_FO)
    solution_energy_FO = np.einsum('ik,ik', solver_FO.XX_FO @ solution_FO, solution_FO)
    
    # Extract the POD basis from the full order solution:
    AA, GG, BB = np.linalg.svd(orthogonal_FO.T @ solver_FO.XX_FO @ orthogonal_FO, full_matrices=False)
    new_sRB = np.sum([np.sqrt(np.sum(GG[ii:]) / solution_energy_FO) > 1e-5 for ii in range(len(GG))])
    cur_basis = np.hstack((cur_basis, orthogonal_FO @ AA[:, :new_sRB] @ np.diag(np.reciprocal(np.sqrt(GG[:new_sRB])))))

    # Assemble reduced basis model:
    solver_RB = ReducedBasisCylinderSolver(cur_basis)
    for kk in range(sTR):
        solver_RB.assemble(F_YIELD=cur_FY, F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], dt=cur_dt)

        # Compute current reduced basis solution and error bound:
        solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)

    # Identify new parameters where to evaluate the full order model:
    cur_FY = cur_FY
    cur_FR = LIST_FR[np.argmax(cur_err_bounds)]
    cur_BC = LIST_BC[np.argmax(cur_err_bounds)]
    cur_LL = LIST_LL[np.argmax(cur_err_bounds)]
    cur_RR = LIST_RR[np.argmax(cur_err_bounds)]

    # Show worse reconstructed parameter configuration:
    print("The current reduced basis size is", cur_basis.shape[1])
    print("The selected Boundary Temperature is", cur_BC, "K")
    print("The selected Fission Rate is", cur_FR, "f/s")
    print("The selected Grain Length is", cur_LL, "m")
    print("The selected Grain Radius is", cur_RR, "m\n")
# Out:
# The current reduced basis size is 16
# The selected Boundary Temperature is 2214.3289954825295 K
# The selected Fission Rate is 2.079482562163385e+19 f/s
# The selected Grain Length is 0.0007605764339441176 m
# The selected Grain Radius is 1.2278125192251341e-05 m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 37
#      34     solver_RB.assemble(F_YIELD=cur_FY, F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], dt=cur_dt)
#      36     # Compute current reduced basis solution and error bound:
# ---> 37     solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
#      39 # Identify new parameters where to evaluate the full order model:
#      40 cur_FY = cur_FY
#
# File ~/Documents/Projects Research/Cylinder Grain Diffusion/model_2d/solver_class.py:197, in ReducedBasisCylinderSolver.solve(self, n_steps, verbose, error_bound)
#     195 solution = np.zeros((self.sRB, n_steps+1))
#     196 for ii in range(n_steps):
# --> 197     solution[:, ii+1] = np.linalg.solve(self.LHS_static, self.RHS_static + self.XX_RB.dot(solution[: , ii:ii+1]))[:, 0]
#     199     # Print current iteration and average temperature and concentration:
#     200     if verbose:
#
# File <__array_function__ internals>:200, in solve(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:386, in solve(a, b)
#     384 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     385 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 386 r = gufunc(a, b, signature=signature, extobj=extobj)
#     388 return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
MM_RB = solver_RB.XX_RB
FF_RB = solver_RB.FF_RB
KK_RB = solver_RB.KK_RB
AA_RB = solver_RB.AA_RB
ZZ_CO = solver_RB.ZZ_FO
II_CO = solver_RB.II_FO

# %%
TT = T_BC + (SOURCE_T * LENGTH**2 / ALPHA_T) * (1 - ZZ_CO**2) / 2

WW = 7.60E-10 * np.exp(- 4.86E-19 / (TT * 1.380649E-23)) +\
     5.64E-25 * np.exp(- 1.91E-19 / (TT * 1.380649E-23)) * np.sqrt(FISSION_RATE) +\
     8.00E-40 * FISSION_RATE

CC_CO = np.hstack((II_CO @ WW / RADIUS**2, II_CO @ WW / LENGTH**2))

SS_RB = np.tensordot(CC_CO, KK_RB, axes=[0, 0])
QQ_RB = SOURCE_C * FF_RB

LHS_RB_static = MM_RB + TIME_DELTA * SS_RB
RHS_RB_static = TIME_DELTA * QQ_RB

# %%
old_sol_RB = np.zeros((MM_RB.shape[0], 1))
for ii in range(1000):
    old_sol_RB = np.linalg.solve(LHS_RB_static, RHS_RB_static + MM_RB.dot(old_sol_RB))
    print(np.dot(AA_RB, old_sol_RB)[0])
# Out:
# 0.0330047607421875

# %%
# Out:
# 12727.272727272726
