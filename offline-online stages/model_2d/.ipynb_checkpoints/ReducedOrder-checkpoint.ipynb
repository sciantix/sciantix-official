# %% [markdown]
# ## **REDUCED BASIS MODEL CONSTRUCTION**

# %% [markdown]
# #### LOAD LIBRARIES

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/lib/python3.13/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.3.3/libexec/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.3/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 92.5 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import itertools
import time
import os
import sys
import json
import pandas as pd

# Import user defined libraries:
from FreeFEM import FFmatrix_fread, FFvector_fread

# %% [markdown]
# #### DEFINE REFERENCE PROBLEM PARAMETERS

# %%
with open("reference case/Reference_parameters.json", "r") as json_file:
    parameters = json.load(json_file)
N_AVOG = parameters["N_AVOG"]  
N_BOLT = parameters["N_BOLT"]  
FISSION_ENERGY = parameters["FISSION_ENERGY"]                       
FISSION_RATE = parameters["FISSION_RATE"]                   
RADIUS = parameters["RADIUS"]
LENGTH = parameters["LENGTH"]
FISSION_YIELD = parameters["FISSION_YIELD"]                 
FUEL_THERMAL_CONDUCTIVITY = parameters["FUEL_THERMAL_CONDUCTIVITY"]
T_BC = parameters["T_BC"]  
C_BC = parameters["C_BC"]  

SOURCE_C = FISSION_RATE * FISSION_YIELD         #[atm / (m^3 s)]
GAMMA_T = (FISSION_RATE * FISSION_ENERGY * LENGTH**2)/(FUEL_THERMAL_CONDUCTIVITY)

      
# Define reference temperature, concentration and linear diffusion parameters:
T_IC  = T_BC # [K]
C_IC = C_BC  # [atm / m^3]
 
# Define final time, time increment:
TIME_FINAL = 1.00E+07  # [s]
TIME_DELTA = 1.00E+04  # [s]

# Compute number of iterations:
N_ITER = int(TIME_FINAL / TIME_DELTA)  # [-]

# Define function evaluating the concentration diffusion coefficient at given z coordinated provided the problem parameters:
def ALPHA_C(ZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE):
    return 7.60E-10 * np.exp(- 4.86E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) + \
           5.64E-25 * np.exp(- 1.91E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) * np.sqrt(FISSION_RATE) + \
           8.00E-40 * FISSION_RATE

# %% [markdown]
# #### IDENTIFY DIRICHLET DOFS AND INTERNAL DOFS

# %%
# Load coordinates:
coordinates_Px = FFvector_fread('mesh_utilities/vv_cc_Px.btxt')
coordinates_Pq = FFvector_fread('mesh_utilities/vv_cc_Pq.btxt')

# Identify degrees of freedom of the Px and Pq spaces:
sFO_Px = coordinates_Px.shape[0]
sFO_Pq = coordinates_Pq.shape[0]
print(rf'Degree of freedom = {sFO_Px}')

# Define vector of all Px indeces:
mask_all = np.arange(sFO_Px, dtype=int)

# Identify indeces of the top, bottom and middle boundaries in Px:
mask_inf_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_sup_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.ones((sFO_Px)))]
mask_mid_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_ext_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.ones((sFO_Px)))]

# Identify indeces of the Dirichlet b.c. for the temperature and concentration field:
mask_bc_T = np.fromiter(set(mask_sup_bc), int)
mask_bc_C = np.fromiter(set(mask_sup_bc) | set(mask_ext_bc) | set(mask_inf_bc), int)

# Identify indeces of the interior for the temperature and concentration field:
mask_in_T = [ii for ii in mask_all if ii not in mask_bc_T]
mask_in_C = [ii for ii in mask_all if ii not in mask_bc_C]
# Out:
# Degree of freedom = 10201

# %% [markdown]
# #### DEFINE FINITE ELEMENT ESSENTIALS

# %%
# Import mass matrices on the Px and on the Pq space:
mass_Px = FFmatrix_fread('mesh_utilities/ww_mm_Px.btxt')
mass_Pq = FFmatrix_fread('mesh_utilities/ww_mm_Pq.btxt')
mass_Pm = FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')

# Extract integration weights and diagonal matrix with their inverse:
weights_Pq = mass_Pq.diagonal()
project_Pq = sparse.diags(np.reciprocal(weights_Pq))

# Import map from Px to Pq and to the dx, dy, dz derivative evaluated in Pq:
PxtoPquu_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdx_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dx_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdy_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dy_Px_Pq.btxt')[:, mask_in_C])

# Define weights for the integration in polar coordinates:
polar_weights_Pq = np.multiply(coordinates_Pq[:, 0], weights_Pq)

# Compute volume of the domain:
volume = np.dot(np.ones(sFO_Pq), polar_weights_Pq)

# Assemble mass matrix and projected forcing term:
forc_C = PxtoPquu_C.T.dot(polar_weights_Pq[:, None])
mass_C = PxtoPquu_C.T.dot(PxtoPquu_C.multiply(polar_weights_Pq[:, None]))
inte_C = PxtoPquu_C.T.dot(polar_weights_Pq) / volume

# Assemble a function assembling the stiffness matrix at a given time:
stiff_C = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / RADIUS**2 * polar_weights_Pq[:, None])) + \
          PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / LENGTH**2 * polar_weights_Pq[:, None]))

# %% [markdown]
# #### DEFINE PARAMETERS TRAINING SET

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215E-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0, 5.00E+19        
MIN_K, MAX_K =  0.9, 8    
MIN_FY, MAX_FY = 0.00, 0.3
MIN_LL, MAX_LL = 0.1E-3, 1.25E-3
MIN_RR, MAX_RR = 0.75E-5, 1.25E-5
MIN_BC, MAX_BC = 0, 2.5E+03                                                                


# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TRAINING = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TRAINING[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# %% [markdown]
# #### CONSTRUCT AN AFFINE DECOMPOSITION FOR THE CONCENTRATION DIFFUSION COEFFICIENTS

# %%
# Compress the training set using singular value decomposition:
UU, SS, VV = np.linalg.svd(TRAINING @ TRAINING.T, full_matrices=False)
NN = np.sum(np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))]) > 1e-6) + 1

# Construct 1D and 3D basis for the concentration diffusion coefficient:
BASIS_D_1D = UU[:, :NN]
BASIS_D_2D = ZZ_1Dto2D @ BASIS_D_1D

# Use a greedy algorithm to identify the points (indeces) to interpolate the exact concentration coefficients:
INT_COO = [np.argmax(np.abs(BASIS_D_1D[:, 0]))]
for ii in range(1, NN):
    INT_COO.append(np.argmax(np.abs(BASIS_D_1D[:, ii] - BASIS_D_1D[:, :ii] @ np.linalg.solve(BASIS_D_1D[INT_COO, :ii],  BASIS_D_1D[INT_COO, ii]))))

# Extrat the z coordinates associated with the selected indeces:
INT_COO = np.array(INT_COO)
INT_CZZ = np.array([ZZ[INT_COO[ii]] for ii in range(NN)])

# Define interpolation operator mapping from the diffusion coefficient evaluated in the interpolation points to the linear combination coefficients:
mapDAtoCO = np.linalg.solve(BASIS_D_1D[INT_COO, :], np.eye(NN))

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TRAINING - BASIS_D_1D @ mapDAtoCO @ TRAINING[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TRAINING, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
print(VV.shape)
print(rf'Number of DEIM modes = {NN}')
# Out:
# 0.0019582750293827425
# (1000, 1000)
# Number of DEIM modes = 8

# %%
#guardiamo la missing energy del termine non-affine -> queste basi ridotte dopo le usiamo per davvero
cmap = plt.get_cmap('RdBu')
color = cmap(0.9)
 
missing = np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))])
fig, (ax1) = plt.subplots(1, figsize=(4,5))
ax1.set_yscale('log')
ax1.plot(range(1,26), missing[:25], '-o')
ax1.tick_params(axis="y", which='both',labelsize=13,  width=1)
ax1.tick_params(axis='x', labelsize=13,  width=1)
ax1.set_xlabel('Number of DEIM modes',fontsize=14)
ax1.set_ylabel('Missing energy',fontsize=14)
#ax1.set_ylabel('Normalized eigenvalues',fontsize=14)
ax1.axvspan(1, NN, color='gray', alpha=0.2)
ax1.set_xlim([0,25])
ax1.set_ylim([1e-7, 1])
ax1.grid(visible=True, which='both', linewidth=1, alpha=0.7)
plt.savefig('plot/Missing energy.pdf', bbox_inches='tight')

# %% [markdown]
# #### ASSEMBLE AFFINELY DECOMPOSED STIFFNESS MATRICES AND COMPUTE THEIR COERCIVITY CONSTANTS
# impiega 1.3 secondi

# %%
# Define two mass matrices respectively linked to the regularity of the solution and of its time derivative:
Y_mass = stiff_C
X_mass = mass_C

# Initialise array for the partial stiffness matrices and for their coercivity constants:
list_basis_stiff_C = np.array([sparse.csr_matrix((mass_C.shape)) for ii in range(2*NN)])
list_coerc_stiff_C = np.zeros((2*NN))

# Iterate over the selected basis for the diffusion coefficient field
for ii in range(NN):

    # Assemble the radial and axial partial stiffness matrices associated with the basis of the diffusivity:
    list_basis_stiff_C[00+ii] = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))
    list_basis_stiff_C[NN+ii] = PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))

    # Compute the sign of the axial and radial partial stiffness matrices:
    tsign_dz_C = np.sign(list_basis_stiff_C[NN + ii].trace())
    tsign_dr_C = np.sign(list_basis_stiff_C[00 + ii].trace())

    # Compute the coercivity constant of the axial and radial partial stiffness matrices:
    list_coerc_stiff_C[NN+ii] = tsign_dz_C / linalg.eigsh(Y_mass, k=1, M=tsign_dz_C * list_basis_stiff_C[NN+ii], which='LM', return_eigenvectors=False)[0]
    list_coerc_stiff_C[00+ii] = tsign_dr_C / linalg.eigsh(Y_mass, k=1, M=tsign_dr_C * list_basis_stiff_C[00+ii], which='LM', return_eigenvectors=False)[0]

# %% [markdown]
# #### COMPUTE THE INTERPOLATION COEFFICIENTS AND THE COERCIVITY COEFFICIENTS FOR ALL THE PARAMETERS

# %%
# Compute hte interpolation coefficients and the coercivity coefficients for the parameters in the training set:
list_inter_coef = np.empty((sTR, 2*NN))
list_coerc_coef = np.empty((sTR))

# Iterate over the training set:
for ii in range(sTR):
    cur_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

    # Compute the interpolation coefficients for the radial and axial partial stiffness matrices:
    list_inter_coef[ii, NN:] = cur_coef / LIST_LL[ii]**2
    list_inter_coef[ii, :NN] = cur_coef / LIST_RR[ii]**2

    # Compute a lower bound for the coercivity constants:
    list_coerc_coef[ii] = np.dot(list_coerc_stiff_C, list_inter_coef[ii, :])

# Compute interpolation and coercivity coeffientrs for the reference parameters:
cur_inter_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE)
cur_inter_coef = np.hstack((cur_inter_coef / RADIUS**2, cur_inter_coef / LENGTH**2))
cur_coerc_coef = np.dot(list_coerc_stiff_C, cur_inter_coef)

# %% [markdown]
# #### COMPUTE THE POD MODES OF THE REFERENCE SOLUTION

# %%
sol_new_C = np.loadtxt('reference case/Fullorder_Cfield.csv', delimiter=',')
# Compute the singular value decomposition of the gramian matrix:
AA, GG, BB = np.linalg.svd(sol_new_C[mask_in_C, :].T @ Y_mass @ sol_new_C[mask_in_C, :], full_matrices=False)

# Compute total Y-energy of the training set:
Y_energy = np.sum([Y_mass.dot(sol_new_C[mask_in_C, ii]).dot(sol_new_C[mask_in_C, ii]) for ii in range(N_ITER+1)])

# Determine number of POD modes to retain:
sRB_C = np.sum([np.sqrt(np.sum(GG[ii:]) / Y_energy) > 1e-4 for ii in range(len(GG))])

# Assemble POD modes for the concentration field at the reference parameters:
BASIS_C_2D = sol_new_C[mask_in_C, :] @ AA[:, :sRB_C] @ np.diag(np.reciprocal(np.sqrt(GG[:sRB_C])))

print(rf'Number of POD modes = {sRB_C}')
# Out:
# Number of POD modes = 8

# %% [markdown]
# #### ASSEMBLE REDUCED MATRICES (LATER MUST BE CODED AS THE METHOD OF A CLASS)

# %%
# Project the Y- and X-mass matrices on the reduced basis space:
Y_mass_RB = BASIS_C_2D.T @ Y_mass @ BASIS_C_2D
X_mass_RB = BASIS_C_2D.T @ X_mass @ BASIS_C_2D

# Compute Rietz representer and projection of the forcing term:
forc_C_rietz_RB = linalg.spsolve(Y_mass, forc_C)
forc_C_proje_RB = BASIS_C_2D.T @ forc_C

# Compute Rietz representer and projection of the mass matrix tested versus the POD basis functions: 
mass_C_right_RB = mass_C @ BASIS_C_2D
mass_C_rietz_RB = linalg.spsolve(Y_mass, mass_C_right_RB)
mass_C_proje_RB = BASIS_C_2D.T @ mass_C_right_RB

# Compute the Rietz representer and projection of all the partial stiffness matrices from the affine decomposition:
list_basis_stiff_C_right_RB = np.array([list_basis_stiff_C[ii] @ BASIS_C_2D for ii in range(2*NN)])
list_basis_stiff_C_rietz_RB = np.array([linalg.spsolve(Y_mass, list_basis_stiff_C_right_RB[ii]) for ii in range(2*NN)])
list_basis_stiff_C_proje_RB = np.array([BASIS_C_2D.T @ list_basis_stiff_C_right_RB[ii] for ii in range(2*NN)])

# Pre-assemble the scalar and vector terms for the residual energy computation:
DD_pr_bb = (forc_C_rietz_RB.T @ forc_C) * (SOURCE_C * SOURCE_C)
DD_pr_bm = (forc_C_rietz_RB.T @ mass_C_right_RB) * (- 2 * SOURCE_C / TIME_DELTA)
DD_pr_mm = (mass_C_rietz_RB.T @ mass_C_right_RB) * (  1 / (TIME_DELTA * TIME_DELTA))

# Pre-assemble all the tensor terms for the residual energy computation:
DD_pr_ab = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ forc_C_rietz_RB for ii in range(2*NN)]) * (-2 * SOURCE_C)
DD_pr_am = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ mass_C_rietz_RB for ii in range(2*NN)]) * ( 2 / TIME_DELTA)
DD_pr_aa = np.array([[list_basis_stiff_C_right_RB[ii, :, :].T @ list_basis_stiff_C_rietz_RB[jj, :, :] for ii in range(2*NN)] for jj in range(2*NN)])

# Compute the weights for the integration of the reduced basis solutions:
weights_RB = np.ones((sFO_Px)) @ mass_Px[:, mask_in_C] @ BASIS_C_2D

# %% [markdown]
# #### COMPUTE REDUCED BASIS SOLUTION

# %%
# Assemble current reduced basis stiffness matrix:
stiff_C_proje_RB = np.tensordot(cur_inter_coef, list_basis_stiff_C_proje_RB, axes=[0, 0])
stiff_C_exact_RB = BASIS_C_2D.T @ stiff_C @ BASIS_C_2D

# Assemble current stiffness cross term for the computation of the residual energy:
cur_DD_pr_ab = np.tensordot(cur_inter_coef, DD_pr_ab, axes=[0, 0])
cur_DD_pr_am = np.tensordot(cur_inter_coef, DD_pr_am, axes=[0, 0])
cur_DD_pr_aa = np.tensordot(cur_inter_coef, np.tensordot(cur_inter_coef, DD_pr_aa, axes=[0, 0]), axes=[0, 0])

# Initialise reduced basis concentration solution:
sol_new_C_RB = np.zeros((sRB_C, N_ITER+1))
sol_new_C_FO = np.zeros((len(mask_in_C), N_ITER+1))

# Initialise errors and errors estimators:
energy_residual = np.empty((N_ITER))
energy_solution = np.empty((N_ITER))
energy_toterror = np.empty((N_ITER))

#
inte_C_RB = inte_C @ BASIS_C_2D

# Integrate using forward Euler up to the final time:
verbose = True
for ii in range(N_ITER):
    cur_time = ii * TIME_DELTA

    # Print current iteration and average temperature and concentration:
    if verbose:
        print('Current time:', cur_time, 's')
        print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, ii], 'atm/m^3\n')

    # Assemble current left-hand-side and right-hand-side
    cur_lhs_RB = mass_C_proje_RB + TIME_DELTA * stiff_C_proje_RB
    cur_rhs_RB = mass_C_proje_RB.dot(sol_new_C_RB[:, ii:ii+1]) + TIME_DELTA * SOURCE_C * forc_C_proje_RB

    # Compute concentration in the interior of the domain:
    sol_new_C_RB[:, ii+1] = np.linalg.solve(cur_lhs_RB, cur_rhs_RB)[:, 0]
    sol_new_C_FO[:, ii+1] = BASIS_C_2D @ sol_new_C_RB[:, ii+1]
    
    # Compute partial errors and error bounds:
    energy_toterror[ii] = TIME_DELTA * stiff_C.dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1]).dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1])
    energy_solution[ii] = TIME_DELTA * stiff_C_proje_RB.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1])
    energy_residual[ii] = TIME_DELTA * (DD_pr_bb[0] + DD_pr_bm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        DD_pr_mm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        cur_DD_pr_ab.dot(sol_new_C_RB[:, ii+1]) + cur_DD_pr_aa.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1]) +\
                                        cur_DD_pr_am.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1]))

# Print current iteration and average temperature and concentration:
if verbose: 
    print('Final time:', N_ITER * TIME_DELTA, 's')
    print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, -1], 'atm/m^3\n\n')

# Add final term energies:
energy_solution[-1] += mass_C_proje_RB.dot(sol_new_C_RB[:, -1]).dot(sol_new_C_RB[:, -1])
energy_toterror[-1] += mass_C.dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1]).dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1])

# Print errors and error bounds:
print('Error bound:', np.sqrt(np.sum(energy_residual) / np.sum(energy_solution) / cur_coerc_coef) )
print('Error exact:', np.sqrt(np.sum(energy_toterror) / np.sum(energy_solution)) )
# Out:
# Current time: 0.0 s
# Average concentration: 0.0 atm/m^3
#
# Current time: 10000.0 s
# Average concentration: 6.077970823773112e+22 atm/m^3
#
# Current time: 20000.0 s
# Average concentration: 1.1627102283016573e+23 atm/m^3
#
# Current time: 30000.0 s
# Average concentration: 1.6790510821246518e+23 atm/m^3
#
# Current time: 40000.0 s
# Average concentration: 2.1643135899350284e+23 atm/m^3
#
# Current time: 50000.0 s
# Average concentration: 2.6230994915020693e+23 atm/m^3
#
# Current time: 60000.0 s
# Average concentration: 3.0586080633622834e+23 atm/m^3
#
# Current time: 70000.0 s
# Average concentration: 3.4732521216600335e+23 atm/m^3
#
# Current time: 80000.0 s
# Average concentration: 3.86894550306158e+23 atm/m^3
#
# Current time: 90000.0 s
# Average concentration: 4.247256892225978e+23 atm/m^3
#
# Current time: 100000.0 s
# Average concentration: 4.60950275784971e+23 atm/m^3
#
# Current time: 110000.0 s
# Average concentration: 4.95680864681533e+23 atm/m^3
#
# Current time: 120000.0 s
# Average concentration: 5.2901519299856895e+23 atm/m^3
#
# Current time: 130000.0 s
# Average concentration: 5.610392660670124e+23 atm/m^3
#
# Current time: 140000.0 s
# Average concentration: 5.918296367304532e+23 atm/m^3
#
# Current time: 150000.0 s
# Average concentration: 6.2145511814159e+23 atm/m^3
#
# Current time: 160000.0 s
# Average concentration: 6.499780900525686e+23 atm/m^3
#
# Current time: 170000.0 s
# Average concentration: 6.774555089597978e+23 atm/m^3
#
# Current time: 180000.0 s
# Average concentration: 7.039396998515079e+23 atm/m^3
#
# Current time: 190000.0 s
# Average concentration: 7.294789850869532e+23 atm/m^3
#
# Current time: 200000.0 s
# Average concentration: 7.5411819048078e+23 atm/m^3
#
# Current time: 210000.0 s
# Average concentration: 7.778990577771523e+23 atm/m^3
#
# Current time: 220000.0 s
# Average concentration: 8.008605849569703e+23 atm/m^3
#
# Current time: 230000.0 s
# Average concentration: 8.230393102767021e+23 atm/m^3
#
# Current time: 240000.0 s
# Average concentration: 8.444695519375061e+23 atm/m^3
#
# Current time: 250000.0 s
# Average concentration: 8.651836123769759e+23 atm/m^3
#
# Current time: 260000.0 s
# Average concentration: 8.852119540477668e+23 atm/m^3
#
# Current time: 270000.0 s
# Average concentration: 9.04583351976411e+23 atm/m^3
#
# Current time: 280000.0 s
# Average concentration: 9.233250272257948e+23 atm/m^3
#
# Current time: 290000.0 s
# Average concentration: 9.414627645057453e+23 atm/m^3
#
# Current time: 300000.0 s
# Average concentration: 9.590210165094014e+23 atm/m^3
#
# Current time: 310000.0 s
# Average concentration: 9.760229970424608e+23 atm/m^3
#
# Current time: 320000.0 s
# Average concentration: 9.924907646176481e+23 atm/m^3
#
# Current time: 330000.0 s
# Average concentration: 1.0084452978786873e+24 atm/m^3
#
# Current time: 340000.0 s
# Average concentration: 1.0239065639754674e+24 atm/m^3
#
# Current time: 350000.0 s
# Average concentration: 1.0388935808193546e+24 atm/m^3
#
# Current time: 360000.0 s
# Average concentration: 1.0534244739932469e+24 atm/m^3
#
# Current time: 370000.0 s
# Average concentration: 1.0675165289663546e+24 atm/m^3
#
# Current time: 380000.0 s
# Average concentration: 1.0811862391624279e+24 atm/m^3
#
# Current time: 390000.0 s
# Average concentration: 1.0944493503472528e+24 atm/m^3
#
# Current time: 400000.0 s
# Average concentration: 1.1073209017330136e+24 atm/m^3
#
# Current time: 410000.0 s
# Average concentration: 1.1198152641406344e+24 atm/m^3
#
# Current time: 420000.0 s
# Average concentration: 1.1319461755141991e+24 atm/m^3
#
# Current time: 430000.0 s
# Average concentration: 1.1437267740422573e+24 atm/m^3
#
# Current time: 440000.0 s
# Average concentration: 1.1551696291077974e+24 atm/m^3
#
# Current time: 450000.0 s
# Average concentration: 1.1662867702608231e+24 atm/m^3
#
# Current time: 460000.0 s
# Average concentration: 1.1770897143838958e+24 atm/m^3
#
# Current time: 470000.0 s
# Average concentration: 1.1875894912009289e+24 atm/m^3
#
# Current time: 480000.0 s
# Average concentration: 1.1977966672624168e+24 atm/m^3
#
# Current time: 490000.0 s
# Average concentration: 1.2077213685255952e+24 atm/m^3
#
# Current time: 500000.0 s
# Average concentration: 1.2173733016354268e+24 atm/m^3
#
# Current time: 510000.0 s
# Average concentration: 1.226761774001391e+24 atm/m^3
#
# Current time: 520000.0 s
# Average concentration: 1.235895712755635e+24 atm/m^3
#
# Current time: 530000.0 s
# Average concentration: 1.2447836826697974e+24 atm/m^3
#
# Current time: 540000.0 s
# Average concentration: 1.2534339031006733e+24 atm/m^3
#
# Current time: 550000.0 s
# Average concentration: 1.2618542640285632e+24 atm/m^3
#
# Current time: 560000.0 s
# Average concentration: 1.2700523412466276e+24 atm/m^3
#
# Current time: 570000.0 s
# Average concentration: 1.278035410754669e+24 atm/m^3
#
# Current time: 580000.0 s
# Average concentration: 1.285810462406413e+24 atm/m^3
#
# Current time: 590000.0 s
# Average concentration: 1.2933842128555004e+24 atm/m^3
#
# Current time: 600000.0 s
# Average concentration: 1.300763117841933e+24 atm/m^3
#
# Current time: 610000.0 s
# Average concentration: 1.3079533838576198e+24 atm/m^3
#
# Current time: 620000.0 s
# Average concentration: 1.314960979226869e+24 atm/m^3
#
# Current time: 630000.0 s
# Average concentration: 1.321791644635152e+24 atm/m^3
#
# Current time: 640000.0 s
# Average concentration: 1.3284509031371562e+24 atm/m^3
#
# Current time: 650000.0 s
# Average concentration: 1.3349440696730794e+24 atm/m^3
#
# Current time: 660000.0 s
# Average concentration: 1.3412762601202057e+24 atm/m^3
#
# Current time: 670000.0 s
# Average concentration: 1.3474523999050513e+24 atm/m^3
#
# Current time: 680000.0 s
# Average concentration: 1.353477232199783e+24 atm/m^3
#
# Current time: 690000.0 s
# Average concentration: 1.3593553257251354e+24 atm/m^3
#
# Current time: 700000.0 s
# Average concentration: 1.3650910821806943e+24 atm/m^3
#
# Current time: 710000.0 s
# Average concentration: 1.3706887433221492e+24 atm/m^3
#
# Current time: 720000.0 s
# Average concentration: 1.3761523977039686e+24 atm/m^3
#
# Current time: 730000.0 s
# Average concentration: 1.3814859871048684e+24 atm/m^3
#
# Current time: 740000.0 s
# Average concentration: 1.386693312652419e+24 atm/m^3
#
# Current time: 750000.0 s
# Average concentration: 1.3917780406622376e+24 atm/m^3
#
# Current time: 760000.0 s
# Average concentration: 1.3967437082062957e+24 atm/m^3
#
# Current time: 770000.0 s
# Average concentration: 1.4015937284240886e+24 atm/m^3
#
# Current time: 780000.0 s
# Average concentration: 1.406331395589637e+24 atm/m^3
#
# Current time: 790000.0 s
# Average concentration: 1.4109598899465705e+24 atm/m^3
#
# Current time: 800000.0 s
# Average concentration: 1.4154822823228832e+24 atm/m^3
#
# Current time: 810000.0 s
# Average concentration: 1.4199015385363212e+24 atm/m^3
#
# Current time: 820000.0 s
# Average concentration: 1.4242205236007456e+24 atm/m^3
#
# Current time: 830000.0 s
# Average concentration: 1.42844200574331e+24 atm/m^3
#
# Current time: 840000.0 s
# Average concentration: 1.432568660241715e+24 atm/m^3
#
# Current time: 850000.0 s
# Average concentration: 1.4366030730903374e+24 atm/m^3
#
# Current time: 860000.0 s
# Average concentration: 1.4405477445035747e+24 atm/m^3
#
# Current time: 870000.0 s
# Average concentration: 1.444405092264285e+24 atm/m^3
#
# Current time: 880000.0 s
# Average concentration: 1.448177454924804e+24 atm/m^3
#
# Current time: 890000.0 s
# Average concentration: 1.451867094867641e+24 atm/m^3
#
# Current time: 900000.0 s
# Average concentration: 1.4554762012325664e+24 atm/m^3
#
# Current time: 910000.0 s
# Average concentration: 1.45900689271648e+24 atm/m^3
#
# Current time: 920000.0 s
# Average concentration: 1.4624612202520993e+24 atm/m^3
#
# Current time: 930000.0 s
# Average concentration: 1.46584116957122e+24 atm/m^3
#
# Current time: 940000.0 s
# Average concentration: 1.4691486636579925e+24 atm/m^3
#
# Current time: 950000.0 s
# Average concentration: 1.47238556509739e+24 atm/m^3
#
# Current time: 960000.0 s
# Average concentration: 1.475553678323776e+24 atm/m^3
#
# Current time: 970000.0 s
# Average concentration: 1.4786547517742435e+24 atm/m^3
#
# Current time: 980000.0 s
# Average concentration: 1.481690479951143e+24 atm/m^3
#
# Current time: 990000.0 s
# Average concentration: 1.4846625053980203e+24 atm/m^3
#
# Current time: 1000000.0 s
# Average concentration: 1.4875724205929606e+24 atm/m^3
#
# Current time: 1010000.0 s
# Average concentration: 1.4904217697631365e+24 atm/m^3
#
# Current time: 1020000.0 s
# Average concentration: 1.4932120506241676e+24 atm/m^3
#
# Current time: 1030000.0 s
# Average concentration: 1.4959447160477382e+24 atm/m^3
#
# Current time: 1040000.0 s
# Average concentration: 1.4986211756607288e+24 atm/m^3
#
# Current time: 1050000.0 s
# Average concentration: 1.5012427973789714e+24 atm/m^3
#
# Current time: 1060000.0 s
# Average concentration: 1.5038109088785753e+24 atm/m^3
#
# Current time: 1070000.0 s
# Average concentration: 1.506326799007647e+24 atm/m^3
#
# Current time: 1080000.0 s
# Average concentration: 1.5087917191410633e+24 atm/m^3
#
# Current time: 1090000.0 s
# Average concentration: 1.511206884480843e+24 atm/m^3
#
# Current time: 1100000.0 s
# Average concentration: 1.5135734753045566e+24 atm/m^3
#
# Current time: 1110000.0 s
# Average concentration: 1.5158926381640537e+24 atm/m^3
#
# Current time: 1120000.0 s
# Average concentration: 1.5181654870367195e+24 atm/m^3
#
# Current time: 1130000.0 s
# Average concentration: 1.5203931044313428e+24 atm/m^3
#
# Current time: 1140000.0 s
# Average concentration: 1.5225765424505963e+24 atm/m^3
#
# Current time: 1150000.0 s
# Average concentration: 1.5247168238120037e+24 atm/m^3
#
# Current time: 1160000.0 s
# Average concentration: 1.5268149428292275e+24 atm/m^3
#
# Current time: 1170000.0 s
# Average concentration: 1.5288718663553786e+24 atm/m^3
#
# Current time: 1180000.0 s
# Average concentration: 1.5308885346899905e+24 atm/m^3
#
# Current time: 1190000.0 s
# Average concentration: 1.5328658624512316e+24 atm/m^3
#
# Current time: 1200000.0 s
# Average concentration: 1.534804739414834e+24 atm/m^3
#
# Current time: 1210000.0 s
# Average concentration: 1.5367060313211674e+24 atm/m^3
#
# Current time: 1220000.0 s
# Average concentration: 1.538570580651812e+24 atm/m^3
#
# Current time: 1230000.0 s
# Average concentration: 1.5403992073769186e+24 atm/m^3
#
# Current time: 1240000.0 s
# Average concentration: 1.542192709674593e+24 atm/m^3
#
# Current time: 1250000.0 s
# Average concentration: 1.543951864623481e+24 atm/m^3
#
# Current time: 1260000.0 s
# Average concentration: 1.545677428869673e+24 atm/m^3
#
# Current time: 1270000.0 s
# Average concentration: 1.5473701392690017e+24 atm/m^3
#
# Current time: 1280000.0 s
# Average concentration: 1.5490307135057578e+24 atm/m^3
#
# Current time: 1290000.0 s
# Average concentration: 1.5506598506887874e+24 atm/m^3
#
# Current time: 1300000.0 s
# Average concentration: 1.5522582319259276e+24 atm/m^3
#
# Current time: 1310000.0 s
# Average concentration: 1.5538265208776392e+24 atm/m^3
#
# Current time: 1320000.0 s
# Average concentration: 1.5553653642907114e+24 atm/m^3
#
# Current time: 1330000.0 s
# Average concentration: 1.556875392512841e+24 atm/m^3
#
# Current time: 1340000.0 s
# Average concentration: 1.558357219988855e+24 atm/m^3
#
# Current time: 1350000.0 s
# Average concentration: 1.5598114457393323e+24 atm/m^3
#
# Current time: 1360000.0 s
# Average concentration: 1.561238653822323e+24 atm/m^3
#
# Current time: 1370000.0 s
# Average concentration: 1.5626394137788437e+24 atm/m^3
#
# Current time: 1380000.0 s
# Average concentration: 1.5640142810627938e+24 atm/m^3
#
# Current time: 1390000.0 s
# Average concentration: 1.5653637974559247e+24 atm/m^3
#
# Current time: 1400000.0 s
# Average concentration: 1.5666884914684344e+24 atm/m^3
#
# Current time: 1410000.0 s
# Average concentration: 1.5679888787257682e+24 atm/m^3
#
# Current time: 1420000.0 s
# Average concentration: 1.5692654623421593e+24 atm/m^3
#
# Current time: 1430000.0 s
# Average concentration: 1.5705187332814333e+24 atm/m^3
#
# Current time: 1440000.0 s
# Average concentration: 1.5717491707055663e+24 atm/m^3
#
# Current time: 1450000.0 s
# Average concentration: 1.5729572423114755e+24 atm/m^3
#
# Current time: 1460000.0 s
# Average concentration: 1.574143404656495e+24 atm/m^3
#
# Current time: 1470000.0 s
# Average concentration: 1.5753081034729716e+24 atm/m^3
#
# Current time: 1480000.0 s
# Average concentration: 1.5764517739723898e+24 atm/m^3
#
# Current time: 1490000.0 s
# Average concentration: 1.5775748411394448e+24 atm/m^3
#
# Current time: 1500000.0 s
# Average concentration: 1.5786777200164202e+24 atm/m^3
#
# Current time: 1510000.0 s
# Average concentration: 1.5797608159782546e+24 atm/m^3
#
# Current time: 1520000.0 s
# Average concentration: 1.5808245249986357e+24 atm/m^3
#
# Current time: 1530000.0 s
# Average concentration: 1.5818692339074656e+24 atm/m^3
#
# Current time: 1540000.0 s
# Average concentration: 1.58289532064002e+24 atm/m^3
#
# Current time: 1550000.0 s
# Average concentration: 1.583903154478096e+24 atm/m^3
#
# Current time: 1560000.0 s
# Average concentration: 1.584893096283463e+24 atm/m^3
#
# Current time: 1570000.0 s
# Average concentration: 1.5858654987238894e+24 atm/m^3
#
# Current time: 1580000.0 s
# Average concentration: 1.5868207064920164e+24 atm/m^3
#
# Current time: 1590000.0 s
# Average concentration: 1.5877590565173414e+24 atm/m^3
#
# Current time: 1600000.0 s
# Average concentration: 1.5886808781715703e+24 atm/m^3
#
# Current time: 1610000.0 s
# Average concentration: 1.589586493467558e+24 atm/m^3
#
# Current time: 1620000.0 s
# Average concentration: 1.5904762172520888e+24 atm/m^3
#
# Current time: 1630000.0 s
# Average concentration: 1.5913503573927054e+24 atm/m^3
#
# Current time: 1640000.0 s
# Average concentration: 1.5922092149588024e+24 atm/m^3
#
# Current time: 1650000.0 s
# Average concentration: 1.593053084397186e+24 atm/m^3
#
# Current time: 1660000.0 s
# Average concentration: 1.5938822537023002e+24 atm/m^3
#
# Current time: 1670000.0 s
# Average concentration: 1.5946970045813002e+24 atm/m^3
#
# Current time: 1680000.0 s
# Average concentration: 1.5954976126141607e+24 atm/m^3
#
# Current time: 1690000.0 s
# Average concentration: 1.5962843474089838e+24 atm/m^3
#
# Current time: 1700000.0 s
# Average concentration: 1.5970574727526834e+24 atm/m^3
#
# Current time: 1710000.0 s
# Average concentration: 1.5978172467571986e+24 atm/m^3
#
# Current time: 1720000.0 s
# Average concentration: 1.59856392200139e+24 atm/m^3
#
# Current time: 1730000.0 s
# Average concentration: 1.5992977456687693e+24 atm/m^3
#
# Current time: 1740000.0 s
# Average concentration: 1.6000189596812084e+24 atm/m^3
#
# Current time: 1750000.0 s
# Average concentration: 1.6007278008287494e+24 atm/m^3
#
# Current time: 1760000.0 s
# Average concentration: 1.6014245008956664e+24 atm/m^3
#
# Current time: 1770000.0 s
# Average concentration: 1.6021092867828933e+24 atm/m^3
#
# Current time: 1780000.0 s
# Average concentration: 1.6027823806269396e+24 atm/m^3
#
# Current time: 1790000.0 s
# Average concentration: 1.603443999915413e+24 atm/m^3
#
# Current time: 1800000.0 s
# Average concentration: 1.60409435759927e+24 atm/m^3
#
# Current time: 1810000.0 s
# Average concentration: 1.6047336622018832e+24 atm/m^3
#
# Current time: 1820000.0 s
# Average concentration: 1.6053621179250462e+24 atm/m^3
#
# Current time: 1830000.0 s
# Average concentration: 1.6059799247520139e+24 atm/m^3
#
# Current time: 1840000.0 s
# Average concentration: 1.6065872785476663e+24 atm/m^3
#
# Current time: 1850000.0 s
# Average concentration: 1.6071843711558988e+24 atm/m^3
#
# Current time: 1860000.0 s
# Average concentration: 1.6077713904943206e+24 atm/m^3
#
# Current time: 1870000.0 s
# Average concentration: 1.608348520646357e+24 atm/m^3
#
# Current time: 1880000.0 s
# Average concentration: 1.6089159419508238e+24 atm/m^3
#
# Current time: 1890000.0 s
# Average concentration: 1.6094738310890727e+24 atm/m^3
#
# Current time: 1900000.0 s
# Average concentration: 1.6100223611697708e+24 atm/m^3
#
# Current time: 1910000.0 s
# Average concentration: 1.6105617018113931e+24 atm/m^3
#
# Current time: 1920000.0 s
# Average concentration: 1.6110920192224995e+24 atm/m^3
#
# Current time: 1930000.0 s
# Average concentration: 1.6116134762798658e+24 atm/m^3
#
# Current time: 1940000.0 s
# Average concentration: 1.6121262326045398e+24 atm/m^3
#
# Current time: 1950000.0 s
# Average concentration: 1.6126304446358764e+24 atm/m^3
#
# Current time: 1960000.0 s
# Average concentration: 1.6131262657036226e+24 atm/m^3
#
# Current time: 1970000.0 s
# Average concentration: 1.6136138460981094e+24 atm/m^3
#
# Current time: 1980000.0 s
# Average concentration: 1.6140933331386094e+24 atm/m^3
#
# Current time: 1990000.0 s
# Average concentration: 1.6145648712399116e+24 atm/m^3
#
# Current time: 2000000.0 s
# Average concentration: 1.6150286019771798e+24 atm/m^3
#
# Current time: 2010000.0 s
# Average concentration: 1.615484664149121e+24 atm/m^3
#
# Current time: 2020000.0 s
# Average concentration: 1.6159331938395472e+24 atm/m^3
#
# Current time: 2030000.0 s
# Average concentration: 1.6163743244773549e+24 atm/m^3
#
# Current time: 2040000.0 s
# Average concentration: 1.616808186894973e+24 atm/m^3
#
# Current time: 2050000.0 s
# Average concentration: 1.6172349093853317e+24 atm/m^3
#
# Current time: 2060000.0 s
# Average concentration: 1.6176546177573962e+24 atm/m^3
#
# Current time: 2070000.0 s
# Average concentration: 1.6180674353902956e+24 atm/m^3
#
# Current time: 2080000.0 s
# Average concentration: 1.6184734832860962e+24 atm/m^3
#
# Current time: 2090000.0 s
# Average concentration: 1.6188728801212653e+24 atm/m^3
#
# Current time: 2100000.0 s
# Average concentration: 1.6192657422968454e+24 atm/m^3
#
# Current time: 2110000.0 s
# Average concentration: 1.6196521839873954e+24 atm/m^3
#
# Current time: 2120000.0 s
# Average concentration: 1.620032317188722e+24 atm/m^3
#
# Current time: 2130000.0 s
# Average concentration: 1.6204062517644362e+24 atm/m^3
#
# Current time: 2140000.0 s
# Average concentration: 1.6207740954913766e+24 atm/m^3
#
# Current time: 2150000.0 s
# Average concentration: 1.62113595410392e+24 atm/m^3
#
# Current time: 2160000.0 s
# Average concentration: 1.6214919313372225e+24 atm/m^3
#
# Current time: 2170000.0 s
# Average concentration: 1.6218421289694104e+24 atm/m^3
#
# Current time: 2180000.0 s
# Average concentration: 1.6221866468627598e+24 atm/m^3
#
# Current time: 2190000.0 s
# Average concentration: 1.6225255830038824e+24 atm/m^3
#
# Current time: 2200000.0 s
# Average concentration: 1.6228590335429582e+24 atm/m^3
#
# Current time: 2210000.0 s
# Average concentration: 1.6231870928320285e+24 atm/m^3
#
# Current time: 2220000.0 s
# Average concentration: 1.6235098534623824e+24 atm/m^3
#
# Current time: 2230000.0 s
# Average concentration: 1.6238274063010606e+24 atm/m^3
#
# Current time: 2240000.0 s
# Average concentration: 1.6241398405264982e+24 atm/m^3
#
# Current time: 2250000.0 s
# Average concentration: 1.6244472436633326e+24 atm/m^3
#
# Current time: 2260000.0 s
# Average concentration: 1.6247497016163982e+24 atm/m^3
#
# Current time: 2270000.0 s
# Average concentration: 1.625047298703927e+24 atm/m^3
#
# Current time: 2280000.0 s
# Average concentration: 1.6253401176899808e+24 atm/m^3
#
# Current time: 2290000.0 s
# Average concentration: 1.6256282398161322e+24 atm/m^3
#
# Current time: 2300000.0 s
# Average concentration: 1.6259117448324178e+24 atm/m^3
#
# Current time: 2310000.0 s
# Average concentration: 1.626190711027578e+24 atm/m^3
#
# Current time: 2320000.0 s
# Average concentration: 1.6264652152586045e+24 atm/m^3
#
# Current time: 2330000.0 s
# Average concentration: 1.6267353329796168e+24 atm/m^3
#
# Current time: 2340000.0 s
# Average concentration: 1.6270011382700786e+24 atm/m^3
#
# Current time: 2350000.0 s
# Average concentration: 1.6272627038623795e+24 atm/m^3
#
# Current time: 2360000.0 s
# Average concentration: 1.6275201011687872e+24 atm/m^3
#
# Current time: 2370000.0 s
# Average concentration: 1.627773400307806e+24 atm/m^3
#
# Current time: 2380000.0 s
# Average concentration: 1.6280226701299235e+24 atm/m^3
#
# Current time: 2390000.0 s
# Average concentration: 1.6282679782428043e+24 atm/m^3
#
# Current time: 2400000.0 s
# Average concentration: 1.6285093910359065e+24 atm/m^3
#
# Current time: 2410000.0 s
# Average concentration: 1.628746973704556e+24 atm/m^3
#
# Current time: 2420000.0 s
# Average concentration: 1.628980790273492e+24 atm/m^3
#
# Current time: 2430000.0 s
# Average concentration: 1.6292109036198855e+24 atm/m^3
#
# Current time: 2440000.0 s
# Average concentration: 1.6294373754958575e+24 atm/m^3
#
# Current time: 2450000.0 s
# Average concentration: 1.629660266550502e+24 atm/m^3
#
# Current time: 2460000.0 s
# Average concentration: 1.629879636351419e+24 atm/m^3
#
# Current time: 2470000.0 s
# Average concentration: 1.630095543405793e+24 atm/m^3
#
# Current time: 2480000.0 s
# Average concentration: 1.6303080451810034e+24 atm/m^3
#
# Current time: 2490000.0 s
# Average concentration: 1.630517198124788e+24 atm/m^3
#
# Current time: 2500000.0 s
# Average concentration: 1.6307230576849754e+24 atm/m^3
#
# Current time: 2510000.0 s
# Average concentration: 1.630925678328789e+24 atm/m^3
#
# Current time: 2520000.0 s
# Average concentration: 1.6311251135617382e+24 atm/m^3
#
# Current time: 2530000.0 s
# Average concentration: 1.6313214159461037e+24 atm/m^3
#
# Current time: 2540000.0 s
# Average concentration: 1.631514637119031e+24 atm/m^3
#
# Current time: 2550000.0 s
# Average concentration: 1.63170482781023e+24 atm/m^3
#
# Current time: 2560000.0 s
# Average concentration: 1.6318920378593118e+24 atm/m^3
#
# Current time: 2570000.0 s
# Average concentration: 1.6320763162327477e+24 atm/m^3
#
# Current time: 2580000.0 s
# Average concentration: 1.632257711040476e+24 atm/m^3
#
# Current time: 2590000.0 s
# Average concentration: 1.6324362695521536e+24 atm/m^3
#
# Current time: 2600000.0 s
# Average concentration: 1.6326120382130734e+24 atm/m^3
#
# Current time: 2610000.0 s
# Average concentration: 1.632785062659742e+24 atm/m^3
#
# Current time: 2620000.0 s
# Average concentration: 1.6329553877351354e+24 atm/m^3
#
# Current time: 2630000.0 s
# Average concentration: 1.6331230575036358e+24 atm/m^3
#
# Current time: 2640000.0 s
# Average concentration: 1.6332881152656598e+24 atm/m^3
#
# Current time: 2650000.0 s
# Average concentration: 1.6334506035719773e+24 atm/m^3
#
# Current time: 2660000.0 s
# Average concentration: 1.633610564237744e+24 atm/m^3
#
# Current time: 2670000.0 s
# Average concentration: 1.63376803835624e+24 atm/m^3
#
# Current time: 2680000.0 s
# Average concentration: 1.633923066312318e+24 atm/m^3
#
# Current time: 2690000.0 s
# Average concentration: 1.6340756877955916e+24 atm/m^3
#
# Current time: 2700000.0 s
# Average concentration: 1.6342259418133405e+24 atm/m^3
#
# Current time: 2710000.0 s
# Average concentration: 1.6343738667031604e+24 atm/m^3
#
# Current time: 2720000.0 s
# Average concentration: 1.6345195001453475e+24 atm/m^3
#
# Current time: 2730000.0 s
# Average concentration: 1.6346628791750393e+24 atm/m^3
#
# Current time: 2740000.0 s
# Average concentration: 1.634804040194105e+24 atm/m^3
#
# Current time: 2750000.0 s
# Average concentration: 1.6349430189827974e+24 atm/m^3
#
# Current time: 2760000.0 s
# Average concentration: 1.6350798507111667e+24 atm/m^3
#
# Current time: 2770000.0 s
# Average concentration: 1.6352145699502507e+24 atm/m^3
#
# Current time: 2780000.0 s
# Average concentration: 1.635347210683035e+24 atm/m^3
#
# Current time: 2790000.0 s
# Average concentration: 1.6354778063151936e+24 atm/m^3
#
# Current time: 2800000.0 s
# Average concentration: 1.6356063896856195e+24 atm/m^3
#
# Current time: 2810000.0 s
# Average concentration: 1.635732993076742e+24 atm/m^3
#
# Current time: 2820000.0 s
# Average concentration: 1.6358576482246387e+24 atm/m^3
#
# Current time: 2830000.0 s
# Average concentration: 1.6359803863289504e+24 atm/m^3
#
# Current time: 2840000.0 s
# Average concentration: 1.6361012380625943e+24 atm/m^3
#
# Current time: 2850000.0 s
# Average concentration: 1.6362202335812904e+24 atm/m^3
#
# Current time: 2860000.0 s
# Average concentration: 1.6363374025328938e+24 atm/m^3
#
# Current time: 2870000.0 s
# Average concentration: 1.6364527740665537e+24 atm/m^3
#
# Current time: 2880000.0 s
# Average concentration: 1.6365663768416815e+24 atm/m^3
#
# Current time: 2890000.0 s
# Average concentration: 1.6366782390367504e+24 atm/m^3
#
# Current time: 2900000.0 s
# Average concentration: 1.636788388357921e+24 atm/m^3
#
# Current time: 2910000.0 s
# Average concentration: 1.6368968520474976e+24 atm/m^3
#
# Current time: 2920000.0 s
# Average concentration: 1.6370036568922227e+24 atm/m^3
#
# Current time: 2930000.0 s
# Average concentration: 1.6371088292314076e+24 atm/m^3
#
# Current time: 2940000.0 s
# Average concentration: 1.6372123949649069e+24 atm/m^3
#
# Current time: 2950000.0 s
# Average concentration: 1.6373143795609376e+24 atm/m^3
#
# Current time: 2960000.0 s
# Average concentration: 1.6374148080637514e+24 atm/m^3
#
# Current time: 2970000.0 s
# Average concentration: 1.6375137051011525e+24 atm/m^3
#
# Current time: 2980000.0 s
# Average concentration: 1.6376110948918753e+24 atm/m^3
#
# Current time: 2990000.0 s
# Average concentration: 1.63770700125282e+24 atm/m^3
#
# Current time: 3000000.0 s
# Average concentration: 1.637801447606152e+24 atm/m^3
#
# Current time: 3010000.0 s
# Average concentration: 1.6378944569862583e+24 atm/m^3
#
# Current time: 3020000.0 s
# Average concentration: 1.6379860520465796e+24 atm/m^3
#
# Current time: 3030000.0 s
# Average concentration: 1.6380762550663075e+24 atm/m^3
#
# Current time: 3040000.0 s
# Average concentration: 1.6381650879569546e+24 atm/m^3
#
# Current time: 3050000.0 s
# Average concentration: 1.6382525722688042e+24 atm/m^3
#
# Current time: 3060000.0 s
# Average concentration: 1.6383387291972314e+24 atm/m^3
#
# Current time: 3070000.0 s
# Average concentration: 1.6384235795889105e+24 atm/m^3
#
# Current time: 3080000.0 s
# Average concentration: 1.6385071439479027e+24 atm/m^3
#
# Current time: 3090000.0 s
# Average concentration: 1.638589442441628e+24 atm/m^3
#
# Current time: 3100000.0 s
# Average concentration: 1.6386704949067306e+24 atm/m^3
#
# Current time: 3110000.0 s
# Average concentration: 1.638750320854824e+24 atm/m^3
#
# Current time: 3120000.0 s
# Average concentration: 1.6388289394781413e+24 atm/m^3
#
# Current time: 3130000.0 s
# Average concentration: 1.6389063696550684e+24 atm/m^3
#
# Current time: 3140000.0 s
# Average concentration: 1.6389826299555818e+24 atm/m^3
#
# Current time: 3150000.0 s
# Average concentration: 1.6390577386465824e+24 atm/m^3
#
# Current time: 3160000.0 s
# Average concentration: 1.639131713697127e+24 atm/m^3
#
# Current time: 3170000.0 s
# Average concentration: 1.639204572783572e+24 atm/m^3
#
# Current time: 3180000.0 s
# Average concentration: 1.6392763332946066e+24 atm/m^3
#
# Current time: 3190000.0 s
# Average concentration: 1.6393470123362116e+24 atm/m^3
#
# Current time: 3200000.0 s
# Average concentration: 1.6394166267365106e+24 atm/m^3
#
# Current time: 3210000.0 s
# Average concentration: 1.6394851930505395e+24 atm/m^3
#
# Current time: 3220000.0 s
# Average concentration: 1.6395527275649302e+24 atm/m^3
#
# Current time: 3230000.0 s
# Average concentration: 1.6396192463025006e+24 atm/m^3
#
# Current time: 3240000.0 s
# Average concentration: 1.639684765026766e+24 atm/m^3
#
# Current time: 3250000.0 s
# Average concentration: 1.6397492992463702e+24 atm/m^3
#
# Current time: 3260000.0 s
# Average concentration: 1.6398128642194272e+24 atm/m^3
#
# Current time: 3270000.0 s
# Average concentration: 1.6398754749577923e+24 atm/m^3
#
# Current time: 3280000.0 s
# Average concentration: 1.6399371462312514e+24 atm/m^3
#
# Current time: 3290000.0 s
# Average concentration: 1.639997892571631e+24 atm/m^3
#
# Current time: 3300000.0 s
# Average concentration: 1.6400577282768405e+24 atm/m^3
#
# Current time: 3310000.0 s
# Average concentration: 1.640116667414838e+24 atm/m^3
#
# Current time: 3320000.0 s
# Average concentration: 1.6401747238275207e+24 atm/m^3
#
# Current time: 3330000.0 s
# Average concentration: 1.6402319111345523e+24 atm/m^3
#
# Current time: 3340000.0 s
# Average concentration: 1.640288242737112e+24 atm/m^3
#
# Current time: 3350000.0 s
# Average concentration: 1.640343731821587e+24 atm/m^3
#
# Current time: 3360000.0 s
# Average concentration: 1.64039839136319e+24 atm/m^3
#
# Current time: 3370000.0 s
# Average concentration: 1.6404522341295137e+24 atm/m^3
#
# Current time: 3380000.0 s
# Average concentration: 1.6405052726840225e+24 atm/m^3
#
# Current time: 3390000.0 s
# Average concentration: 1.6405575193894831e+24 atm/m^3
#
# Current time: 3400000.0 s
# Average concentration: 1.6406089864113308e+24 atm/m^3
#
# Current time: 3410000.0 s
# Average concentration: 1.6406596857209782e+24 atm/m^3
#
# Current time: 3420000.0 s
# Average concentration: 1.6407096290990599e+24 atm/m^3
#
# Current time: 3430000.0 s
# Average concentration: 1.640758828138628e+24 atm/m^3
#
# Current time: 3440000.0 s
# Average concentration: 1.640807294248283e+24 atm/m^3
#
# Current time: 3450000.0 s
# Average concentration: 1.6408550386552527e+24 atm/m^3
#
# Current time: 3460000.0 s
# Average concentration: 1.6409020724084156e+24 atm/m^3
#
# Current time: 3470000.0 s
# Average concentration: 1.6409484063812717e+24 atm/m^3
#
# Current time: 3480000.0 s
# Average concentration: 1.640994051274859e+24 atm/m^3
#
# Current time: 3490000.0 s
# Average concentration: 1.6410390176206187e+24 atm/m^3
#
# Current time: 3500000.0 s
# Average concentration: 1.6410833157832124e+24 atm/m^3
#
# Current time: 3510000.0 s
# Average concentration: 1.6411269559632905e+24 atm/m^3
#
# Current time: 3520000.0 s
# Average concentration: 1.6411699482002005e+24 atm/m^3
#
# Current time: 3530000.0 s
# Average concentration: 1.6412123023746674e+24 atm/m^3
#
# Current time: 3540000.0 s
# Average concentration: 1.641254028211409e+24 atm/m^3
#
# Current time: 3550000.0 s
# Average concentration: 1.6412951352817154e+24 atm/m^3
#
# Current time: 3560000.0 s
# Average concentration: 1.6413356330059787e+24 atm/m^3
#
# Current time: 3570000.0 s
# Average concentration: 1.641375530656183e+24 atm/m^3
#
# Current time: 3580000.0 s
# Average concentration: 1.641414837358347e+24 atm/m^3
#
# Current time: 3590000.0 s
# Average concentration: 1.6414535620949252e+24 atm/m^3
#
# Current time: 3600000.0 s
# Average concentration: 1.641491713707168e+24 atm/m^3
#
# Current time: 3610000.0 s
# Average concentration: 1.641529300897441e+24 atm/m^3
#
# Current time: 3620000.0 s
# Average concentration: 1.6415663322315016e+24 atm/m^3
#
# Current time: 3630000.0 s
# Average concentration: 1.6416028161407376e+24 atm/m^3
#
# Current time: 3640000.0 s
# Average concentration: 1.641638760924373e+24 atm/m^3
#
# Current time: 3650000.0 s
# Average concentration: 1.6416741747516187e+24 atm/m^3
#
# Current time: 3660000.0 s
# Average concentration: 1.6417090656638087e+24 atm/m^3
#
# Current time: 3670000.0 s
# Average concentration: 1.6417434415764832e+24 atm/m^3
#
# Current time: 3680000.0 s
# Average concentration: 1.6417773102814367e+24 atm/m^3
#
# Current time: 3690000.0 s
# Average concentration: 1.6418106794487441e+24 atm/m^3
#
# Current time: 3700000.0 s
# Average concentration: 1.6418435566287345e+24 atm/m^3
#
# Current time: 3710000.0 s
# Average concentration: 1.641875949253943e+24 atm/m^3
#
# Current time: 3720000.0 s
# Average concentration: 1.641907864641026e+24 atm/m^3
#
# Current time: 3730000.0 s
# Average concentration: 1.6419393099926373e+24 atm/m^3
#
# Current time: 3740000.0 s
# Average concentration: 1.6419702923992861e+24 atm/m^3
#
# Current time: 3750000.0 s
# Average concentration: 1.6420008188411497e+24 atm/m^3
#
# Current time: 3760000.0 s
# Average concentration: 1.6420308961898606e+24 atm/m^3
#
# Current time: 3770000.0 s
# Average concentration: 1.6420605312102657e+24 atm/m^3
#
# Current time: 3780000.0 s
# Average concentration: 1.6420897305621517e+24 atm/m^3
#
# Current time: 3790000.0 s
# Average concentration: 1.6421185008019422e+24 atm/m^3
#
# Current time: 3800000.0 s
# Average concentration: 1.6421468483843621e+24 atm/m^3
#
# Current time: 3810000.0 s
# Average concentration: 1.6421747796640866e+24 atm/m^3
#
# Current time: 3820000.0 s
# Average concentration: 1.6422023008973468e+24 atm/m^3
#
# Current time: 3830000.0 s
# Average concentration: 1.6422294182435154e+24 atm/m^3
#
# Current time: 3840000.0 s
# Average concentration: 1.642256137766668e+24 atm/m^3
#
# Current time: 3850000.0 s
# Average concentration: 1.64228246543711e+24 atm/m^3
#
# Current time: 3860000.0 s
# Average concentration: 1.6423084071328867e+24 atm/m^3
#
# Current time: 3870000.0 s
# Average concentration: 1.6423339686412637e+24 atm/m^3
#
# Current time: 3880000.0 s
# Average concentration: 1.6423591556601784e+24 atm/m^3
#
# Current time: 3890000.0 s
# Average concentration: 1.6423839737996796e+24 atm/m^3
#
# Current time: 3900000.0 s
# Average concentration: 1.6424084285833242e+24 atm/m^3
#
# Current time: 3910000.0 s
# Average concentration: 1.6424325254495687e+24 atm/m^3
#
# Current time: 3920000.0 s
# Average concentration: 1.6424562697531234e+24 atm/m^3
#
# Current time: 3930000.0 s
# Average concentration: 1.642479666766299e+24 atm/m^3
#
# Current time: 3940000.0 s
# Average concentration: 1.6425027216803097e+24 atm/m^3
#
# Current time: 3950000.0 s
# Average concentration: 1.642525439606576e+24 atm/m^3
#
# Current time: 3960000.0 s
# Average concentration: 1.642547825577993e+24 atm/m^3
#
# Current time: 3970000.0 s
# Average concentration: 1.6425698845501776e+24 atm/m^3
#
# Current time: 3980000.0 s
# Average concentration: 1.6425916214027022e+24 atm/m^3
#
# Current time: 3990000.0 s
# Average concentration: 1.6426130409403055e+24 atm/m^3
#
# Current time: 4000000.0 s
# Average concentration: 1.642634147894074e+24 atm/m^3
#
# Current time: 4010000.0 s
# Average concentration: 1.6426549469226166e+24 atm/m^3
#
# Current time: 4020000.0 s
# Average concentration: 1.6426754426132151e+24 atm/m^3
#
# Current time: 4030000.0 s
# Average concentration: 1.6426956394829498e+24 atm/m^3
#
# Current time: 4040000.0 s
# Average concentration: 1.642715541979818e+24 atm/m^3
#
# Current time: 4050000.0 s
# Average concentration: 1.6427351544838207e+24 atm/m^3
#
# Current time: 4060000.0 s
# Average concentration: 1.6427544813080448e+24 atm/m^3
#
# Current time: 4070000.0 s
# Average concentration: 1.6427735266997138e+24 atm/m^3
#
# Current time: 4080000.0 s
# Average concentration: 1.6427922948412353e+24 atm/m^3
#
# Current time: 4090000.0 s
# Average concentration: 1.642810789851216e+24 atm/m^3
#
# Current time: 4100000.0 s
# Average concentration: 1.6428290157854772e+24 atm/m^3
#
# Current time: 4110000.0 s
# Average concentration: 1.6428469766380367e+24 atm/m^3
#
# Current time: 4120000.0 s
# Average concentration: 1.6428646763420856e+24 atm/m^3
#
# Current time: 4130000.0 s
# Average concentration: 1.6428821187709435e+24 atm/m^3
#
# Current time: 4140000.0 s
# Average concentration: 1.642899307739004e+24 atm/m^3
#
# Current time: 4150000.0 s
# Average concentration: 1.6429162470026587e+24 atm/m^3
#
# Current time: 4160000.0 s
# Average concentration: 1.6429329402612057e+24 atm/m^3
#
# Current time: 4170000.0 s
# Average concentration: 1.6429493911577496e+24 atm/m^3
#
# Current time: 4180000.0 s
# Average concentration: 1.6429656032800822e+24 atm/m^3
#
# Current time: 4190000.0 s
# Average concentration: 1.6429815801615493e+24 atm/m^3
#
# Current time: 4200000.0 s
# Average concentration: 1.6429973252819011e+24 atm/m^3
#
# Current time: 4210000.0 s
# Average concentration: 1.643012842068133e+24 atm/m^3
#
# Current time: 4220000.0 s
# Average concentration: 1.6430281338953153e+24 atm/m^3
#
# Current time: 4230000.0 s
# Average concentration: 1.6430432040873965e+24 atm/m^3
#
# Current time: 4240000.0 s
# Average concentration: 1.64305805591801e+24 atm/m^3
#
# Current time: 4250000.0 s
# Average concentration: 1.6430726926112545e+24 atm/m^3
#
# Current time: 4260000.0 s
# Average concentration: 1.643087117342467e+24 atm/m^3
#
# Current time: 4270000.0 s
# Average concentration: 1.643101333238989e+24 atm/m^3
#
# Current time: 4280000.0 s
# Average concentration: 1.643115343380907e+24 atm/m^3
#
# Current time: 4290000.0 s
# Average concentration: 1.643129150801793e+24 atm/m^3
#
# Current time: 4300000.0 s
# Average concentration: 1.6431427584894277e+24 atm/m^3
#
# Current time: 4310000.0 s
# Average concentration: 1.643156169386512e+24 atm/m^3
#
# Current time: 4320000.0 s
# Average concentration: 1.6431693863913687e+24 atm/m^3
#
# Current time: 4330000.0 s
# Average concentration: 1.6431824123586312e+24 atm/m^3
#
# Current time: 4340000.0 s
# Average concentration: 1.6431952500999204e+24 atm/m^3
#
# Current time: 4350000.0 s
# Average concentration: 1.6432079023845189e+24 atm/m^3
#
# Current time: 4360000.0 s
# Average concentration: 1.6432203719400172e+24 atm/m^3
#
# Current time: 4370000.0 s
# Average concentration: 1.643232661452967e+24 atm/m^3
#
# Current time: 4380000.0 s
# Average concentration: 1.6432447735695185e+24 atm/m^3
#
# Current time: 4390000.0 s
# Average concentration: 1.6432567108960362e+24 atm/m^3
#
# Current time: 4400000.0 s
# Average concentration: 1.6432684759997266e+24 atm/m^3
#
# Current time: 4410000.0 s
# Average concentration: 1.6432800714092327e+24 atm/m^3
#
# Current time: 4420000.0 s
# Average concentration: 1.6432914996152398e+24 atm/m^3
#
# Current time: 4430000.0 s
# Average concentration: 1.6433027630710524e+24 atm/m^3
#
# Current time: 4440000.0 s
# Average concentration: 1.6433138641931795e+24 atm/m^3
#
# Current time: 4450000.0 s
# Average concentration: 1.6433248053618964e+24 atm/m^3
#
# Current time: 4460000.0 s
# Average concentration: 1.6433355889218068e+24 atm/m^3
#
# Current time: 4470000.0 s
# Average concentration: 1.6433462171823897e+24 atm/m^3
#
# Current time: 4480000.0 s
# Average concentration: 1.6433566924185403e+24 atm/m^3
#
# Current time: 4490000.0 s
# Average concentration: 1.6433670168711074e+24 atm/m^3
#
# Current time: 4500000.0 s
# Average concentration: 1.6433771927474107e+24 atm/m^3
#
# Current time: 4510000.0 s
# Average concentration: 1.6433872222217602e+24 atm/m^3
#
# Current time: 4520000.0 s
# Average concentration: 1.6433971074359614e+24 atm/m^3
#
# Current time: 4530000.0 s
# Average concentration: 1.643406850499816e+24 atm/m^3
#
# Current time: 4540000.0 s
# Average concentration: 1.6434164534916127e+24 atm/m^3
#
# Current time: 4550000.0 s
# Average concentration: 1.6434259184586083e+24 atm/m^3
#
# Current time: 4560000.0 s
# Average concentration: 1.6434352474175083e+24 atm/m^3
#
# Current time: 4570000.0 s
# Average concentration: 1.6434444423549316e+24 atm/m^3
#
# Current time: 4580000.0 s
# Average concentration: 1.643453505227873e+24 atm/m^3
#
# Current time: 4590000.0 s
# Average concentration: 1.6434624379641531e+24 atm/m^3
#
# Current time: 4600000.0 s
# Average concentration: 1.6434712424628695e+24 atm/m^3
#
# Current time: 4610000.0 s
# Average concentration: 1.643479920594836e+24 atm/m^3
#
# Current time: 4620000.0 s
# Average concentration: 1.6434884742030084e+24 atm/m^3
#
# Current time: 4630000.0 s
# Average concentration: 1.6434969051029176e+24 atm/m^3
#
# Current time: 4640000.0 s
# Average concentration: 1.6435052150830845e+24 atm/m^3
#
# Current time: 4650000.0 s
# Average concentration: 1.6435134059054342e+24 atm/m^3
#
# Current time: 4660000.0 s
# Average concentration: 1.6435214793056977e+24 atm/m^3
#
# Current time: 4670000.0 s
# Average concentration: 1.643529436993816e+24 atm/m^3
#
# Current time: 4680000.0 s
# Average concentration: 1.6435372806543314e+24 atm/m^3
#
# Current time: 4690000.0 s
# Average concentration: 1.6435450119467735e+24 atm/m^3
#
# Current time: 4700000.0 s
# Average concentration: 1.6435526325060415e+24 atm/m^3
#
# Current time: 4710000.0 s
# Average concentration: 1.6435601439427753e+24 atm/m^3
#
# Current time: 4720000.0 s
# Average concentration: 1.6435675478437297e+24 atm/m^3
#
# Current time: 4730000.0 s
# Average concentration: 1.643574845772135e+24 atm/m^3
#
# Current time: 4740000.0 s
# Average concentration: 1.6435820392680518e+24 atm/m^3
#
# Current time: 4750000.0 s
# Average concentration: 1.6435891298487262e+24 atm/m^3
#
# Current time: 4760000.0 s
# Average concentration: 1.6435961190089374e+24 atm/m^3
#
# Current time: 4770000.0 s
# Average concentration: 1.6436030082213342e+24 atm/m^3
#
# Current time: 4780000.0 s
# Average concentration: 1.6436097989367728e+24 atm/m^3
#
# Current time: 4790000.0 s
# Average concentration: 1.6436164925846465e+24 atm/m^3
#
# Current time: 4800000.0 s
# Average concentration: 1.6436230905732148e+24 atm/m^3
#
# Current time: 4810000.0 s
# Average concentration: 1.643629594289915e+24 atm/m^3
#
# Current time: 4820000.0 s
# Average concentration: 1.6436360051016857e+24 atm/m^3
#
# Current time: 4830000.0 s
# Average concentration: 1.6436423243552727e+24 atm/m^3
#
# Current time: 4840000.0 s
# Average concentration: 1.6436485533775343e+24 atm/m^3
#
# Current time: 4850000.0 s
# Average concentration: 1.6436546934757445e+24 atm/m^3
#
# Current time: 4860000.0 s
# Average concentration: 1.6436607459378848e+24 atm/m^3
#
# Current time: 4870000.0 s
# Average concentration: 1.6436667120329403e+24 atm/m^3
#
# Current time: 4880000.0 s
# Average concentration: 1.6436725930111822e+24 atm/m^3
#
# Current time: 4890000.0 s
# Average concentration: 1.6436783901044527e+24 atm/m^3
#
# Current time: 4900000.0 s
# Average concentration: 1.6436841045264428e+24 atm/m^3
#
# Current time: 4910000.0 s
# Average concentration: 1.6436897374729626e+24 atm/m^3
#
# Current time: 4920000.0 s
# Average concentration: 1.6436952901222164e+24 atm/m^3
#
# Current time: 4930000.0 s
# Average concentration: 1.6437007636350614e+24 atm/m^3
#
# Current time: 4940000.0 s
# Average concentration: 1.6437061591552764e+24 atm/m^3
#
# Current time: 4950000.0 s
# Average concentration: 1.643711477809811e+24 atm/m^3
#
# Current time: 4960000.0 s
# Average concentration: 1.6437167207090442e+24 atm/m^3
#
# Current time: 4970000.0 s
# Average concentration: 1.6437218889470315e+24 atm/m^3
#
# Current time: 4980000.0 s
# Average concentration: 1.643726983601749e+24 atm/m^3
#
# Current time: 4990000.0 s
# Average concentration: 1.6437320057353377e+24 atm/m^3
#
# Current time: 5000000.0 s
# Average concentration: 1.6437369563943394e+24 atm/m^3
#
# Current time: 5010000.0 s
# Average concentration: 1.6437418366099281e+24 atm/m^3
#
# Current time: 5020000.0 s
# Average concentration: 1.643746647398151e+24 atm/m^3
#
# Current time: 5030000.0 s
# Average concentration: 1.6437513897601405e+24 atm/m^3
#
# Current time: 5040000.0 s
# Average concentration: 1.64375606468235e+24 atm/m^3
#
# Current time: 5050000.0 s
# Average concentration: 1.643760673136767e+24 atm/m^3
#
# Current time: 5060000.0 s
# Average concentration: 1.643765216081132e+24 atm/m^3
#
# Current time: 5070000.0 s
# Average concentration: 1.643769694459153e+24 atm/m^3
#
# Current time: 5080000.0 s
# Average concentration: 1.6437741092007127e+24 atm/m^3
#
# Current time: 5090000.0 s
# Average concentration: 1.6437784612220764e+24 atm/m^3
#
# Current time: 5100000.0 s
# Average concentration: 1.6437827514260967e+24 atm/m^3
#
# Current time: 5110000.0 s
# Average concentration: 1.6437869807024147e+24 atm/m^3
#
# Current time: 5120000.0 s
# Average concentration: 1.6437911499276542e+24 atm/m^3
#
# Current time: 5130000.0 s
# Average concentration: 1.6437952599656175e+24 atm/m^3
#
# Current time: 5140000.0 s
# Average concentration: 1.6437993116674788e+24 atm/m^3
#
# Current time: 5150000.0 s
# Average concentration: 1.643803305871968e+24 atm/m^3
#
# Current time: 5160000.0 s
# Average concentration: 1.6438072434055638e+24 atm/m^3
#
# Current time: 5170000.0 s
# Average concentration: 1.6438111250826683e+24 atm/m^3
#
# Current time: 5180000.0 s
# Average concentration: 1.6438149517057926e+24 atm/m^3
#
# Current time: 5190000.0 s
# Average concentration: 1.6438187240657313e+24 atm/m^3
#
# Current time: 5200000.0 s
# Average concentration: 1.6438224429417375e+24 atm/m^3
#
# Current time: 5210000.0 s
# Average concentration: 1.6438261091016952e+24 atm/m^3
#
# Current time: 5220000.0 s
# Average concentration: 1.643829723302288e+24 atm/m^3
#
# Current time: 5230000.0 s
# Average concentration: 1.643833286289166e+24 atm/m^3
#
# Current time: 5240000.0 s
# Average concentration: 1.6438367987971097e+24 atm/m^3
#
# Current time: 5250000.0 s
# Average concentration: 1.6438402615501913e+24 atm/m^3
#
# Current time: 5260000.0 s
# Average concentration: 1.643843675261934e+24 atm/m^3
#
# Current time: 5270000.0 s
# Average concentration: 1.6438470406354713e+24 atm/m^3
#
# Current time: 5280000.0 s
# Average concentration: 1.643850358363694e+24 atm/m^3
#
# Current time: 5290000.0 s
# Average concentration: 1.6438536291294123e+24 atm/m^3
#
# Current time: 5300000.0 s
# Average concentration: 1.6438568536054976e+24 atm/m^3
#
# Current time: 5310000.0 s
# Average concentration: 1.643860032455031e+24 atm/m^3
#
# Current time: 5320000.0 s
# Average concentration: 1.6438631663314542e+24 atm/m^3
#
# Current time: 5330000.0 s
# Average concentration: 1.6438662558787044e+24 atm/m^3
#
# Current time: 5340000.0 s
# Average concentration: 1.64386930173136e+24 atm/m^3
#
# Current time: 5350000.0 s
# Average concentration: 1.6438723045147772e+24 atm/m^3
#
# Current time: 5360000.0 s
# Average concentration: 1.6438752648452316e+24 atm/m^3
#
# Current time: 5370000.0 s
# Average concentration: 1.6438781833300422e+24 atm/m^3
#
# Current time: 5380000.0 s
# Average concentration: 1.643881060567716e+24 atm/m^3
#
# Current time: 5390000.0 s
# Average concentration: 1.6438838971480673e+24 atm/m^3
#
# Current time: 5400000.0 s
# Average concentration: 1.6438866936523546e+24 atm/m^3
#
# Current time: 5410000.0 s
# Average concentration: 1.6438894506534026e+24 atm/m^3
#
# Current time: 5420000.0 s
# Average concentration: 1.6438921687157287e+24 atm/m^3
#
# Current time: 5430000.0 s
# Average concentration: 1.6438948483956656e+24 atm/m^3
#
# Current time: 5440000.0 s
# Average concentration: 1.64389749024148e+24 atm/m^3
#
# Current time: 5450000.0 s
# Average concentration: 1.6439000947934942e+24 atm/m^3
#
# Current time: 5460000.0 s
# Average concentration: 1.6439026625842028e+24 atm/m^3
#
# Current time: 5470000.0 s
# Average concentration: 1.6439051941383866e+24 atm/m^3
#
# Current time: 5480000.0 s
# Average concentration: 1.6439076899732295e+24 atm/m^3
#
# Current time: 5490000.0 s
# Average concentration: 1.6439101505984261e+24 atm/m^3
#
# Current time: 5500000.0 s
# Average concentration: 1.643912576516295e+24 atm/m^3
#
# Current time: 5510000.0 s
# Average concentration: 1.643914968221889e+24 atm/m^3
#
# Current time: 5520000.0 s
# Average concentration: 1.6439173262030975e+24 atm/m^3
#
# Current time: 5530000.0 s
# Average concentration: 1.6439196509407537e+24 atm/m^3
#
# Current time: 5540000.0 s
# Average concentration: 1.6439219429087414e+24 atm/m^3
#
# Current time: 5550000.0 s
# Average concentration: 1.6439242025740952e+24 atm/m^3
#
# Current time: 5560000.0 s
# Average concentration: 1.6439264303970985e+24 atm/m^3
#
# Current time: 5570000.0 s
# Average concentration: 1.6439286268313877e+24 atm/m^3
#
# Current time: 5580000.0 s
# Average concentration: 1.6439307923240454e+24 atm/m^3
#
# Current time: 5590000.0 s
# Average concentration: 1.6439329273157005e+24 atm/m^3
#
# Current time: 5600000.0 s
# Average concentration: 1.6439350322406196e+24 atm/m^3
#
# Current time: 5610000.0 s
# Average concentration: 1.643937107526805e+24 atm/m^3
#
# Current time: 5620000.0 s
# Average concentration: 1.6439391535960797e+24 atm/m^3
#
# Current time: 5630000.0 s
# Average concentration: 1.643941170864183e+24 atm/m^3
#
# Current time: 5640000.0 s
# Average concentration: 1.6439431597408607e+24 atm/m^3
#
# Current time: 5650000.0 s
# Average concentration: 1.6439451206299487e+24 atm/m^3
#
# Current time: 5660000.0 s
# Average concentration: 1.6439470539294658e+24 atm/m^3
#
# Current time: 5670000.0 s
# Average concentration: 1.6439489600316896e+24 atm/m^3
#
# Current time: 5680000.0 s
# Average concentration: 1.6439508393232505e+24 atm/m^3
#
# Current time: 5690000.0 s
# Average concentration: 1.6439526921852084e+24 atm/m^3
#
# Current time: 5700000.0 s
# Average concentration: 1.6439545189931355e+24 atm/m^3
#
# Current time: 5710000.0 s
# Average concentration: 1.643956320117198e+24 atm/m^3
#
# Current time: 5720000.0 s
# Average concentration: 1.6439580959222337e+24 atm/m^3
#
# Current time: 5730000.0 s
# Average concentration: 1.643959846767831e+24 atm/m^3
#
# Current time: 5740000.0 s
# Average concentration: 1.6439615730084053e+24 atm/m^3
#
# Current time: 5750000.0 s
# Average concentration: 1.6439632749932725e+24 atm/m^3
#
# Current time: 5760000.0 s
# Average concentration: 1.6439649530667265e+24 atm/m^3
#
# Current time: 5770000.0 s
# Average concentration: 1.6439666075681135e+24 atm/m^3
#
# Current time: 5780000.0 s
# Average concentration: 1.6439682388319005e+24 atm/m^3
#
# Current time: 5790000.0 s
# Average concentration: 1.643969847187749e+24 atm/m^3
#
# Current time: 5800000.0 s
# Average concentration: 1.6439714329605833e+24 atm/m^3
#
# Current time: 5810000.0 s
# Average concentration: 1.6439729964706618e+24 atm/m^3
#
# Current time: 5820000.0 s
# Average concentration: 1.6439745380336443e+24 atm/m^3
#
# Current time: 5830000.0 s
# Average concentration: 1.6439760579606584e+24 atm/m^3
#
# Current time: 5840000.0 s
# Average concentration: 1.6439775565583667e+24 atm/m^3
#
# Current time: 5850000.0 s
# Average concentration: 1.6439790341290302e+24 atm/m^3
#
# Current time: 5860000.0 s
# Average concentration: 1.6439804909705746e+24 atm/m^3
#
# Current time: 5870000.0 s
# Average concentration: 1.6439819273766532e+24 atm/m^3
#
# Current time: 5880000.0 s
# Average concentration: 1.6439833436367052e+24 atm/m^3
#
# Current time: 5890000.0 s
# Average concentration: 1.643984740036022e+24 atm/m^3
#
# Current time: 5900000.0 s
# Average concentration: 1.6439861168558064e+24 atm/m^3
#
# Current time: 5910000.0 s
# Average concentration: 1.6439874743732307e+24 atm/m^3
#
# Current time: 5920000.0 s
# Average concentration: 1.643988812861496e+24 atm/m^3
#
# Current time: 5930000.0 s
# Average concentration: 1.64399013258989e+24 atm/m^3
#
# Current time: 5940000.0 s
# Average concentration: 1.6439914338238432e+24 atm/m^3
#
# Current time: 5950000.0 s
# Average concentration: 1.643992716824988e+24 atm/m^3
#
# Current time: 5960000.0 s
# ...
#
# Current time: 8040000.0 s
# Average concentration: 1.6440786947188358e+24 atm/m^3
#
# Current time: 8050000.0 s
# Average concentration: 1.644078763156122e+24 atm/m^3
#
# Current time: 8060000.0 s
# Average concentration: 1.644078830652598e+24 atm/m^3
#
# Current time: 8070000.0 s
# Average concentration: 1.6440788972212522e+24 atm/m^3
#
# Current time: 8080000.0 s
# Average concentration: 1.6440789628748894e+24 atm/m^3
#
# Current time: 8090000.0 s
# Average concentration: 1.6440790276261388e+24 atm/m^3
#
# Current time: 8100000.0 s
# Average concentration: 1.6440790914874524e+24 atm/m^3
#
# Current time: 8110000.0 s
# Average concentration: 1.6440791544711112e+24 atm/m^3
#
# Current time: 8120000.0 s
# Average concentration: 1.6440792165892242e+24 atm/m^3
#
# Current time: 8130000.0 s
# Average concentration: 1.6440792778537354e+24 atm/m^3
#
# Current time: 8140000.0 s
# Average concentration: 1.6440793382764203e+24 atm/m^3
#
# Current time: 8150000.0 s
# Average concentration: 1.6440793978688913e+24 atm/m^3
#
# Current time: 8160000.0 s
# Average concentration: 1.6440794566426014e+24 atm/m^3
#
# Current time: 8170000.0 s
# Average concentration: 1.644079514608844e+24 atm/m^3
#
# Current time: 8180000.0 s
# Average concentration: 1.6440795717787552e+24 atm/m^3
#
# Current time: 8190000.0 s
# Average concentration: 1.6440796281633178e+24 atm/m^3
#
# Current time: 8200000.0 s
# Average concentration: 1.6440796837733628e+24 atm/m^3
#
# Current time: 8210000.0 s
# Average concentration: 1.6440797386195696e+24 atm/m^3
#
# Current time: 8220000.0 s
# Average concentration: 1.6440797927124702e+24 atm/m^3
#
# Current time: 8230000.0 s
# Average concentration: 1.6440798460624516e+24 atm/m^3
#
# Current time: 8240000.0 s
# Average concentration: 1.644079898679754e+24 atm/m^3
#
# Current time: 8250000.0 s
# Average concentration: 1.6440799505744807e+24 atm/m^3
#
# Current time: 8260000.0 s
# Average concentration: 1.64408000175659e+24 atm/m^3
#
# Current time: 8270000.0 s
# Average concentration: 1.6440800522359059e+24 atm/m^3
#
# Current time: 8280000.0 s
# Average concentration: 1.6440801020221137e+24 atm/m^3
#
# Current time: 8290000.0 s
# Average concentration: 1.6440801511247656e+24 atm/m^3
#
# Current time: 8300000.0 s
# Average concentration: 1.6440801995532822e+24 atm/m^3
#
# Current time: 8310000.0 s
# Average concentration: 1.6440802473169526e+24 atm/m^3
#
# Current time: 8320000.0 s
# Average concentration: 1.644080294424938e+24 atm/m^3
#
# Current time: 8330000.0 s
# Average concentration: 1.6440803408862713e+24 atm/m^3
#
# Current time: 8340000.0 s
# Average concentration: 1.6440803867098642e+24 atm/m^3
#
# Current time: 8350000.0 s
# Average concentration: 1.6440804319045015e+24 atm/m^3
#
# Current time: 8360000.0 s
# Average concentration: 1.6440804764788454e+24 atm/m^3
#
# Current time: 8370000.0 s
# Average concentration: 1.6440805204414421e+24 atm/m^3
#
# Current time: 8380000.0 s
# Average concentration: 1.644080563800717e+24 atm/m^3
#
# Current time: 8390000.0 s
# Average concentration: 1.6440806065649784e+24 atm/m^3
#
# Current time: 8400000.0 s
# Average concentration: 1.6440806487424224e+24 atm/m^3
#
# Current time: 8410000.0 s
# Average concentration: 1.6440806903411303e+24 atm/m^3
#
# Current time: 8420000.0 s
# Average concentration: 1.6440807313690698e+24 atm/m^3
#
# Current time: 8430000.0 s
# Average concentration: 1.6440807718341007e+24 atm/m^3
#
# Current time: 8440000.0 s
# Average concentration: 1.6440808117439735e+24 atm/m^3
#
# Current time: 8450000.0 s
# Average concentration: 1.6440808511063306e+24 atm/m^3
#
# Current time: 8460000.0 s
# Average concentration: 1.6440808899287096e+24 atm/m^3
#
# Current time: 8470000.0 s
# Average concentration: 1.6440809282185436e+24 atm/m^3
#
# Current time: 8480000.0 s
# Average concentration: 1.6440809659831637e+24 atm/m^3
#
# Current time: 8490000.0 s
# Average concentration: 1.6440810032297982e+24 atm/m^3
#
# Current time: 8500000.0 s
# Average concentration: 1.6440810399655766e+24 atm/m^3
#
# Current time: 8510000.0 s
# Average concentration: 1.6440810761975285e+24 atm/m^3
#
# Current time: 8520000.0 s
# Average concentration: 1.6440811119325885e+24 atm/m^3
#
# Current time: 8530000.0 s
# Average concentration: 1.6440811471775937e+24 atm/m^3
#
# Current time: 8540000.0 s
# Average concentration: 1.6440811819392873e+24 atm/m^3
#
# Current time: 8550000.0 s
# Average concentration: 1.6440812162243182e+24 atm/m^3
#
# Current time: 8560000.0 s
# Average concentration: 1.6440812500392456e+24 atm/m^3
#
# Current time: 8570000.0 s
# Average concentration: 1.644081283390536e+24 atm/m^3
#
# Current time: 8580000.0 s
# Average concentration: 1.6440813162845675e+24 atm/m^3
#
# Current time: 8590000.0 s
# Average concentration: 1.6440813487276303e+24 atm/m^3
#
# Current time: 8600000.0 s
# Average concentration: 1.6440813807259288e+24 atm/m^3
#
# Current time: 8610000.0 s
# Average concentration: 1.6440814122855777e+24 atm/m^3
#
# Current time: 8620000.0 s
# Average concentration: 1.644081443412611e+24 atm/m^3
#
# Current time: 8630000.0 s
# Average concentration: 1.6440814741129776e+24 atm/m^3
#
# Current time: 8640000.0 s
# Average concentration: 1.6440815043925446e+24 atm/m^3
#
# Current time: 8650000.0 s
# Average concentration: 1.6440815342571004e+24 atm/m^3
#
# Current time: 8660000.0 s
# Average concentration: 1.6440815637123493e+24 atm/m^3
#
# Current time: 8670000.0 s
# Average concentration: 1.6440815927639193e+24 atm/m^3
#
# Current time: 8680000.0 s
# Average concentration: 1.6440816214173614e+24 atm/m^3
#
# Current time: 8690000.0 s
# Average concentration: 1.6440816496781475e+24 atm/m^3
#
# Current time: 8700000.0 s
# Average concentration: 1.644081677551677e+24 atm/m^3
#
# Current time: 8710000.0 s
# Average concentration: 1.6440817050432708e+24 atm/m^3
#
# Current time: 8720000.0 s
# Average concentration: 1.6440817321581803e+24 atm/m^3
#
# Current time: 8730000.0 s
# Average concentration: 1.6440817589015828e+24 atm/m^3
#
# Current time: 8740000.0 s
# Average concentration: 1.644081785278583e+24 atm/m^3
#
# Current time: 8750000.0 s
# Average concentration: 1.6440818112942184e+24 atm/m^3
#
# Current time: 8760000.0 s
# Average concentration: 1.6440818369534528e+24 atm/m^3
#
# Current time: 8770000.0 s
# Average concentration: 1.644081862261185e+24 atm/m^3
#
# Current time: 8780000.0 s
# Average concentration: 1.644081887222245e+24 atm/m^3
#
# Current time: 8790000.0 s
# Average concentration: 1.6440819118413948e+24 atm/m^3
#
# Current time: 8800000.0 s
# Average concentration: 1.6440819361233325e+24 atm/m^3
#
# Current time: 8810000.0 s
# Average concentration: 1.6440819600726913e+24 atm/m^3
#
# Current time: 8820000.0 s
# Average concentration: 1.6440819836940395e+24 atm/m^3
#
# Current time: 8830000.0 s
# Average concentration: 1.644082006991884e+24 atm/m^3
#
# Current time: 8840000.0 s
# Average concentration: 1.6440820299706668e+24 atm/m^3
#
# Current time: 8850000.0 s
# Average concentration: 1.6440820526347714e+24 atm/m^3
#
# Current time: 8860000.0 s
# Average concentration: 1.6440820749885196e+24 atm/m^3
#
# Current time: 8870000.0 s
# Average concentration: 1.6440820970361737e+24 atm/m^3
#
# Current time: 8880000.0 s
# Average concentration: 1.6440821187819367e+24 atm/m^3
#
# Current time: 8890000.0 s
# Average concentration: 1.6440821402299562e+24 atm/m^3
#
# Current time: 8900000.0 s
# Average concentration: 1.6440821613843191e+24 atm/m^3
#
# Current time: 8910000.0 s
# Average concentration: 1.6440821822490582e+24 atm/m^3
#
# Current time: 8920000.0 s
# Average concentration: 1.6440822028281505e+24 atm/m^3
#
# Current time: 8930000.0 s
# Average concentration: 1.6440822231255166e+24 atm/m^3
#
# Current time: 8940000.0 s
# Average concentration: 1.6440822431450252e+24 atm/m^3
#
# Current time: 8950000.0 s
# Average concentration: 1.6440822628904907e+24 atm/m^3
#
# Current time: 8960000.0 s
# Average concentration: 1.6440822823656752e+24 atm/m^3
#
# Current time: 8970000.0 s
# Average concentration: 1.6440823015742877e+24 atm/m^3
#
# Current time: 8980000.0 s
# Average concentration: 1.644082320519989e+24 atm/m^3
#
# Current time: 8990000.0 s
# Average concentration: 1.6440823392063875e+24 atm/m^3
#
# Current time: 9000000.0 s
# Average concentration: 1.6440823576370397e+24 atm/m^3
#
# Current time: 9010000.0 s
# Average concentration: 1.6440823758154577e+24 atm/m^3
#
# Current time: 9020000.0 s
# Average concentration: 1.6440823937451022e+24 atm/m^3
#
# Current time: 9030000.0 s
# Average concentration: 1.6440824114293871e+24 atm/m^3
#
# Current time: 9040000.0 s
# Average concentration: 1.6440824288716796e+24 atm/m^3
#
# Current time: 9050000.0 s
# Average concentration: 1.6440824460752997e+24 atm/m^3
#
# Current time: 9060000.0 s
# Average concentration: 1.6440824630435228e+24 atm/m^3
#
# Current time: 9070000.0 s
# Average concentration: 1.6440824797795775e+24 atm/m^3
#
# Current time: 9080000.0 s
# Average concentration: 1.6440824962866497e+24 atm/m^3
#
# Current time: 9090000.0 s
# Average concentration: 1.6440825125678794e+24 atm/m^3
#
# Current time: 9100000.0 s
# Average concentration: 1.6440825286263675e+24 atm/m^3
#
# Current time: 9110000.0 s
# Average concentration: 1.6440825444651662e+24 atm/m^3
#
# Current time: 9120000.0 s
# Average concentration: 1.6440825600872918e+24 atm/m^3
#
# Current time: 9130000.0 s
# Average concentration: 1.6440825754957138e+24 atm/m^3
#
# Current time: 9140000.0 s
# Average concentration: 1.644082590693364e+24 atm/m^3
#
# Current time: 9150000.0 s
# Average concentration: 1.6440826056831338e+24 atm/m^3
#
# Current time: 9160000.0 s
# Average concentration: 1.6440826204678742e+24 atm/m^3
#
# Current time: 9170000.0 s
# Average concentration: 1.6440826350503952e+24 atm/m^3
#
# Current time: 9180000.0 s
# Average concentration: 1.6440826494334714e+24 atm/m^3
#
# Current time: 9190000.0 s
# Average concentration: 1.6440826636198372e+24 atm/m^3
#
# Current time: 9200000.0 s
# Average concentration: 1.64408267761219e+24 atm/m^3
#
# Current time: 9210000.0 s
# Average concentration: 1.6440826914131896e+24 atm/m^3
#
# Current time: 9220000.0 s
# Average concentration: 1.6440827050254581e+24 atm/m^3
#
# Current time: 9230000.0 s
# Average concentration: 1.644082718451585e+24 atm/m^3
#
# Current time: 9240000.0 s
# Average concentration: 1.6440827316941213e+24 atm/m^3
#
# Current time: 9250000.0 s
# Average concentration: 1.6440827447555842e+24 atm/m^3
#
# Current time: 9260000.0 s
# Average concentration: 1.6440827576384545e+24 atm/m^3
#
# Current time: 9270000.0 s
# Average concentration: 1.644082770345181e+24 atm/m^3
#
# Current time: 9280000.0 s
# Average concentration: 1.6440827828781788e+24 atm/m^3
#
# Current time: 9290000.0 s
# Average concentration: 1.6440827952398278e+24 atm/m^3
#
# Current time: 9300000.0 s
# Average concentration: 1.6440828074324765e+24 atm/m^3
#
# Current time: 9310000.0 s
# Average concentration: 1.644082819458441e+24 atm/m^3
#
# Current time: 9320000.0 s
# Average concentration: 1.644082831320006e+24 atm/m^3
#
# Current time: 9330000.0 s
# Average concentration: 1.6440828430194253e+24 atm/m^3
#
# Current time: 9340000.0 s
# Average concentration: 1.6440828545589187e+24 atm/m^3
#
# Current time: 9350000.0 s
# Average concentration: 1.6440828659406792e+24 atm/m^3
#
# Current time: 9360000.0 s
# Average concentration: 1.6440828771668666e+24 atm/m^3
#
# Current time: 9370000.0 s
# Average concentration: 1.6440828882396126e+24 atm/m^3
#
# Current time: 9380000.0 s
# Average concentration: 1.64408289916102e+24 atm/m^3
#
# Current time: 9390000.0 s
# Average concentration: 1.6440829099331627e+24 atm/m^3
#
# Current time: 9400000.0 s
# Average concentration: 1.6440829205580848e+24 atm/m^3
#
# Current time: 9410000.0 s
# Average concentration: 1.6440829310378028e+24 atm/m^3
#
# Current time: 9420000.0 s
# Average concentration: 1.6440829413743057e+24 atm/m^3
#
# Current time: 9430000.0 s
# Average concentration: 1.6440829515695558e+24 atm/m^3
#
# Current time: 9440000.0 s
# Average concentration: 1.6440829616254886e+24 atm/m^3
#
# Current time: 9450000.0 s
# Average concentration: 1.6440829715440107e+24 atm/m^3
#
# Current time: 9460000.0 s
# Average concentration: 1.6440829813270037e+24 atm/m^3
#
# Current time: 9470000.0 s
# Average concentration: 1.644082990976325e+24 atm/m^3
#
# Current time: 9480000.0 s
# Average concentration: 1.644083000493805e+24 atm/m^3
#
# Current time: 9490000.0 s
# Average concentration: 1.6440830098812495e+24 atm/m^3
#
# Current time: 9500000.0 s
# Average concentration: 1.6440830191404375e+24 atm/m^3
#
# Current time: 9510000.0 s
# Average concentration: 1.6440830282731268e+24 atm/m^3
#
# Current time: 9520000.0 s
# Average concentration: 1.6440830372810495e+24 atm/m^3
#
# Current time: 9530000.0 s
# Average concentration: 1.6440830461659136e+24 atm/m^3
#
# Current time: 9540000.0 s
# Average concentration: 1.6440830549294035e+24 atm/m^3
#
# Current time: 9550000.0 s
# Average concentration: 1.6440830635731814e+24 atm/m^3
#
# Current time: 9560000.0 s
# Average concentration: 1.644083072098886e+24 atm/m^3
#
# Current time: 9570000.0 s
# Average concentration: 1.6440830805081336e+24 atm/m^3
#
# Current time: 9580000.0 s
# Average concentration: 1.644083088802518e+24 atm/m^3
#
# Current time: 9590000.0 s
# Average concentration: 1.644083096983612e+24 atm/m^3
#
# Current time: 9600000.0 s
# Average concentration: 1.644083105052967e+24 atm/m^3
#
# Current time: 9610000.0 s
# Average concentration: 1.644083113012111e+24 atm/m^3
#
# Current time: 9620000.0 s
# Average concentration: 1.6440831208625532e+24 atm/m^3
#
# Current time: 9630000.0 s
# Average concentration: 1.644083128605781e+24 atm/m^3
#
# Current time: 9640000.0 s
# Average concentration: 1.6440831362432627e+24 atm/m^3
#
# Current time: 9650000.0 s
# Average concentration: 1.644083143776445e+24 atm/m^3
#
# Current time: 9660000.0 s
# Average concentration: 1.6440831512067546e+24 atm/m^3
#
# Current time: 9670000.0 s
# Average concentration: 1.6440831585356006e+24 atm/m^3
#
# Current time: 9680000.0 s
# Average concentration: 1.6440831657643701e+24 atm/m^3
#
# Current time: 9690000.0 s
# Average concentration: 1.6440831728944333e+24 atm/m^3
#
# Current time: 9700000.0 s
# Average concentration: 1.6440831799271405e+24 atm/m^3
#
# Current time: 9710000.0 s
# Average concentration: 1.644083186863823e+24 atm/m^3
#
# Current time: 9720000.0 s
# Average concentration: 1.6440831937057958e+24 atm/m^3
#
# Current time: 9730000.0 s
# Average concentration: 1.6440832004543545e+24 atm/m^3
#
# Current time: 9740000.0 s
# Average concentration: 1.6440832071107772e+24 atm/m^3
#
# Current time: 9750000.0 s
# Average concentration: 1.6440832136763227e+24 atm/m^3
#
# Current time: 9760000.0 s
# Average concentration: 1.644083220152236e+24 atm/m^3
#
# Current time: 9770000.0 s
# Average concentration: 1.6440832265397422e+24 atm/m^3
#
# Current time: 9780000.0 s
# Average concentration: 1.6440832328400518e+24 atm/m^3
#
# Current time: 9790000.0 s
# Average concentration: 1.6440832390543565e+24 atm/m^3
#
# Current time: 9800000.0 s
# Average concentration: 1.6440832451838323e+24 atm/m^3
#
# Current time: 9810000.0 s
# Average concentration: 1.6440832512296414e+24 atm/m^3
#
# Current time: 9820000.0 s
# Average concentration: 1.6440832571929262e+24 atm/m^3
#
# Current time: 9830000.0 s
# Average concentration: 1.644083263074816e+24 atm/m^3
#
# Current time: 9840000.0 s
# Average concentration: 1.6440832688764243e+24 atm/m^3
#
# Current time: 9850000.0 s
# Average concentration: 1.644083274598848e+24 atm/m^3
#
# Current time: 9860000.0 s
# Average concentration: 1.6440832802431701e+24 atm/m^3
#
# Current time: 9870000.0 s
# Average concentration: 1.6440832858104592e+24 atm/m^3
#
# Current time: 9880000.0 s
# Average concentration: 1.644083291301768e+24 atm/m^3
#
# Current time: 9890000.0 s
# Average concentration: 1.644083296718137e+24 atm/m^3
#
# Current time: 9900000.0 s
# Average concentration: 1.6440833020605888e+24 atm/m^3
#
# Current time: 9910000.0 s
# Average concentration: 1.644083307330135e+24 atm/m^3
#
# Current time: 9920000.0 s
# Average concentration: 1.644083312527772e+24 atm/m^3
#
# Current time: 9930000.0 s
# Average concentration: 1.6440833176544836e+24 atm/m^3
#
# Current time: 9940000.0 s
# Average concentration: 1.6440833227112388e+24 atm/m^3
#
# Current time: 9950000.0 s
# Average concentration: 1.644083327698995e+24 atm/m^3
#
# Current time: 9960000.0 s
# Average concentration: 1.6440833326186943e+24 atm/m^3
#
# Current time: 9970000.0 s
# Average concentration: 1.6440833374712673e+24 atm/m^3
#
# Current time: 9980000.0 s
# Average concentration: 1.6440833422576312e+24 atm/m^3
#
# Current time: 9990000.0 s
# Average concentration: 1.6440833469786912e+24 atm/m^3
#
# Final time: 10000000.0 s
# Average concentration: 1.644083351635342e+24 atm/m^3
#
#
# Error bound: 0.0006289922335460917
# Error exact: 7.171285288965996e-05

# %% [markdown]
# #### SAVE ESSENTIAL FILES

# %%
# Save essentail files:
np.save('model_files/FF_FO.npy', forc_C)
np.save('model_files/XX_FO.npy', np.array([mass_C]))
np.save('model_files/YY_FO.npy', np.array([stiff_C]))
np.save('model_files/KK_FO.npy', list_basis_stiff_C)
np.save('model_files/CC_FO.npy', list_coerc_stiff_C)
np.save('model_files/ZZ_FO.npy', INT_CZZ)
np.save('model_files/II_FO.npy', mapDAtoCO)
np.save('model_files/AA_FO.npy', inte_C)

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import numpy as np
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import time
import sys
import json
import h5py
import time

# Import user defined libraries:
from solver_class import FiniteElementCylinderSolver, ReducedBasisCylinderSolver

# %%
# #Define size of the training parameter set:
# sTR = 10000
# FISSION_ENERGY = 3.215e-11

# # Define parameters ranges:
# MIN_FR, MAX_FR = 0, 5.00E+19        
# MIN_K, MAX_K =  0.9, 8    
# MIN_FY, MAX_FY = 0.00, 0.3
# MIN_LL, MAX_LL = 0.1E-3, 1.25E-3
# MIN_RR, MAX_RR = 0.75E-5, 1.25E-5
# MIN_BC, MAX_BC = 0, 2.5E+03         

# # Compute a list of random parameters within the range:
# LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR)) 
# LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
# LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
# LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
# LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
# LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
# LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# %% [markdown]
# #### POD-GREEDY

# %%
import numpy as np 
loaded_data = np.load('checkpoint/training_set.npz')
LIST_FR = loaded_data['FR']
LIST_BC = loaded_data['BC']
LIST_LL = loaded_data['LL']
LIST_RR = loaded_data['RR']
LIST_FY = loaded_data['FY']
LIST_K = loaded_data['K']
LIST_GG = loaded_data['GG']

sTR = LIST_BC.shape[0]

# %%
#############################
##### SAVE CHECKPOINT #######
#############################
def salva_checkpoint(step, cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, basis, cur_err_bounds, elapsed_time):
    import os
    worst_error = cur_err_bounds[np.argmax(cur_err_bounds)]  # Salva il valore dell'errore massimo
    
    # Creazione della cartella per lo step corrente
    step_folder = f"checkpoint/step_{step}"
    os.makedirs(step_folder, exist_ok=True)

    # Salvataggio dei parametri in formato JSON
    data = {
        "N_AVOG": 6.022141E+23,
        "N_BOLT": 1.380649E-23,
        "FISSION_ENERGY": 3.215E-11,
        "FISSION_RATE": cur_FR,
        "FUEL_THERMAL_CONDUCTIVITY": cur_K,
        "FISSION_YIELD": cur_FY,
        "LENGTH": cur_LL,
        "RADIUS": cur_RR,
        "T_BC": cur_BC,
        "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)],
        "TIME_ELAPSED": elapsed_time
    }

    json_path = os.path.join(step_folder, "worst_reconstructed_parameters.json")
    with open(json_path, "w") as json_file:
        json.dump(data, json_file, indent=4)
    # with open("checkpoint/worst reconstructed parameters.json", "w") as json_file:
    #     json.dump(data, json_file, indent=4)

    # Salvataggio delle matrici in un file HDF5
    hdf5_path = os.path.join(step_folder, "matrici_RB.h5")
    with h5py.File(hdf5_path, 'w') as hf:
    #with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
        hf.create_dataset('MM_RB', data=MM_RB)
        hf.create_dataset('FF_RB', data=FF_RB)
        hf.create_dataset('KK_RB', data=KK_RB)
        hf.create_dataset('AA_RB', data=AA_RB)
        hf.create_dataset('ZZ_CO', data=ZZ_CO)
        hf.create_dataset('II_CO', data=II_CO)
        hf.create_dataset('basis', data=basis)

    return worst_error

#############################
##### LOAD CHECKPOINT #######
#############################
import os
def carica_checkpoint():
    try:
        # Caricamento dei parametri dal file JSON
        with open("checkpoint/worst_reconstructed_parameters.json", "r") as json_file:
            data = json.load(json_file)
        cur_BC = data["T_BC"]
        cur_FR = data["FISSION_RATE"]
        cur_LL = data["LENGTH"]
        cur_RR = data["RADIUS"]
        cur_FY = data["FISSION_YIELD"]
        cur_K = data["FUEL_THERMAL_CONDUCTIVITY"]
        elapsed_time = data["TIME_ELAPSED"]

        # Caricamento delle basi dal file HDF5
        with h5py.File('checkpoint/matrici_RB.h5', 'r') as hf:
            basis = hf['basis'][:]
    
    except FileNotFoundError:
        # Se i file non sono trovati, imposta i parametri di default e matrici vuote
        print("Checkpoint files not found. Starting from scratch.")
        
        # Parametri di default
        cur_FR = 3.00E+19
        cur_K = 2.208
        cur_FY = 2.40E-01
        cur_LL = 1.00E-03
        cur_RR = 1.00E-05
        cur_BC = 2.00E+03
        
        basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
        elapsed_time = 0  # Inizio da zero
    
    return cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, basis, elapsed_time

# %%
start_time = time.time()
# cur_FR = 3.00E+19
# cur_K = 2.208
# cur_FY = 2.40E-01
# cur_LL = 1.00E-03
# cur_RR = 1.00E-05
# cur_BC = 2.00E+03
cur_dt = 1.00E+04
step = 41

#Define empty basis functions matrix and empty list of error bounds:
#cur_basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
cur_err_bounds = np.empty((sTR))

cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, cur_basis, check_point_elapsed_time = carica_checkpoint()

cost_FO = 0 
cost_POD = 0
cost_EB = 0
# Enter reduced basis space loop:
new_sRB = np.inf
while new_sRB > 0:
    
    # Assemble full order model and compute full order solution associated with the current parameter selection:
    t0 = time.time()
    solver_FO = FiniteElementCylinderSolver()
    solver_FO.assemble(RADIUS=cur_RR, LENGTH=cur_LL, F_RATE=cur_FR, F_YIELD=cur_FY, T_BC=cur_BC, KTH=cur_K, dt=cur_dt)
    solution_FO = solver_FO.solve(n_steps=1000, verbose=False)
    cost_FO += time.time()-t0

    # Compute orthogonal complement to the basis function and solution energy:
    t0 = time.time()
    orthogonal_FO = solution_FO - cur_basis @ np.linalg.solve(cur_basis.T @ solver_FO.XX_FO @ cur_basis, cur_basis.T @ solver_FO.XX_FO @ solution_FO)
    solution_energy_FO = np.einsum('ik,ik', solver_FO.XX_FO @ solution_FO, solution_FO)
    
    # Extract the POD basis from the full order solution:
    AA, GG, BB = np.linalg.svd(orthogonal_FO.T @ solver_FO.XX_FO @ orthogonal_FO, full_matrices=False)
    new_sRB = np.sum([np.sqrt(np.sum(GG[ii:]) / solution_energy_FO) > 1e-5 for ii in range(len(GG))])
    cur_basis = np.hstack((cur_basis, orthogonal_FO @ AA[:, :new_sRB] @ np.diag(np.reciprocal(np.sqrt(GG[:new_sRB])))))
    cost_POD += time.time()-t0

    # Assemble reduced basis model:
    t0 = time.time()
    solver_RB = ReducedBasisCylinderSolver(cur_basis)
    for kk in range(sTR):
        solver_RB.assemble(F_YIELD=cur_FY, F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], KTH=LIST_K[kk], dt=cur_dt)

        # Compute current reduced basis solution and error bound:
        solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
    cost_EB += time.time()-t0

    # Identify new parameters where to evaluate the full order model:
    #cur_FY = cur_FY
    cur_FY = LIST_FY[np.argmax(cur_err_bounds)]
    cur_FR = LIST_FR[np.argmax(cur_err_bounds)]
    cur_BC = LIST_BC[np.argmax(cur_err_bounds)]
    cur_LL = LIST_LL[np.argmax(cur_err_bounds)]
    cur_RR = LIST_RR[np.argmax(cur_err_bounds)]
    cur_K = LIST_K[np.argmax(cur_err_bounds)]

    # Show worse reconstructed parameter configuration:
    print("The current reduced basis size is", cur_basis.shape[1])
    print("The selected Fission Rate is", cur_FR, "f/s")
    print("The selected Fuel Thermal Conductivity is", cur_K, "W/(m K)")
    print("The selected Fission Yield is", cur_FY, "at/fiss")
    print("The selected Grain Length is", cur_LL, "m")
    print("The selected Grain Radius is", cur_RR, "m")
    print("The selected Boundary Temperature is", cur_BC, "K")

    current_time = time.time()
    elapsed_time = current_time - start_time 
    total_elapsed_time = elapsed_time + check_point_elapsed_time 

    # Salvataggio dello stato dopo ogni ciclo
    MM_RB = solver_RB.XX_RB    #matrice di massa. 2D
    FF_RB = solver_RB.FF_RB    #funzionalità contro il vettore unitario. 1D
    KK_RB = solver_RB.KK_RB    #basi della decomposizione affine della stiffness. 3D
    AA_RB = solver_RB.AA_RB    #l'integratore per calcolare il valor medio sul volume data la soluzione ridotta, questo può essere sostituito dalla funzione che calcola il valor medio su diversi slice. 1D
    ZZ_CO = solver_RB.ZZ_FO    #coordinate a cui dobbiamo valutare la temperatura. 1D
    II_CO = solver_RB.II_FO    #coefficienti che mappano i valori del coefficiente di diffusione valutata sulle temperature nei coefficienti di combinazione lineare della decomposizione affine. 2D
    basis = cur_basis 

    #worst_error = cur_err_bounds[np.argmax(cur_err_bounds)]
    worst_error = salva_checkpoint(step, cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, cur_basis, cur_err_bounds, total_elapsed_time)
    print(f"Maximum cur_err_bounds: {worst_error}")
    print(f"Elapsed time during this simulation: {elapsed_time / 60:.2f} minutes")
    print(f"Overall elapsed time (considering also the checkpoint): {total_elapsed_time/ 60:.2f} minutes\n")

    # Incrementa il contatore dello step
    step += 1
print(rf'Il tempo impiegato dal FO = {cost_FO}, Il tempo impiegato dalla POD = {cost_POD}, Il tempo impiegato da error bound = {cost_EB}')
# Out:
# Checkpoint files not found. Starting from scratch.
# The current reduced basis size is 9
# The selected Fission Rate is 1.0790107138614058e+16 f/s
# The selected Fuel Thermal Conductivity is 5.753328875969315 W/(m K)
# The selected Fission Yield is 0.24274509177761872 at/fiss
# The selected Grain Length is 0.0012054350390584248 m
# The selected Grain Radius is 1.0350207245772175e-05 m
# The selected Boundary Temperature is 858.6776673824936 K
# Maximum cur_err_bounds: 46.790837491152196
# Elapsed time during this simulation: 0.58 minutes
# Overall elapsed time (considering also the checkpoint): 0.58 minutes
#
# The current reduced basis size is 12
# The selected Fission Rate is 4.686786747338653e+19 f/s
# The selected Fuel Thermal Conductivity is 1.5239285222621963 W/(m K)
# The selected Fission Yield is 0.22443492265558618 at/fiss
# The selected Grain Length is 0.00010388224642449789 m
# The selected Grain Radius is 1.1870842522114192e-05 m
# The selected Boundary Temperature is 2310.0810075170675 K
# Maximum cur_err_bounds: 26.229747651841105
# Elapsed time during this simulation: 1.18 minutes
# Overall elapsed time (considering also the checkpoint): 1.18 minutes
#
# The current reduced basis size is 18
# The selected Fission Rate is 3.892262310377348e+18 f/s
# The selected Fuel Thermal Conductivity is 6.951970532824371 W/(m K)
# The selected Fission Yield is 0.23401507246437933 at/fiss
# The selected Grain Length is 0.00010881430093481013 m
# The selected Grain Radius is 1.0953272014795503e-05 m
# The selected Boundary Temperature is 778.1869338899209 K
# Maximum cur_err_bounds: 1.4374367710797453
# Elapsed time during this simulation: 1.88 minutes
# Overall elapsed time (considering also the checkpoint): 1.88 minutes
#
# The current reduced basis size is 23
# The selected Fission Rate is 4.681802965436679e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1567514524195295 W/(m K)
# The selected Fission Yield is 0.19051208573468825 at/fiss
# The selected Grain Length is 0.0012269039313312592 m
# The selected Grain Radius is 1.1472677402459275e-05 m
# The selected Boundary Temperature is 800.5166059001679 K
# Maximum cur_err_bounds: 0.43048641225809814
# Elapsed time during this simulation: 2.69 minutes
# Overall elapsed time (considering also the checkpoint): 2.69 minutes
#
# The current reduced basis size is 31
# The selected Fission Rate is 4.6770088436675265e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9458030851786468 W/(m K)
# The selected Fission Yield is 0.15162866799581787 at/fiss
# The selected Grain Length is 0.0002575690019352677 m
# The selected Grain Radius is 1.0891984852778886e-05 m
# The selected Boundary Temperature is 1997.8963733149326 K
# Maximum cur_err_bounds: 0.41594615599596985
# Elapsed time during this simulation: 3.63 minutes
# Overall elapsed time (considering also the checkpoint): 3.63 minutes
#
# The current reduced basis size is 38
# The selected Fission Rate is 4.409078535552821e+19 f/s
# The selected Fuel Thermal Conductivity is 2.2546042474911956 W/(m K)
# The selected Fission Yield is 0.0571139387875822 at/fiss
# The selected Grain Length is 0.00010195008951490384 m
# The selected Grain Radius is 1.2003325328793065e-05 m
# The selected Boundary Temperature is 637.7223880925534 K
# Maximum cur_err_bounds: 0.25010155538680623
# Elapsed time during this simulation: 4.73 minutes
# Overall elapsed time (considering also the checkpoint): 4.73 minutes
#
# The current reduced basis size is 43
# The selected Fission Rate is 4.9550559254492045e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0970019710232255 W/(m K)
# The selected Fission Yield is 0.04905942913993181 at/fiss
# The selected Grain Length is 0.0010793370811107447 m
# The selected Grain Radius is 1.0992465036521727e-05 m
# The selected Boundary Temperature is 1546.5921480287486 K
# Maximum cur_err_bounds: 0.2219120283784277
# Elapsed time during this simulation: 6.12 minutes
# Overall elapsed time (considering also the checkpoint): 6.12 minutes
#
# The current reduced basis size is 52
# The selected Fission Rate is 8.102161811036402e+17 f/s
# The selected Fuel Thermal Conductivity is 6.079205851758932 W/(m K)
# The selected Fission Yield is 0.18830288322488972 at/fiss
# The selected Grain Length is 0.0002687653919821633 m
# The selected Grain Radius is 9.496811940905669e-06 m
# The selected Boundary Temperature is 2244.5156706396356 K
# Maximum cur_err_bounds: 0.11671002800715102
# Elapsed time during this simulation: 7.81 minutes
# Overall elapsed time (considering also the checkpoint): 7.81 minutes
#
# The current reduced basis size is 55
# The selected Fission Rate is 4.706908256063123e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0308958966974129 W/(m K)
# The selected Fission Yield is 0.09201827407150906 at/fiss
# The selected Grain Length is 0.001170891365962639 m
# The selected Grain Radius is 1.1546855855587505e-05 m
# The selected Boundary Temperature is 401.3706148062318 K
# Maximum cur_err_bounds: 0.08783887470472461
# Elapsed time during this simulation: 9.59 minutes
# Overall elapsed time (considering also the checkpoint): 9.59 minutes
#
# The current reduced basis size is 62
# The selected Fission Rate is 9.235152689523462e+16 f/s
# The selected Fuel Thermal Conductivity is 5.736571410838148 W/(m K)
# The selected Fission Yield is 0.26187419996650885 at/fiss
# The selected Grain Length is 0.001180443443601056 m
# The selected Grain Radius is 7.74652255131481e-06 m
# The selected Boundary Temperature is 2384.78883511732 K
# Maximum cur_err_bounds: 0.05670856762813929
# Elapsed time during this simulation: 11.59 minutes
# Overall elapsed time (considering also the checkpoint): 11.59 minutes
#
# The current reduced basis size is 65
# The selected Fission Rate is 1.6029965942381087e+19 f/s
# The selected Fuel Thermal Conductivity is 6.134647093032057 W/(m K)
# The selected Fission Yield is 0.05414964175564022 at/fiss
# The selected Grain Length is 0.0012485509460277975 m
# The selected Grain Radius is 8.023678297205439e-06 m
# The selected Boundary Temperature is 726.0579054077324 K
# Maximum cur_err_bounds: 0.04712057777356082
# Elapsed time during this simulation: 14.20 minutes
# Overall elapsed time (considering also the checkpoint): 14.20 minutes
#
# The current reduced basis size is 69
# The selected Fission Rate is 4.996121416130112e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9789576847004605 W/(m K)
# The selected Fission Yield is 0.24055211219427688 at/fiss
# The selected Grain Length is 0.0011646674781088226 m
# The selected Grain Radius is 9.57828096710532e-06 m
# The selected Boundary Temperature is 1727.346949134678 K
# Maximum cur_err_bounds: 0.04226254296743523
# Elapsed time during this simulation: 17.02 minutes
# Overall elapsed time (considering also the checkpoint): 17.02 minutes
#
# The current reduced basis size is 78
# The selected Fission Rate is 2.021675826676788e+19 f/s
# The selected Fuel Thermal Conductivity is 6.6023641276565215 W/(m K)
# The selected Fission Yield is 0.20369207776360837 at/fiss
# The selected Grain Length is 0.00012453054343726278 m
# The selected Grain Radius is 9.487852585687289e-06 m
# The selected Boundary Temperature is 1350.6849436377772 K
# Maximum cur_err_bounds: 0.02533487107669747
# Elapsed time during this simulation: 20.30 minutes
# Overall elapsed time (considering also the checkpoint): 20.30 minutes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 49
#      46     solver_RB.assemble(F_YIELD=cur_FY, F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], KTH=LIST_K[kk], dt=cur_dt)
#      48     # Compute current reduced basis solution and error bound:
# ---> 49     solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
#      50 cost_EB += time.time()-t0
#      52 # Identify new parameters where to evaluate the full order model:
#      53 #cur_FY = cur_FY
#
# File ~/Library/CloudStorage/OneDrive-PolitecnicodiMilano/PhD/Git/rom-cylinder_DEIM-POD/offline-online stages/model_2d/solver_class.py:201, in ReducedBasisCylinderSolver.solve(self, n_steps, verbose, error_bound)
#     199 solution = np.zeros((self.sRB, n_steps+1))
#     200 for ii in range(n_steps):
# --> 201     solution[:, ii+1] = sp.linalg.lu_solve((self.LU, self.PIV), self.RHS_static[:, 0] + self.XX_RB.dot(solution[: , ii]))
#     203     # Print current iteration and average temperature and concentration:
#     204     if verbose:
#
# KeyboardInterrupt:

# %%
cur_err_bounds[np.argmax(cur_err_bounds)]
# Out:
# np.float64(0.02511927102840516)

# %%
#np.savez('checkpoint/training_set.npz', FR=LIST_FR, BC=LIST_BC, LL=LIST_LL, RR=LIST_RR, FY=LIST_FY, K=LIST_K, GG=LIST_GG)

# %%
import json
# Parametri con nomi diretti
data = {
    "N_AVOG": 6.022141E+23,
    "N_BOLT": 1.380649E-23,
    "FISSION_ENERGY": 3.215E-11,
    "FISSION_RATE": cur_FR,
    "FUEL_THERMAL_CONDUCTIVITY": cur_K,
    "FISSION_YIELD": cur_FY,
    "LENGTH": cur_LL,
    "RADIUS": cur_RR,
    "T_BC": cur_BC,
    "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)], 
    "TIME_ELAPSED": total_elapsed_time
}

# Scrittura su file JSON
with open("checkpoint/worst reconstructed parameters.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# %%
MM_RB = solver_RB.XX_RB    #matrice di massa. 2D
FF_RB = solver_RB.FF_RB    #funzionalità contro il vettore unitario. 1D
KK_RB = solver_RB.KK_RB    #basi della decomposizione affine della stiffness. 3D
AA_RB = solver_RB.AA_RB    #l'integratore per calcolare il valor medio sul volume data la soluzione ridotta, questo può essere sostituito dalla funzione che calcola il valor medio su diversi slice. 1D
ZZ_CO = solver_RB.ZZ_FO    #coordinate a cui dobbiamo valutare la temperatura. 1D
II_CO = solver_RB.II_FO    #coefficienti che mappano i valori del coefficiente di diffusione valutata sulle temperature nei coefficienti di combinazione lineare della decomposizione affine. 2D
basis = cur_basis

# %%
# Salviamo tutte le matrici in un unico file HDF5
import h5py
with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
    hf.create_dataset('MM_RB', data=MM_RB)
    hf.create_dataset('FF_RB', data=FF_RB)
    hf.create_dataset('KK_RB', data=KK_RB)
    hf.create_dataset('AA_RB', data=AA_RB)
    hf.create_dataset('ZZ_CO', data=ZZ_CO)
    hf.create_dataset('II_CO', data=II_CO)
    hf.create_dataset('basis', data=basis)
