# %% [markdown]
# ## **REDUCED BASIS MODEL CONSTRUCTION**

# %% [markdown]
# #### LOAD LIBRARIES

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import itertools
import time
import os
import sys
import json
import pandas as pd

# Import user defined libraries:
from FreeFEM import FFmatrix_fread, FFvector_fread

# %% [markdown]
# #### DEFINE REFERENCE PROBLEM PARAMETERS

# %%
with open("../reference case/Reference_parameters.json", "r") as json_file:
    parameters = json.load(json_file)
N_AVOG = parameters["N_AVOG"]  
N_BOLT = parameters["N_BOLT"]  
FISSION_ENERGY = parameters["FISSION_ENERGY"]                       
FISSION_RATE = parameters["FISSION_RATE"]                   
RADIUS = parameters["RADIUS"]
LENGTH = parameters["LENGTH"]
FISSION_YIELD = parameters["FISSION_YIELD"]                 
FUEL_THERMAL_CONDUCTIVITY = parameters["FUEL_THERMAL_CONDUCTIVITY"]
T_BC = parameters["T_BC"]  
C_BC = parameters["C_BC"]  

SOURCE_C = FISSION_RATE * FISSION_YIELD         #[atm / (m^3 s)]
GAMMA_T = (FISSION_RATE * FISSION_ENERGY * LENGTH**2)/(FUEL_THERMAL_CONDUCTIVITY)

      
# Define reference temperature, concentration and linear diffusion parameters:
T_IC  = T_BC # [K]
C_IC = C_BC  # [atm / m^3]
 
# Define final time, time increment:
TIME_FINAL = 1.00E+07  # [s]
TIME_DELTA = 1.00E+04  # [s]

# Compute number of iterations:
N_ITER = int(TIME_FINAL / TIME_DELTA)  # [-]

# Define function evaluating the concentration diffusion coefficient at given z coordinated provided the problem parameters:
def ALPHA_C(ZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE):
    return 7.60E-10 * np.exp(- 4.86E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) + \
           5.64E-25 * np.exp(- 1.91E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) * np.sqrt(FISSION_RATE) + \
           8.00E-40 * FISSION_RATE

# %% [markdown]
# #### IDENTIFY DIRICHLET DOFS AND INTERNAL DOFS

# %%
# Load coordinates:
coordinates_Px = FFvector_fread('mesh_utilities/vv_cc_Px.btxt')
coordinates_Pq = FFvector_fread('mesh_utilities/vv_cc_Pq.btxt')

# Identify degrees of freedom of the Px and Pq spaces:
sFO_Px = coordinates_Px.shape[0]
sFO_Pq = coordinates_Pq.shape[0]
print(rf'Degree of freedom = {sFO_Px}')

# Define vector of all Px indeces:
mask_all = np.arange(sFO_Px, dtype=int)

# Identify indeces of the top, bottom and middle boundaries in Px:
mask_inf_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_sup_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.ones((sFO_Px)))]
mask_mid_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_ext_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.ones((sFO_Px)))]

# Identify indeces of the Dirichlet b.c. for the temperature and concentration field:
mask_bc_T = np.fromiter(set(mask_sup_bc), int)
mask_bc_C = np.fromiter(set(mask_sup_bc) | set(mask_ext_bc) | set(mask_inf_bc), int)

# Identify indeces of the interior for the temperature and concentration field:
mask_in_T = [ii for ii in mask_all if ii not in mask_bc_T]
mask_in_C = [ii for ii in mask_all if ii not in mask_bc_C]
# Out:
# Degree of freedom = 10201

# %% [markdown]
# #### DEFINE FINITE ELEMENT ESSENTIALS

# %%
# Import mass matrices on the Px and on the Pq space:
mass_Px = FFmatrix_fread('mesh_utilities/ww_mm_Px.btxt')
mass_Pq = FFmatrix_fread('mesh_utilities/ww_mm_Pq.btxt')
mass_Pm = FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')

# Extract integration weights and diagonal matrix with their inverse:
weights_Pq = mass_Pq.diagonal()
project_Pq = sparse.diags(np.reciprocal(weights_Pq))

# Import map from Px to Pq and to the dx, dy, dz derivative evaluated in Pq:
PxtoPquu_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdx_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dx_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdy_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dy_Px_Pq.btxt')[:, mask_in_C])

# Define weights for the integration in polar coordinates:
polar_weights_Pq = np.multiply(coordinates_Pq[:, 0], weights_Pq)

# Compute volume of the domain:
volume = np.dot(np.ones(sFO_Pq), polar_weights_Pq)

# Assemble mass matrix and projected forcing term:
forc_C = PxtoPquu_C.T.dot(polar_weights_Pq[:, None])
mass_C = PxtoPquu_C.T.dot(PxtoPquu_C.multiply(polar_weights_Pq[:, None]))
inte_C = PxtoPquu_C.T.dot(polar_weights_Pq) / volume

# Assemble a function assembling the stiffness matrix at a given time:
stiff_C = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / RADIUS**2 * polar_weights_Pq[:, None])) + \
          PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / LENGTH**2 * polar_weights_Pq[:, None]))

# %% [markdown]
# #### DEFINE PARAMETERS TRAINING SET

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215E-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0.00, 5.00E+19        
MIN_K, MAX_K =  0.9, 8.00    
MIN_FY, MAX_FY = 0.00, 0.3
MIN_LL, MAX_LL = 0.1E-3, 1.50E-3
MIN_RR, MAX_RR = 0.75E-5, 2.00E-5
MIN_BC, MAX_BC = 300, 2.5E+03 


# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TRAINING = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TRAINING[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# %% [markdown]
# #### CONSTRUCT AN AFFINE DECOMPOSITION FOR THE CONCENTRATION DIFFUSION COEFFICIENTS

# %%
# Compress the training set using singular value decomposition:
UU, SS, VV = np.linalg.svd(TRAINING @ TRAINING.T, full_matrices=False)
NN = np.sum(np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))]) > 1e-6) + 1

# Construct 1D and 3D basis for the concentration diffusion coefficient:
BASIS_D_1D = UU[:, :NN]
BASIS_D_2D = ZZ_1Dto2D @ BASIS_D_1D

# Use a greedy algorithm to identify the points (indeces) to interpolate the exact concentration coefficients:
INT_COO = [np.argmax(np.abs(BASIS_D_1D[:, 0]))]
for ii in range(1, NN):
    INT_COO.append(np.argmax(np.abs(BASIS_D_1D[:, ii] - BASIS_D_1D[:, :ii] @ np.linalg.solve(BASIS_D_1D[INT_COO, :ii],  BASIS_D_1D[INT_COO, ii]))))

# Extrat the z coordinates associated with the selected indeces:
INT_COO = np.array(INT_COO)
INT_CZZ = np.array([ZZ[INT_COO[ii]] for ii in range(NN)])

# Define interpolation operator mapping from the diffusion coefficient evaluated in the interpolation points to the linear combination coefficients:
mapDAtoCO = np.linalg.solve(BASIS_D_1D[INT_COO, :], np.eye(NN))

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TRAINING - BASIS_D_1D @ mapDAtoCO @ TRAINING[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TRAINING, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
print(VV.shape)
print(rf'Number of DEIM modes = {NN}')
# Out:
# 0.001313599001889472
# (1000, 1000)
# Number of DEIM modes = 8

# %%
#guardiamo la missing energy del termine non-affine -> queste basi ridotte dopo le usiamo per davvero
cmap = plt.get_cmap('RdBu')
color = cmap(0.9)

missing = np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))])
fig, (ax1) = plt.subplots(1, figsize=(4,5))
ax1.set_yscale('log')
ax1.plot(range(1,26), missing[:25], '-o')
ax1.tick_params(axis="y", which='both',labelsize=13,  width=1)
ax1.tick_params(axis='x', labelsize=13,  width=1)
ax1.set_xlabel('Number of DEIM modes',fontsize=14)
ax1.set_ylabel('Missing energy',fontsize=14)
#ax1.set_ylabel('Normalized eigenvalues',fontsize=14)
ax1.axvspan(1, NN, color='gray', alpha=0.2)
ax1.set_xlim([0,25])
ax1.set_ylim([1e-7, 1])
ax1.grid(visible=True, which='both', linewidth=1, alpha=0.7)
#plt.savefig('plot/Missing energy.pdf', bbox_inches='tight')

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215E-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0.00, 5.00E+19        
MIN_K, MAX_K =  0.9, 8.00    
MIN_FY, MAX_FY = 0.00, 0.3
MIN_LL, MAX_LL = 0.1E-3, 1.50E-3
MIN_RR, MAX_RR = 0.75E-5, 2.00E-5
MIN_BC, MAX_BC = 300, 2.5E+03 


# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TEST = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TEST[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TEST - BASIS_D_1D @ mapDAtoCO @ TEST[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TEST, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
# Out:
# 0.0012266971357533817

# %% [markdown]
# #### ASSEMBLE AFFINELY DECOMPOSED STIFFNESS MATRICES AND COMPUTE THEIR COERCIVITY CONSTANTS
# impiega 1.3 secondi

# %%
# Define two mass matrices respectively linked to the regularity of the solution and of its time derivative:
Y_mass = stiff_C
X_mass = mass_C

# Initialise array for the partial stiffness matrices and for their coercivity constants:
list_basis_stiff_C = np.array([sparse.csr_matrix((mass_C.shape)) for ii in range(2*NN)])
list_coerc_stiff_C = np.zeros((2*NN))

# Iterate over the selected basis for the diffusion coefficient field
for ii in range(NN):

    # Assemble the radial and axial partial stiffness matrices associated with the basis of the diffusivity:
    list_basis_stiff_C[00+ii] = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))
    list_basis_stiff_C[NN+ii] = PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))

    # Compute the sign of the axial and radial partial stiffness matrices:
    tsign_dz_C = np.sign(list_basis_stiff_C[NN + ii].trace())
    tsign_dr_C = np.sign(list_basis_stiff_C[00 + ii].trace())

    # Compute the coercivity constant of the axial and radial partial stiffness matrices:
    list_coerc_stiff_C[NN+ii] = tsign_dz_C / linalg.eigsh(Y_mass, k=1, M=tsign_dz_C * list_basis_stiff_C[NN+ii], which='LM', return_eigenvectors=False)[0]
    list_coerc_stiff_C[00+ii] = tsign_dr_C / linalg.eigsh(Y_mass, k=1, M=tsign_dr_C * list_basis_stiff_C[00+ii], which='LM', return_eigenvectors=False)[0]

# %% [markdown]
# #### COMPUTE THE INTERPOLATION COEFFICIENTS AND THE COERCIVITY COEFFICIENTS FOR ALL THE PARAMETERS

# %%
# Compute hte interpolation coefficients and the coercivity coefficients for the parameters in the training set:
list_inter_coef = np.empty((sTR, 2*NN))
list_coerc_coef = np.empty((sTR))

# Iterate over the training set:
for ii in range(sTR):
    cur_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

    # Compute the interpolation coefficients for the radial and axial partial stiffness matrices:
    list_inter_coef[ii, NN:] = cur_coef / LIST_LL[ii]**2
    list_inter_coef[ii, :NN] = cur_coef / LIST_RR[ii]**2

    # Compute a lower bound for the coercivity constants:
    list_coerc_coef[ii] = np.dot(list_coerc_stiff_C, list_inter_coef[ii, :])

# Compute interpolation and coercivity coeffientrs for the reference parameters:
cur_inter_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE)
cur_inter_coef = np.hstack((cur_inter_coef / RADIUS**2, cur_inter_coef / LENGTH**2))
cur_coerc_coef = np.dot(list_coerc_stiff_C, cur_inter_coef)

# %% [markdown]
# #### COMPUTE THE POD MODES OF THE REFERENCE SOLUTION

# %%
sol_new_C = np.loadtxt('../reference case/Fullorder_Cfield.csv', delimiter=',')
# Compute the singular value decomposition of the gramian matrix:
AA, GG, BB = np.linalg.svd(sol_new_C[mask_in_C, :].T @ Y_mass @ sol_new_C[mask_in_C, :], full_matrices=False)

# Compute total Y-energy of the training set:
Y_energy = np.sum([Y_mass.dot(sol_new_C[mask_in_C, ii]).dot(sol_new_C[mask_in_C, ii]) for ii in range(N_ITER+1)])

# Determine number of POD modes to retain:
sRB_C = np.sum([np.sqrt(np.sum(GG[ii:]) / Y_energy) > 1e-4 for ii in range(len(GG))])

# Assemble POD modes for the concentration field at the reference parameters:
BASIS_C_2D = sol_new_C[mask_in_C, :] @ AA[:, :sRB_C] @ np.diag(np.reciprocal(np.sqrt(GG[:sRB_C])))

print(rf'Number of POD modes = {sRB_C}')
# Out:
# Number of POD modes = 8

# %% [markdown]
# #### ASSEMBLE REDUCED MATRICES (LATER MUST BE CODED AS THE METHOD OF A CLASS)

# %%
# Project the Y- and X-mass matrices on the reduced basis space:
Y_mass_RB = BASIS_C_2D.T @ Y_mass @ BASIS_C_2D
X_mass_RB = BASIS_C_2D.T @ X_mass @ BASIS_C_2D

# Compute Rietz representer and projection of the forcing term:
forc_C_rietz_RB = linalg.spsolve(Y_mass, forc_C)
forc_C_proje_RB = BASIS_C_2D.T @ forc_C

# Compute Rietz representer and projection of the mass matrix tested versus the POD basis functions: 
mass_C_right_RB = mass_C @ BASIS_C_2D
mass_C_rietz_RB = linalg.spsolve(Y_mass, mass_C_right_RB)
mass_C_proje_RB = BASIS_C_2D.T @ mass_C_right_RB

# Compute the Rietz representer and projection of all the partial stiffness matrices from the affine decomposition:
list_basis_stiff_C_right_RB = np.array([list_basis_stiff_C[ii] @ BASIS_C_2D for ii in range(2*NN)])
list_basis_stiff_C_rietz_RB = np.array([linalg.spsolve(Y_mass, list_basis_stiff_C_right_RB[ii]) for ii in range(2*NN)])
list_basis_stiff_C_proje_RB = np.array([BASIS_C_2D.T @ list_basis_stiff_C_right_RB[ii] for ii in range(2*NN)])

# Pre-assemble the scalar and vector terms for the residual energy computation:
DD_pr_bb = (forc_C_rietz_RB.T @ forc_C) * (SOURCE_C * SOURCE_C)
DD_pr_bm = (forc_C_rietz_RB.T @ mass_C_right_RB) * (- 2 * SOURCE_C / TIME_DELTA)
DD_pr_mm = (mass_C_rietz_RB.T @ mass_C_right_RB) * (  1 / (TIME_DELTA * TIME_DELTA))

# Pre-assemble all the tensor terms for the residual energy computation:
DD_pr_ab = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ forc_C_rietz_RB for ii in range(2*NN)]) * (-2 * SOURCE_C)
DD_pr_am = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ mass_C_rietz_RB for ii in range(2*NN)]) * ( 2 / TIME_DELTA)
DD_pr_aa = np.array([[list_basis_stiff_C_right_RB[ii, :, :].T @ list_basis_stiff_C_rietz_RB[jj, :, :] for ii in range(2*NN)] for jj in range(2*NN)])

# Compute the weights for the integration of the reduced basis solutions:
weights_RB = np.ones((sFO_Px)) @ mass_Px[:, mask_in_C] @ BASIS_C_2D

# %% [markdown]
# #### COMPUTE REDUCED BASIS SOLUTION

# %%
# Assemble current reduced basis stiffness matrix:
stiff_C_proje_RB = np.tensordot(cur_inter_coef, list_basis_stiff_C_proje_RB, axes=[0, 0])
stiff_C_exact_RB = BASIS_C_2D.T @ stiff_C @ BASIS_C_2D

# Assemble current stiffness cross term for the computation of the residual energy:
cur_DD_pr_ab = np.tensordot(cur_inter_coef, DD_pr_ab, axes=[0, 0])
cur_DD_pr_am = np.tensordot(cur_inter_coef, DD_pr_am, axes=[0, 0])
cur_DD_pr_aa = np.tensordot(cur_inter_coef, np.tensordot(cur_inter_coef, DD_pr_aa, axes=[0, 0]), axes=[0, 0])

# Initialise reduced basis concentration solution:
sol_new_C_RB = np.zeros((sRB_C, N_ITER+1))
sol_new_C_FO = np.zeros((len(mask_in_C), N_ITER+1))

# Initialise errors and errors estimators:
energy_residual = np.empty((N_ITER))
energy_solution = np.empty((N_ITER))
energy_toterror = np.empty((N_ITER))

#
inte_C_RB = inte_C @ BASIS_C_2D

# Integrate using forward Euler up to the final time:
verbose = True
for ii in range(N_ITER):
    cur_time = ii * TIME_DELTA

    # Print current iteration and average temperature and concentration:
    if verbose:
        print('Current time:', cur_time, 's')
        print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, ii], 'atm/m^3\n')

    # Assemble current left-hand-side and right-hand-side
    cur_lhs_RB = mass_C_proje_RB + TIME_DELTA * stiff_C_proje_RB
    cur_rhs_RB = mass_C_proje_RB.dot(sol_new_C_RB[:, ii:ii+1]) + TIME_DELTA * SOURCE_C * forc_C_proje_RB

    # Compute concentration in the interior of the domain:
    sol_new_C_RB[:, ii+1] = np.linalg.solve(cur_lhs_RB, cur_rhs_RB)[:, 0]
    sol_new_C_FO[:, ii+1] = BASIS_C_2D @ sol_new_C_RB[:, ii+1]
    
    # Compute partial errors and error bounds:
    energy_toterror[ii] = TIME_DELTA * stiff_C.dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1]).dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1])
    energy_solution[ii] = TIME_DELTA * stiff_C_proje_RB.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1])
    energy_residual[ii] = TIME_DELTA * (DD_pr_bb[0] + DD_pr_bm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        DD_pr_mm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        cur_DD_pr_ab.dot(sol_new_C_RB[:, ii+1]) + cur_DD_pr_aa.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1]) +\
                                        cur_DD_pr_am.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1]))

# Print current iteration and average temperature and concentration:
if verbose: 
    print('Final time:', N_ITER * TIME_DELTA, 's')
    print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, -1], 'atm/m^3\n\n')

# Add final term energies:
energy_solution[-1] += mass_C_proje_RB.dot(sol_new_C_RB[:, -1]).dot(sol_new_C_RB[:, -1])
energy_toterror[-1] += mass_C.dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1]).dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1])

# Print errors and error bounds:
print('Error bound:', np.sqrt(np.sum(energy_residual) / np.sum(energy_solution) / cur_coerc_coef) )
print('Error exact:', np.sqrt(np.sum(energy_toterror) / np.sum(energy_solution)) )
# Out:
# Current time: 0.0 s
# Average concentration: 0.0 atm/m^3
#
# Current time: 10000.0 s
# Average concentration: 6.077970765819007e+22 atm/m^3
#
# Current time: 20000.0 s
# Average concentration: 1.1627102139985829e+23 atm/m^3
#
# Current time: 30000.0 s
# Average concentration: 1.6790510574609433e+23 atm/m^3
#
# Current time: 40000.0 s
# Average concentration: 2.1643135534197685e+23 atm/m^3
#
# Current time: 50000.0 s
# Average concentration: 2.6230994418757032e+23 atm/m^3
#
# Current time: 60000.0 s
# Average concentration: 3.058607999542063e+23 atm/m^3
#
# Current time: 70000.0 s
# Average concentration: 3.4732520427032016e+23 atm/m^3
#
# Current time: 80000.0 s
# Average concentration: 3.868945408137013e+23 atm/m^3
#
# Current time: 90000.0 s
# Average concentration: 4.2472567805927047e+23 atm/m^3
#
# Current time: 100000.0 s
# Average concentration: 4.6095026288411037e+23 atm/m^3
#
# Current time: 110000.0 s
# Average concentration: 4.9568084998275987e+23 atm/m^3
#
# Current time: 120000.0 s
# Average concentration: 5.290151764469403e+23 atm/m^3
#
# Current time: 130000.0 s
# Average concentration: 5.610392476123815e+23 atm/m^3
#
# Current time: 140000.0 s
# Average concentration: 5.918296163269715e+23 atm/m^3
#
# Current time: 150000.0 s
# Average concentration: 6.214550957473037e+23 atm/m^3
#
# Current time: 160000.0 s
# Average concentration: 6.499780656290838e+23 atm/m^3
#
# Current time: 170000.0 s
# Average concentration: 6.774554824719953e+23 atm/m^3
#
# Current time: 180000.0 s
# Average concentration: 7.039396712672927e+23 atm/m^3
#
# Current time: 190000.0 s
# Average concentration: 7.294789543770345e+23 atm/m^3
#
# Current time: 200000.0 s
# Average concentration: 7.541181576184794e+23 atm/m^3
#
# Current time: 210000.0 s
# Average concentration: 7.778990227382282e+23 atm/m^3
#
# Current time: 220000.0 s
# Average concentration: 8.0086054771946e+23 atm/m^3
#
# Current time: 230000.0 s
# Average concentration: 8.230392708207802e+23 atm/m^3
#
# Current time: 240000.0 s
# Average concentration: 8.444695102453581e+23 atm/m^3
#
# Current time: 250000.0 s
# Average concentration: 8.651835684326782e+23 atm/m^3
#
# Current time: 260000.0 s
# Average concentration: 8.852119078371806e+23 atm/m^3
#
# Current time: 270000.0 s
# Average concentration: 9.04583303487085e+23 atm/m^3
#
# Current time: 280000.0 s
# Average concentration: 9.233249764468728e+23 atm/m^3
#
# Current time: 290000.0 s
# Average concentration: 9.414627114278836e+23 atm/m^3
#
# Current time: 300000.0 s
# Average concentration: 9.590209611246901e+23 atm/m^3
#
# Current time: 310000.0 s
# Average concentration: 9.76022939344352e+23 atm/m^3
#
# Current time: 320000.0 s
# Average concentration: 9.924907046008863e+23 atm/m^3
#
# Current time: 330000.0 s
# Average concentration: 1.008445235539247e+24 atm/m^3
#
# Current time: 340000.0 s
# Average concentration: 1.023906499310493e+24 atm/m^3
#
# Current time: 350000.0 s
# Average concentration: 1.0388935138271047e+24 atm/m^3
#
# Current time: 360000.0 s
# Average concentration: 1.0534244046730395e+24 atm/m^3
#
# Current time: 370000.0 s
# Average concentration: 1.0675164573185174e+24 atm/m^3
#
# Current time: 380000.0 s
# Average concentration: 1.0811861651882508e+24 atm/m^3
#
# Current time: 390000.0 s
# Average concentration: 1.0944492740489414e+24 atm/m^3
#
# Current time: 400000.0 s
# Average concentration: 1.1073208231136468e+24 atm/m^3
#
# Current time: 410000.0 s
# Average concentration: 1.1198151832041218e+24 atm/m^3
#
# Current time: 420000.0 s
# Average concentration: 1.1319460922652446e+24 atm/m^3
#
# Current time: 430000.0 s
# Average concentration: 1.1437266884863206e+24 atm/m^3
#
# Current time: 440000.0 s
# Average concentration: 1.1551695412510562e+24 atm/m^3
#
# Current time: 450000.0 s
# Average concentration: 1.1662866801101417e+24 atm/m^3
#
# Current time: 460000.0 s
# Average concentration: 1.1770896219467914e+24 atm/m^3
#
# Current time: 470000.0 s
# Average concentration: 1.1875893964855413e+24 atm/m^3
#
# Current time: 480000.0 s
# Average concentration: 1.1977965702774776e+24 atm/m^3
#
# Current time: 490000.0 s
# Average concentration: 1.2077212692803997e+24 atm/m^3
#
# Current time: 500000.0 s
# Average concentration: 1.2173732001398056e+24 atm/m^3
#
# Current time: 510000.0 s
# Average concentration: 1.2267616702656864e+24 atm/m^3
#
# Current time: 520000.0 s
# Average concentration: 1.2358956067906734e+24 atm/m^3
#
# Current time: 530000.0 s
# Average concentration: 1.2447835744868667e+24 atm/m^3
#
# Current time: 540000.0 s
# Average concentration: 1.253433792711498e+24 atm/m^3
#
# Current time: 550000.0 s
# Average concentration: 1.2618541514452844e+24 atm/m^3
#
# Current time: 560000.0 s
# Average concentration: 1.2700522264817795e+24 atm/m^3
#
# Current time: 570000.0 s
# Average concentration: 1.2780352938211586e+24 atm/m^3
#
# Current time: 580000.0 s
# Average concentration: 1.285810343317502e+24 atm/m^3
#
# Current time: 590000.0 s
# Average concentration: 1.2933840916247845e+24 atm/m^3
#
# Current time: 600000.0 s
# Average concentration: 1.300762994483324e+24 atm/m^3
#
# Current time: 610000.0 s
# Average concentration: 1.307953258385328e+24 atm/m^3
#
# Current time: 620000.0 s
# Average concentration: 1.3149608516553877e+24 atm/m^3
#
# Current time: 630000.0 s
# Average concentration: 1.3217915149792366e+24 atm/m^3
#
# Current time: 640000.0 s
# Average concentration: 1.3284507714118106e+24 atm/m^3
#
# Current time: 650000.0 s
# Average concentration: 1.3349439358935443e+24 atm/m^3
#
# Current time: 660000.0 s
# Average concentration: 1.3412761243019385e+24 atm/m^3
#
# Current time: 670000.0 s
# Average concentration: 1.347452262063713e+24 atm/m^3
#
# Current time: 680000.0 s
# Average concentration: 1.3534770923512267e+24 atm/m^3
#
# Current time: 690000.0 s
# Average concentration: 1.3593551838853923e+24 atm/m^3
#
# Current time: 700000.0 s
# Average concentration: 1.3650909383659583e+24 atm/m^3
#
# Current time: 710000.0 s
# Average concentration: 1.3706885975487663e+24 atm/m^3
#
# Current time: 720000.0 s
# Average concentration: 1.3761522499884244e+24 atm/m^3
#
# Current time: 730000.0 s
# Average concentration: 1.3814858374637778e+24 atm/m^3
#
# Current time: 740000.0 s
# Average concentration: 1.3866931611025141e+24 atm/m^3
#
# Current time: 750000.0 s
# Average concentration: 1.391777887220357e+24 atm/m^3
#
# Current time: 760000.0 s
# Average concentration: 1.3967435528893723e+24 atm/m^3
#
# Current time: 770000.0 s
# Average concentration: 1.401593571249143e+24 atm/m^3
#
# Current time: 780000.0 s
# Average concentration: 1.4063312365737632e+24 atm/m^3
#
# Current time: 790000.0 s
# Average concentration: 1.4109597291069296e+24 atm/m^3
#
# Current time: 800000.0 s
# Average concentration: 1.4154821196766948e+24 atm/m^3
#
# Current time: 810000.0 s
# Average concentration: 1.4199013741008507e+24 atm/m^3
#
# Current time: 820000.0 s
# Average concentration: 1.4242203573933004e+24 atm/m^3
#
# Current time: 830000.0 s
# Average concentration: 1.4284418377812275e+24 atm/m^3
#
# Current time: 840000.0 s
# Average concentration: 1.4325684905423565e+24 atm/m^3
#
# Current time: 850000.0 s
# Average concentration: 1.4366029016710796e+24 atm/m^3
#
# Current time: 860000.0 s
# Average concentration: 1.4405475713818048e+24 atm/m^3
#
# Current time: 870000.0 s
# Average concentration: 1.4444049174573895e+24 atm/m^3
#
# Current time: 880000.0 s
# Average concentration: 1.4481772784501638e+24 atm/m^3
#
# Current time: 890000.0 s
# Average concentration: 1.4518669167426254e+24 atm/m^3
#
# Current time: 900000.0 s
# Average concentration: 1.455476021474526e+24 atm/m^3
#
# Current time: 910000.0 s
# Average concentration: 1.4590067113427406e+24 atm/m^3
#
# Current time: 920000.0 s
# Average concentration: 1.4624610372799545e+24 atm/m^3
#
# Current time: 930000.0 s
# Average concentration: 1.4658409850179293e+24 atm/m^3
#
# Current time: 940000.0 s
# Average concentration: 1.4691484775407722e+24 atm/m^3
#
# Current time: 950000.0 s
# Average concentration: 1.4723853774334106e+24 atm/m^3
#
# Current time: 960000.0 s
# Average concentration: 1.4755534891301559e+24 atm/m^3
#
# Current time: 970000.0 s
# Average concentration: 1.4786545610680423e+24 atm/m^3
#
# Current time: 980000.0 s
# Average concentration: 1.481690287749359e+24 atm/m^3
#
# Current time: 990000.0 s
# Average concentration: 1.4846623117175862e+24 atm/m^3
#
# Current time: 1000000.0 s
# Average concentration: 1.48757222545074e+24 atm/m^3
#
# Current time: 1010000.0 s
# Average concentration: 1.4904215731759166e+24 atm/m^3
#
# Current time: 1020000.0 s
# Average concentration: 1.4932118526086582e+24 atm/m^3
#
# Current time: 1030000.0 s
# Average concentration: 1.495944516620566e+24 atm/m^3
#
# Current time: 1040000.0 s
# Average concentration: 1.4986209748384355e+24 atm/m^3
#
# Current time: 1050000.0 s
# Average concentration: 1.5012425951780083e+24 atm/m^3
#
# Current time: 1060000.0 s
# Average concentration: 1.503810705315304e+24 atm/m^3
#
# Current time: 1070000.0 s
# Average concentration: 1.5063265940983318e+24 atm/m^3
#
# Current time: 1080000.0 s
# Average concentration: 1.5087915129018697e+24 atm/m^3
#
# Current time: 1090000.0 s
# Average concentration: 1.511206676927837e+24 atm/m^3
#
# Current time: 1100000.0 s
# Average concentration: 1.5135732664536994e+24 atm/m^3
#
# Current time: 1110000.0 s
# Average concentration: 1.5158924280312017e+24 atm/m^3
#
# Current time: 1120000.0 s
# Average concentration: 1.5181652756376185e+24 atm/m^3
#
# Current time: 1130000.0 s
# Average concentration: 1.5203928917816295e+24 atm/m^3
#
# Current time: 1140000.0 s
# Average concentration: 1.522576328565793e+24 atm/m^3
#
# Current time: 1150000.0 s
# Average concentration: 1.5247166087075196e+24 atm/m^3
#
# Current time: 1160000.0 s
# Average concentration: 1.5268147265203542e+24 atm/m^3
#
# Current time: 1170000.0 s
# Average concentration: 1.5288716488572896e+24 atm/m^3
#
# Current time: 1180000.0 s
# Average concentration: 1.530888316017739e+24 atm/m^3
#
# Current time: 1190000.0 s
# Average concentration: 1.532865642619749e+24 atm/m^3
#
# Current time: 1200000.0 s
# Average concentration: 1.5348045184389276e+24 atm/m^3
#
# Current time: 1210000.0 s
# Average concentration: 1.536705809215523e+24 atm/m^3
#
# Current time: 1220000.0 s
# Average concentration: 1.5385703574309893e+24 atm/m^3
#
# Current time: 1230000.0 s
# Average concentration: 1.5403989830553487e+24 atm/m^3
#
# Current time: 1240000.0 s
# Average concentration: 1.5421924842665812e+24 atm/m^3
#
# Current time: 1250000.0 s
# Average concentration: 1.543951638143204e+24 atm/m^3
#
# Current time: 1260000.0 s
# Average concentration: 1.5456772013311777e+24 atm/m^3
#
# Current time: 1270000.0 s
# Average concentration: 1.5473699106862053e+24 atm/m^3
#
# Current time: 1280000.0 s
# Average concentration: 1.5490304838924454e+24 atm/m^3
#
# Current time: 1290000.0 s
# Average concentration: 1.5506596200586168e+24 atm/m^3
#
# Current time: 1300000.0 s
# Average concentration: 1.5522580002924213e+24 atm/m^3
#
# Current time: 1310000.0 s
# Average concentration: 1.553826288254189e+24 atm/m^3
#
# Current time: 1320000.0 s
# Average concentration: 1.555365130690579e+24 atm/m^3
#
# Current time: 1330000.0 s
# Average concentration: 1.5568751579491506e+24 atm/m^3
#
# Current time: 1340000.0 s
# Average concentration: 1.558356984474602e+24 atm/m^3
#
# Current time: 1350000.0 s
# Average concentration: 1.5598112092873763e+24 atm/m^3
#
# Current time: 1360000.0 s
# Average concentration: 1.5612384164453927e+24 atm/m^3
#
# Current time: 1370000.0 s
# Average concentration: 1.5626391754895317e+24 atm/m^3
#
# Current time: 1380000.0 s
# Average concentration: 1.5640140418735635e+24 atm/m^3
#
# Current time: 1390000.0 s
# Average concentration: 1.5653635573791027e+24 atm/m^3
#
# Current time: 1400000.0 s
# Average concentration: 1.5666882505162165e+24 atm/m^3
#
# Current time: 1410000.0 s
# Average concentration: 1.567988636910217e+24 atm/m^3
#
# Current time: 1420000.0 s
# Average concentration: 1.5692652196752048e+24 atm/m^3
#
# Current time: 1430000.0 s
# Average concentration: 1.570518489774874e+24 atm/m^3
#
# Current time: 1440000.0 s
# Average concentration: 1.57174892637107e+24 atm/m^3
#
# Current time: 1450000.0 s
# Average concentration: 1.5729569971605762e+24 atm/m^3
#
# Current time: 1460000.0 s
# Average concentration: 1.5741431587005975e+24 atm/m^3
#
# Current time: 1470000.0 s
# Average concentration: 1.575307856723348e+24 atm/m^3
#
# Current time: 1480000.0 s
# Average concentration: 1.576451526440185e+24 atm/m^3
#
# Current time: 1490000.0 s
# Average concentration: 1.5775745928356725e+24 atm/m^3
#
# Current time: 1500000.0 s
# Average concentration: 1.5786774709519657e+24 atm/m^3
#
# Current time: 1510000.0 s
# Average concentration: 1.579760566163874e+24 atm/m^3
#
# Current time: 1520000.0 s
# Average concentration: 1.5808242744449576e+24 atm/m^3
#
# Current time: 1530000.0 s
# Average concentration: 1.5818689826249929e+24 atm/m^3
#
# Current time: 1540000.0 s
# Average concentration: 1.5828950686391288e+24 atm/m^3
#
# Current time: 1550000.0 s
# Average concentration: 1.5839029017690358e+24 atm/m^3
#
# Current time: 1560000.0 s
# Average concentration: 1.5848928428763606e+24 atm/m^3
#
# Current time: 1570000.0 s
# Average concentration: 1.5858652446287448e+24 atm/m^3
#
# Current time: 1580000.0 s
# Average concentration: 1.586820451718708e+24 atm/m^3
#
# Current time: 1590000.0 s
# Average concentration: 1.5877588010756258e+24 atm/m^3
#
# Current time: 1600000.0 s
# Average concentration: 1.588680622071081e+24 atm/m^3
#
# Current time: 1610000.0 s
# Average concentration: 1.5895862367178078e+24 atm/m^3
#
# Current time: 1620000.0 s
# Average concentration: 1.5904759598624716e+24 atm/m^3
#
# Current time: 1630000.0 s
# Average concentration: 1.591350099372495e+24 atm/m^3
#
# Current time: 1640000.0 s
# Average concentration: 1.592208956317155e+24 atm/m^3
#
# Current time: 1650000.0 s
# Average concentration: 1.593052825143141e+24 atm/m^3
#
# Current time: 1660000.0 s
# Average concentration: 1.593881993844782e+24 atm/m^3
#
# Current time: 1670000.0 s
# Average concentration: 1.5946967441291152e+24 atm/m^3
#
# Current time: 1680000.0 s
# Average concentration: 1.5954973515760028e+24 atm/m^3
#
# Current time: 1690000.0 s
# Average concentration: 1.596284085793432e+24 atm/m^3
#
# Current time: 1700000.0 s
# Average concentration: 1.5970572105682054e+24 atm/m^3
#
# Current time: 1710000.0 s
# Average concentration: 1.5978169840121498e+24 atm/m^3
#
# Current time: 1720000.0 s
# Average concentration: 1.5985636587040168e+24 atm/m^3
#
# Current time: 1730000.0 s
# Average concentration: 1.599297481827208e+24 atm/m^3
#
# Current time: 1740000.0 s
# Average concentration: 1.600018695303487e+24 atm/m^3
#
# Current time: 1750000.0 s
# Average concentration: 1.6007275359227877e+24 atm/m^3
#
# Current time: 1760000.0 s
# Average concentration: 1.6014242354692814e+24 atm/m^3
#
# Current time: 1770000.0 s
# Average concentration: 1.6021090208437926e+24 atm/m^3
#
# Current time: 1780000.0 s
# Average concentration: 1.6027821141827274e+24 atm/m^3
#
# Current time: 1790000.0 s
# Average concentration: 1.603443732973591e+24 atm/m^3
#
# Current time: 1800000.0 s
# Average concentration: 1.604094090167237e+24 atm/m^3
#
# Current time: 1810000.0 s
# Average concentration: 1.604733394286937e+24 atm/m^3
#
# Current time: 1820000.0 s
# Average concentration: 1.6053618495343857e+24 atm/m^3
#
# Current time: 1830000.0 s
# Average concentration: 1.6059796558927377e+24 atm/m^3
#
# Current time: 1840000.0 s
# Average concentration: 1.6065870092267757e+24 atm/m^3
#
# Current time: 1850000.0 s
# Average concentration: 1.6071841013802981e+24 atm/m^3
#
# Current time: 1860000.0 s
# Average concentration: 1.6077711202708179e+24 atm/m^3
#
# Current time: 1870000.0 s
# Average concentration: 1.6083482499816645e+24 atm/m^3
#
# Current time: 1880000.0 s
# Average concentration: 1.6089156708515606e+24 atm/m^3
#
# Current time: 1890000.0 s
# Average concentration: 1.6094735595617672e+24 atm/m^3
#
# Current time: 1900000.0 s
# Average concentration: 1.6100220892208584e+24 atm/m^3
#
# Current time: 1910000.0 s
# Average concentration: 1.6105614294472167e+24 atm/m^3
#
# Current time: 1920000.0 s
# Average concentration: 1.6110917464493142e+24 atm/m^3
#
# Current time: 1930000.0 s
# Average concentration: 1.6116132031038377e+24 atm/m^3
#
# Current time: 1940000.0 s
# Average concentration: 1.6121259590317464e+24 atm/m^3
#
# Current time: 1950000.0 s
# Average concentration: 1.6126301706723092e+24 atm/m^3
#
# Current time: 1960000.0 s
# Average concentration: 1.6131259913551863e+24 atm/m^3
#
# Current time: 1970000.0 s
# Average concentration: 1.6136135713706264e+24 atm/m^3
#
# Current time: 1980000.0 s
# Average concentration: 1.6140930580378178e+24 atm/m^3
#
# Current time: 1990000.0 s
# Average concentration: 1.6145645957714676e+24 atm/m^3
#
# Current time: 2000000.0 s
# Average concentration: 1.6150283261466553e+24 atm/m^3
#
# Current time: 2010000.0 s
# Average concentration: 1.6154843879620106e+24 atm/m^3
#
# Current time: 2020000.0 s
# Average concentration: 1.6159329173012655e+24 atm/m^3
#
# Current time: 2030000.0 s
# Average concentration: 1.6163740475932354e+24 atm/m^3
#
# Current time: 2040000.0 s
# Average concentration: 1.616807909670273e+24 atm/m^3
#
# Current time: 2050000.0 s
# Average concentration: 1.6172346318252327e+24 atm/m^3
#
# Current time: 2060000.0 s
# Average concentration: 1.6176543398670035e+24 atm/m^3
#
# Current time: 2070000.0 s
# Average concentration: 1.6180671571746385e+24 atm/m^3
#
# Current time: 2080000.0 s
# Average concentration: 1.6184732047501315e+24 atm/m^3
#
# Current time: 2090000.0 s
# Average concentration: 1.618872601269876e+24 atm/m^3
#
# Current time: 2100000.0 s
# Average concentration: 1.6192654631348425e+24 atm/m^3
#
# Current time: 2110000.0 s
# Average concentration: 1.6196519045195202e+24 atm/m^3
#
# Current time: 2120000.0 s
# Average concentration: 1.6200320374196455e+24 atm/m^3
#
# Current time: 2130000.0 s
# Average concentration: 1.6204059716987604e+24 atm/m^3
#
# Current time: 2140000.0 s
# Average concentration: 1.6207738151336352e+24 atm/m^3
#
# Current time: 2150000.0 s
# Average concentration: 1.6211356734585804e+24 atm/m^3
#
# Current time: 2160000.0 s
# Average concentration: 1.621491650408683e+24 atm/m^3
#
# Current time: 2170000.0 s
# Average concentration: 1.621841847762006e+24 atm/m^3
#
# Current time: 2180000.0 s
# Average concentration: 1.6221863653807587e+24 atm/m^3
#
# Current time: 2190000.0 s
# Average concentration: 1.6225253012514907e+24 atm/m^3
#
# Current time: 2200000.0 s
# Average concentration: 1.6228587515243186e+24 atm/m^3
#
# Current time: 2210000.0 s
# Average concentration: 1.623186810551222e+24 atm/m^3
#
# Current time: 2220000.0 s
# Average concentration: 1.6235095709234282e+24 atm/m^3
#
# Current time: 2230000.0 s
# Average concentration: 1.6238271235079174e+24 atm/m^3
#
# Current time: 2240000.0 s
# Average concentration: 1.6241395574830657e+24 atm/m^3
#
# Current time: 2250000.0 s
# Average concentration: 1.6244469603734517e+24 atm/m^3
#
# Current time: 2260000.0 s
# Average concentration: 1.6247494180838514e+24 atm/m^3
#
# Current time: 2270000.0 s
# Average concentration: 1.6250470149324381e+24 atm/m^3
#
# Current time: 2280000.0 s
# Average concentration: 1.62533983368322e+24 atm/m^3
#
# Current time: 2290000.0 s
# Average concentration: 1.6256279555777136e+24 atm/m^3
#
# Current time: 2300000.0 s
# Average concentration: 1.6259114603659005e+24 atm/m^3
#
# Current time: 2310000.0 s
# Average concentration: 1.6261904263364658e+24 atm/m^3
#
# Current time: 2320000.0 s
# Average concentration: 1.626464930346348e+24 atm/m^3
#
# Current time: 2330000.0 s
# Average concentration: 1.626735047849616e+24 atm/m^3
#
# Current time: 2340000.0 s
# Average concentration: 1.6270008529256797e+24 atm/m^3
#
# Current time: 2350000.0 s
# Average concentration: 1.6272624183068784e+24 atm/m^3
#
# Current time: 2360000.0 s
# Average concentration: 1.6275198154054304e+24 atm/m^3
#
# Current time: 2370000.0 s
# Average concentration: 1.6277731143397888e+24 atm/m^3
#
# Current time: 2380000.0 s
# Average concentration: 1.6280223839603937e+24 atm/m^3
#
# Current time: 2390000.0 s
# Average concentration: 1.628267691874861e+24 atm/m^3
#
# Current time: 2400000.0 s
# Average concentration: 1.6285091044726004e+24 atm/m^3
#
# Current time: 2410000.0 s
# Average concentration: 1.6287466869488924e+24 atm/m^3
#
# Current time: 2420000.0 s
# Average concentration: 1.628980503328428e+24 atm/m^3
#
# Current time: 2430000.0 s
# Average concentration: 1.6292106164883357e+24 atm/m^3
#
# Current time: 2440000.0 s
# Average concentration: 1.6294370881806898e+24 atm/m^3
#
# Current time: 2450000.0 s
# Average concentration: 1.6296599790545395e+24 atm/m^3
#
# Current time: 2460000.0 s
# Average concentration: 1.6298793486774423e+24 atm/m^3
#
# Current time: 2470000.0 s
# Average concentration: 1.630095255556541e+24 atm/m^3
#
# Current time: 2480000.0 s
# Average concentration: 1.630307757159171e+24 atm/m^3
#
# Current time: 2490000.0 s
# Average concentration: 1.6305169099330297e+24 atm/m^3
#
# Current time: 2500000.0 s
# Average concentration: 1.6307227693259021e+24 atm/m^3
#
# Current time: 2510000.0 s
# Average concentration: 1.630925389804974e+24 atm/m^3
#
# Current time: 2520000.0 s
# Average concentration: 1.6311248248757146e+24 atm/m^3
#
# Current time: 2530000.0 s
# Average concentration: 1.631321127100365e+24 atm/m^3
#
# Current time: 2540000.0 s
# Average concentration: 1.6315143481160299e+24 atm/m^3
#
# Current time: 2550000.0 s
# Average concentration: 1.631704538652384e+24 atm/m^3
#
# Current time: 2560000.0 s
# Average concentration: 1.6318917485490003e+24 atm/m^3
#
# Current time: 2570000.0 s
# Average concentration: 1.6320760267723144e+24 atm/m^3
#
# Current time: 2580000.0 s
# Average concentration: 1.6322574214322248e+24 atm/m^3
#
# Current time: 2590000.0 s
# Average concentration: 1.6324359797983553e+24 atm/m^3
#
# Current time: 2600000.0 s
# Average concentration: 1.6326117483159624e+24 atm/m^3
#
# Current time: 2610000.0 s
# Average concentration: 1.632784772621518e+24 atm/m^3
#
# Current time: 2620000.0 s
# Average concentration: 1.6329550975579643e+24 atm/m^3
#
# Current time: 2630000.0 s
# Average concentration: 1.6331227671896497e+24 atm/m^3
#
# Current time: 2640000.0 s
# Average concentration: 1.6332878248169562e+24 atm/m^3
#
# Current time: 2650000.0 s
# Average concentration: 1.6334503129906233e+24 atm/m^3
#
# Current time: 2660000.0 s
# Average concentration: 1.633610273525775e+24 atm/m^3
#
# Current time: 2670000.0 s
# Average concentration: 1.6337677475156554e+24 atm/m^3
#
# Current time: 2680000.0 s
# Average concentration: 1.63392277534509e+24 atm/m^3
#
# Current time: 2690000.0 s
# Average concentration: 1.6340753967036605e+24 atm/m^3
#
# Current time: 2700000.0 s
# Average concentration: 1.634225650598617e+24 atm/m^3
#
# Current time: 2710000.0 s
# Average concentration: 1.6343735753675237e+24 atm/m^3
#
# Current time: 2720000.0 s
# Average concentration: 1.634519208690648e+24 atm/m^3
#
# Current time: 2730000.0 s
# Average concentration: 1.6346625876030992e+24 atm/m^3
#
# Current time: 2740000.0 s
# Average concentration: 1.6348037485067168e+24 atm/m^3
#
# Current time: 2750000.0 s
# Average concentration: 1.634942727181726e+24 atm/m^3
#
# Current time: 2760000.0 s
# Average concentration: 1.6350795587981513e+24 atm/m^3
#
# Current time: 2770000.0 s
# Average concentration: 1.6352142779270018e+24 atm/m^3
#
# Current time: 2780000.0 s
# Average concentration: 1.6353469185512348e+24 atm/m^3
#
# Current time: 2790000.0 s
# Average concentration: 1.6354775140765e+24 atm/m^3
#
# Current time: 2800000.0 s
# Average concentration: 1.6356060973416637e+24 atm/m^3
#
# Current time: 2810000.0 s
# Average concentration: 1.6357327006291296e+24 atm/m^3
#
# Current time: 2820000.0 s
# Average concentration: 1.635857355674952e+24 atm/m^3
#
# Current time: 2830000.0 s
# Average concentration: 1.635980093678744e+24 atm/m^3
#
# Current time: 2840000.0 s
# Average concentration: 1.636100945313401e+24 atm/m^3
#
# Current time: 2850000.0 s
# Average concentration: 1.6362199407346163e+24 atm/m^3
#
# Current time: 2860000.0 s
# Average concentration: 1.6363371095902234e+24 atm/m^3
#
# Current time: 2870000.0 s
# Average concentration: 1.6364524810293478e+24 atm/m^3
#
# Current time: 2880000.0 s
# Average concentration: 1.6365660837113774e+24 atm/m^3
#
# Current time: 2890000.0 s
# Average concentration: 1.636677945814764e+24 atm/m^3
#
# Current time: 2900000.0 s
# Average concentration: 1.6367880950456448e+24 atm/m^3
#
# Current time: 2910000.0 s
# Average concentration: 1.6368965586463027e+24 atm/m^3
#
# Current time: 2920000.0 s
# Average concentration: 1.6370033634034593e+24 atm/m^3
#
# Current time: 2930000.0 s
# Average concentration: 1.6371085356564042e+24 atm/m^3
#
# Current time: 2940000.0 s
# Average concentration: 1.6372121013049708e+24 atm/m^3
#
# Current time: 2950000.0 s
# Average concentration: 1.6373140858173573e+24 atm/m^3
#
# Current time: 2960000.0 s
# Average concentration: 1.6374145142377936e+24 atm/m^3
#
# Current time: 2970000.0 s
# Average concentration: 1.637513411194063e+24 atm/m^3
#
# Current time: 2980000.0 s
# Average concentration: 1.6376108009048817e+24 atm/m^3
#
# Current time: 2990000.0 s
# Average concentration: 1.6377067071871321e+24 atm/m^3
#
# Current time: 3000000.0 s
# Average concentration: 1.6378011534629583e+24 atm/m^3
#
# Current time: 3010000.0 s
# Average concentration: 1.6378941627667315e+24 atm/m^3
#
# Current time: 3020000.0 s
# Average concentration: 1.6379857577518713e+24 atm/m^3
#
# Current time: 3030000.0 s
# Average concentration: 1.6380759606975514e+24 atm/m^3
#
# Current time: 3040000.0 s
# Average concentration: 1.6381647935152679e+24 atm/m^3
#
# Current time: 3050000.0 s
# Average concentration: 1.638252277755285e+24 atm/m^3
#
# Current time: 3060000.0 s
# Average concentration: 1.638338434612963e+24 atm/m^3
#
# Current time: 3070000.0 s
# Average concentration: 1.6384232849349582e+24 atm/m^3
#
# Current time: 3080000.0 s
# Average concentration: 1.6385068492253144e+24 atm/m^3
#
# Current time: 3090000.0 s
# Average concentration: 1.638589147651436e+24 atm/m^3
#
# Current time: 3100000.0 s
# Average concentration: 1.6386702000499504e+24 atm/m^3
#
# Current time: 3110000.0 s
# Average concentration: 1.6387500259324562e+24 atm/m^3
#
# Current time: 3120000.0 s
# Average concentration: 1.6388286444911693e+24 atm/m^3
#
# Current time: 3130000.0 s
# Average concentration: 1.638906074604462e+24 atm/m^3
#
# Current time: 3140000.0 s
# Average concentration: 1.6389823348422945e+24 atm/m^3
#
# Current time: 3150000.0 s
# Average concentration: 1.6390574434715518e+24 atm/m^3
#
# Current time: 3160000.0 s
# Average concentration: 1.6391314184612788e+24 atm/m^3
#
# Current time: 3170000.0 s
# Average concentration: 1.6392042774878149e+24 atm/m^3
#
# Current time: 3180000.0 s
# Average concentration: 1.6392760379398364e+24 atm/m^3
#
# Current time: 3190000.0 s
# Average concentration: 1.6393467169233088e+24 atm/m^3
#
# Current time: 3200000.0 s
# Average concentration: 1.639416331266344e+24 atm/m^3
#
# Current time: 3210000.0 s
# Average concentration: 1.6394848975239636e+24 atm/m^3
#
# Current time: 3220000.0 s
# Average concentration: 1.6395524319827858e+24 atm/m^3
#
# Current time: 3230000.0 s
# Average concentration: 1.6396189506656139e+24 atm/m^3
#
# Current time: 3240000.0 s
# Average concentration: 1.639684469335953e+24 atm/m^3
#
# Current time: 3250000.0 s
# Average concentration: 1.639749003502433e+24 atm/m^3
#
# Current time: 3260000.0 s
# Average concentration: 1.6398125684231555e+24 atm/m^3
#
# Current time: 3270000.0 s
# Average concentration: 1.6398751791099644e+24 atm/m^3
#
# Current time: 3280000.0 s
# Average concentration: 1.639936850332631e+24 atm/m^3
#
# Current time: 3290000.0 s
# Average concentration: 1.6399975966229714e+24 atm/m^3
#
# Current time: 3300000.0 s
# Average concentration: 1.6400574322788848e+24 atm/m^3
#
# Current time: 3310000.0 s
# Average concentration: 1.6401163713683154e+24 atm/m^3
#
# Current time: 3320000.0 s
# Average concentration: 1.6401744277331496e+24 atm/m^3
#
# Current time: 3330000.0 s
# Average concentration: 1.6402316149930397e+24 atm/m^3
#
# Current time: 3340000.0 s
# Average concentration: 1.6402879465491548e+24 atm/m^3
#
# Current time: 3350000.0 s
# Average concentration: 1.6403434355878711e+24 atm/m^3
#
# Current time: 3360000.0 s
# Average concentration: 1.6403980950843899e+24 atm/m^3
#
# Current time: 3370000.0 s
# Average concentration: 1.6404519378062953e+24 atm/m^3
#
# Current time: 3380000.0 s
# Average concentration: 1.64050497631704e+24 atm/m^3
#
# Current time: 3390000.0 s
# Average concentration: 1.6405572229793807e+24 atm/m^3
#
# Current time: 3400000.0 s
# Average concentration: 1.6406086899587426e+24 atm/m^3
#
# Current time: 3410000.0 s
# Average concentration: 1.6406593892265282e+24 atm/m^3
#
# Current time: 3420000.0 s
# Average concentration: 1.640709332563363e+24 atm/m^3
#
# Current time: 3430000.0 s
# Average concentration: 1.6407585315622894e+24 atm/m^3
#
# Current time: 3440000.0 s
# Average concentration: 1.640806997631899e+24 atm/m^3
#
# Current time: 3450000.0 s
# Average concentration: 1.6408547419994097e+24 atm/m^3
#
# Current time: 3460000.0 s
# Average concentration: 1.640901775713691e+24 atm/m^3
#
# Current time: 3470000.0 s
# Average concentration: 1.6409481096482334e+24 atm/m^3
#
# Current time: 3480000.0 s
# Average concentration: 1.6409937545040663e+24 atm/m^3
#
# Current time: 3490000.0 s
# Average concentration: 1.6410387208126233e+24 atm/m^3
#
# Current time: 3500000.0 s
# Average concentration: 1.6410830189385575e+24 atm/m^3
#
# Current time: 3510000.0 s
# Average concentration: 1.6411266590825098e+24 atm/m^3
#
# Current time: 3520000.0 s
# Average concentration: 1.6411696512838218e+24 atm/m^3
#
# Current time: 3530000.0 s
# Average concentration: 1.6412120054232088e+24 atm/m^3
#
# Current time: 3540000.0 s
# Average concentration: 1.641253731225379e+24 atm/m^3
#
# Current time: 3550000.0 s
# Average concentration: 1.641294838261616e+24 atm/m^3
#
# Current time: 3560000.0 s
# Average concentration: 1.641335335952305e+24 atm/m^3
#
# Current time: 3570000.0 s
# Average concentration: 1.6413752335694223e+24 atm/m^3
#
# Current time: 3580000.0 s
# Average concentration: 1.641414540238979e+24 atm/m^3
#
# Current time: 3590000.0 s
# Average concentration: 1.6414532649434215e+24 atm/m^3
#
# Current time: 3600000.0 s
# Average concentration: 1.6414914165239933e+24 atm/m^3
#
# Current time: 3610000.0 s
# Average concentration: 1.6415290036830533e+24 atm/m^3
#
# Current time: 3620000.0 s
# Average concentration: 1.6415660349863512e+24 atm/m^3
#
# Current time: 3630000.0 s
# Average concentration: 1.64160251886527e+24 atm/m^3
#
# Current time: 3640000.0 s
# Average concentration: 1.641638463619023e+24 atm/m^3
#
# Current time: 3650000.0 s
# Average concentration: 1.6416738774168178e+24 atm/m^3
#
# Current time: 3660000.0 s
# Average concentration: 1.641708768299981e+24 atm/m^3
#
# Current time: 3670000.0 s
# Average concentration: 1.6417431441840447e+24 atm/m^3
#
# Current time: 3680000.0 s
# Average concentration: 1.6417770128607996e+24 atm/m^3
#
# Current time: 3690000.0 s
# Average concentration: 1.6418103820003138e+24 atm/m^3
#
# Current time: 3700000.0 s
# Average concentration: 1.641843259152909e+24 atm/m^3
#
# Current time: 3710000.0 s
# Average concentration: 1.6418756517511142e+24 atm/m^3
#
# Current time: 3720000.0 s
# Average concentration: 1.641907567111578e+24 atm/m^3
#
# Current time: 3730000.0 s
# Average concentration: 1.6419390124369533e+24 atm/m^3
#
# Current time: 3740000.0 s
# Average concentration: 1.6419699948177405e+24 atm/m^3
#
# Current time: 3750000.0 s
# Average concentration: 1.642000521234111e+24 atm/m^3
#
# Current time: 3760000.0 s
# Average concentration: 1.642030598557694e+24 atm/m^3
#
# Current time: 3770000.0 s
# Average concentration: 1.642060233553329e+24 atm/m^3
#
# Current time: 3780000.0 s
# Average concentration: 1.642089432880797e+24 atm/m^3
#
# Current time: 3790000.0 s
# Average concentration: 1.6421182030965154e+24 atm/m^3
#
# Current time: 3800000.0 s
# Average concentration: 1.6421465506552076e+24 atm/m^3
#
# Current time: 3810000.0 s
# Average concentration: 1.6421744819115403e+24 atm/m^3
#
# Current time: 3820000.0 s
# Average concentration: 1.6422020031217408e+24 atm/m^3
#
# Current time: 3830000.0 s
# Average concentration: 1.6422291204451765e+24 atm/m^3
#
# Current time: 3840000.0 s
# Average concentration: 1.642255839945917e+24 atm/m^3
#
# Current time: 3850000.0 s
# Average concentration: 1.6422821675942654e+24 atm/m^3
#
# Current time: 3860000.0 s
# Average concentration: 1.6423081092682594e+24 atm/m^3
#
# Current time: 3870000.0 s
# Average concentration: 1.6423336707551608e+24 atm/m^3
#
# Current time: 3880000.0 s
# Average concentration: 1.6423588577529048e+24 atm/m^3
#
# Current time: 3890000.0 s
# Average concentration: 1.642383675871532e+24 atm/m^3
#
# Current time: 3900000.0 s
# Average concentration: 1.6424081306345978e+24 atm/m^3
#
# Current time: 3910000.0 s
# Average concentration: 1.6424322274805518e+24 atm/m^3
#
# Current time: 3920000.0 s
# Average concentration: 1.6424559717641024e+24 atm/m^3
#
# Current time: 3930000.0 s
# Average concentration: 1.642479368757553e+24 atm/m^3
#
# Current time: 3940000.0 s
# Average concentration: 1.6425024236521167e+24 atm/m^3
#
# Current time: 3950000.0 s
# Average concentration: 1.642525141559208e+24 atm/m^3
#
# Current time: 3960000.0 s
# Average concentration: 1.6425475275117183e+24 atm/m^3
#
# Current time: 3970000.0 s
# Average concentration: 1.642569586465261e+24 atm/m^3
#
# Current time: 3980000.0 s
# Average concentration: 1.6425913232994059e+24 atm/m^3
#
# Current time: 3990000.0 s
# Average concentration: 1.6426127428188838e+24 atm/m^3
#
# Current time: 4000000.0 s
# Average concentration: 1.642633849754781e+24 atm/m^3
#
# Current time: 4010000.0 s
# Average concentration: 1.642654648765701e+24 atm/m^3
#
# Current time: 4020000.0 s
# Average concentration: 1.6426751444389224e+24 atm/m^3
#
# Current time: 4030000.0 s
# Average concentration: 1.642695341291522e+24 atm/m^3
#
# Current time: 4040000.0 s
# Average concentration: 1.642715243771492e+24 atm/m^3
#
# Current time: 4050000.0 s
# Average concentration: 1.642734856258833e+24 atm/m^3
#
# Current time: 4060000.0 s
# Average concentration: 1.6427541830666247e+24 atm/m^3
#
# Current time: 4070000.0 s
# Average concentration: 1.6427732284420898e+24 atm/m^3
#
# Current time: 4080000.0 s
# Average concentration: 1.6427919965676308e+24 atm/m^3
#
# Current time: 4090000.0 s
# Average concentration: 1.642810491561854e+24 atm/m^3
#
# Current time: 4100000.0 s
# Average concentration: 1.6428287174805745e+24 atm/m^3
#
# Current time: 4110000.0 s
# Average concentration: 1.6428466783178074e+24 atm/m^3
#
# Current time: 4120000.0 s
# Average concentration: 1.64286437800674e+24 atm/m^3
#
# Current time: 4130000.0 s
# Average concentration: 1.642881820420692e+24 atm/m^3
#
# Current time: 4140000.0 s
# Average concentration: 1.6428990093740517e+24 atm/m^3
#
# Current time: 4150000.0 s
# Average concentration: 1.642915948623207e+24 atm/m^3
#
# Current time: 4160000.0 s
# Average concentration: 1.6429326418674538e+24 atm/m^3
#
# Current time: 4170000.0 s
# Average concentration: 1.6429490927498944e+24 atm/m^3
#
# Current time: 4180000.0 s
# Average concentration: 1.6429653048583174e+24 atm/m^3
#
# Current time: 4190000.0 s
# Average concentration: 1.6429812817260637e+24 atm/m^3
#
# Current time: 4200000.0 s
# Average concentration: 1.642997026832883e+24 atm/m^3
#
# Current time: 4210000.0 s
# Average concentration: 1.6430125436057688e+24 atm/m^3
#
# Current time: 4220000.0 s
# Average concentration: 1.6430278354197868e+24 atm/m^3
#
# Current time: 4230000.0 s
# Average concentration: 1.6430429055988837e+24 atm/m^3
#
# Current time: 4240000.0 s
# Average concentration: 1.6430577574166897e+24 atm/m^3
#
# Current time: 4250000.0 s
# Average concentration: 1.643072394097301e+24 atm/m^3
#
# Current time: 4260000.0 s
# Average concentration: 1.6430868188160533e+24 atm/m^3
#
# Current time: 4270000.0 s
# Average concentration: 1.6431010347002838e+24 atm/m^3
#
# Current time: 4280000.0 s
# Average concentration: 1.6431150448300778e+24 atm/m^3
#
# Current time: 4290000.0 s
# Average concentration: 1.643128852239004e+24 atm/m^3
#
# Current time: 4300000.0 s
# Average concentration: 1.6431424599148416e+24 atm/m^3
#
# Current time: 4310000.0 s
# Average concentration: 1.6431558708002888e+24 atm/m^3
#
# Current time: 4320000.0 s
# Average concentration: 1.6431690877936654e+24 atm/m^3
#
# Current time: 4330000.0 s
# Average concentration: 1.6431821137496024e+24 atm/m^3
#
# Current time: 4340000.0 s
# Average concentration: 1.643194951479721e+24 atm/m^3
#
# Current time: 4350000.0 s
# Average concentration: 1.6432076037532972e+24 atm/m^3
#
# Current time: 4360000.0 s
# Average concentration: 1.6432200732979228e+24 atm/m^3
#
# Current time: 4370000.0 s
# Average concentration: 1.6432323628001476e+24 atm/m^3
#
# Current time: 4380000.0 s
# Average concentration: 1.6432444749061165e+24 atm/m^3
#
# Current time: 4390000.0 s
# Average concentration: 1.6432564122221956e+24 atm/m^3
#
# Current time: 4400000.0 s
# Average concentration: 1.6432681773155852e+24 atm/m^3
#
# Current time: 4410000.0 s
# Average concentration: 1.643279772714931e+24 atm/m^3
#
# Current time: 4420000.0 s
# Average concentration: 1.6432912009109127e+24 atm/m^3
#
# Current time: 4430000.0 s
# Average concentration: 1.643302464356836e+24 atm/m^3
#
# Current time: 4440000.0 s
# Average concentration: 1.6433135654692053e+24 atm/m^3
#
# Current time: 4450000.0 s
# Average concentration: 1.6433245066282953e+24 atm/m^3
#
# Current time: 4460000.0 s
# Average concentration: 1.643335290178708e+24 atm/m^3
#
# Current time: 4470000.0 s
# Average concentration: 1.6433459184299187e+24 atm/m^3
#
# Current time: 4480000.0 s
# Average concentration: 1.643356393656823e+24 atm/m^3
#
# Current time: 4490000.0 s
# Average concentration: 1.6433667181002673e+24 atm/m^3
#
# Current time: 4500000.0 s
# Average concentration: 1.6433768939675692e+24 atm/m^3
#
# Current time: 4510000.0 s
# Average concentration: 1.6433869234330362e+24 atm/m^3
#
# Current time: 4520000.0 s
# Average concentration: 1.6433968086384743e+24 atm/m^3
#
# Current time: 4530000.0 s
# Average concentration: 1.6434065516936813e+24 atm/m^3
#
# Current time: 4540000.0 s
# Average concentration: 1.6434161546769448e+24 atm/m^3
#
# Current time: 4550000.0 s
# Average concentration: 1.643425619635521e+24 atm/m^3
#
# Current time: 4560000.0 s
# Average concentration: 1.6434349485861137e+24 atm/m^3
#
# Current time: 4570000.0 s
# Average concentration: 1.6434441435153393e+24 atm/m^3
#
# Current time: 4580000.0 s
# Average concentration: 1.643453206380191e+24 atm/m^3
#
# Current time: 4590000.0 s
# Average concentration: 1.6434621391084896e+24 atm/m^3
#
# Current time: 4600000.0 s
# Average concentration: 1.6434709435993298e+24 atm/m^3
#
# Current time: 4610000.0 s
# Average concentration: 1.6434796217235223e+24 atm/m^3
#
# Current time: 4620000.0 s
# Average concentration: 1.6434881753240243e+24 atm/m^3
#
# Current time: 4630000.0 s
# Average concentration: 1.6434966062163636e+24 atm/m^3
#
# Current time: 4640000.0 s
# Average concentration: 1.6435049161890596e+24 atm/m^3
#
# Current time: 4650000.0 s
# Average concentration: 1.6435131070040368e+24 atm/m^3
#
# Current time: 4660000.0 s
# Average concentration: 1.6435211803970246e+24 atm/m^3
#
# Current time: 4670000.0 s
# Average concentration: 1.6435291380779635e+24 atm/m^3
#
# Current time: 4680000.0 s
# Average concentration: 1.6435369817313923e+24 atm/m^3
#
# Current time: 4690000.0 s
# Average concentration: 1.6435447130168422e+24 atm/m^3
#
# Current time: 4700000.0 s
# Average concentration: 1.6435523335692087e+24 atm/m^3
#
# Current time: 4710000.0 s
# Average concentration: 1.643559844999132e+24 atm/m^3
#
# Current time: 4720000.0 s
# Average concentration: 1.6435672488933643e+24 atm/m^3
#
# Current time: 4730000.0 s
# Average concentration: 1.6435745468151352e+24 atm/m^3
#
# Current time: 4740000.0 s
# Average concentration: 1.6435817403045027e+24 atm/m^3
#
# Current time: 4750000.0 s
# Average concentration: 1.6435888308787156e+24 atm/m^3
#
# Current time: 4760000.0 s
# Average concentration: 1.643595820032548e+24 atm/m^3
#
# Current time: 4770000.0 s
# Average concentration: 1.6436027092386478e+24 atm/m^3
#
# Current time: 4780000.0 s
# Average concentration: 1.6436094999478722e+24 atm/m^3
#
# Current time: 4790000.0 s
# Average concentration: 1.6436161935896145e+24 atm/m^3
#
# Current time: 4800000.0 s
# Average concentration: 1.6436227915721288e+24 atm/m^3
#
# Current time: 4810000.0 s
# Average concentration: 1.6436292952828546e+24 atm/m^3
#
# Current time: 4820000.0 s
# Average concentration: 1.6436357060887282e+24 atm/m^3
#
# Current time: 4830000.0 s
# Average concentration: 1.6436420253364938e+24 atm/m^3
#
# Current time: 4840000.0 s
# Average concentration: 1.64364825435301e+24 atm/m^3
#
# Current time: 4850000.0 s
# Average concentration: 1.6436543944455488e+24 atm/m^3
#
# Current time: 4860000.0 s
# Average concentration: 1.643660446902091e+24 atm/m^3
#
# Current time: 4870000.0 s
# Average concentration: 1.6436664129916206e+24 atm/m^3
#
# Current time: 4880000.0 s
# Average concentration: 1.6436722939644087e+24 atm/m^3
#
# Current time: 4890000.0 s
# Average concentration: 1.643678091052295e+24 atm/m^3
#
# Current time: 4900000.0 s
# Average concentration: 1.64368380546897e+24 atm/m^3
#
# Current time: 4910000.0 s
# Average concentration: 1.6436894384102427e+24 atm/m^3
#
# Current time: 4920000.0 s
# Average concentration: 1.6436949910543168e+24 atm/m^3
#
# Current time: 4930000.0 s
# Average concentration: 1.6437004645620495e+24 atm/m^3
#
# Current time: 4940000.0 s
# Average concentration: 1.6437058600772178e+24 atm/m^3
#
# Current time: 4950000.0 s
# Average concentration: 1.6437111787267693e+24 atm/m^3
#
# Current time: 4960000.0 s
# Average concentration: 1.6437164216210836e+24 atm/m^3
#
# Current time: 4970000.0 s
# Average concentration: 1.643721589854215e+24 atm/m^3
#
# Current time: 4980000.0 s
# Average concentration: 1.6437266845041386e+24 atm/m^3
#
# Current time: 4990000.0 s
# Average concentration: 1.6437317066329944e+24 atm/m^3
#
# Current time: 5000000.0 s
# Average concentration: 1.6437366572873245e+24 atm/m^3
#
# Current time: 5010000.0 s
# Average concentration: 1.6437415374983028e+24 atm/m^3
#
# Current time: 5020000.0 s
# Average concentration: 1.6437463482819729e+24 atm/m^3
#
# Current time: 5030000.0 s
# Average concentration: 1.643751090639468e+24 atm/m^3
#
# Current time: 5040000.0 s
# Average concentration: 1.6437557655572385e+24 atm/m^3
#
# Current time: 5050000.0 s
# Average concentration: 1.6437603740072737e+24 atm/m^3
#
# Current time: 5060000.0 s
# Average concentration: 1.643764916947314e+24 atm/m^3
#
# Current time: 5070000.0 s
# Average concentration: 1.6437693953210644e+24 atm/m^3
#
# Current time: 5080000.0 s
# Average concentration: 1.6437738100584076e+24 atm/m^3
#
# Current time: 5090000.0 s
# Average concentration: 1.6437781620756082e+24 atm/m^3
#
# Current time: 5100000.0 s
# Average concentration: 1.6437824522755184e+24 atm/m^3
#
# Current time: 5110000.0 s
# Average concentration: 1.6437866815477785e+24 atm/m^3
#
# Current time: 5120000.0 s
# Average concentration: 1.643790850769011e+24 atm/m^3
#
# Current time: 5130000.0 s
# Average concentration: 1.643794960803018e+24 atm/m^3
#
# Current time: 5140000.0 s
# Average concentration: 1.643799012500972e+24 atm/m^3
#
# Current time: 5150000.0 s
# Average concentration: 1.6438030067016056e+24 atm/m^3
#
# Current time: 5160000.0 s
# Average concentration: 1.6438069442313938e+24 atm/m^3
#
# Current time: 5170000.0 s
# Average concentration: 1.6438108259047383e+24 atm/m^3
#
# Current time: 5180000.0 s
# Average concentration: 1.6438146525241513e+24 atm/m^3
#
# Current time: 5190000.0 s
# Average concentration: 1.643818424880425e+24 atm/m^3
#
# Current time: 5200000.0 s
# Average concentration: 1.6438221437528108e+24 atm/m^3
#
# Current time: 5210000.0 s
# Average concentration: 1.643825809909195e+24 atm/m^3
#
# Current time: 5220000.0 s
# Average concentration: 1.6438294241062582e+24 atm/m^3
#
# Current time: 5230000.0 s
# Average concentration: 1.6438329870896516e+24 atm/m^3
#
# Current time: 5240000.0 s
# Average concentration: 1.6438364995941543e+24 atm/m^3
#
# Current time: 5250000.0 s
# Average concentration: 1.6438399623438386e+24 atm/m^3
#
# Current time: 5260000.0 s
# Average concentration: 1.643843376052227e+24 atm/m^3
#
# Current time: 5270000.0 s
# Average concentration: 1.64384674142245e+24 atm/m^3
#
# Current time: 5280000.0 s
# Average concentration: 1.6438500591474014e+24 atm/m^3
#
# Current time: 5290000.0 s
# Average concentration: 1.64385332990989e+24 atm/m^3
#
# Current time: 5300000.0 s
# Average concentration: 1.6438565543827848e+24 atm/m^3
#
# Current time: 5310000.0 s
# Average concentration: 1.6438597332291684e+24 atm/m^3
#
# Current time: 5320000.0 s
# Average concentration: 1.6438628671024807e+24 atm/m^3
#
# Current time: 5330000.0 s
# Average concentration: 1.6438659566466595e+24 atm/m^3
#
# Current time: 5340000.0 s
# Average concentration: 1.643869002496281e+24 atm/m^3
#
# Current time: 5350000.0 s
# Average concentration: 1.6438720052767038e+24 atm/m^3
#
# Current time: 5360000.0 s
# Average concentration: 1.6438749656041992e+24 atm/m^3
#
# Current time: 5370000.0 s
# Average concentration: 1.6438778840860879e+24 atm/m^3
#
# Current time: 5380000.0 s
# Average concentration: 1.643880761320876e+24 atm/m^3
#
# Current time: 5390000.0 s
# Average concentration: 1.6438835978983767e+24 atm/m^3
#
# Current time: 5400000.0 s
# Average concentration: 1.6438863943998497e+24 atm/m^3
#
# Current time: 5410000.0 s
# Average concentration: 1.6438891513981197e+24 atm/m^3
#
# Current time: 5420000.0 s
# Average concentration: 1.6438918694577008e+24 atm/m^3
#
# Current time: 5430000.0 s
# Average concentration: 1.6438945491349276e+24 atm/m^3
#
# Current time: 5440000.0 s
# Average concentration: 1.6438971909780648e+24 atm/m^3
#
# Current time: 5450000.0 s
# Average concentration: 1.6438997955274356e+24 atm/m^3
#
# Current time: 5460000.0 s
# Average concentration: 1.643902363315533e+24 atm/m^3
#
# Current time: 5470000.0 s
# Average concentration: 1.6439048948671396e+24 atm/m^3
#
# Current time: 5480000.0 s
# Average concentration: 1.643907390699435e+24 atm/m^3
#
# Current time: 5490000.0 s
# Average concentration: 1.6439098513221175e+24 atm/m^3
#
# Current time: 5500000.0 s
# Average concentration: 1.6439122772375034e+24 atm/m^3
#
# Current time: 5510000.0 s
# Average concentration: 1.6439146689406444e+24 atm/m^3
#
# Current time: 5520000.0 s
# Average concentration: 1.6439170269194284e+24 atm/m^3
#
# Current time: 5530000.0 s
# Average concentration: 1.6439193516546912e+24 atm/m^3
#
# Current time: 5540000.0 s
# Average concentration: 1.643921643620316e+24 atm/m^3
#
# Current time: 5550000.0 s
# Average concentration: 1.643923903283335e+24 atm/m^3
#
# Current time: 5560000.0 s
# Average concentration: 1.6439261311040325e+24 atm/m^3
#
# Current time: 5570000.0 s
# Average concentration: 1.643928327536044e+24 atm/m^3
#
# Current time: 5580000.0 s
# Average concentration: 1.6439304930264536e+24 atm/m^3
#
# Current time: 5590000.0 s
# Average concentration: 1.6439326280158866e+24 atm/m^3
#
# Current time: 5600000.0 s
# Average concentration: 1.643934732938613e+24 atm/m^3
#
# Current time: 5610000.0 s
# Average concentration: 1.6439368082226304e+24 atm/m^3
#
# Current time: 5620000.0 s
# Average concentration: 1.6439388542897643e+24 atm/m^3
#
# Current time: 5630000.0 s
# Average concentration: 1.6439408715557543e+24 atm/m^3
#
# Current time: 5640000.0 s
# Average concentration: 1.6439428604303432e+24 atm/m^3
#
# Current time: 5650000.0 s
# Average concentration: 1.6439448213173683e+24 atm/m^3
#
# Current time: 5660000.0 s
# Average concentration: 1.643946754614847e+24 atm/m^3
#
# Current time: 5670000.0 s
# Average concentration: 1.6439486607150582e+24 atm/m^3
#
# Current time: 5680000.0 s
# Average concentration: 1.6439505400046314e+24 atm/m^3
#
# Current time: 5690000.0 s
# Average concentration: 1.6439523928646254e+24 atm/m^3
#
# Current time: 5700000.0 s
# Average concentration: 1.6439542196706125e+24 atm/m^3
#
# Current time: 5710000.0 s
# Average concentration: 1.6439560207927596e+24 atm/m^3
#
# Current time: 5720000.0 s
# Average concentration: 1.6439577965959032e+24 atm/m^3
#
# Current time: 5730000.0 s
# Average concentration: 1.643959547439631e+24 atm/m^3
#
# Current time: 5740000.0 s
# Average concentration: 1.6439612736783576e+24 atm/m^3
#
# Current time: 5750000.0 s
# Average concentration: 1.643962975661401e+24 atm/m^3
#
# Current time: 5760000.0 s
# Average concentration: 1.6439646537330537e+24 atm/m^3
#
# Current time: 5770000.0 s
# Average concentration: 1.643966308232661e+24 atm/m^3
#
# Current time: 5780000.0 s
# Average concentration: 1.6439679394946906e+24 atm/m^3
#
# Current time: 5790000.0 s
# Average concentration: 1.6439695478488013e+24 atm/m^3
#
# Current time: 5800000.0 s
# Average concentration: 1.6439711336199197e+24 atm/m^3
#
# Current time: 5810000.0 s
# Average concentration: 1.6439726971283028e+24 atm/m^3
#
# Current time: 5820000.0 s
# Average concentration: 1.643974238689611e+24 atm/m^3
#
# Current time: 5830000.0 s
# Average concentration: 1.6439757586149716e+24 atm/m^3
#
# Current time: 5840000.0 s
# Average concentration: 1.6439772572110462e+24 atm/m^3
#
# Current time: 5850000.0 s
# Average concentration: 1.6439787347800958e+24 atm/m^3
#
# Current time: 5860000.0 s
# Average concentration: 1.6439801916200468e+24 atm/m^3
#
# Current time: 5870000.0 s
# Average concentration: 1.64398162802455e+24 atm/m^3
#
# Current time: 5880000.0 s
# Average concentration: 1.6439830442830459e+24 atm/m^3
#
# Current time: 5890000.0 s
# Average concentration: 1.6439844406808262e+24 atm/m^3
#
# Current time: 5900000.0 s
# Average concentration: 1.6439858174990927e+24 atm/m^3
#
# Current time: 5910000.0 s
# Average concentration: 1.6439871750150163e+24 atm/m^3
#
# Current time: 5920000.0 s
# Average concentration: 1.6439885135018005e+24 atm/m^3
#
# Current time: 5930000.0 s
# Average concentration: 1.6439898332287314e+24 atm/m^3
#
# Current time: 5940000.0 s
# Average concentration: 1.6439911344612385e+24 atm/m^3
#
# Current time: 5950000.0 s
# Average concentration: 1.6439924174609543e+24 atm/m^3
#
# Current time: 5960000.0 s
# ...
#
# Current time: 8040000.0 s
# Average concentration: 1.6440783952461627e+24 atm/m^3
#
# Current time: 8050000.0 s
# Average concentration: 1.6440784636833315e+24 atm/m^3
#
# Current time: 8060000.0 s
# Average concentration: 1.6440785311796925e+24 atm/m^3
#
# Current time: 8070000.0 s
# Average concentration: 1.644078597748233e+24 atm/m^3
#
# Current time: 8080000.0 s
# Average concentration: 1.6440786634017575e+24 atm/m^3
#
# Current time: 8090000.0 s
# Average concentration: 1.6440787281528952e+24 atm/m^3
#
# Current time: 8100000.0 s
# Average concentration: 1.6440787920140995e+24 atm/m^3
#
# Current time: 8110000.0 s
# Average concentration: 1.6440788549976488e+24 atm/m^3
#
# Current time: 8120000.0 s
# Average concentration: 1.6440789171156553e+24 atm/m^3
#
# Current time: 8130000.0 s
# Average concentration: 1.6440789783800596e+24 atm/m^3
#
# Current time: 8140000.0 s
# Average concentration: 1.6440790388026399e+24 atm/m^3
#
# Current time: 8150000.0 s
# Average concentration: 1.644079098395008e+24 atm/m^3
#
# Current time: 8160000.0 s
# Average concentration: 1.6440791571686153e+24 atm/m^3
#
# Current time: 8170000.0 s
# Average concentration: 1.644079215134757e+24 atm/m^3
#
# Current time: 8180000.0 s
# Average concentration: 1.644079272304568e+24 atm/m^3
#
# Current time: 8190000.0 s
# Average concentration: 1.6440793286890327e+24 atm/m^3
#
# Current time: 8200000.0 s
# Average concentration: 1.64407938429898e+24 atm/m^3
#
# Current time: 8210000.0 s
# Average concentration: 1.6440794391450904e+24 atm/m^3
#
# Current time: 8220000.0 s
# Average concentration: 1.644079493237896e+24 atm/m^3
#
# Current time: 8230000.0 s
# Average concentration: 1.6440795465877831e+24 atm/m^3
#
# Current time: 8240000.0 s
# Average concentration: 1.6440795992049934e+24 atm/m^3
#
# Current time: 8250000.0 s
# Average concentration: 1.644079651099628e+24 atm/m^3
#
# Current time: 8260000.0 s
# Average concentration: 1.6440797022816466e+24 atm/m^3
#
# Current time: 8270000.0 s
# Average concentration: 1.6440797527608731e+24 atm/m^3
#
# Current time: 8280000.0 s
# Average concentration: 1.6440798025469913e+24 atm/m^3
#
# Current time: 8290000.0 s
# Average concentration: 1.6440798516495563e+24 atm/m^3
#
# Current time: 8300000.0 s
# Average concentration: 1.6440799000779856e+24 atm/m^3
#
# Current time: 8310000.0 s
# Average concentration: 1.6440799478415702e+24 atm/m^3
#
# Current time: 8320000.0 s
# Average concentration: 1.6440799949494715e+24 atm/m^3
#
# Current time: 8330000.0 s
# Average concentration: 1.644080041410722e+24 atm/m^3
#
# Current time: 8340000.0 s
# Average concentration: 1.644080087234232e+24 atm/m^3
#
# Current time: 8350000.0 s
# Average concentration: 1.6440801324287864e+24 atm/m^3
#
# Current time: 8360000.0 s
# Average concentration: 1.6440801770030514e+24 atm/m^3
#
# Current time: 8370000.0 s
# Average concentration: 1.6440802209655682e+24 atm/m^3
#
# Current time: 8380000.0 s
# Average concentration: 1.644080264324765e+24 atm/m^3
#
# Current time: 8390000.0 s
# Average concentration: 1.6440803070889492e+24 atm/m^3
#
# Current time: 8400000.0 s
# Average concentration: 1.6440803492663162e+24 atm/m^3
#
# Current time: 8410000.0 s
# Average concentration: 1.644080390864947e+24 atm/m^3
#
# Current time: 8420000.0 s
# Average concentration: 1.6440804318928114e+24 atm/m^3
#
# Current time: 8430000.0 s
# Average concentration: 1.6440804723577677e+24 atm/m^3
#
# Current time: 8440000.0 s
# Average concentration: 1.6440805122675675e+24 atm/m^3
#
# Current time: 8450000.0 s
# Average concentration: 1.6440805516298518e+24 atm/m^3
#
# Current time: 8460000.0 s
# Average concentration: 1.6440805904521592e+24 atm/m^3
#
# Current time: 8470000.0 s
# Average concentration: 1.6440806287419228e+24 atm/m^3
#
# Current time: 8480000.0 s
# Average concentration: 1.6440806665064724e+24 atm/m^3
#
# Current time: 8490000.0 s
# Average concentration: 1.6440807037530378e+24 atm/m^3
#
# Current time: 8500000.0 s
# Average concentration: 1.6440807404887483e+24 atm/m^3
#
# Current time: 8510000.0 s
# Average concentration: 1.6440807767206332e+24 atm/m^3
#
# Current time: 8520000.0 s
# Average concentration: 1.6440808124556268e+24 atm/m^3
#
# Current time: 8530000.0 s
# Average concentration: 1.6440808477005657e+24 atm/m^3
#
# Current time: 8540000.0 s
# Average concentration: 1.644080882462194e+24 atm/m^3
#
# Current time: 8550000.0 s
# Average concentration: 1.6440809167471608e+24 atm/m^3
#
# Current time: 8560000.0 s
# Average concentration: 1.6440809505620243e+24 atm/m^3
#
# Current time: 8570000.0 s
# Average concentration: 1.6440809839132515e+24 atm/m^3
#
# Current time: 8580000.0 s
# Average concentration: 1.6440810168072214e+24 atm/m^3
#
# Current time: 8590000.0 s
# Average concentration: 1.644081049250224e+24 atm/m^3
#
# Current time: 8600000.0 s
# Average concentration: 1.6440810812484614e+24 atm/m^3
#
# Current time: 8610000.0 s
# Average concentration: 1.64408111280805e+24 atm/m^3
#
# Current time: 8620000.0 s
# Average concentration: 1.6440811439350236e+24 atm/m^3
#
# Current time: 8630000.0 s
# Average concentration: 1.6440811746353314e+24 atm/m^3
#
# Current time: 8640000.0 s
# Average concentration: 1.6440812049148417e+24 atm/m^3
#
# Current time: 8650000.0 s
# Average concentration: 1.6440812347793393e+24 atm/m^3
#
# Current time: 8660000.0 s
# Average concentration: 1.6440812642345326e+24 atm/m^3
#
# Current time: 8670000.0 s
# Average concentration: 1.644081293286047e+24 atm/m^3
#
# Current time: 8680000.0 s
# Average concentration: 1.644081321939434e+24 atm/m^3
#
# Current time: 8690000.0 s
# Average concentration: 1.6440813502001663e+24 atm/m^3
#
# Current time: 8700000.0 s
# Average concentration: 1.6440813780736418e+24 atm/m^3
#
# Current time: 8710000.0 s
# Average concentration: 1.644081405565183e+24 atm/m^3
#
# Current time: 8720000.0 s
# Average concentration: 1.6440814326800401e+24 atm/m^3
#
# Current time: 8730000.0 s
# Average concentration: 1.6440814594233903e+24 atm/m^3
#
# Current time: 8740000.0 s
# Average concentration: 1.6440814858003395e+24 atm/m^3
#
# Current time: 8750000.0 s
# Average concentration: 1.644081511815924e+24 atm/m^3
#
# Current time: 8760000.0 s
# Average concentration: 1.644081537475108e+24 atm/m^3
#
# Current time: 8770000.0 s
# Average concentration: 1.6440815627827908e+24 atm/m^3
#
# Current time: 8780000.0 s
# Average concentration: 1.6440815877438013e+24 atm/m^3
#
# Current time: 8790000.0 s
# Average concentration: 1.6440816123629028e+24 atm/m^3
#
# Current time: 8800000.0 s
# Average concentration: 1.6440816366447922e+24 atm/m^3
#
# Current time: 8810000.0 s
# Average concentration: 1.644081660594104e+24 atm/m^3
#
# Current time: 8820000.0 s
# Average concentration: 1.644081684215406e+24 atm/m^3
#
# Current time: 8830000.0 s
# Average concentration: 1.6440817075132032e+24 atm/m^3
#
# Current time: 8840000.0 s
# Average concentration: 1.6440817304919413e+24 atm/m^3
#
# Current time: 8850000.0 s
# Average concentration: 1.644081753156001e+24 atm/m^3
#
# Current time: 8860000.0 s
# Average concentration: 1.6440817755097049e+24 atm/m^3
#
# Current time: 8870000.0 s
# Average concentration: 1.6440817975573152e+24 atm/m^3
#
# Current time: 8880000.0 s
# Average concentration: 1.644081819303035e+24 atm/m^3
#
# Current time: 8890000.0 s
# Average concentration: 1.6440818407510108e+24 atm/m^3
#
# Current time: 8900000.0 s
# Average concentration: 1.644081861905332e+24 atm/m^3
#
# Current time: 8910000.0 s
# Average concentration: 1.644081882770029e+24 atm/m^3
#
# Current time: 8920000.0 s
# Average concentration: 1.6440819033490803e+24 atm/m^3
#
# Current time: 8930000.0 s
# Average concentration: 1.6440819236464048e+24 atm/m^3
#
# Current time: 8940000.0 s
# Average concentration: 1.6440819436658739e+24 atm/m^3
#
# Current time: 8950000.0 s
# Average concentration: 1.6440819634112993e+24 atm/m^3
#
# Current time: 8960000.0 s
# Average concentration: 1.6440819828864436e+24 atm/m^3
#
# Current time: 8970000.0 s
# Average concentration: 1.6440820020950183e+24 atm/m^3
#
# Current time: 8980000.0 s
# Average concentration: 1.6440820210406812e+24 atm/m^3
#
# Current time: 8990000.0 s
# Average concentration: 1.644082039727041e+24 atm/m^3
#
# Current time: 9000000.0 s
# Average concentration: 1.6440820581576565e+24 atm/m^3
#
# Current time: 9010000.0 s
# Average concentration: 1.6440820763360382e+24 atm/m^3
#
# Current time: 9020000.0 s
# Average concentration: 1.6440820942656454e+24 atm/m^3
#
# Current time: 9030000.0 s
# Average concentration: 1.644082111949895e+24 atm/m^3
#
# Current time: 9040000.0 s
# Average concentration: 1.644082129392152e+24 atm/m^3
#
# Current time: 9050000.0 s
# Average concentration: 1.644082146595738e+24 atm/m^3
#
# Current time: 9060000.0 s
# Average concentration: 1.6440821635639248e+24 atm/m^3
#
# Current time: 9070000.0 s
# Average concentration: 1.6440821802999446e+24 atm/m^3
#
# Current time: 9080000.0 s
# Average concentration: 1.6440821968069827e+24 atm/m^3
#
# Current time: 9090000.0 s
# Average concentration: 1.6440822130881794e+24 atm/m^3
#
# Current time: 9100000.0 s
# Average concentration: 1.644082229146634e+24 atm/m^3
#
# Current time: 9110000.0 s
# Average concentration: 1.6440822449854001e+24 atm/m^3
#
# Current time: 9120000.0 s
# Average concentration: 1.6440822606074922e+24 atm/m^3
#
# Current time: 9130000.0 s
# Average concentration: 1.6440822760158828e+24 atm/m^3
#
# Current time: 9140000.0 s
# Average concentration: 1.6440822912135016e+24 atm/m^3
#
# Current time: 9150000.0 s
# Average concentration: 1.6440823062032403e+24 atm/m^3
#
# Current time: 9160000.0 s
# Average concentration: 1.6440823209879496e+24 atm/m^3
#
# Current time: 9170000.0 s
# Average concentration: 1.6440823355704408e+24 atm/m^3
#
# Current time: 9180000.0 s
# Average concentration: 1.6440823499534863e+24 atm/m^3
#
# Current time: 9190000.0 s
# Average concentration: 1.6440823641398226e+24 atm/m^3
#
# Current time: 9200000.0 s
# Average concentration: 1.6440823781321453e+24 atm/m^3
#
# Current time: 9210000.0 s
# Average concentration: 1.644082391933115e+24 atm/m^3
#
# Current time: 9220000.0 s
# Average concentration: 1.6440824055453547e+24 atm/m^3
#
# Current time: 9230000.0 s
# Average concentration: 1.6440824189714533e+24 atm/m^3
#
# Current time: 9240000.0 s
# Average concentration: 1.6440824322139617e+24 atm/m^3
#
# Current time: 9250000.0 s
# Average concentration: 1.6440824452753953e+24 atm/m^3
#
# Current time: 9260000.0 s
# Average concentration: 1.6440824581582386e+24 atm/m^3
#
# Current time: 9270000.0 s
# Average concentration: 1.6440824708649377e+24 atm/m^3
#
# Current time: 9280000.0 s
# Average concentration: 1.6440824833979087e+24 atm/m^3
#
# Current time: 9290000.0 s
# Average concentration: 1.6440824957595305e+24 atm/m^3
#
# Current time: 9300000.0 s
# Average concentration: 1.644082507952153e+24 atm/m^3
#
# Current time: 9310000.0 s
# Average concentration: 1.6440825199780928e+24 atm/m^3
#
# Current time: 9320000.0 s
# Average concentration: 1.6440825318396315e+24 atm/m^3
#
# Current time: 9330000.0 s
# Average concentration: 1.6440825435390244e+24 atm/m^3
#
# Current time: 9340000.0 s
# Average concentration: 1.6440825550784931e+24 atm/m^3
#
# Current time: 9350000.0 s
# Average concentration: 1.6440825664602292e+24 atm/m^3
#
# Current time: 9360000.0 s
# Average concentration: 1.644082577686392e+24 atm/m^3
#
# Current time: 9370000.0 s
# Average concentration: 1.6440825887591142e+24 atm/m^3
#
# Current time: 9380000.0 s
# Average concentration: 1.6440825996804985e+24 atm/m^3
#
# Current time: 9390000.0 s
# Average concentration: 1.6440826104526177e+24 atm/m^3
#
# Current time: 9400000.0 s
# Average concentration: 1.6440826210775159e+24 atm/m^3
#
# Current time: 9410000.0 s
# Average concentration: 1.6440826315572114e+24 atm/m^3
#
# Current time: 9420000.0 s
# Average concentration: 1.6440826418936928e+24 atm/m^3
#
# Current time: 9430000.0 s
# Average concentration: 1.6440826520889205e+24 atm/m^3
#
# Current time: 9440000.0 s
# Average concentration: 1.6440826621448303e+24 atm/m^3
#
# Current time: 9450000.0 s
# Average concentration: 1.6440826720633303e+24 atm/m^3
#
# Current time: 9460000.0 s
# Average concentration: 1.6440826818463024e+24 atm/m^3
#
# Current time: 9470000.0 s
# Average concentration: 1.6440826914956022e+24 atm/m^3
#
# Current time: 9480000.0 s
# Average concentration: 1.6440827010130616e+24 atm/m^3
#
# Current time: 9490000.0 s
# Average concentration: 1.6440827104004852e+24 atm/m^3
#
# Current time: 9500000.0 s
# Average concentration: 1.644082719659653e+24 atm/m^3
#
# Current time: 9510000.0 s
# Average concentration: 1.6440827287923214e+24 atm/m^3
#
# Current time: 9520000.0 s
# Average concentration: 1.6440827378002242e+24 atm/m^3
#
# Current time: 9530000.0 s
# Average concentration: 1.6440827466850684e+24 atm/m^3
#
# Current time: 9540000.0 s
# Average concentration: 1.6440827554485382e+24 atm/m^3
#
# Current time: 9550000.0 s
# Average concentration: 1.644082764092297e+24 atm/m^3
#
# Current time: 9560000.0 s
# Average concentration: 1.6440827726179816e+24 atm/m^3
#
# Current time: 9570000.0 s
# Average concentration: 1.6440827810272098e+24 atm/m^3
#
# Current time: 9580000.0 s
# Average concentration: 1.6440827893215755e+24 atm/m^3
#
# Current time: 9590000.0 s
# Average concentration: 1.6440827975026512e+24 atm/m^3
#
# Current time: 9600000.0 s
# Average concentration: 1.6440828055719885e+24 atm/m^3
#
# Current time: 9610000.0 s
# Average concentration: 1.6440828135311142e+24 atm/m^3
#
# Current time: 9620000.0 s
# Average concentration: 1.6440828213815387e+24 atm/m^3
#
# Current time: 9630000.0 s
# Average concentration: 1.6440828291247495e+24 atm/m^3
#
# Current time: 9640000.0 s
# Average concentration: 1.6440828367622139e+24 atm/m^3
#
# Current time: 9650000.0 s
# Average concentration: 1.6440828442953787e+24 atm/m^3
#
# Current time: 9660000.0 s
# Average concentration: 1.6440828517256713e+24 atm/m^3
#
# Current time: 9670000.0 s
# Average concentration: 1.6440828590545002e+24 atm/m^3
#
# Current time: 9680000.0 s
# Average concentration: 1.6440828662832533e+24 atm/m^3
#
# Current time: 9690000.0 s
# Average concentration: 1.6440828734133006e+24 atm/m^3
#
# Current time: 9700000.0 s
# Average concentration: 1.6440828804459907e+24 atm/m^3
#
# Current time: 9710000.0 s
# Average concentration: 1.6440828873826587e+24 atm/m^3
#
# Current time: 9720000.0 s
# Average concentration: 1.644082894224616e+24 atm/m^3
#
# Current time: 9730000.0 s
# Average concentration: 1.644082900973159e+24 atm/m^3
#
# Current time: 9740000.0 s
# Average concentration: 1.6440829076295648e+24 atm/m^3
#
# Current time: 9750000.0 s
# Average concentration: 1.6440829141950958e+24 atm/m^3
#
# Current time: 9760000.0 s
# Average concentration: 1.6440829206709938e+24 atm/m^3
#
# Current time: 9770000.0 s
# Average concentration: 1.6440829270584864e+24 atm/m^3
#
# Current time: 9780000.0 s
# Average concentration: 1.6440829333587806e+24 atm/m^3
#
# Current time: 9790000.0 s
# Average concentration: 1.6440829395730705e+24 atm/m^3
#
# Current time: 9800000.0 s
# Average concentration: 1.6440829457025327e+24 atm/m^3
#
# Current time: 9810000.0 s
# Average concentration: 1.6440829517483268e+24 atm/m^3
#
# Current time: 9820000.0 s
# Average concentration: 1.6440829577115974e+24 atm/m^3
#
# Current time: 9830000.0 s
# Average concentration: 1.6440829635934724e+24 atm/m^3
#
# Current time: 9840000.0 s
# Average concentration: 1.644082969395067e+24 atm/m^3
#
# Current time: 9850000.0 s
# Average concentration: 1.6440829751174769e+24 atm/m^3
#
# Current time: 9860000.0 s
# Average concentration: 1.6440829807617862e+24 atm/m^3
#
# Current time: 9870000.0 s
# Average concentration: 1.6440829863290624e+24 atm/m^3
#
# Current time: 9880000.0 s
# Average concentration: 1.6440829918203577e+24 atm/m^3
#
# Current time: 9890000.0 s
# Average concentration: 1.644082997236712e+24 atm/m^3
#
# Current time: 9900000.0 s
# Average concentration: 1.6440830025791517e+24 atm/m^3
#
# Current time: 9910000.0 s
# Average concentration: 1.644083007848686e+24 atm/m^3
#
# Current time: 9920000.0 s
# Average concentration: 1.644083013046311e+24 atm/m^3
#
# Current time: 9930000.0 s
# Average concentration: 1.6440830181730108e+24 atm/m^3
#
# Current time: 9940000.0 s
# Average concentration: 1.644083023229754e+24 atm/m^3
#
# Current time: 9950000.0 s
# Average concentration: 1.644083028217498e+24 atm/m^3
#
# Current time: 9960000.0 s
# Average concentration: 1.644083033137184e+24 atm/m^3
#
# Current time: 9970000.0 s
# Average concentration: 1.6440830379897457e+24 atm/m^3
#
# Current time: 9980000.0 s
# Average concentration: 1.6440830427760988e+24 atm/m^3
#
# Current time: 9990000.0 s
# Average concentration: 1.6440830474971483e+24 atm/m^3
#
# Final time: 10000000.0 s
# Average concentration: 1.6440830521537876e+24 atm/m^3
#
#
# Error bound: 0.0016199492345538814
# Error exact: 7.171352887565976e-05

# %% [markdown]
# #### SAVE ESSENTIAL FILES

# %%
# Save essentail files:
np.save('model_files/FF_FO.npy', forc_C)
np.save('model_files/XX_FO.npy', np.array([mass_C]))
np.save('model_files/YY_FO.npy', np.array([stiff_C]))
np.save('model_files/KK_FO.npy', list_basis_stiff_C)
np.save('model_files/CC_FO.npy', list_coerc_stiff_C)
np.save('model_files/ZZ_FO.npy', INT_CZZ)
np.save('model_files/II_FO.npy', mapDAtoCO)
np.save('model_files/AA_FO.npy', inte_C)

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import numpy as np
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import time
import sys
import json
import h5py
import time

# Import user defined libraries:
from solver_class import FiniteElementCylinderSolver, ReducedBasisCylinderSolver

# %%
# #Define size of the training parameter set:
#sTR = 10000
#FISSION_ENERGY = 3.215e-11

# # Define parameters ranges:
#MIN_FR, MAX_FR = 0.00, 5.00E+19        
#MIN_K, MAX_K =  0.9, 8.00    
#MIN_FY, MAX_FY = 0.00, 0.3
#MIN_LL, MAX_LL = 0.1E-3, 1.50E-3   #Oltre 1.50E-3 crasha all'SVD 
#MIN_RR, MAX_RR = 0.75E-5, 2.00E-5  #funziona
#MIN_BC, MAX_BC = 300, 2.5E+03     #funziona        

# # Compute a list of random parameters within the range:
#LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR)) 
#LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
#LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
#LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
#LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
#LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
##LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

#np.savez('checkpoint/training_set.npz', FR=LIST_FR, BC=LIST_BC, LL=LIST_LL, RR=LIST_RR, FY=LIST_FY, K=LIST_K)

# %% [markdown]
# #### POD-GREEDY

# %%
# import numpy as np 
loaded_data = np.load('checkpoint/training_set.npz')
LIST_FR = loaded_data['FR']
LIST_BC = loaded_data['BC']
LIST_LL = loaded_data['LL']
LIST_RR = loaded_data['RR']
LIST_FY = loaded_data['FY']
LIST_K = loaded_data['K']
# # LIST_GG = loaded_data['GG']

sTR = LIST_BC.shape[0]

# %%
#############################
##### SAVE CHECKPOINT #######
#############################
def salva_checkpoint(step, cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, basis, cur_err_bounds, elapsed_time, cost_FO, cost_POD, cost_EB):
    import os
    worst_error = cur_err_bounds[np.argmax(cur_err_bounds)]  # Salva il valore dell'errore massimo
    
    # Creazione della cartella per lo step corrente
    step_folder = f"checkpoint/step_{step}"
    os.makedirs(step_folder, exist_ok=True)

    # Salvataggio dei parametri in formato JSON
    data = {
        "N_AVOG": 6.022141E+23,
        "N_BOLT": 1.380649E-23,
        "FISSION_ENERGY": 3.215E-11,
        "FISSION_RATE": cur_FR,
        "FUEL_THERMAL_CONDUCTIVITY": cur_K,
        "FISSION_YIELD": cur_FY,
        "LENGTH": cur_LL,
        "RADIUS": cur_RR,
        "T_BC": cur_BC,
        "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)],
        "TIME_ELAPSED": elapsed_time, 
        "COST_FO": cost_FO, 
        "COST_POD": cost_POD,
        "COST_EB": cost_EB
    }

    json_path = os.path.join(step_folder, "worst_reconstructed_parameters.json")
    with open(json_path, "w") as json_file:
        json.dump(data, json_file, indent=4)
    # with open("checkpoint/worst reconstructed parameters.json", "w") as json_file:
    #     json.dump(data, json_file, indent=4)

    # Salvataggio delle matrici in un file HDF5
    hdf5_path = os.path.join(step_folder, "matrici_RB.h5")
    with h5py.File(hdf5_path, 'w') as hf:
    #with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
        hf.create_dataset('MM_RB', data=MM_RB)
        hf.create_dataset('FF_RB', data=FF_RB)
        hf.create_dataset('KK_RB', data=KK_RB)
        hf.create_dataset('AA_RB', data=AA_RB)
        hf.create_dataset('ZZ_CO', data=ZZ_CO)
        hf.create_dataset('II_CO', data=II_CO)
        hf.create_dataset('basis', data=basis)

    return worst_error

#############################
##### LOAD CHECKPOINT #######
#############################
import os
def carica_checkpoint():
    try:
        # Caricamento dei parametri dal file JSON
        with open("checkpoint/worst_reconstructed_parameters.json", "r") as json_file:
            data = json.load(json_file)
        cur_BC = data["T_BC"]
        cur_FR = data["FISSION_RATE"]
        cur_LL = data["LENGTH"]
        cur_RR = data["RADIUS"]
        cur_FY = data["FISSION_YIELD"]
        cur_K = data["FUEL_THERMAL_CONDUCTIVITY"]
        maximum_error_bound = data["Maximum cur_err_bounds"]
        elapsed_time = data["TIME_ELAPSED"]
        cost_FO = data["COST_FO"]
        cost_POD = data["COST_POD"]
        cost_EB = data["COST_EB"]

        # Caricamento delle basi dal file HDF5
        with h5py.File('checkpoint/matrici_RB.h5', 'r') as hf:
            basis = hf['basis'][:]
    
    except FileNotFoundError:
        # Se i file non sono trovati, imposta i parametri di default e matrici vuote
        print("Checkpoint files not found. Starting from scratch.")
        
        # Parametri di default
        cur_FR = 3.00E+19
        cur_K = 2.208
        cur_FY = 2.40E-01
        cur_LL = 1.00E-03
        cur_RR = 1.00E-05
        cur_BC = 2.00E+03
        
        basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
        maximum_error_bound = 1
        elapsed_time = 0        # Inizio da zero
        cost_FO = 0
        cost_POD = 0
        cost_EB = 0
    
    return cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, basis, maximum_error_bound, elapsed_time, cost_FO, cost_POD, cost_EB

# %%
# Define greedy-POD tolerance:
greedy_POD_tol = 1e-3

# Define reference parameters:
# cur_FR = 3.00E+19
# cur_K = 2.208
# cur_FY = 2.40E-01
# cur_LL = 1.00E-03
# cur_RR = 1.00E-05
# cur_BC = 2.00E+03
cur_dt = 1.00E+04

# Define empty basis functions matrix and empty list of error bounds:
#cur_basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
cur_err_bounds = np.empty((sTR))

cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, cur_basis, maximum_error_bound, check_point_elapsed_time, check_point_cost_FO, check_point_cost_POD, check_point_cost_EB = carica_checkpoint()

# Enter reduced basis space loop:
#maximum_error_bound = 1
elapsed_time = check_point_elapsed_time
cost_FO = check_point_cost_FO
cost_POD = check_point_cost_POD
cost_EB = check_point_cost_EB
## da cambiare la somma del tempo del checkpoint
while maximum_error_bound > greedy_POD_tol:
    t0 = time.time()

    # Assemble full order model and compute full order solution associated with the current parameter selection:
    t0_FO = time.time()
    solver_FO = FiniteElementCylinderSolver()
    solver_FO.assemble(RADIUS=cur_RR, LENGTH=cur_LL, F_RATE=cur_FR, F_YIELD=cur_FY, T_BC=cur_BC, KTH=cur_K,  dt=cur_dt)
    solution_FO = solver_FO.solve(n_steps=1000, verbose=False)
    cost_FO += (time.time() - t0_FO) 

    # Compute orthogonal complement to the basis function and solution energy: ---->(strong-greedy-weak-greedy)
    t0_POD = time.time()
    orthogonal_FO = solution_FO - cur_basis @ np.linalg.solve(cur_basis.T @ solver_FO.XX_FO @ cur_basis, cur_basis.T @ solver_FO.XX_FO @ solution_FO)
    
    # Identify the worst reconstructed time instant:
    cur_time_error = np.empty((1000))
    for ii in range(1000):
        cur_time_error[ii] = solver_FO.XX_FO.dot(orthogonal_FO[:, ii+1]).dot(orthogonal_FO[:, ii+1]) /\
                             solver_FO.XX_FO.dot(solution_FO[:, ii+1]).dot(solution_FO[:, ii+1]) 
    
    # Extract the strong Greedy basis from the full order solution:
    cur_time_argmax = np.argmax(cur_time_error) + 1
    cur_new_basis = orthogonal_FO[:, cur_time_argmax:cur_time_argmax+1] 
    cur_new_basis = cur_new_basis / np.sqrt(solver_FO.XX_FO.dot(cur_new_basis[:, 0]).dot(cur_new_basis[:, 0]))
    cur_basis = np.hstack((cur_basis, cur_new_basis))
    cost_POD += (time.time() - t0_POD) 

    # Assemble reduced basis model:
    t0_EB = time.time()
    solver_RB = ReducedBasisCylinderSolver(cur_basis)                          #---->(strong-greedy-weak-greedy)
    for kk in range(sTR):
        solver_RB.assemble(F_YIELD=LIST_FY[kk], F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], KTH=LIST_K[kk], dt=cur_dt)

        # Compute current reduced basis solution and error bound:
        solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
    cost_EB += (time.time() - t0_EB)


    # Identify new parameters where to evaluate the full order model:
    #cur_FY = cur_FY
    cur_FY = LIST_FY[np.argmax(cur_err_bounds)]
    cur_FR = LIST_FR[np.argmax(cur_err_bounds)]
    cur_BC = LIST_BC[np.argmax(cur_err_bounds)]
    cur_LL = LIST_LL[np.argmax(cur_err_bounds)]
    cur_RR = LIST_RR[np.argmax(cur_err_bounds)]
    cur_K  = LIST_K[np.argmax(cur_err_bounds)]
    
    # Save maximum error bound:
    maximum_error_bound = np.max(cur_err_bounds)
    elapsed_time += (time.time() - t0)

    # Show worse reconstructed parameter configuration:
    print("The current reduced basis size is", cur_basis.shape[1])
    print("The current error bound is", np.max(cur_err_bounds))
    print(f"Elapsed time during this step greedy is {time.time() - t0:.2f} seconds")
    print(f"Overall elapsed time (+ checkpoint) is {elapsed_time / 60:.2f} minutes")
    print(f"The overall time of: FO = {cost_FO/60:.5f} min, POD = {cost_POD/60:.5f} min, error bound = {cost_EB/60:.5f} min\n")
    print("The selected Fission Rate is", cur_FR, "f/s")
    print("The selected Fuel Thermal Conductivity is", cur_K, "W/(m K)")
    print("The selected Fission Yield is", cur_FY, "at/fiss")
    print("The selected Grain Length is", cur_LL, "m")
    print("The selected Grain Radius is", cur_RR, "m")
    print("The selected Boundary Temperature is", cur_BC, "K")
    print("------------------------------------------------------")

    # Salvataggio dello stato dopo ogni ciclo
    MM_RB = solver_RB.XX_RB    
    FF_RB = solver_RB.FF_RB    
    KK_RB = solver_RB.KK_RB    
    AA_RB = solver_RB.AA_RB    
    ZZ_CO = solver_RB.ZZ_FO    
    II_CO = solver_RB.II_FO    
    basis = cur_basis 
    worst_error = salva_checkpoint(MM_RB.shape[0], cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, cur_basis, cur_err_bounds, elapsed_time, cost_FO, cost_POD, cost_EB)

print(rf'Il tempo impiegato dal FO = {cost_FO/60:.5f}, Il tempo impiegato dalla POD = {cost_POD/60:.5f}, Il tempo impiegato da error bound = {cost_EB/60:.5f}')
# Out:
# The current reduced basis size is 76
# The current error bound is 0.03231228293464784
# Elapsed time during this step greedy is 207.58 seconds
# Overall elapsed time (+ checkpoint) is 996.01 minutes
# The overall time of: FO = 1.30552 min, POD = 0.42329 min, error bound = 237.54900 min
#
# The selected Fission Rate is 2.5435466971328483e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1106199041884972 W/(m K)
# The selected Fission Yield is 0.12568841951435214 at/fiss
# The selected Grain Length is 0.0002973669383103687 m
# The selected Grain Radius is 1.867178824769379e-05 m
# The selected Boundary Temperature is 1651.5779914760897 K
# ------------------------------------------------------
# The current reduced basis size is 77
# The current error bound is 0.033606726482566816
# Elapsed time during this step greedy is 208.39 seconds
# Overall elapsed time (+ checkpoint) is 999.48 minutes
# The overall time of: FO = 1.32233 min, POD = 0.42992 min, error bound = 240.99875 min
#
# The selected Fission Rate is 4.846957102676274e+19 f/s
# The selected Fuel Thermal Conductivity is 1.6749220590516265 W/(m K)
# The selected Fission Yield is 0.28363664462069166 at/fiss
# The selected Grain Length is 0.0006750158487024856 m
# The selected Grain Radius is 1.9399340023103053e-05 m
# The selected Boundary Temperature is 1303.7537498025504 K
# ------------------------------------------------------
# The current reduced basis size is 78
# The current error bound is 0.03141300773798507
# Elapsed time during this step greedy is 225.22 seconds
# Overall elapsed time (+ checkpoint) is 1003.24 minutes
# The overall time of: FO = 1.33893 min, POD = 0.43607 min, error bound = 244.72961 min
#
# The selected Fission Rate is 4.4110282954151485e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9915832655911182 W/(m K)
# The selected Fission Yield is 0.18458030534078215 at/fiss
# The selected Grain Length is 0.0011131485868721344 m
# The selected Grain Radius is 1.7749048082169416e-05 m
# The selected Boundary Temperature is 679.1213532381528 K
# ------------------------------------------------------
# The current reduced basis size is 79
# The current error bound is 0.030955400225466004
# Elapsed time during this step greedy is 226.74 seconds
# Overall elapsed time (+ checkpoint) is 1007.02 minutes
# The overall time of: FO = 1.35553 min, POD = 0.44156 min, error bound = 248.48656 min
#
# The selected Fission Rate is 4.4110282954151485e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9915832655911182 W/(m K)
# The selected Fission Yield is 0.18458030534078215 at/fiss
# The selected Grain Length is 0.0011131485868721344 m
# The selected Grain Radius is 1.7749048082169416e-05 m
# The selected Boundary Temperature is 679.1213532381528 K
# ------------------------------------------------------
# The current reduced basis size is 80
# The current error bound is 0.030435731362827286
# Elapsed time during this step greedy is 216.31 seconds
# Overall elapsed time (+ checkpoint) is 1010.62 minutes
# The overall time of: FO = 1.37183 min, POD = 0.44641 min, error bound = 252.07051 min
#
# The selected Fission Rate is 3.919357243069823e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1881234227179387 W/(m K)
# The selected Fission Yield is 0.2879515611870254 at/fiss
# The selected Grain Length is 0.0011967222065558175 m
# The selected Grain Radius is 1.885309233228055e-05 m
# The selected Boundary Temperature is 946.9407134711943 K
# ------------------------------------------------------
# The current reduced basis size is 81
# The current error bound is 0.029274217160354065
# Elapsed time during this step greedy is 219.29 seconds
# Overall elapsed time (+ checkpoint) is 1014.28 minutes
# The overall time of: FO = 1.38770 min, POD = 0.45130 min, error bound = 255.70458 min
#
# The selected Fission Rate is 4.491215232699555e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9872540569893506 W/(m K)
# The selected Fission Yield is 0.035514034591637565 at/fiss
# The selected Grain Length is 0.00032082829663844 m
# The selected Grain Radius is 1.393478806794745e-05 m
# The selected Boundary Temperature is 1451.9322639872762 K
# ------------------------------------------------------
# The current reduced basis size is 82
# The current error bound is 0.026440636066984026
# Elapsed time during this step greedy is 230.48 seconds
# Overall elapsed time (+ checkpoint) is 1018.12 minutes
# The overall time of: FO = 1.40574 min, POD = 0.45638 min, error bound = 259.52285 min
#
# The selected Fission Rate is 4.4110282954151485e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9915832655911182 W/(m K)
# The selected Fission Yield is 0.18458030534078215 at/fiss
# The selected Grain Length is 0.0011131485868721344 m
# The selected Grain Radius is 1.7749048082169416e-05 m
# The selected Boundary Temperature is 679.1213532381528 K
# ------------------------------------------------------
# The current reduced basis size is 83
# The current error bound is 0.026006435619188462
# Elapsed time during this step greedy is 264.51 seconds
# Overall elapsed time (+ checkpoint) is 1022.53 minutes
# The overall time of: FO = 1.42354 min, POD = 0.46182 min, error bound = 263.90807 min
#
# The selected Fission Rate is 1.176385648908801e+18 f/s
# The selected Fuel Thermal Conductivity is 5.785066226564537 W/(m K)
# The selected Fission Yield is 0.23336283666809904 at/fiss
# The selected Grain Length is 0.0004352239159330409 m
# The selected Grain Radius is 1.8273123107479112e-05 m
# The selected Boundary Temperature is 1818.4126997936007 K
# ------------------------------------------------------
# The current reduced basis size is 84
# The current error bound is 0.024234557816648808
# Elapsed time during this step greedy is 236.48 seconds
# Overall elapsed time (+ checkpoint) is 1026.47 minutes
# The overall time of: FO = 1.43901 min, POD = 0.46755 min, error bound = 267.82818 min
#
# The selected Fission Rate is 3.1606651116039946e+19 f/s
# The selected Fuel Thermal Conductivity is 1.3677400518963987 W/(m K)
# The selected Fission Yield is 0.08121449570872744 at/fiss
# The selected Grain Length is 0.001432711749275012 m
# The selected Grain Radius is 1.0894818317088541e-05 m
# The selected Boundary Temperature is 1144.5749530261487 K
# ------------------------------------------------------
# The current reduced basis size is 85
# The current error bound is 0.022329142460884684
# Elapsed time during this step greedy is 244.08 seconds
# Overall elapsed time (+ checkpoint) is 1030.53 minutes
# The overall time of: FO = 1.45529 min, POD = 0.47259 min, error bound = 271.87477 min
#
# The selected Fission Rate is 9.163324788930154e+18 f/s
# The selected Fuel Thermal Conductivity is 6.0902584679673275 W/(m K)
# The selected Fission Yield is 0.08944140291381998 at/fiss
# The selected Grain Length is 0.0001150925506287477 m
# The selected Grain Radius is 1.4323045388283005e-05 m
# The selected Boundary Temperature is 2462.6744349436813 K
# ------------------------------------------------------
# The current reduced basis size is 86
# The current error bound is 0.021556213111226175
# Elapsed time during this step greedy is 244.24 seconds
# Overall elapsed time (+ checkpoint) is 1034.61 minutes
# The overall time of: FO = 1.47147 min, POD = 0.47786 min, error bound = 275.92396 min
#
# The selected Fission Rate is 3.970860113230818e+19 f/s
# The selected Fuel Thermal Conductivity is 2.128973552356371 W/(m K)
# The selected Fission Yield is 0.07880752222624474 at/fiss
# The selected Grain Length is 0.000638901074495172 m
# The selected Grain Radius is 1.9923169334884248e-05 m
# The selected Boundary Temperature is 1745.8434417913807 K
# ------------------------------------------------------
# The current reduced basis size is 87
# The current error bound is 0.020723707770840694
# Elapsed time during this step greedy is 260.02 seconds
# Overall elapsed time (+ checkpoint) is 1038.94 minutes
# The overall time of: FO = 1.48812 min, POD = 0.48357 min, error bound = 280.23521 min
#
# The selected Fission Rate is 4.199469956384458e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9537108363940351 W/(m K)
# The selected Fission Yield is 0.28657299840809564 at/fiss
# The selected Grain Length is 0.00126019981631014 m
# The selected Grain Radius is 1.8795547143767168e-05 m
# The selected Boundary Temperature is 1554.5596621148966 K
# ------------------------------------------------------
# The current reduced basis size is 88
# The current error bound is 0.019927341242183528
# Elapsed time during this step greedy is 243.72 seconds
# Overall elapsed time (+ checkpoint) is 1043.00 minutes
# The overall time of: FO = 1.50466 min, POD = 0.48836 min, error bound = 284.27595 min
#
# The selected Fission Rate is 3.0206261592462717e+19 f/s
# The selected Fuel Thermal Conductivity is 3.590578591446107 W/(m K)
# The selected Fission Yield is 0.16966278004041416 at/fiss
# The selected Grain Length is 0.00012911176103258312 m
# The selected Grain Radius is 1.9760164144391954e-05 m
# The selected Boundary Temperature is 872.6082857218772 K
# ------------------------------------------------------
# The current reduced basis size is 89
# The current error bound is 0.020985329324448986
# Elapsed time during this step greedy is 259.45 seconds
# Overall elapsed time (+ checkpoint) is 1047.32 minutes
# The overall time of: FO = 1.52116 min, POD = 0.49411 min, error bound = 288.57786 min
#
# The selected Fission Rate is 1.2586035961026548e+19 f/s
# The selected Fuel Thermal Conductivity is 3.653718705394722 W/(m K)
# The selected Fission Yield is 0.10632456742241693 at/fiss
# The selected Grain Length is 0.00016257682264040352 m
# The selected Grain Radius is 1.9334003996665908e-05 m
# The selected Boundary Temperature is 1386.5508603633707 K
# ------------------------------------------------------
# The current reduced basis size is 90
# The current error bound is 0.019499316916838687
# Elapsed time during this step greedy is 266.78 seconds
# Overall elapsed time (+ checkpoint) is 1051.77 minutes
# The overall time of: FO = 1.53874 min, POD = 0.49989 min, error bound = 293.00061 min
#
# The selected Fission Rate is 4.199469956384458e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9537108363940351 W/(m K)
# The selected Fission Yield is 0.28657299840809564 at/fiss
# The selected Grain Length is 0.00126019981631014 m
# The selected Grain Radius is 1.8795547143767168e-05 m
# The selected Boundary Temperature is 1554.5596621148966 K
# ------------------------------------------------------
# The current reduced basis size is 91
# The current error bound is 0.019411228412624618
# Elapsed time during this step greedy is 247.09 seconds
# Overall elapsed time (+ checkpoint) is 1055.89 minutes
# The overall time of: FO = 1.55619 min, POD = 0.50593 min, error bound = 297.09523 min
#
# The selected Fission Rate is 4.199469956384458e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9537108363940351 W/(m K)
# The selected Fission Yield is 0.28657299840809564 at/fiss
# The selected Grain Length is 0.00126019981631014 m
# The selected Grain Radius is 1.8795547143767168e-05 m
# The selected Boundary Temperature is 1554.5596621148966 K
# ------------------------------------------------------
# The current reduced basis size is 92
# The current error bound is 0.01886656932966518
# Elapsed time during this step greedy is 254.77 seconds
# Overall elapsed time (+ checkpoint) is 1060.14 minutes
# The overall time of: FO = 1.57246 min, POD = 0.51089 min, error bound = 301.32023 min
#
# The selected Fission Rate is 3.885596478176202e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9655661991325262 W/(m K)
# The selected Fission Yield is 0.02237080649168227 at/fiss
# The selected Grain Length is 0.0014219262501540455 m
# The selected Grain Radius is 9.427198663269196e-06 m
# The selected Boundary Temperature is 549.8654356182765 K
# ------------------------------------------------------
# The current reduced basis size is 93
# The current error bound is 0.018517045040529097
# Elapsed time during this step greedy is 265.32 seconds
# Overall elapsed time (+ checkpoint) is 1064.56 minutes
# The overall time of: FO = 1.59022 min, POD = 0.51623 min, error bound = 305.71920 min
#
# The selected Fission Rate is 4.336488981040438e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1568025013064116 W/(m K)
# The selected Fission Yield is 0.13625592175291906 at/fiss
# The selected Grain Length is 0.001391625656970381 m
# The selected Grain Radius is 8.344959613743982e-06 m
# The selected Boundary Temperature is 1567.3607332307733 K
# ------------------------------------------------------
# The current reduced basis size is 94
# The current error bound is 0.018347866185615277
# Elapsed time during this step greedy is 255.75 seconds
# Overall elapsed time (+ checkpoint) is 1068.82 minutes
# The overall time of: FO = 1.60732 min, POD = 0.52130 min, error bound = 309.95957 min
#
# The selected Fission Rate is 4.336488981040438e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1568025013064116 W/(m K)
# The selected Fission Yield is 0.13625592175291906 at/fiss
# The selected Grain Length is 0.001391625656970381 m
# The selected Grain Radius is 8.344959613743982e-06 m
# The selected Boundary Temperature is 1567.3607332307733 K
# ------------------------------------------------------
# The current reduced basis size is 95
# The current error bound is 0.017997239436034873
# Elapsed time during this step greedy is 282.47 seconds
# Overall elapsed time (+ checkpoint) is 1073.53 minutes
# The overall time of: FO = 1.62376 min, POD = 0.52771 min, error bound = 314.64448 min
#
# The selected Fission Rate is 3.885596478176202e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9655661991325262 W/(m K)
# The selected Fission Yield is 0.02237080649168227 at/fiss
# The selected Grain Length is 0.0014219262501540455 m
# The selected Grain Radius is 9.427198663269196e-06 m
# The selected Boundary Temperature is 549.8654356182765 K
# ------------------------------------------------------
# The current reduced basis size is 96
# The current error bound is 0.017989387997542718
# Elapsed time during this step greedy is 195.29 seconds
# Overall elapsed time (+ checkpoint) is 1076.78 minutes
# The overall time of: FO = 1.63986 min, POD = 0.53373 min, error bound = 317.87714 min
#
# The selected Fission Rate is 3.885596478176202e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9655661991325262 W/(m K)
# The selected Fission Yield is 0.02237080649168227 at/fiss
# The selected Grain Length is 0.0014219262501540455 m
# The selected Grain Radius is 9.427198663269196e-06 m
# The selected Boundary Temperature is 549.8654356182765 K
# ------------------------------------------------------
# The current reduced basis size is 97
# The current error bound is 0.017845838321926676
# Elapsed time during this step greedy is 234.98 seconds
# Overall elapsed time (+ checkpoint) is 1080.70 minutes
# The overall time of: FO = 1.65629 min, POD = 0.53928 min, error bound = 321.77142 min
#
# The selected Fission Rate is 3.885596478176202e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9655661991325262 W/(m K)
# The selected Fission Yield is 0.02237080649168227 at/fiss
# The selected Grain Length is 0.0014219262501540455 m
# The selected Grain Radius is 9.427198663269196e-06 m
# The selected Boundary Temperature is 549.8654356182765 K
# ------------------------------------------------------
# The current reduced basis size is 98
# The current error bound is 0.016180672274113857
# Elapsed time during this step greedy is 279.34 seconds
# Overall elapsed time (+ checkpoint) is 1085.35 minutes
# The overall time of: FO = 1.67372 min, POD = 0.55959 min, error bound = 326.38939 min
#
# The selected Fission Rate is 4.336488981040438e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1568025013064116 W/(m K)
# The selected Fission Yield is 0.13625592175291906 at/fiss
# The selected Grain Length is 0.001391625656970381 m
# The selected Grain Radius is 8.344959613743982e-06 m
# The selected Boundary Temperature is 1567.3607332307733 K
# ------------------------------------------------------
# The current reduced basis size is 99
# The current error bound is 0.016096962037062994
# Elapsed time during this step greedy is 248.68 seconds
# Overall elapsed time (+ checkpoint) is 1089.50 minutes
# The overall time of: FO = 1.69276 min, POD = 0.56540 min, error bound = 330.50917 min
#
# The selected Fission Rate is 1.5775656100995185e+18 f/s
# The selected Fuel Thermal Conductivity is 6.720430491006051 W/(m K)
# The selected Fission Yield is 0.037020526226878556 at/fiss
# The selected Grain Length is 0.0014114751355487445 m
# The selected Grain Radius is 8.337817306700574e-06 m
# The selected Boundary Temperature is 653.2420005045109 K
# ------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 60
#      57     solver_RB.assemble(F_YIELD=LIST_FY[kk], F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], KTH=LIST_K[kk], dt=cur_dt)
#      59     # Compute current reduced basis solution and error bound:
# ---> 60     solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
#      61 cost_EB += (time.time() - t0_EB)
#      64 # Identify new parameters where to evaluate the full order model:
#      65 #cur_FY = cur_FY
#
# File ~/Library/CloudStorage/OneDrive-PolitecnicodiMilano/PhD/Git/rom-cylinder_DEIM-POD/offline-online stages/model_2d/strong-greedy-weak-greedy algorithm/solver_class.py:201, in ReducedBasisCylinderSolver.solve(self, n_steps, verbose, error_bound)
#     199 solution = np.zeros((self.sRB, n_steps+1))
#     200 for ii in range(n_steps):
# --> 201     solution[:, ii+1] = sp.linalg.lu_solve((self.LU, self.PIV), self.RHS_static[:, 0] + self.XX_RB.dot(solution[: , ii]))
#     203     # Print current iteration and average temperature and concentration:
#     204     if verbose:
#
# KeyboardInterrupt:

# %%
cur_err_bounds[np.argmax(cur_err_bounds)]
# Out:
# 0.2930992003851943

# %%
import json
# Parametri con nomi diretti
data = {
    "N_AVOG": 6.022141E+23,
    "N_BOLT": 1.380649E-23,
    "FISSION_ENERGY": 3.215E-11,
    "FISSION_RATE": cur_FR,
    "FUEL_THERMAL_CONDUCTIVITY": cur_K,
    "FISSION_YIELD": cur_FY,
    "LENGTH": cur_LL,
    "RADIUS": cur_RR,
    "T_BC": cur_BC,
    "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)], 
    "TIME_ELAPSED": elapsed_time, 
    "COST_FO": cost_FO, 
    "COST_POD": cost_POD,
    "COST_EB": cost_EB
}

# Scrittura su file JSON
with open("checkpoint/worst_reconstructed_parameters.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# %%
MM_RB = solver_RB.XX_RB    #matrice di massa. 2D
FF_RB = solver_RB.FF_RB    #funzionalità contro il vettore unitario. 1D
KK_RB = solver_RB.KK_RB    #basi della decomposizione affine della stiffness. 3D
AA_RB = solver_RB.AA_RB    #l'integratore per calcolare il valor medio sul volume data la soluzione ridotta, questo può essere sostituito dalla funzione che calcola il valor medio su diversi slice. 1D
ZZ_CO = solver_RB.ZZ_FO    #coordinate a cui dobbiamo valutare la temperatura. 1D
II_CO = solver_RB.II_FO    #coefficienti che mappano i valori del coefficiente di diffusione valutata sulle temperature nei coefficienti di combinazione lineare della decomposizione affine. 2D
basis = cur_basis

# %%
# Salviamo tutte le matrici in un unico file HDF5
import h5py
with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
    hf.create_dataset('MM_RB', data=MM_RB)
    hf.create_dataset('FF_RB', data=FF_RB)
    hf.create_dataset('KK_RB', data=KK_RB)
    hf.create_dataset('AA_RB', data=AA_RB)
    hf.create_dataset('ZZ_CO', data=ZZ_CO)
    hf.create_dataset('II_CO', data=II_CO)
    hf.create_dataset('basis', data=basis)
