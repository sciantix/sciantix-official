# %% [markdown]
# ## **REDUCED BASIS MODEL CONSTRUCTION**

# %% [markdown]
# #### LOAD LIBRARIES

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import itertools
import time
import os
import sys
import json
import pandas as pd

# Import user defined libraries:
from FreeFEM import FFmatrix_fread, FFvector_fread

# %% [markdown]
# #### DEFINE REFERENCE PROBLEM PARAMETERS

# %%
with open("reference case/Reference_parameters.json", "r") as json_file:
    parameters = json.load(json_file)
N_AVOG = parameters["N_AVOG"]  
N_BOLT = parameters["N_BOLT"]  
FISSION_ENERGY = parameters["FISSION_ENERGY"]                       
FISSION_RATE = parameters["FISSION_RATE"]                   
RADIUS = parameters["RADIUS"]
LENGTH = parameters["LENGTH"]
FISSION_YIELD = parameters["FISSION_YIELD"]                 
FUEL_THERMAL_CONDUCTIVITY = parameters["FUEL_THERMAL_CONDUCTIVITY"]
T_BC = parameters["T_BC"]  
C_BC = parameters["C_BC"]  

SOURCE_C = FISSION_RATE * FISSION_YIELD         #[atm / (m^3 s)]
GAMMA_T = (FISSION_RATE * FISSION_ENERGY * LENGTH**2)/(FUEL_THERMAL_CONDUCTIVITY)

      
# Define reference temperature, concentration and linear diffusion parameters:
T_IC  = T_BC # [K]
C_IC = C_BC  # [atm / m^3]
 
# Define final time, time increment:
TIME_FINAL = 1.00E+07  # [s]
TIME_DELTA = 1.00E+04  # [s]

# Compute number of iterations:
N_ITER = int(TIME_FINAL / TIME_DELTA)  # [-]

# Define function evaluating the concentration diffusion coefficient at given z coordinated provided the problem parameters:
def ALPHA_C(ZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE):
    return 7.60E-10 * np.exp(- 4.86E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) + \
           5.64E-25 * np.exp(- 1.91E-19 / (T_BC + GAMMA_T * (1 - ZZ**2) / 2) / N_BOLT) * np.sqrt(FISSION_RATE) + \
           8.00E-40 * FISSION_RATE

# %% [markdown]
# #### IDENTIFY DIRICHLET DOFS AND INTERNAL DOFS

# %%
# Load coordinates:
coordinates_Px = FFvector_fread('mesh_utilities/vv_cc_Px.btxt')
coordinates_Pq = FFvector_fread('mesh_utilities/vv_cc_Pq.btxt')

# Identify degrees of freedom of the Px and Pq spaces:
sFO_Px = coordinates_Px.shape[0]
sFO_Pq = coordinates_Pq.shape[0]
print(rf'Degree of freedom = {sFO_Px}')

# Define vector of all Px indeces:
mask_all = np.arange(sFO_Px, dtype=int)

# Identify indeces of the top, bottom and middle boundaries in Px:
mask_inf_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_sup_bc = mask_all[np.isclose([coordinates_Px[ii, 1] for ii in range(sFO_Px)], np.ones((sFO_Px)))]
mask_mid_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.zeros((sFO_Px)))]
mask_ext_bc = mask_all[np.isclose([coordinates_Px[ii, 0] for ii in range(sFO_Px)], np.ones((sFO_Px)))]

# Identify indeces of the Dirichlet b.c. for the temperature and concentration field:
mask_bc_T = np.fromiter(set(mask_sup_bc), int)
mask_bc_C = np.fromiter(set(mask_sup_bc) | set(mask_ext_bc) | set(mask_inf_bc), int)

# Identify indeces of the interior for the temperature and concentration field:
mask_in_T = [ii for ii in mask_all if ii not in mask_bc_T]
mask_in_C = [ii for ii in mask_all if ii not in mask_bc_C]
# Out:
# Degree of freedom = 10201

# %% [markdown]
# #### DEFINE FINITE ELEMENT ESSENTIALS

# %%
# Import mass matrices on the Px and on the Pq space:
mass_Px = FFmatrix_fread('mesh_utilities/ww_mm_Px.btxt')
mass_Pq = FFmatrix_fread('mesh_utilities/ww_mm_Pq.btxt')
mass_Pm = FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')

# Extract integration weights and diagonal matrix with their inverse:
weights_Pq = mass_Pq.diagonal()
project_Pq = sparse.diags(np.reciprocal(weights_Pq))

# Import map from Px to Pq and to the dx, dy, dz derivative evaluated in Pq:
PxtoPquu_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_uu_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdx_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dx_Px_Pq.btxt')[:, mask_in_C])
PxtoPqdy_C = project_Pq.dot(FFmatrix_fread('mesh_utilities/ww_dy_Px_Pq.btxt')[:, mask_in_C])

# Define weights for the integration in polar coordinates:
polar_weights_Pq = np.multiply(coordinates_Pq[:, 0], weights_Pq)

# Compute volume of the domain:
volume = np.dot(np.ones(sFO_Pq), polar_weights_Pq)

# Assemble mass matrix and projected forcing term:
forc_C = PxtoPquu_C.T.dot(polar_weights_Pq[:, None])
mass_C = PxtoPquu_C.T.dot(PxtoPquu_C.multiply(polar_weights_Pq[:, None]))
inte_C = PxtoPquu_C.T.dot(polar_weights_Pq) / volume

# Assemble a function assembling the stiffness matrix at a given time:
stiff_C = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / RADIUS**2 * polar_weights_Pq[:, None])) + \
          PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(ALPHA_C(coordinates_Pq[:, 1:2]) / LENGTH**2 * polar_weights_Pq[:, None]))

# %% [markdown]
# #### DEFINE PARAMETERS TRAINING SET

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215E-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0.00, 5.00E+19        
MIN_K, MAX_K =  0.9, 8.00    
MIN_FY, MAX_FY = 0.00, 0.3
MIN_LL, MAX_LL = 0.1E-3, 1.50E-3
MIN_RR, MAX_RR = 0.75E-5, 2.00E-5
MIN_BC, MAX_BC = 300, 2.5E+03 


# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TRAINING = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TRAINING[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# %% [markdown]
# #### CONSTRUCT AN AFFINE DECOMPOSITION FOR THE CONCENTRATION DIFFUSION COEFFICIENTS

# %%
# Compress the training set using singular value decomposition:
UU, SS, VV = np.linalg.svd(TRAINING @ TRAINING.T, full_matrices=False)
NN = np.sum(np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))]) > 1e-6) + 1

# Construct 1D and 3D basis for the concentration diffusion coefficient:
BASIS_D_1D = UU[:, :NN]
BASIS_D_2D = ZZ_1Dto2D @ BASIS_D_1D

# Use a greedy algorithm to identify the points (indeces) to interpolate the exact concentration coefficients:
INT_COO = [np.argmax(np.abs(BASIS_D_1D[:, 0]))]
for ii in range(1, NN):
    INT_COO.append(np.argmax(np.abs(BASIS_D_1D[:, ii] - BASIS_D_1D[:, :ii] @ np.linalg.solve(BASIS_D_1D[INT_COO, :ii],  BASIS_D_1D[INT_COO, ii]))))

# Extrat the z coordinates associated with the selected indeces:
INT_COO = np.array(INT_COO)
INT_CZZ = np.array([ZZ[INT_COO[ii]] for ii in range(NN)])

# Define interpolation operator mapping from the diffusion coefficient evaluated in the interpolation points to the linear combination coefficients:
mapDAtoCO = np.linalg.solve(BASIS_D_1D[INT_COO, :], np.eye(NN))

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TRAINING - BASIS_D_1D @ mapDAtoCO @ TRAINING[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TRAINING, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
print(VV.shape)
print(rf'Number of DEIM modes = {NN}')
# Out:
# 0.002441629784137635
# (1000, 1000)
# Number of DEIM modes = 8

# %%
#guardiamo la missing energy del termine non-affine -> queste basi ridotte dopo le usiamo per davvero
cmap = plt.get_cmap('RdBu')
color = cmap(0.9)

missing = np.sqrt([np.sum(SS[ii:]) / np.sum(SS) for ii in range(len(SS))])
fig, (ax1) = plt.subplots(1, figsize=(4,5))
ax1.set_yscale('log')
ax1.plot(range(1,26), missing[:25], '-o')
ax1.tick_params(axis="y", which='both',labelsize=13,  width=1)
ax1.tick_params(axis='x', labelsize=13,  width=1)
ax1.set_xlabel('Number of DEIM modes',fontsize=14)
ax1.set_ylabel('Missing energy',fontsize=14)
#ax1.set_ylabel('Normalized eigenvalues',fontsize=14)
ax1.axvspan(1, NN, color='gray', alpha=0.2)
ax1.set_xlim([0,25])
ax1.set_ylim([1e-7, 1])
ax1.grid(visible=True, which='both', linewidth=1, alpha=0.7)
plt.savefig('plot/Missing energy.pdf', bbox_inches='tight')

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215E-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0.00, 5.00E+19        
MIN_K, MAX_K =  0.9, 8.00    
MIN_FY, MAX_FY = 0.00, 0.3
MIN_LL, MAX_LL = 0.1E-3, 1.50E-3
MIN_RR, MAX_RR = 0.75E-5, 2.00E-5
MIN_BC, MAX_BC = 300, 2.5E+03 


# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

# Extract z coordinates from the list of all Pq points coordinates and map those coordinates to the Pq points:
ZZ = np.sort(list(set(coordinates_Pq[:, 1])))
ZZ_1Dto2D = sparse.csr_matrix(np.array([coordinates_Pq[:, 1] == ZZ[kk] for kk in range(len(ZZ))]).T) * 1

# Compute a training set of concentration diffusion coefficients evaluated at the z coordinates: 
TEST = np.empty((len(ZZ), sTR))
for ii in range(sTR):
    TEST[:, ii] = ALPHA_C(ZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

# Estimate the absolute and relative errors committed with this interpolation approach:
ABS_ERR = np.linalg.norm(TEST - BASIS_D_1D @ mapDAtoCO @ TEST[INT_COO, :], axis=0) 
REL_ERR = ABS_ERR / np.linalg.norm(TEST, axis=0)

# Print maximum error:
print(np.max(REL_ERR))
# Out:
# 0.0032117956870523295

# %% [markdown]
# #### ASSEMBLE AFFINELY DECOMPOSED STIFFNESS MATRICES AND COMPUTE THEIR COERCIVITY CONSTANTS
# impiega 1.3 secondi

# %%
# Define two mass matrices respectively linked to the regularity of the solution and of its time derivative:
Y_mass = stiff_C
X_mass = mass_C

# Initialise array for the partial stiffness matrices and for their coercivity constants:
list_basis_stiff_C = np.array([sparse.csr_matrix((mass_C.shape)) for ii in range(2*NN)])
list_coerc_stiff_C = np.zeros((2*NN))

# Iterate over the selected basis for the diffusion coefficient field
for ii in range(NN):

    # Assemble the radial and axial partial stiffness matrices associated with the basis of the diffusivity:
    list_basis_stiff_C[00+ii] = PxtoPqdx_C.T.dot(PxtoPqdx_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))
    list_basis_stiff_C[NN+ii] = PxtoPqdy_C.T.dot(PxtoPqdy_C.multiply(BASIS_D_2D[:, ii:ii+1] * polar_weights_Pq[:, None]))

    # Compute the sign of the axial and radial partial stiffness matrices:
    tsign_dz_C = np.sign(list_basis_stiff_C[NN + ii].trace())
    tsign_dr_C = np.sign(list_basis_stiff_C[00 + ii].trace())

    # Compute the coercivity constant of the axial and radial partial stiffness matrices:
    list_coerc_stiff_C[NN+ii] = tsign_dz_C / linalg.eigsh(Y_mass, k=1, M=tsign_dz_C * list_basis_stiff_C[NN+ii], which='LM', return_eigenvectors=False)[0]
    list_coerc_stiff_C[00+ii] = tsign_dr_C / linalg.eigsh(Y_mass, k=1, M=tsign_dr_C * list_basis_stiff_C[00+ii], which='LM', return_eigenvectors=False)[0]

# %% [markdown]
# #### COMPUTE THE INTERPOLATION COEFFICIENTS AND THE COERCIVITY COEFFICIENTS FOR ALL THE PARAMETERS

# %%
# Compute hte interpolation coefficients and the coercivity coefficients for the parameters in the training set:
list_inter_coef = np.empty((sTR, 2*NN))
list_coerc_coef = np.empty((sTR))

# Iterate over the training set:
for ii in range(sTR):
    cur_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=LIST_BC[ii], GAMMA_T=LIST_GG[ii], FISSION_RATE=LIST_FR[ii])

    # Compute the interpolation coefficients for the radial and axial partial stiffness matrices:
    list_inter_coef[ii, NN:] = cur_coef / LIST_LL[ii]**2
    list_inter_coef[ii, :NN] = cur_coef / LIST_RR[ii]**2

    # Compute a lower bound for the coercivity constants:
    list_coerc_coef[ii] = np.dot(list_coerc_stiff_C, list_inter_coef[ii, :])

# Compute interpolation and coercivity coeffientrs for the reference parameters:
cur_inter_coef = mapDAtoCO @ ALPHA_C(INT_CZZ, T_BC=T_BC, GAMMA_T=GAMMA_T, FISSION_RATE=FISSION_RATE)
cur_inter_coef = np.hstack((cur_inter_coef / RADIUS**2, cur_inter_coef / LENGTH**2))
cur_coerc_coef = np.dot(list_coerc_stiff_C, cur_inter_coef)

# %% [markdown]
# #### COMPUTE THE POD MODES OF THE REFERENCE SOLUTION

# %%
sol_new_C = np.loadtxt('../reference case/Fullorder_Cfield.csv', delimiter=',')
# Compute the singular value decomposition of the gramian matrix:
AA, GG, BB = np.linalg.svd(sol_new_C[mask_in_C, :].T @ Y_mass @ sol_new_C[mask_in_C, :], full_matrices=False)

# Compute total Y-energy of the training set:
Y_energy = np.sum([Y_mass.dot(sol_new_C[mask_in_C, ii]).dot(sol_new_C[mask_in_C, ii]) for ii in range(N_ITER+1)])

# Determine number of POD modes to retain:
sRB_C = np.sum([np.sqrt(np.sum(GG[ii:]) / Y_energy) > 1e-4 for ii in range(len(GG))])

# Assemble POD modes for the concentration field at the reference parameters:
BASIS_C_2D = sol_new_C[mask_in_C, :] @ AA[:, :sRB_C] @ np.diag(np.reciprocal(np.sqrt(GG[:sRB_C])))

print(rf'Number of POD modes = {sRB_C}')
# Out:
# Number of POD modes = 8

# %% [markdown]
# #### ASSEMBLE REDUCED MATRICES (LATER MUST BE CODED AS THE METHOD OF A CLASS)

# %%
# Project the Y- and X-mass matrices on the reduced basis space:
Y_mass_RB = BASIS_C_2D.T @ Y_mass @ BASIS_C_2D
X_mass_RB = BASIS_C_2D.T @ X_mass @ BASIS_C_2D

# Compute Rietz representer and projection of the forcing term:
forc_C_rietz_RB = linalg.spsolve(Y_mass, forc_C)
forc_C_proje_RB = BASIS_C_2D.T @ forc_C

# Compute Rietz representer and projection of the mass matrix tested versus the POD basis functions: 
mass_C_right_RB = mass_C @ BASIS_C_2D
mass_C_rietz_RB = linalg.spsolve(Y_mass, mass_C_right_RB)
mass_C_proje_RB = BASIS_C_2D.T @ mass_C_right_RB

# Compute the Rietz representer and projection of all the partial stiffness matrices from the affine decomposition:
list_basis_stiff_C_right_RB = np.array([list_basis_stiff_C[ii] @ BASIS_C_2D for ii in range(2*NN)])
list_basis_stiff_C_rietz_RB = np.array([linalg.spsolve(Y_mass, list_basis_stiff_C_right_RB[ii]) for ii in range(2*NN)])
list_basis_stiff_C_proje_RB = np.array([BASIS_C_2D.T @ list_basis_stiff_C_right_RB[ii] for ii in range(2*NN)])

# Pre-assemble the scalar and vector terms for the residual energy computation:
DD_pr_bb = (forc_C_rietz_RB.T @ forc_C) * (SOURCE_C * SOURCE_C)
DD_pr_bm = (forc_C_rietz_RB.T @ mass_C_right_RB) * (- 2 * SOURCE_C / TIME_DELTA)
DD_pr_mm = (mass_C_rietz_RB.T @ mass_C_right_RB) * (  1 / (TIME_DELTA * TIME_DELTA))

# Pre-assemble all the tensor terms for the residual energy computation:
DD_pr_ab = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ forc_C_rietz_RB for ii in range(2*NN)]) * (-2 * SOURCE_C)
DD_pr_am = np.array([ list_basis_stiff_C_right_RB[ii, :, :].T @ mass_C_rietz_RB for ii in range(2*NN)]) * ( 2 / TIME_DELTA)
DD_pr_aa = np.array([[list_basis_stiff_C_right_RB[ii, :, :].T @ list_basis_stiff_C_rietz_RB[jj, :, :] for ii in range(2*NN)] for jj in range(2*NN)])

# Compute the weights for the integration of the reduced basis solutions:
weights_RB = np.ones((sFO_Px)) @ mass_Px[:, mask_in_C] @ BASIS_C_2D

# %% [markdown]
# #### COMPUTE REDUCED BASIS SOLUTION

# %%
# Assemble current reduced basis stiffness matrix:
stiff_C_proje_RB = np.tensordot(cur_inter_coef, list_basis_stiff_C_proje_RB, axes=[0, 0])
stiff_C_exact_RB = BASIS_C_2D.T @ stiff_C @ BASIS_C_2D

# Assemble current stiffness cross term for the computation of the residual energy:
cur_DD_pr_ab = np.tensordot(cur_inter_coef, DD_pr_ab, axes=[0, 0])
cur_DD_pr_am = np.tensordot(cur_inter_coef, DD_pr_am, axes=[0, 0])
cur_DD_pr_aa = np.tensordot(cur_inter_coef, np.tensordot(cur_inter_coef, DD_pr_aa, axes=[0, 0]), axes=[0, 0])

# Initialise reduced basis concentration solution:
sol_new_C_RB = np.zeros((sRB_C, N_ITER+1))
sol_new_C_FO = np.zeros((len(mask_in_C), N_ITER+1))

# Initialise errors and errors estimators:
energy_residual = np.empty((N_ITER))
energy_solution = np.empty((N_ITER))
energy_toterror = np.empty((N_ITER))

#
inte_C_RB = inte_C @ BASIS_C_2D

# Integrate using forward Euler up to the final time:
verbose = True
for ii in range(N_ITER):
    cur_time = ii * TIME_DELTA

    # Print current iteration and average temperature and concentration:
    if verbose:
        print('Current time:', cur_time, 's')
        print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, ii], 'atm/m^3\n')

    # Assemble current left-hand-side and right-hand-side
    cur_lhs_RB = mass_C_proje_RB + TIME_DELTA * stiff_C_proje_RB
    cur_rhs_RB = mass_C_proje_RB.dot(sol_new_C_RB[:, ii:ii+1]) + TIME_DELTA * SOURCE_C * forc_C_proje_RB

    # Compute concentration in the interior of the domain:
    sol_new_C_RB[:, ii+1] = np.linalg.solve(cur_lhs_RB, cur_rhs_RB)[:, 0]
    sol_new_C_FO[:, ii+1] = BASIS_C_2D @ sol_new_C_RB[:, ii+1]
    
    # Compute partial errors and error bounds:
    energy_toterror[ii] = TIME_DELTA * stiff_C.dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1]).dot(sol_new_C_FO[:, ii+1] - sol_new_C[mask_in_C, ii+1])
    energy_solution[ii] = TIME_DELTA * stiff_C_proje_RB.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1])
    energy_residual[ii] = TIME_DELTA * (DD_pr_bb[0] + DD_pr_bm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        DD_pr_mm.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]) +\
                                        cur_DD_pr_ab.dot(sol_new_C_RB[:, ii+1]) + cur_DD_pr_aa.dot(sol_new_C_RB[:, ii+1]).dot(sol_new_C_RB[:, ii+1]) +\
                                        cur_DD_pr_am.dot(sol_new_C_RB[:, ii+1] - sol_new_C_RB[:, ii]).dot(sol_new_C_RB[:, ii+1]))

# Print current iteration and average temperature and concentration:
if verbose: 
    print('Final time:', N_ITER * TIME_DELTA, 's')
    print('Average concentration:', inte_C_RB @ sol_new_C_RB[:, -1], 'atm/m^3\n\n')

# Add final term energies:
energy_solution[-1] += mass_C_proje_RB.dot(sol_new_C_RB[:, -1]).dot(sol_new_C_RB[:, -1])
energy_toterror[-1] += mass_C.dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1]).dot(sol_new_C[mask_in_C, -1] - sol_new_C_FO[:, -1])

# Print errors and error bounds:
print('Error bound:', np.sqrt(np.sum(energy_residual) / np.sum(energy_solution) / cur_coerc_coef) )
print('Error exact:', np.sqrt(np.sum(energy_toterror) / np.sum(energy_solution)) )
# Out:
# Current time: 0.0 s
# Average concentration: 1.644082987585468e+24 atm/m^3
#
# Current time: 9690000.0 s
# Average concentration: 1.6440829947155157e+24 atm/m^3
#
# Current time: 9700000.0 s
# Average concentration: 1.6440830017482066e+24 atm/m^3
#
# Current time: 9710000.0 s
# Average concentration: 1.6440830086848732e+24 atm/m^3
#
# Current time: 9720000.0 s
# Average concentration: 1.644083015526831e+24 atm/m^3
#
# Current time: 9730000.0 s
# Average concentration: 1.6440830222753738e+24 atm/m^3
#
# Current time: 9740000.0 s
# Average concentration: 1.6440830289317812e+24 atm/m^3
#
# Current time: 9750000.0 s
# Average concentration: 1.6440830354973128e+24 atm/m^3
#
# Current time: 9760000.0 s
# Average concentration: 1.644083041973211e+24 atm/m^3
#
# Current time: 9770000.0 s
# Average concentration: 1.6440830483607028e+24 atm/m^3
#
# Current time: 9780000.0 s
# Average concentration: 1.6440830546609976e+24 atm/m^3
#
# Current time: 9790000.0 s
# Average concentration: 1.6440830608752883e+24 atm/m^3
#
# Current time: 9800000.0 s
# Average concentration: 1.6440830670047502e+24 atm/m^3
#
# Current time: 9810000.0 s
# Average concentration: 1.6440830730505438e+24 atm/m^3
#
# Current time: 9820000.0 s
# Average concentration: 1.6440830790138149e+24 atm/m^3
#
# Current time: 9830000.0 s
# Average concentration: 1.6440830848956912e+24 atm/m^3
#
# Current time: 9840000.0 s
# Average concentration: 1.6440830906972855e+24 atm/m^3
#
# Current time: 9850000.0 s
# Average concentration: 1.6440830964196957e+24 atm/m^3
#
# Current time: 9860000.0 s
# Average concentration: 1.6440831020640043e+24 atm/m^3
#
# Current time: 9870000.0 s
# Average concentration: 1.6440831076312813e+24 atm/m^3
#
# Current time: 9880000.0 s
# Average concentration: 1.644083113122578e+24 atm/m^3
#
# Current time: 9890000.0 s
# Average concentration: 1.6440831185389343e+24 atm/m^3
#
# Current time: 9900000.0 s
# Average concentration: 1.6440831238813735e+24 atm/m^3
#
# Current time: 9910000.0 s
# Average concentration: 1.6440831291509076e+24 atm/m^3
#
# Current time: 9920000.0 s
# Average concentration: 1.6440831343485326e+24 atm/m^3
#
# Current time: 9930000.0 s
# Average concentration: 1.644083139475232e+24 atm/m^3
#
# Current time: 9940000.0 s
# Average concentration: 1.6440831445319757e+24 atm/m^3
#
# Current time: 9950000.0 s
# Average concentration: 1.6440831495197202e+24 atm/m^3
#
# Current time: 9960000.0 s
# Average concentration: 1.644083154439408e+24 atm/m^3
#
# Current time: 9970000.0 s
# Average concentration: 1.6440831592919693e+24 atm/m^3
#
# Current time: 9980000.0 s
# Average concentration: 1.6440831640783214e+24 atm/m^3
#
# Current time: 9990000.0 s
# Average concentration: 1.644083168799371e+24 atm/m^3
#
# Final time: 10000000.0 s
# Average concentration: 1.6440831734560094e+24 atm/m^3
#
#
# Error bound: 0.0013632751119819742
# Error exact: 7.171326285350572e-05

# %% [markdown]
# #### SAVE ESSENTIAL FILES

# %%
# Save essentail files:
np.save('model_files/FF_FO.npy', forc_C)
np.save('model_files/XX_FO.npy', np.array([mass_C]))
np.save('model_files/YY_FO.npy', np.array([stiff_C]))
np.save('model_files/KK_FO.npy', list_basis_stiff_C)
np.save('model_files/CC_FO.npy', list_coerc_stiff_C)
np.save('model_files/ZZ_FO.npy', INT_CZZ)
np.save('model_files/II_FO.npy', mapDAtoCO)
np.save('model_files/AA_FO.npy', inte_C)

# %%
# Pulizia
from IPython import get_ipython
get_ipython().run_line_magic('clear', '')
get_ipython().run_line_magic('reset', '-f')

# Import libraries:
import numpy as np
import scipy.sparse as sparse
import scipy.sparse.linalg as linalg
import time
import sys
import json
import h5py
import time

# Import user defined libraries:
from solver_class import FiniteElementCylinderSolver, ReducedBasisCylinderSolver

# %%
# #Define size of the training parameter set:
#sTR = 10000
#FISSION_ENERGY = 3.215e-11

# # Define parameters ranges:
#MIN_FR, MAX_FR = 0.00, 5.00E+19        
#MIN_K, MAX_K =  0.9, 8.00    
#MIN_FY, MAX_FY = 0.00, 0.3
#MIN_LL, MAX_LL = 0.1E-3, 1.50E-3   #Oltre 1.50E-3 crasha all'SVD 
#MIN_RR, MAX_RR = 0.75E-5, 2.00E-5  #funziona
#MIN_BC, MAX_BC = 300, 2.5E+03     #funziona        

# # Compute a list of random parameters within the range:
#LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR)) 
#LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
#LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
#LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
#LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
#LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
##LIST_GG = (LIST_FR * FISSION_ENERGY * LIST_LL**2)/LIST_K

#np.savez('checkpoint/training_set.npz', FR=LIST_FR, BC=LIST_BC, LL=LIST_LL, RR=LIST_RR, FY=LIST_FY, K=LIST_K)

# %% [markdown]
# #### POD-GREEDY

# %%
# import numpy as np 
loaded_data = np.load('checkpoint/training_set.npz')
LIST_FR = loaded_data['FR']
LIST_BC = loaded_data['BC']
LIST_LL = loaded_data['LL']
LIST_RR = loaded_data['RR']
LIST_FY = loaded_data['FY']
LIST_K = loaded_data['K']
# # LIST_GG = loaded_data['GG']

sTR = LIST_BC.shape[0]

# %%
#############################
##### SAVE CHECKPOINT #######
#############################
def salva_checkpoint(step, cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, basis, cur_err_bounds, elapsed_time, cost_FO, cost_POD, cost_EB):
    import os
    worst_error = cur_err_bounds[np.argmax(cur_err_bounds)]  # Salva il valore dell'errore massimo
    
    # Creazione della cartella per lo step corrente
    step_folder = f"checkpoint/step_{step}"
    os.makedirs(step_folder, exist_ok=True)

    # Salvataggio dei parametri in formato JSON
    data = {
        "N_AVOG": 6.022141E+23,
        "N_BOLT": 1.380649E-23,
        "FISSION_ENERGY": 3.215E-11,
        "FISSION_RATE": cur_FR,
        "FUEL_THERMAL_CONDUCTIVITY": cur_K,
        "FISSION_YIELD": cur_FY,
        "LENGTH": cur_LL,
        "RADIUS": cur_RR,
        "T_BC": cur_BC,
        "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)],
        "TIME_ELAPSED": elapsed_time, 
        "COST_FO": cost_FO, 
        "COST_POD": cost_POD,
        "COST_EB": cost_EB
    }

    json_path = os.path.join(step_folder, "worst_reconstructed_parameters.json")
    with open(json_path, "w") as json_file:
        json.dump(data, json_file, indent=4)
    # with open("checkpoint/worst reconstructed parameters.json", "w") as json_file:
    #     json.dump(data, json_file, indent=4)

    # Salvataggio delle matrici in un file HDF5
    hdf5_path = os.path.join(step_folder, "matrici_RB.h5")
    with h5py.File(hdf5_path, 'w') as hf:
    #with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
        hf.create_dataset('MM_RB', data=MM_RB)
        hf.create_dataset('FF_RB', data=FF_RB)
        hf.create_dataset('KK_RB', data=KK_RB)
        hf.create_dataset('AA_RB', data=AA_RB)
        hf.create_dataset('ZZ_CO', data=ZZ_CO)
        hf.create_dataset('II_CO', data=II_CO)
        hf.create_dataset('basis', data=basis)

    return worst_error

#############################
##### LOAD CHECKPOINT #######
#############################
import os
def carica_checkpoint():
    try:
        # Caricamento dei parametri dal file JSON
        with open("checkpoint/worst_reconstructed_parameters.json", "r") as json_file:
            data = json.load(json_file)
        cur_BC = data["T_BC"]
        cur_FR = data["FISSION_RATE"]
        cur_LL = data["LENGTH"]
        cur_RR = data["RADIUS"]
        cur_FY = data["FISSION_YIELD"]
        cur_K = data["FUEL_THERMAL_CONDUCTIVITY"]
        maximum_error_bound = data["Maximum cur_err_bounds"]
        elapsed_time = data["TIME_ELAPSED"]
        cost_FO = data["COST_FO"]
        cost_POD = data["COST_POD"]
        cost_EB = data["COST_EB"]

        # Caricamento delle basi dal file HDF5
        with h5py.File('checkpoint/matrici_RB.h5', 'r') as hf:
            basis = hf['basis'][:]
    
    except FileNotFoundError:
        # Se i file non sono trovati, imposta i parametri di default e matrici vuote
        print("Checkpoint files not found. Starting from scratch.")
        
        # Parametri di default
        cur_FR = 3.00E+19
        cur_K = 2.208
        cur_FY = 2.40E-01
        cur_LL = 1.00E-03
        cur_RR = 1.00E-05
        cur_BC = 2.00E+03
        
        basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
        maximum_error_bound = 1
        elapsed_time = 0        # Inizio da zero
        cost_FO = 0
        cost_POD = 0
        cost_EB = 0
    
    return cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, basis, maximum_error_bound, elapsed_time, cost_FO, cost_POD, cost_EB

# %%
# Define greedy-POD tolerance:
greedy_POD_tol = 1e-3

# Define reference parameters:
# cur_FR = 3.00E+19
# cur_K = 2.208
# cur_FY = 2.40E-01
# cur_LL = 1.00E-03
# cur_RR = 1.00E-05
# cur_BC = 2.00E+03
cur_dt = 1.00E+04

# Define empty basis functions matrix and empty list of error bounds:
#cur_basis = np.empty((FiniteElementCylinderSolver.sFO, 0))
cur_err_bounds = np.empty((sTR))

cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, cur_basis, maximum_error_bound, check_point_elapsed_time, check_point_cost_FO, check_point_cost_POD, check_point_cost_EB = carica_checkpoint()

# Enter reduced basis space loop:
#maximum_error_bound = 1
elapsed_time = 0
cost_FO = 0
cost_POD = 0
cost_EB = 0
## da cambiare la somma del tempo del checkpoint
while maximum_error_bound > greedy_POD_tol:
    t0 = time.time()

    # Assemble full order model and compute full order solution associated with the current parameter selection:
    t0_FO = time.time()
    solver_FO = FiniteElementCylinderSolver()
    solver_FO.assemble(RADIUS=cur_RR, LENGTH=cur_LL, F_RATE=cur_FR, F_YIELD=cur_FY, T_BC=cur_BC, KTH=cur_K,  dt=cur_dt)
    solution_FO = solver_FO.solve(n_steps=1000, verbose=False)
    cost_FO += (time.time() - t0_FO) + check_point_cost_FO

    # Compute orthogonal complement to the basis function and solution energy:
    t0_POD = time.time()
    orthogonal_FO = solution_FO - cur_basis @ np.linalg.solve(cur_basis.T @ solver_FO.XX_FO @ cur_basis, cur_basis.T @ solver_FO.XX_FO @ solution_FO)
    solution_energy_FO = np.einsum('ik,ik', solver_FO.XX_FO @ solution_FO, solution_FO)
    
    # Extract the POD basis from the full order solution:
    AA, GG, BB = np.linalg.svd(orthogonal_FO.T @ solver_FO.XX_FO @ orthogonal_FO, full_matrices=False)
    cur_basis = np.hstack((cur_basis, orthogonal_FO @ AA[:, :1] @ np.diag(np.reciprocal(np.sqrt(GG[:1])))))
    cost_POD += (time.time() - t0_POD) + check_point_cost_POD

    # Assemble reduced basis model:
    t0_EB = time.time()
    solver_RB = ReducedBasisCylinderSolver(cur_basis)
    for kk in range(sTR):
        solver_RB.assemble(F_YIELD=LIST_FY[kk], F_RATE=LIST_FR[kk], T_BC=LIST_BC[kk], LENGTH=LIST_LL[kk], RADIUS=LIST_RR[kk], KTH=LIST_K[kk], dt=cur_dt)

        # Compute current reduced basis solution and error bound:
        solution_RB, cur_err_bounds[kk] = solver_RB.solve(n_steps=1000, error_bound=True)
    cost_EB += (time.time() - t0_EB) + check_point_cost_EB


    # Identify new parameters where to evaluate the full order model:
    #cur_FY = cur_FY
    cur_FY = LIST_FY[np.argmax(cur_err_bounds)]
    cur_FR = LIST_FR[np.argmax(cur_err_bounds)]
    cur_BC = LIST_BC[np.argmax(cur_err_bounds)]
    cur_LL = LIST_LL[np.argmax(cur_err_bounds)]
    cur_RR = LIST_RR[np.argmax(cur_err_bounds)]
    cur_K  = LIST_K[np.argmax(cur_err_bounds)]
    
    # Save maximum error bound:
    maximum_error_bound = np.max(cur_err_bounds)
    elapsed_time += (time.time() - t0) + check_point_elapsed_time

    # Show worse reconstructed parameter configuration:
    print("The current reduced basis size is", cur_basis.shape[1])
    print("The current error bound is", np.max(cur_err_bounds))
    print(f"Elapsed time during this step greedy is {time.time() - t0:.2f} seconds")
    print(f"Overall elapsed time (+ checkpoint) is {elapsed_time / 60:.2f} minutes")
    print(f"The overall time of: FO = {cost_FO/60:.5f} min, POD = {cost_POD/60:.5f} min, error bound = {cost_EB/60:.5f} min\n")
    print("The selected Fission Rate is", cur_FR, "f/s")
    print("The selected Fuel Thermal Conductivity is", cur_K, "W/(m K)")
    print("The selected Fission Yield is", cur_FY, "at/fiss")
    print("The selected Grain Length is", cur_LL, "m")
    print("The selected Grain Radius is", cur_RR, "m")
    print("The selected Boundary Temperature is", cur_BC, "K")
    print("------------------------------------------------------")

    # Salvataggio dello stato dopo ogni ciclo
    MM_RB = solver_RB.XX_RB    
    FF_RB = solver_RB.FF_RB    
    KK_RB = solver_RB.KK_RB    
    AA_RB = solver_RB.AA_RB    
    ZZ_CO = solver_RB.ZZ_FO    
    II_CO = solver_RB.II_FO    
    basis = cur_basis 
    worst_error = salva_checkpoint(MM_RB.shape[0], cur_BC, cur_FR, cur_LL, cur_RR, cur_FY, cur_K, MM_RB, FF_RB, KK_RB, AA_RB, ZZ_CO, II_CO, cur_basis, cur_err_bounds, elapsed_time, cost_FO, cost_POD, cost_EB)

print(rf'Il tempo impiegato dal FO = {cost_FO/60:.5f}, Il tempo impiegato dalla POD = {cost_POD/60:.5f}, Il tempo impiegato da error bound = {cost_EB/60:.5f}')
# Out:
# The current reduced basis size is 140
# The current error bound is 0.0029262704294955445
# Elapsed time during this step greedy is 505.75 seconds
# Overall elapsed time (+ checkpoint) is 573.27 minutes
# The overall time of: FO = 1.71612 min, POD = 1.76148 min, error bound = 569.79619 min
#
# The selected Fission Rate is 1.341502153168132e+19 f/s
# The selected Fuel Thermal Conductivity is 2.4102068169141693 W/(m K)
# The selected Fission Yield is 0.010759096613245743 at/fiss
# The selected Grain Length is 0.0014714071970198424 m
# The selected Grain Radius is 1.076240451869498e-05 m
# The selected Boundary Temperature is 1104.9258109346672 K
# ------------------------------------------------------
# The current reduced basis size is 141
# The current error bound is 0.002863339163035617
# Elapsed time during this step greedy is 507.02 seconds
# Overall elapsed time (+ checkpoint) is 1146.57 minutes
# The overall time of: FO = 3.43210 min, POD = 3.52192 min, error bound = 1139.61469 min
#
# The selected Fission Rate is 4.900785464897085e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0691627935710455 W/(m K)
# The selected Fission Yield is 0.05225809067507411 at/fiss
# The selected Grain Length is 0.0011742777659499942 m
# The selected Grain Radius is 1.8708678326220346e-05 m
# The selected Boundary Temperature is 397.8118432029367 K
# ------------------------------------------------------
# The current reduced basis size is 142
# The current error bound is 0.002717405827148139
# Elapsed time during this step greedy is 519.19 seconds
# Overall elapsed time (+ checkpoint) is 1720.07 minutes
# The overall time of: FO = 5.14806 min, POD = 5.28229 min, error bound = 1709.63616 min
#
# The selected Fission Rate is 3.6684909875314643e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0841408114923123 W/(m K)
# The selected Fission Yield is 0.22029875195214088 at/fiss
# The selected Grain Length is 0.0013904885643749422 m
# The selected Grain Radius is 1.406490526902479e-05 m
# The selected Boundary Temperature is 460.47669753932865 K
# ------------------------------------------------------
# The current reduced basis size is 143
# The current error bound is 0.002609406206656791
# Elapsed time during this step greedy is 525.47 seconds
# Overall elapsed time (+ checkpoint) is 2293.67 minutes
# The overall time of: FO = 6.86410 min, POD = 7.04215 min, error bound = 2279.76269 min
#
# The selected Fission Rate is 3.709970954465323e+19 f/s
# The selected Fuel Thermal Conductivity is 1.4028903191825945 W/(m K)
# The selected Fission Yield is 0.29523858057370633 at/fiss
# The selected Grain Length is 0.0009539735549231955 m
# The selected Grain Radius is 1.9841938586664233e-05 m
# The selected Boundary Temperature is 1299.4755255780065 K
# ------------------------------------------------------
# The current reduced basis size is 144
# The current error bound is 0.002634042714851091
# Elapsed time during this step greedy is 526.81 seconds
# Overall elapsed time (+ checkpoint) is 2867.29 minutes
# The overall time of: FO = 8.58004 min, POD = 8.80089 min, error bound = 2849.91275 min
#
# The selected Fission Rate is 4.8524036210424414e+19 f/s
# The selected Fuel Thermal Conductivity is 2.207208395066065 W/(m K)
# The selected Fission Yield is 0.16066080097122135 at/fiss
# The selected Grain Length is 0.0014135395994985874 m
# The selected Grain Radius is 8.9172100673832e-06 m
# The selected Boundary Temperature is 419.8236769521231 K
# ------------------------------------------------------
# The current reduced basis size is 145
# The current error bound is 0.002580804315609868
# Elapsed time during this step greedy is 533.86 seconds
# Overall elapsed time (+ checkpoint) is 3441.04 minutes
# The overall time of: FO = 10.29628 min, POD = 10.56227 min, error bound = 3420.17738 min
#
# The selected Fission Rate is 4.658276861724686e+19 f/s
# The selected Fuel Thermal Conductivity is 6.60577666127946 W/(m K)
# The selected Fission Yield is 0.15214784138091922 at/fiss
# The selected Grain Length is 0.00010056505193702385 m
# The selected Grain Radius is 1.8785222214563675e-05 m
# The selected Boundary Temperature is 1721.8252038146554 K
# ------------------------------------------------------
# The current reduced basis size is 146
# The current error bound is 0.0025487161907745254
# Elapsed time during this step greedy is 703.12 seconds
# Overall elapsed time (+ checkpoint) is 4017.60 minutes
# The overall time of: FO = 12.01229 min, POD = 12.32535 min, error bound = 3993.26153 min
#
# The selected Fission Rate is 4.336488981040438e+19 f/s
# The selected Fuel Thermal Conductivity is 1.1568025013064116 W/(m K)
# The selected Fission Yield is 0.13625592175291906 at/fiss
# The selected Grain Length is 0.001391625656970381 m
# The selected Grain Radius is 8.344959613743982e-06 m
# The selected Boundary Temperature is 1567.3607332307733 K
# ------------------------------------------------------
# The current reduced basis size is 147
# The current error bound is 0.002391358937561168
# Elapsed time during this step greedy is 630.24 seconds
# Overall elapsed time (+ checkpoint) is 4592.95 minutes
# The overall time of: FO = 13.72841 min, POD = 14.09149 min, error bound = 4565.12787 min
#
# The selected Fission Rate is 3.980582360163872e+19 f/s
# The selected Fuel Thermal Conductivity is 1.8454153801617763 W/(m K)
# The selected Fission Yield is 0.23057534471758176 at/fiss
# The selected Grain Length is 0.0004361149603038391 m
# The selected Grain Radius is 1.523002642466766e-05 m
# The selected Boundary Temperature is 1453.1691722268085 K
# ------------------------------------------------------
# The current reduced basis size is 148
# The current error bound is 0.002550406340714382
# Elapsed time during this step greedy is 534.43 seconds
# Overall elapsed time (+ checkpoint) is 5166.70 minutes
# The overall time of: FO = 15.44519 min, POD = 15.85237 min, error bound = 5135.40204 min
#
# The selected Fission Rate is 8.779643689863948e+17 f/s
# The selected Fuel Thermal Conductivity is 7.102106990274933 W/(m K)
# The selected Fission Yield is 0.11414180862003342 at/fiss
# The selected Grain Length is 0.0014923073578097033 m
# The selected Grain Radius is 1.1193370614338317e-05 m
# The selected Boundary Temperature is 423.184418791014 K
# ------------------------------------------------------
# The current reduced basis size is 149
# The current error bound is 0.002388698020593851
# Elapsed time during this step greedy is 583.26 seconds
# Overall elapsed time (+ checkpoint) is 5741.27 minutes
# The overall time of: FO = 17.16159 min, POD = 17.61225 min, error bound = 5706.49144 min
#
# The selected Fission Rate is 4.6725591206095856e+19 f/s
# The selected Fuel Thermal Conductivity is 6.818851837945955 W/(m K)
# The selected Fission Yield is 0.019135188426296856 at/fiss
# The selected Grain Length is 0.0013034933274647868 m
# The selected Grain Radius is 7.695100307001652e-06 m
# The selected Boundary Temperature is 557.6096326648232 K
# ------------------------------------------------------
# The current reduced basis size is 150
# The current error bound is 0.0023427289969381046
# Elapsed time during this step greedy is 590.65 seconds
# Overall elapsed time (+ checkpoint) is 6315.96 minutes
# The overall time of: FO = 18.87790 min, POD = 19.37357 min, error bound = 6277.70260 min
#
# The selected Fission Rate is 4.42757987853366e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0418975662757275 W/(m K)
# The selected Fission Yield is 0.2817574492133971 at/fiss
# The selected Grain Length is 0.0014130059575767563 m
# The selected Grain Radius is 8.16075821193949e-06 m
# The selected Boundary Temperature is 1237.5944945602578 K
# ------------------------------------------------------
# The current reduced basis size is 151
# The current error bound is 0.002308250159826248
# Elapsed time during this step greedy is 549.02 seconds
# Overall elapsed time (+ checkpoint) is 6889.95 minutes
# The overall time of: FO = 20.59391 min, POD = 21.13403 min, error bound = 6848.22116 min
#
# The selected Fission Rate is 4.1927437478900785e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9320449638815279 W/(m K)
# The selected Fission Yield is 0.14496196915842022 at/fiss
# The selected Grain Length is 0.0013389807932312737 m
# The selected Grain Radius is 1.6697499661927427e-05 m
# The selected Boundary Temperature is 868.0211891739403 K
# ------------------------------------------------------
# The current reduced basis size is 152
# The current error bound is 0.0022576591997833994
# Elapsed time during this step greedy is 546.89 seconds
# Overall elapsed time (+ checkpoint) is 7463.91 minutes
# The overall time of: FO = 22.31073 min, POD = 22.89463 min, error bound = 7418.70310 min
#
# The selected Fission Rate is 4.988872331500514e+19 f/s
# The selected Fuel Thermal Conductivity is 7.616827441943895 W/(m K)
# The selected Fission Yield is 0.045350192263063506 at/fiss
# The selected Grain Length is 0.00010582041478996259 m
# The selected Grain Radius is 1.1977087687313647e-05 m
# The selected Boundary Temperature is 1295.3646198401661 K
# ------------------------------------------------------
# The current reduced basis size is 153
# The current error bound is 0.0022576368916921935
# Elapsed time during this step greedy is 562.24 seconds
# Overall elapsed time (+ checkpoint) is 8038.13 minutes
# The overall time of: FO = 24.02799 min, POD = 24.65573 min, error bound = 7989.44001 min
#
# The selected Fission Rate is 4.338986109224817e+19 f/s
# The selected Fuel Thermal Conductivity is 1.3036221591766042 W/(m K)
# The selected Fission Yield is 0.0988670168954165 at/fiss
# The selected Grain Length is 0.0014930145137876719 m
# The selected Grain Radius is 1.097979316082298e-05 m
# The selected Boundary Temperature is 597.4963458202727 K
# ------------------------------------------------------
# The current reduced basis size is 154
# The current error bound is 0.0021957279806209397
# Elapsed time during this step greedy is 567.54 seconds
# Overall elapsed time (+ checkpoint) is 8612.43 minutes
# The overall time of: FO = 25.74416 min, POD = 26.41644 min, error bound = 8560.26677 min
#
# The selected Fission Rate is 1.8982983920306506e+17 f/s
# The selected Fuel Thermal Conductivity is 1.1885235088491046 W/(m K)
# The selected Fission Yield is 0.10719595225880975 at/fiss
# The selected Grain Length is 0.0012224525252196594 m
# The selected Grain Radius is 1.614759015345512e-05 m
# The selected Boundary Temperature is 874.3521881736672 K
# ------------------------------------------------------
# The current reduced basis size is 155
# The current error bound is 0.002096712024630245
# Elapsed time during this step greedy is 579.07 seconds
# Overall elapsed time (+ checkpoint) is 9186.93 minutes
# The overall time of: FO = 27.46032 min, POD = 28.17644 min, error bound = 9131.28644 min
#
# The selected Fission Rate is 4.897893890066643e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0611643088093543 W/(m K)
# The selected Fission Yield is 0.11435446661953186 at/fiss
# The selected Grain Length is 0.0013444052896000127 m
# The selected Grain Radius is 1.8283908779053486e-05 m
# The selected Boundary Temperature is 592.2154440042609 K
# ------------------------------------------------------
# The current reduced basis size is 156
# The current error bound is 0.002147772385884356
# Elapsed time during this step greedy is 579.19 seconds
# Overall elapsed time (+ checkpoint) is 9761.42 minutes
# The overall time of: FO = 29.17651 min, POD = 29.93759 min, error bound = 9702.30689 min
#
# The selected Fission Rate is 2.711555902961828e+19 f/s
# The selected Fuel Thermal Conductivity is 0.921057318699028 W/(m K)
# The selected Fission Yield is 0.23301996857843468 at/fiss
# The selected Grain Length is 0.0013135209966675925 m
# The selected Grain Radius is 1.5127095993353866e-05 m
# The selected Boundary Temperature is 429.2968181815659 K
# ------------------------------------------------------
# The current reduced basis size is 157
# The current error bound is 0.0021291818357793775
# Elapsed time during this step greedy is 582.74 seconds
# Overall elapsed time (+ checkpoint) is 10335.98 minutes
# The overall time of: FO = 30.89268 min, POD = 31.69833 min, error bound = 10273.38696 min
#
# The selected Fission Rate is 1.6506147777113172e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0292229864290123 W/(m K)
# The selected Fission Yield is 0.17001812393174767 at/fiss
# The selected Grain Length is 0.0013200130137873314 m
# The selected Grain Radius is 1.912220997868805e-05 m
# The selected Boundary Temperature is 967.2973433066129 K
# ------------------------------------------------------
# The current reduced basis size is 158
# The current error bound is 0.0020338390234545863
# Elapsed time during this step greedy is 608.99 seconds
# Overall elapsed time (+ checkpoint) is 10910.98 minutes
# The overall time of: FO = 32.60878 min, POD = 33.45930 min, error bound = 10844.90429 min
#
# The selected Fission Rate is 3.331591354858171e+18 f/s
# The selected Fuel Thermal Conductivity is 7.992845371774544 W/(m K)
# The selected Fission Yield is 0.18945409478184685 at/fiss
# The selected Grain Length is 0.00020221119932016803 m
# The selected Grain Radius is 1.956474712637218e-05 m
# The selected Boundary Temperature is 1739.0214702846336 K
# ------------------------------------------------------
# The current reduced basis size is 159
# The current error bound is 0.001924753837752201
# Elapsed time during this step greedy is 591.35 seconds
# Overall elapsed time (+ checkpoint) is 11485.68 minutes
# The overall time of: FO = 34.32478 min, POD = 35.21978 min, error bound = 11416.12828 min
#
# The selected Fission Rate is 1.953880687095065e+19 f/s
# The selected Fuel Thermal Conductivity is 1.2281835929767144 W/(m K)
# The selected Fission Yield is 0.07667894007993693 at/fiss
# The selected Grain Length is 0.001268369164235876 m
# The selected Grain Radius is 1.81055782813769e-05 m
# The selected Boundary Temperature is 830.898823533455 K
# ------------------------------------------------------
# The current reduced basis size is 160
# The current error bound is 0.0018781278528685731
# Elapsed time during this step greedy is 592.82 seconds
# Overall elapsed time (+ checkpoint) is 12060.40 minutes
# The overall time of: FO = 36.04199 min, POD = 36.98106 min, error bound = 11987.37481 min
#
# The selected Fission Rate is 3.3381436858411917e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9549896110640412 W/(m K)
# The selected Fission Yield is 0.16185533352697204 at/fiss
# The selected Grain Length is 0.0014938164931108844 m
# The selected Grain Radius is 1.9821524008129604e-05 m
# The selected Boundary Temperature is 1985.0220920269176 K
# ------------------------------------------------------
# The current reduced basis size is 161
# The current error bound is 0.0018326952460570288
# Elapsed time during this step greedy is 612.00 seconds
# Overall elapsed time (+ checkpoint) is 12635.45 minutes
# The overall time of: FO = 37.75862 min, POD = 38.74168 min, error bound = 12558.94226 min
#
# The selected Fission Rate is 2.2390383373377188e+19 f/s
# The selected Fuel Thermal Conductivity is 7.724180441694413 W/(m K)
# The selected Fission Yield is 0.22451767141013065 at/fiss
# The selected Grain Length is 0.00011655194961278953 m
# The selected Grain Radius is 1.9851126462710895e-05 m
# The selected Boundary Temperature is 1414.2099770331897 K
# ------------------------------------------------------
# The current reduced basis size is 162
# The current error bound is 0.0017530861566521143
# Elapsed time during this step greedy is 648.80 seconds
# Overall elapsed time (+ checkpoint) is 13211.10 minutes
# The overall time of: FO = 39.47488 min, POD = 40.50255 min, error bound = 13131.12313 min
#
# The selected Fission Rate is 1.953880687095065e+19 f/s
# The selected Fuel Thermal Conductivity is 1.2281835929767144 W/(m K)
# The selected Fission Yield is 0.07667894007993693 at/fiss
# The selected Grain Length is 0.001268369164235876 m
# The selected Grain Radius is 1.81055782813769e-05 m
# The selected Boundary Temperature is 830.898823533455 K
# ------------------------------------------------------
# The current reduced basis size is 163
# The current error bound is 0.0017879670573349737
# Elapsed time during this step greedy is 673.06 seconds
# Overall elapsed time (+ checkpoint) is 13787.17 minutes
# The overall time of: FO = 41.19101 min, POD = 42.26411 min, error bound = 13703.70777 min
#
# The selected Fission Rate is 1.8303799863830794e+17 f/s
# The selected Fuel Thermal Conductivity is 7.210388858815446 W/(m K)
# The selected Fission Yield is 0.2011862094763863 at/fiss
# The selected Grain Length is 0.0013781166704898398 m
# The selected Grain Radius is 1.1634355599551784e-05 m
# The selected Boundary Temperature is 629.1749076354507 K
# ------------------------------------------------------
# The current reduced basis size is 164
# The current error bound is 0.0017033169183167732
# Elapsed time during this step greedy is 658.09 seconds
# Overall elapsed time (+ checkpoint) is 14362.98 minutes
# The overall time of: FO = 42.90777 min, POD = 44.02430 min, error bound = 14276.04369 min
#
# The selected Fission Rate is 3.763292581421937e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9349599733300203 W/(m K)
# The selected Fission Yield is 0.14887202051813075 at/fiss
# The selected Grain Length is 0.0013893286741953916 m
# The selected Grain Radius is 1.5521775407571583e-05 m
# The selected Boundary Temperature is 1358.9585600128642 K
# ------------------------------------------------------
# The current reduced basis size is 165
# The current error bound is 0.0016793514988734362
# Elapsed time during this step greedy is 663.46 seconds
# Overall elapsed time (+ checkpoint) is 14938.88 minutes
# The overall time of: FO = 44.62410 min, POD = 45.78631 min, error bound = 14848.46765 min
#
# The selected Fission Rate is 3.1251997685996446e+19 f/s
# The selected Fuel Thermal Conductivity is 2.1598663450473117 W/(m K)
# The selected Fission Yield is 0.02168840530210514 at/fiss
# The selected Grain Length is 0.000785420220626255 m
# The selected Grain Radius is 1.8139301860123137e-05 m
# The selected Boundary Temperature is 1648.2368763357567 K
# ------------------------------------------------------
# The current reduced basis size is 166
# The current error bound is 0.0016727560299281416
# Elapsed time during this step greedy is 666.57 seconds
# Overall elapsed time (+ checkpoint) is 15514.84 minutes
# The overall time of: FO = 46.34013 min, POD = 47.54872 min, error bound = 15420.94332 min
#
# The selected Fission Rate is 6.289573251801861e+18 f/s
# The selected Fuel Thermal Conductivity is 2.335186531081047 W/(m K)
# The selected Fission Yield is 0.16343833944958858 at/fiss
# The selected Grain Length is 0.00010868761485753903 m
# The selected Grain Radius is 1.4948442217332477e-05 m
# The selected Boundary Temperature is 444.168900076603 K
# ------------------------------------------------------
# The current reduced basis size is 167
# The current error bound is 0.0015299841225082456
# Elapsed time during this step greedy is 668.86 seconds
# Overall elapsed time (+ checkpoint) is 16090.83 minutes
# The overall time of: FO = 48.05631 min, POD = 49.30963 min, error bound = 15993.45847 min
#
# The selected Fission Rate is 4.672140078581931e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9795158248650854 W/(m K)
# The selected Fission Yield is 0.17349814963320898 at/fiss
# The selected Grain Length is 0.0013317835074670653 m
# The selected Grain Radius is 1.0360762426361193e-05 m
# The selected Boundary Temperature is 572.1809959859395 K
# ------------------------------------------------------
# The current reduced basis size is 168
# The current error bound is 0.0015026137246505647
# Elapsed time during this step greedy is 798.91 seconds
# Overall elapsed time (+ checkpoint) is 16668.99 minutes
# The overall time of: FO = 49.77240 min, POD = 51.07069 min, error bound = 16568.14103 min
#
# The selected Fission Rate is 4.561272861813178e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0232191706710962 W/(m K)
# The selected Fission Yield is 0.2482479255526661 at/fiss
# The selected Grain Length is 0.0011380515924588146 m
# The selected Grain Radius is 8.237773016858018e-06 m
# The selected Boundary Temperature is 1746.724653645213 K
# ------------------------------------------------------
# The current reduced basis size is 169
# The current error bound is 0.0015030006319561638
# Elapsed time during this step greedy is 657.60 seconds
# Overall elapsed time (+ checkpoint) is 17244.79 minutes
# The overall time of: FO = 51.48869 min, POD = 52.84308 min, error bound = 17140.45702 min
#
# The selected Fission Rate is 4.5919671161879536e+19 f/s
# The selected Fuel Thermal Conductivity is 5.1262908293221585 W/(m K)
# The selected Fission Yield is 0.20840014053241926 at/fiss
# The selected Grain Length is 0.00014868269432058984 m
# The selected Grain Radius is 8.744920252421312e-06 m
# The selected Boundary Temperature is 1219.0441391886675 K
# ------------------------------------------------------
# The current reduced basis size is 170
# The current error bound is 0.001491130808696628
# Elapsed time during this step greedy is 659.58 seconds
# Overall elapsed time (+ checkpoint) is 17820.63 minutes
# The overall time of: FO = 53.20503 min, POD = 54.60998 min, error bound = 17712.81144 min
#
# The selected Fission Rate is 4.368829348045926e+19 f/s
# The selected Fuel Thermal Conductivity is 0.991971506052985 W/(m K)
# The selected Fission Yield is 0.15078361992598213 at/fiss
# The selected Grain Length is 0.0014254176253787152 m
# The selected Grain Radius is 1.1656647551324104e-05 m
# The selected Boundary Temperature is 1418.5066759838257 K
# ------------------------------------------------------
# The current reduced basis size is 171
# The current error bound is 0.001297105262152938
# Elapsed time during this step greedy is 674.64 seconds
# Overall elapsed time (+ checkpoint) is 18396.72 minutes
# The overall time of: FO = 54.92113 min, POD = 56.37072 min, error bound = 18285.42315 min
#
# The selected Fission Rate is 3.822761571937114e+19 f/s
# The selected Fuel Thermal Conductivity is 1.2335699976386965 W/(m K)
# The selected Fission Yield is 0.21698425748429198 at/fiss
# The selected Grain Length is 0.0012142195695511915 m
# The selected Grain Radius is 7.698301626524513e-06 m
# The selected Boundary Temperature is 785.3721670158895 K
# ------------------------------------------------------
# The current reduced basis size is 172
# The current error bound is 0.0013144071128867493
# Elapsed time during this step greedy is 681.16 seconds
# Overall elapsed time (+ checkpoint) is 18972.92 minutes
# The overall time of: FO = 56.63717 min, POD = 58.13158 min, error bound = 18858.14347 min
#
# The selected Fission Rate is 4.890541109177292e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0352893373073646 W/(m K)
# The selected Fission Yield is 0.24555678173456488 at/fiss
# The selected Grain Length is 0.001377606015554708 m
# The selected Grain Radius is 1.1134961538722757e-05 m
# The selected Boundary Temperature is 557.759092270376 K
# ------------------------------------------------------
# The current reduced basis size is 173
# The current error bound is 0.0012983016901705546
# Elapsed time during this step greedy is 690.84 seconds
# Overall elapsed time (+ checkpoint) is 19549.28 minutes
# The overall time of: FO = 58.35317 min, POD = 59.89173 min, error bound = 19431.02586 min
#
# The selected Fission Rate is 4.900785464897085e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0691627935710455 W/(m K)
# The selected Fission Yield is 0.05225809067507411 at/fiss
# The selected Grain Length is 0.0011742777659499942 m
# The selected Grain Radius is 1.8708678326220346e-05 m
# The selected Boundary Temperature is 397.8118432029367 K
# ------------------------------------------------------
# The current reduced basis size is 174
# The current error bound is 0.0013296361437653238
# Elapsed time during this step greedy is 703.53 seconds
# Overall elapsed time (+ checkpoint) is 20125.85 minutes
# The overall time of: FO = 60.06918 min, POD = 61.65271 min, error bound = 20004.11894 min
#
# The selected Fission Rate is 4.900785464897085e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0691627935710455 W/(m K)
# The selected Fission Yield is 0.05225809067507411 at/fiss
# The selected Grain Length is 0.0011742777659499942 m
# The selected Grain Radius is 1.8708678326220346e-05 m
# The selected Boundary Temperature is 397.8118432029367 K
# ------------------------------------------------------
# The current reduced basis size is 175
# The current error bound is 0.0012938001499820748
# Elapsed time during this step greedy is 710.79 seconds
# Overall elapsed time (+ checkpoint) is 20702.54 minutes
# The overall time of: FO = 61.78530 min, POD = 63.41379 min, error bound = 20577.33290 min
#
# The selected Fission Rate is 2.711555902961828e+19 f/s
# The selected Fuel Thermal Conductivity is 0.921057318699028 W/(m K)
# The selected Fission Yield is 0.23301996857843468 at/fiss
# The selected Grain Length is 0.0013135209966675925 m
# The selected Grain Radius is 1.5127095993353866e-05 m
# The selected Boundary Temperature is 429.2968181815659 K
# ------------------------------------------------------
# The current reduced basis size is 176
# The current error bound is 0.0012822194419138083
# Elapsed time during this step greedy is 698.31 seconds
# Overall elapsed time (+ checkpoint) is 21279.02 minutes
# The overall time of: FO = 63.50241 min, POD = 65.17515 min, error bound = 21150.33746 min
#
# The selected Fission Rate is 1.6506147777113172e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0292229864290123 W/(m K)
# The selected Fission Yield is 0.17001812393174767 at/fiss
# The selected Grain Length is 0.0013200130137873314 m
# The selected Grain Radius is 1.912220997868805e-05 m
# The selected Boundary Temperature is 967.2973433066129 K
# ------------------------------------------------------
# The current reduced basis size is 177
# The current error bound is 0.0012351063383021729
# Elapsed time during this step greedy is 708.83 seconds
# Overall elapsed time (+ checkpoint) is 21855.68 minutes
# The overall time of: FO = 65.21886 min, POD = 66.93637 min, error bound = 21723.51826 min
#
# The selected Fission Rate is 5.578508145779709e+18 f/s
# The selected Fuel Thermal Conductivity is 2.6553887228076176 W/(m K)
# The selected Fission Yield is 0.20282656709249433 at/fiss
# The selected Grain Length is 0.001444474194931829 m
# The selected Grain Radius is 1.94724346284496e-05 m
# The selected Boundary Temperature is 1033.7216089886017 K
# ------------------------------------------------------
# The current reduced basis size is 178
# The current error bound is 0.0011816384418251887
# Elapsed time during this step greedy is 719.58 seconds
# Overall elapsed time (+ checkpoint) is 22432.52 minutes
# The overall time of: FO = 66.93488 min, POD = 68.69864 min, error bound = 22296.87754 min
#
# The selected Fission Rate is 3.323422133748084e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0762864077681806 W/(m K)
# The selected Fission Yield is 0.20877054939470385 at/fiss
# The selected Grain Length is 0.001410569999531716 m
# The selected Grain Radius is 1.8384265274267998e-05 m
# The selected Boundary Temperature is 1597.9643366597015 K
# ------------------------------------------------------
# The current reduced basis size is 179
# The current error bound is 0.0011668256669362643
# Elapsed time during this step greedy is 719.30 seconds
# Overall elapsed time (+ checkpoint) is 23009.35 minutes
# The overall time of: FO = 68.65111 min, POD = 70.45842 min, error bound = 22870.23451 min
#
# The selected Fission Rate is 4.11047864649307e+19 f/s
# The selected Fuel Thermal Conductivity is 1.635557223936028 W/(m K)
# The selected Fission Yield is 0.28470086937007894 at/fiss
# The selected Grain Length is 0.001003804407754974 m
# The selected Grain Radius is 1.1967596772501903e-05 m
# The selected Boundary Temperature is 1277.5917878676946 K
# ------------------------------------------------------
# The current reduced basis size is 180
# The current error bound is 0.0011742595678434864
# Elapsed time during this step greedy is 721.54 seconds
# Overall elapsed time (+ checkpoint) is 23586.22 minutes
# The overall time of: FO = 70.36852 min, POD = 72.23662 min, error bound = 23443.60917 min
#
# The selected Fission Rate is 4.080181709929329e+19 f/s
# The selected Fuel Thermal Conductivity is 5.460060330538037 W/(m K)
# The selected Fission Yield is 0.26786370590062325 at/fiss
# The selected Grain Length is 0.00010435455588533849 m
# The selected Grain Radius is 1.9850954424602096e-05 m
# The selected Boundary Temperature is 305.2071906183731 K
# ------------------------------------------------------
# The current reduced basis size is 181
# The current error bound is 0.0014696227698024022
# Elapsed time during this step greedy is 788.93 seconds
# Overall elapsed time (+ checkpoint) is 24164.21 minutes
# The overall time of: FO = 72.08590 min, POD = 73.99753 min, error bound = 24018.12440 min
#
# The selected Fission Rate is 6834471357602956.0 f/s
# The selected Fuel Thermal Conductivity is 2.2005452785778807 W/(m K)
# The selected Fission Yield is 0.23287116045152112 at/fiss
# The selected Grain Length is 0.00035622376704996724 m
# The selected Grain Radius is 1.716699136266956e-05 m
# The selected Boundary Temperature is 974.1817829242182 K
# ------------------------------------------------------
# The current reduced basis size is 182
# The current error bound is 0.0011468609915427142
# Elapsed time during this step greedy is 1789.36 seconds
# Overall elapsed time (+ checkpoint) is 24758.88 minutes
# The overall time of: FO = 73.80542 min, POD = 75.77675 min, error bound = 24609.29278 min
#
# The selected Fission Rate is 3.7507180539037286e+18 f/s
# The selected Fuel Thermal Conductivity is 7.149511247257239 W/(m K)
# The selected Fission Yield is 0.11376039987872555 at/fiss
# The selected Grain Length is 0.000100572062238628 m
# The selected Grain Radius is 1.925479103847435e-05 m
# The selected Boundary Temperature is 646.8868468843186 K
# ------------------------------------------------------
# The current reduced basis size is 183
# The current error bound is 0.001319870559727834
# Elapsed time during this step greedy is 830.21 seconds
# Overall elapsed time (+ checkpoint) is 25337.56 minutes
# The overall time of: FO = 75.52188 min, POD = 77.53939 min, error bound = 25184.49509 min
#
# The selected Fission Rate is 3.934071485233903e+18 f/s
# The selected Fuel Thermal Conductivity is 6.0756519922198935 W/(m K)
# The selected Fission Yield is 0.048135154597080065 at/fiss
# The selected Grain Length is 0.00010549421123272579 m
# The selected Grain Radius is 1.771829084533667e-05 m
# The selected Boundary Temperature is 713.733199908854 K
# ------------------------------------------------------
# The current reduced basis size is 184
# The current error bound is 0.0011258992499823164
# Elapsed time during this step greedy is 723.56 seconds
# Overall elapsed time (+ checkpoint) is 25914.47 minutes
# The overall time of: FO = 77.23844 min, POD = 79.30090 min, error bound = 25757.92098 min
#
# The selected Fission Rate is 4.634671387047633e+19 f/s
# The selected Fuel Thermal Conductivity is 1.2775748000206806 W/(m K)
# The selected Fission Yield is 0.11560256988110751 at/fiss
# The selected Grain Length is 0.0012798386761808081 m
# The selected Grain Radius is 7.884374190282412e-06 m
# The selected Boundary Temperature is 320.1849355262804 K
# ------------------------------------------------------
# The current reduced basis size is 185
# The current error bound is 0.0010800137857959295
# Elapsed time during this step greedy is 756.77 seconds
# Overall elapsed time (+ checkpoint) is 26491.92 minutes
# The overall time of: FO = 78.95460 min, POD = 81.06173 min, error bound = 26331.90139 min
#
# The selected Fission Rate is 2.7955115215883784e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0787234658359666 W/(m K)
# The selected Fission Yield is 0.2868231667631012 at/fiss
# The selected Grain Length is 0.00045452067659318494 m
# The selected Grain Radius is 1.8504527364800718e-05 m
# The selected Boundary Temperature is 1763.6098749426 K
# ------------------------------------------------------
# The current reduced basis size is 186
# The current error bound is 0.0010798071137460773
# Elapsed time during this step greedy is 744.19 seconds
# Overall elapsed time (+ checkpoint) is 27069.17 minutes
# The overall time of: FO = 80.67088 min, POD = 82.83675 min, error bound = 26905.65786 min
#
# The selected Fission Rate is 2.8299713929331253e+19 f/s
# The selected Fuel Thermal Conductivity is 0.9255950656443197 W/(m K)
# The selected Fission Yield is 0.11216174128648171 at/fiss
# The selected Grain Length is 0.0014329566431469502 m
# The selected Grain Radius is 1.5685161988073342e-05 m
# The selected Boundary Temperature is 1277.4540413141651 K
# ------------------------------------------------------
# The current reduced basis size is 187
# The current error bound is 0.0010707007332589817
# Elapsed time during this step greedy is 757.65 seconds
# Overall elapsed time (+ checkpoint) is 27646.64 minutes
# The overall time of: FO = 82.38699 min, POD = 84.61106 min, error bound = 27479.63953 min
#
# The selected Fission Rate is 4.680312914035935e+19 f/s
# The selected Fuel Thermal Conductivity is 1.0180601034205252 W/(m K)
# The selected Fission Yield is 0.08717954803195777 at/fiss
# The selected Grain Length is 0.00019880917723717758 m
# The selected Grain Radius is 1.8782919270415602e-05 m
# The selected Boundary Temperature is 1064.822226241166 K
# ------------------------------------------------------
# The current reduced basis size is 188
# The current error bound is 0.001018689846488879
# Elapsed time during this step greedy is 774.74 seconds
# Overall elapsed time (+ checkpoint) is 28224.40 minutes
# The overall time of: FO = 84.10314 min, POD = 86.37448 min, error bound = 28053.91689 min
#
# The selected Fission Rate is 2.458564590895316e+19 f/s
# The selected Fuel Thermal Conductivity is 3.762364540848524 W/(m K)
# The selected Fission Yield is 0.0036314236925148124 at/fiss
# The selected Grain Length is 0.0012511105734539446 m
# The selected Grain Radius is 1.938831521503275e-05 m
# The selected Boundary Temperature is 1394.2655483678611 K
# ------------------------------------------------------
# The current reduced basis size is 189
# The current error bound is 0.001002447316526676
# Elapsed time during this step greedy is 780.37 seconds
# Overall elapsed time (+ checkpoint) is 28802.25 minutes
# The overall time of: FO = 85.81968 min, POD = 88.13610 min, error bound = 28628.28952 min
#
# The selected Fission Rate is 6.828284176539357e+16 f/s
# The selected Fuel Thermal Conductivity is 6.3845692572332675 W/(m K)
# The selected Fission Yield is 0.12278629667244798 at/fiss
# The selected Grain Length is 0.001178116141349301 m
# The selected Grain Radius is 1.337783329708961e-05 m
# The selected Boundary Temperature is 2444.1945117182936 K
# ------------------------------------------------------
# The current reduced basis size is 190
# The current error bound is 0.0009996691952819435
# Elapsed time during this step greedy is 793.95 seconds
# Overall elapsed time (+ checkpoint) is 29380.33 minutes
# The overall time of: FO = 87.53572 min, POD = 89.90797 min, error bound = 29202.87869 min
#
# The selected Fission Rate is 2.3795368176432955e+19 f/s
# The selected Fuel Thermal Conductivity is 0.93874475728478 W/(m K)
# The selected Fission Yield is 0.29776096949880265 at/fiss
# The selected Grain Length is 0.001470922663813056 m
# The selected Grain Radius is 1.2882098326181413e-05 m
# The selected Boundary Temperature is 679.3845894220453 K
# ------------------------------------------------------
# Il tempo impiegato dal FO = 87.53572, Il tempo impiegato dalla POD = 89.90797, Il tempo impiegato da error bound = 29202.87869

# %%
cur_err_bounds[np.argmax(cur_err_bounds)]
# Out:
# np.float64(0.0009996691952819435)

# %%
import json
# Parametri con nomi diretti
data = {
    "N_AVOG": 6.022141E+23,
    "N_BOLT": 1.380649E-23,
    "FISSION_ENERGY": 3.215E-11,
    "FISSION_RATE": cur_FR,
    "FUEL_THERMAL_CONDUCTIVITY": cur_K,
    "FISSION_YIELD": cur_FY,
    "LENGTH": cur_LL,
    "RADIUS": cur_RR,
    "T_BC": cur_BC,
    "Maximum cur_err_bounds": cur_err_bounds[np.argmax(cur_err_bounds)], 
    "TIME_ELAPSED": elapsed_time, 
    "COST_FO": cost_FO, 
    "COST_POD": cost_POD,
    "COST_EB": cost_EB
}

# Scrittura su file JSON
with open("checkpoint/worst_reconstructed_parameters.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# %%
MM_RB = solver_RB.XX_RB    #matrice di massa. 2D
FF_RB = solver_RB.FF_RB    #funzionalità contro il vettore unitario. 1D
KK_RB = solver_RB.KK_RB    #basi della decomposizione affine della stiffness. 3D
AA_RB = solver_RB.AA_RB    #l'integratore per calcolare il valor medio sul volume data la soluzione ridotta, questo può essere sostituito dalla funzione che calcola il valor medio su diversi slice. 1D
ZZ_CO = solver_RB.ZZ_FO    #coordinate a cui dobbiamo valutare la temperatura. 1D
II_CO = solver_RB.II_FO    #coefficienti che mappano i valori del coefficiente di diffusione valutata sulle temperature nei coefficienti di combinazione lineare della decomposizione affine. 2D
basis = cur_basis

# %%
# Salviamo tutte le matrici in un unico file HDF5
import h5py
with h5py.File('checkpoint/matrici_RB.h5', 'w') as hf:
    hf.create_dataset('MM_RB', data=MM_RB)
    hf.create_dataset('FF_RB', data=FF_RB)
    hf.create_dataset('KK_RB', data=KK_RB)
    hf.create_dataset('AA_RB', data=AA_RB)
    hf.create_dataset('ZZ_CO', data=ZZ_CO)
    hf.create_dataset('II_CO', data=II_CO)
    hf.create_dataset('basis', data=basis)
