# %% [markdown]
# A histogram is a graph showing frequency distributions.

# %%
# Pulizia
from IPython import get_ipython
get_ipython().magic('clear')
get_ipython().magic('reset -f')

# Import libraries:
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2595/1326388153.py:3: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('clear')
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2595/1326388153.py:4: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -f')

# %%
# Define size of the training parameter set:
sTR = 10000
FISSION_ENERGY = 3.215e-11

# Define parameters ranges:
MIN_FR, MAX_FR = 0, 5.00E+19                                                                  
MIN_BC, MAX_BC = 1.75E+03, 2.5E+03                                                           
MIN_LL, MAX_LL = 0.75E-3, 1.25E-3
MIN_RR, MAX_RR = 0.75E-5, 1.25E-5
MIN_FY, MAX_FY = 0.00, 0.3 
MIN_K, MAX_K =  0.9, 8                                                                        

# Compute a list of random parameters within the range:
LIST_FR = np.random.uniform(low=MIN_FR, high=MAX_FR, size=(sTR))
LIST_BC = np.random.uniform(low=MIN_BC, high=MAX_BC, size=(sTR))
LIST_LL = np.random.uniform(low=MIN_LL, high=MAX_LL, size=(sTR))
LIST_RR = np.random.uniform(low=MIN_RR, high=MAX_RR, size=(sTR))
LIST_FY = np.random.uniform(low=MIN_FY, high=MAX_FY, size=(sTR))
LIST_K = np.random.uniform(low=MIN_K, high=MAX_K, size=(sTR))
LIST_Q3 = FISSION_ENERGY*LIST_FR
LIST_GG = ((LIST_FR*FISSION_ENERGY)/(LIST_K*2)) * LIST_LL**2

# %%
# Istogramma normalizzato del Fission Rate (FR)
plt.figure(figsize=(8, 5))
counts, bins, patches = plt.hist(LIST_FR, bins=50, edgecolor='black', alpha=0.7)
plt.title('Normalized Histogram of Fission Rate (FR)')
plt.xlabel('Fission Rate (FR)')
plt.ylabel('Frequency of occurrence')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Istogramma normalizzato del Fission Rate (FR)
plt.figure(figsize=(8, 5))
counts, bins, patches = plt.hist(LIST_FY, bins=50, edgecolor='black', alpha=0.7)
plt.title('Normalized Histogram of Fission Yield (FY)')
plt.xlabel('Fission Rate (FR)')
plt.ylabel('Frequency of occurrence')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
if 0.3 in LIST_FY:
    print("0.3 è presente in LIST_FR.")
else:
    print("0.3 non è presente in LIST_FR.")
# Out:
# 0.3 non è presente in LIST_FR.

# %%
# Istogramma normalizzato del Fission Rate (FR)
plt.figure(figsize=(8, 5))
counts, bins, patches = plt.hist(LIST_LL, bins=50, edgecolor='black', alpha=0.7)
plt.title('Normalized Histogram of Fission Rate (FR)')
plt.xlabel('Fission Rate (FR)')
plt.ylabel('Frequency of occurrence')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
