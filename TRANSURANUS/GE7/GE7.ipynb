# %% [markdown]
# ## GE7
#
# The peak power node is in correspondence of the 3°/4° slice.
# Se non è specificata la distinzione tra ROM e SD è perchè i dati sono riferiti al caso con SD.
# - iGrainBoundaryVacancyDiffusivity = 2 (se metto 1 il FGR di SD viene 0.153)
# - iResolutionRate = 3 (se metto 1 il fgr di SD viene 0.1408)

# %%
#!/usr/bin/env python
# -*-coding:utf-8 -*-
'''
@Time    :   08/03/2023 11:29:35
@Author  :   Marty 
'''
'''
@Last edit:   07/05/2023 11:44:36
Ho coinvolto nell'analisi il caso con 10 basi
'''

from IPython import get_ipython
get_ipython().magic('clear')
get_ipython().magic('reset -f')

import numpy as np
from matplotlib import pyplot as plt
# Out:
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2101/679654778.py:13: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('clear')
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2101/679654778.py:14: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -f')

# %% [markdown]
# ## LHR and Neutron flux

# %%
lhr = np.loadtxt('SD/time/section 3/lhr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
flux = np.loadtxt('SD/time/section 3/flux.dat', converters={1: lambda s: s.replace(b'D', b'E')})

xVars = lhr[:,0]  # Time
y1Vars = lhr[:,1] # LHR Slice 3
y2Vars = flux[:,1] # Flux Slice 3

plt.figure(1, figsize=[25,15])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(xVars, y1Vars, color='#0072bd',label='Linear Heat Rate' ,linewidth=1.5)
ax2.plot(xVars, y2Vars, color='#FF7F50',label='Fast neutron flux',linewidth=1.5)
ax1.set_xlabel('Time (h)',fontsize=14)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=14)
ax1.tick_params(axis="y", labelsize=14)
ax2.set_ylabel('Fast neutron flux (n m$^{-2}$s$^{-1}$)',fontsize=14)
ax2.tick_params(axis="y",labelsize=14)
ax1.tick_params(axis='x', labelsize=14)
ax1.set_ylim(0, 70)
ax2.set_ylim(0, 7e17)
ax2.yaxis.get_offset_text().set_fontsize(13) 
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.title('peak power node | height = 225 mm',fontsize=13)#section 3 = 4
ax1.grid(which='both', alpha=0.3)
ax2.grid(which='both', alpha=0.3)
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2,loc="upper center", fontsize=13)
plt.savefig('LHR and Flux.pdf')

# Zoom
plt.figure(2, figsize=[25,15])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(xVars, y1Vars, color='#0072bd',label='Linear Heat Rate' ,linewidth=1.5)
ax2.plot(xVars, y2Vars, color='#FF7F50',label='Fast neutron flux',linewidth=1.5)
ax1.set_xlabel('Time (h)',fontsize=14)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=14)
ax1.tick_params(axis="y", labelsize=14)
ax2.set_ylabel('Fast neutron flux (n m$^{-2}$s$^{-1}$)',fontsize=14)
ax2.tick_params(axis="y",labelsize=14)
ax1.tick_params(axis='x', labelsize=14)
ax1.set_ylim(0, 70)
ax2.set_ylim(0, 7e17)
ax2.yaxis.get_offset_text().set_fontsize(13) 
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.title('peak power node | height = 225 mm',fontsize=13)
ax1.grid(which='both', alpha=0.3)
ax2.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2,loc="upper center", fontsize=13)
plt.savefig('LHR and Flux Zoom.pdf')
print(75.21*3)
# Out:
# 225.63

# %% [markdown]
# # Overview

# %% [markdown]
# ## Gap width

# %%
data = np.loadtxt("SD/time/section 3/Gap width.dat", converters={1: lambda s: s.replace(b'D', b'E')} )
xVars = data[:,0]  # Time
yVars = data[:,1] # Slice 3

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Gap width ($\mu$m)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
#plt.legend(prop={'size': 15})
#plt.savefig('Gap width.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Gap width ($\mu$m)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %% [markdown]
# ## Heat transfer coefficient

# %%
data = np.loadtxt("SD/time/section 3/hgap.dat", converters={1: lambda s: s.replace(b'D', b'E')} )
xVars = data[:,0]  # Time
yVars = data[:,1] # Slice 3

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('h (W/(mm$^2 \cdot$ K))',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
#plt.legend(prop={'size': 15})
#plt.savefig('Gap width.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('h (W/(mm$^2 \cdot$ K))',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %% [markdown]
# ## Pressure

# %%
data = np.loadtxt("SD/time/section 3/gap pressure.dat", converters={1: lambda s: s.replace(b'D', b'E')} )
xVars = data[:,0]  # Time
yVars = data[:,1] # Slice 3

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Pressure in the gap (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
#plt.legend(prop={'size': 10}, loc='best')
#plt.savefig('Pressure.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Pressure in the gap (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %% [markdown]
# ## Contact pressure between fuel and cladding

# %%
data = np.loadtxt("SD/time/section 3/contact pressure.dat", converters={1: lambda s: s.replace(b'D', b'E')} )
xVars = data[:,0]  # Time
yVars = data[:,1] # Slice 3

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Contact pressure (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
#plt.legend(prop={'size': 10}, loc='best')
#plt.savefig('Pressure.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Contact pressure (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %%
data = np.loadtxt("SD/time/section 3/temperatures.dat", converters={1: lambda s: s.replace(b'D', b'E'), 2: lambda s: s.replace(b'D', b'E'), 3: lambda s: s.replace(b'D', b'E'), 4: lambda s: s.replace(b'D', b'E'), 5: lambda s: s.replace(b'D', b'E')})
xVars = data[:,0]  # Time
y1Vars = data[:,1]  # Tfi
y2Vars = data[:,2]  # Tfo
y3Vars = data[:,3]  # Tci
y4Vars = data[:,4]  # Tco
y5Vars = data[:,5]  # Tcool

plt.figure(1, figsize=[5,5])
plt.plot(xVars, y1Vars, label= 'Fuel central temperature', linewidth=1.5)
#plt.plot(xVars, y2Vars, label= 'Outer fuel temperature', linewidth=1.5)
#plt.plot(xVars, y3Vars, label= 'Inner cladding temperature', linewidth=1.5)
#plt.plot(xVars, y4Vars, label= 'Outer cladding temperature', linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Temperature (°C)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.legend(prop={'size': 10}, loc='best')
#plt.savefig('Pressure.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, y1Vars, label= 'Fuel central temperature', linewidth=1.5)
#plt.plot(xVars, y2Vars, label= 'Outer fuel temperature', linewidth=1.5)
#plt.plot(xVars, y3Vars, label= 'Inner cladding temperature', linewidth=1.5)
#plt.plot(xVars, y4Vars, label= 'Outer cladding temperature', linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Temperature (°C)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %% [markdown]
# ## Average equivalent stress in the cladding - Equivalent Von Mises stress

# %%
data = np.loadtxt("SD/time/section 3/VM.dat", converters={1: lambda s: s.replace(b'D', b'E')} )
xVars = data[:,0]  # Time
yVars = data[:,1] # Slice 3

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Equivalent Von Mises stress (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
#plt.legend(prop={'size': 10}, loc='best')
#plt.savefig('Pressure.pdf',bbox_inches='tight')

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Equivalent Von Mises stress (MPa)',fontsize=18)
plt.title('Slice/Section = 3)',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.xlim([4.4925e4,4.495e4])
#plt.legend(prop={'size': 15})
# Out:
# (44925.0, 44950.0)

# %% [markdown]
# # Comparison between SD and ROM

# %% [markdown]
# ### Fission gas created

# %%
sd = np.loadtxt('SD/time/gasCreated.dat', converters={1: lambda s: s.replace(b'D', b'E')})
#rom = np.loadtxt('ROM_GasCreated.dat', converters={1: lambda s: s.replace(b'D', b'E')})
xVars = sd[:,0]  # Time
yVars_sd = sd[:,1] * ((1e-6*6.022e23)/1e-9)  # micro moli/mm^3 -> *e-6*6.022e23 (at/mm^3) -> /1e-9 
#yVars_rom = rom[:,1] * ((1e-6*6.022e23)/1e-9)  # micro moli/mm^3 -> *e-6*6.022e23 (at/mm^3) -> /1e-9 

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars_sd, label='SD',linewidth=1.5)
#plt.plot(xVars, yVars_rom, '--',label='ROM',markevery=100,linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Fission gas created (at/m$^3$)',fontsize=18)
plt.title('Slice/Section = 3',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.yticks(np.arange(0,35,5))
plt.grid(which='both', alpha=0.3)
plt.legend(prop={'size': 15},loc='best')
plt.savefig('Gas created.pdf',bbox_inches="tight")

# %% [markdown]
# ## Gas in grain

# %%
sd = np.loadtxt('SD/time/section 3/gas in grain.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom5 = np.loadtxt('ROM 5/time/section 3/gas in grain.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom10 = np.loadtxt('ROM 10/time/section 3/gas in grain.dat', converters={1: lambda s: s.replace(b'D', b'E')})
xVars = sd[:,0]  # Time
yVars_sd = sd[:,1] * ((1e-6*6.022e23)/1e-9)  # micro moli/mm^3 -> *e-6*6.022e23 (at/mm^3) -> /1e-9 
yVars_rom5 = rom5[:,1] * ((1e-6*6.022e23)/1e-9) # micro moli/mm^3 -> *e-6*6.022e23 (at/mm^3) -> /1e-9
yVars_rom10 = rom10[:,1] * ((1e-6*6.022e23)/1e-9) # micro moli/mm^3 -> *e-6*6.022e23 (at/mm^3) -> /1e-9

plt.figure(1, figsize=[5,5])
plt.plot(xVars, yVars_sd, label='SD',linewidth=1.5)
plt.plot(xVars, yVars_rom5, label='ROM 5 bases',linewidth=1.5)
plt.plot(xVars, yVars_rom10, label='ROM 10 bases',linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Fission gas in the grain (at/m$^3$)',fontsize=18)
plt.title('Slice/Section = 3',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.grid(which='both', alpha=0.3)
plt.legend(prop={'size': 15},loc='best')
plt.savefig('Gas in grain.pdf',bbox_inches="tight")

# Zoom
plt.figure(2, figsize=[5,5])
plt.plot(xVars, yVars_sd, label='SD',linewidth=1.5)
plt.plot(xVars, yVars_rom5, label='ROM 5 bases',linewidth=1.5)
plt.plot(xVars, yVars_rom10, label='ROM 10 bases',linewidth=1.5)
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Fission gas in the grain (at/m$^3$)',fontsize=18)
plt.title('Slice/Section = 3',fontsize=13)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.xlim([4.4925e4,4.495e4])
plt.grid(which='both', alpha=0.3)
plt.legend(prop={'size': 15},loc='best')
plt.savefig('Gas in grain zoom.pdf',bbox_inches="tight")

#Error
err5=np.zeros(np.size(yVars_sd))
err10=np.zeros(np.size(yVars_sd))
for i in range(0, np.size(yVars_sd)):
    err5[i]=abs(yVars_sd[i]-yVars_rom5[i])/abs(yVars_sd[i])*100
    err10[i]=abs(yVars_sd[i]-yVars_rom10[i])/abs(yVars_sd[i])*100

plt.figure(3, figsize=[5,5])
plt.plot(xVars, err5,linewidth=1.5, label= 'ROM 5 bases')
plt.plot(xVars, err10,linewidth=1.5, label= 'ROM 10 bases')
plt.xlabel('Time (h)', fontsize=18)
plt.ylabel('Error (%)',fontsize=18)
plt.title('Gas in grain error',fontsize=13)
plt.grid(which='both', alpha=0.3)
plt.legend()
plt.savefig('Gas in grain error.pdf',bbox_inches="tight")
# Out:
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2101/2998195765.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   err5[i]=abs(yVars_sd[i]-yVars_rom5[i])/abs(yVars_sd[i])*100
# /var/folders/gs/p2p59ns16hlgpqv_027665gm0000gn/T/ipykernel_2101/2998195765.py:42: RuntimeWarning: invalid value encountered in scalar divide
#   err10[i]=abs(yVars_sd[i]-yVars_rom10[i])/abs(yVars_sd[i])*100

# %% [markdown]
# ## Fission gas release

# %%
sd = np.loadtxt('SD/time/section 3/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom5 = np.loadtxt('ROM 5/time/section 3/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom10 = np.loadtxt('ROM 10/time/section 3/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
lhr = np.loadtxt('SD/time/section 3/lhr.dat', converters={1: lambda s: s.replace(b'D', b'E')})


xVars = sd[:,0]  # Time
yVars_sd = sd[:,1] # (/)
yVars_rom5 = rom5[:,1]
yVars_rom10 = rom10[:,1]

xVars_lhr = lhr[:,0]  # Time
yVars_lhr = lhr[:,1] # LHR Slice 3


plt.figure(1, figsize=[25,15])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax2.plot(xVars, yVars_sd, label='Spectral diffusion algorithm', linewidth=1.5)
ax2.plot(xVars, yVars_rom10, label='Reduced order model for spherical grains', linewidth=1.5)
ax2.plot(xVars[-1], 0.1441, 'o',label = 'Experimental FGR', color= '#050402', alpha=0.5)
ax1.plot(xVars, yVars_lhr,'--', label='Linear heat rate', color = '#b3b3b3',linewidth=1.5)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=14)
ax1.set_xlabel('Time (h)',fontsize=14)
ax2.set_ylabel('Fission gas release (/)',fontsize=14)

ax1.tick_params(axis="y", labelsize=14)
ax2.tick_params(axis="y",labelsize=14)
ax1.tick_params(axis='x', labelsize=14)
#ax1.set_ylim(0, 25)
#ax2.set_ylim(0, 5e18)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
plt.title('peak power node | heaight = 225 mm',fontsize=13)#section 3 = 4
ax1.grid(which='both', alpha=0.3)
ax2.grid(which='both', alpha=0.3)
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2,loc="upper center", fontsize=13)
plt.savefig('NuFuel.pdf')


plt.figure(2, figsize=[25,15])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax2.plot(xVars, yVars_sd, label='Spectral diffusion algorithm', linewidth=1.5)
ax2.plot(xVars, yVars_rom10, label='Reduced order model for spherical grains', linewidth=1.5)
ax2.plot(xVars[-1], 0.1441, 'o',label = 'Experimental FGR', color= '#050402', alpha=0.5)
ax1.plot(xVars, yVars_lhr,'--', label='Linear heat rate', color = '#b3b3b3',linewidth=1.5)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=14)
ax1.set_xlabel('Time (h)',fontsize=14)
ax2.set_ylabel('Fission gas release (/)',fontsize=14)
ax1.tick_params(axis="y", labelsize=14)
ax2.tick_params(axis="y",labelsize=14)
ax1.tick_params(axis='x', labelsize=14)
ax1.set_xlim([4.4925e4,4.495e4])
#ax2.set_ylim(0, 5e18)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.title('peak power node | heaight = 225 mm',fontsize=13)#section 3 = 4
ax1.grid(which='both', alpha=0.3)
ax2.grid(which='both', alpha=0.3)
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2,loc="lower center", fontsize=13)
plt.savefig('NuFuel.pdf')


#Error
# err5=np.zeros(np.size(yVars_sd))
# err10=np.zeros(np.size(yVars_sd))
# for i in range(20,np.size(yVars_sd)):
#     err5[i]=(abs(yVars_sd[i]-yVars_rom5[i])/abs(yVars_sd[i]))*100
#     err10[i]=(abs(yVars_sd[i]-yVars_rom10[i])/abs(yVars_sd[i]))*100

# plt.figure(3, figsize=[5,5])
# plt.plot(xVars, err5, linewidth=1.5, label = 'ROM 5 bases')
# plt.plot(xVars, err10, linewidth=1.5, label = 'ROM 10 bases')
# plt.xlabel('Time (h)', fontsize=15)
# plt.ylabel('Error (/)',fontsize=15)
# plt.title('FGR error',fontsize=13)
# plt.grid(which='both', alpha=0.3)
# plt.legend()
# plt.savefig('FGR error.pdf',bbox_inches="tight")

print((0.1441-yVars_sd[-1])/0.1441)
print((0.1441-yVars_rom10[-1])/0.1441)
print(yVars_rom10[-1])
# Out:
# 0.02419639139486474
# 0.19885010409437895
# 0.1154457

# %%
sd = np.loadtxt('SD/time/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom5 = np.loadtxt('ROM 5/time/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom10 = np.loadtxt('ROM 10/time/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
lhr = np.loadtxt('SD/time/lhr.dat', converters={1: lambda s: s.replace(b'D', b'E')})


xVars = sd[:,0]  # Time
yVars_sd = sd[:,1] # (/)
yVars_rom5 = rom5[:,1]
yVars_rom10 = rom10[:,1]

xVars_lhr = lhr[:,0]  # Time
yVars_lhr = lhr[:,1] # LHR Slice 3


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(27,11)) #one row and two columns
ax1a = ax1.twinx()
ax1a.plot(xVars, yVars_sd, label='State-of-the-art algorithm, spectral diffusion with 40 modes', linewidth=2)#Spectral diffusion algorithm con 40 modi
ax1a.plot(xVars, yVars_rom10, label='Reduced order model with 10 modes', linewidth=2) #ROm con 10 modi
ax1a.plot(xVars[-1], 0.1441, 'o',label = 'Experimental data', color= '#050402', alpha=0.5)
ax1.plot(xVars, yVars_lhr,'--', label='Linear power', color = '#b3b3b3',linewidth=2)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=20)
ax1.set_xlabel('Time (h)',fontsize=20)
ax1a.set_ylabel('Fission gas release (/)',fontsize=20)

ax1.tick_params(axis="y", labelsize=20)
ax1a.tick_params(axis="y",labelsize=20)
ax1.tick_params(axis='x', labelsize=20)
ax1.set_ylim(0, 80)
ax1a.set_ylim(0, 0.16)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.title('peak power node | heaight = 225 mm',fontsize=20)#section 3 = 4
ax1.grid(which='both', alpha=0.3)
ax1a.grid(which='both', alpha=0.3)


ax2a = ax2.twinx()
ax2a.plot(xVars, yVars_sd, label='state-of-the-art algorithm', linewidth=2) 
ax2a.plot(xVars, yVars_rom10, label='Reduced order model', linewidth=2)
ax2a.plot(xVars[-1], 0.1441, 'o',label = 'Experimental FGR', color= '#050402', alpha=0.5)
ax2.plot(xVars, yVars_lhr,'--', label='Linear heat rate', color = '#b3b3b3',linewidth=2)
ax2.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=20)
ax2.set_xlabel('Time (h)',fontsize=20)
ax2a.set_ylabel('Fission gas release (/)',fontsize=20)
ax2.tick_params(axis="y", labelsize=20)
ax2a.tick_params(axis="y",labelsize=20)
ax2.tick_params(axis='x', labelsize=20)
ax2.set_xlim([4.4925e4,4.495e4])
ax2.set_ylim(0, 80)
ax2a.set_ylim(0, 0.16)
ax2.set_title('Zoom on the power transient', fontsize=20)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.title('peak power node | heaight = 225 mm',fontsize=20)#section 3 = 4
ax2.grid(which='both', alpha=0.3)
ax2a.grid(which='both', alpha=0.3)
fig.tight_layout(pad=5.0)
h1, l1 = ax1a.get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2,loc='upper center', bbox_to_anchor=(1.2, -0.1), fancybox=True, shadow=False, ncol=4, fontsize=20)

#ax1a.legend(loc='upper center', bbox_to_anchor=(1.2, -0.1), fancybox=True, shadow=False, ncol=4, fontsize=20)
plt.savefig('NuFuel.pdf',bbox_inches='tight')

# %%
print(yVars_sd[-1])
print(((0.1441-yVars_sd[-1])/0.1441)*100)
print(((0.1441-yVars_rom10[-1])/0.1441)*100)
# Out:
# 0.1406133
# 2.419639139486474
# 6.080222068008332

# %% [markdown]
# ## **Time integral**

# %%
sd = np.loadtxt('SD/time integral/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
rom10 = np.loadtxt('ROM 10/time integral/fgr.dat', converters={1: lambda s: s.replace(b'D', b'E')})
lhr = np.loadtxt('SD/time/lhr.dat', converters={1: lambda s: s.replace(b'D', b'E')})


xVars = sd[:,0]  # Time
yVars_sd = sd[:,1] # (/)
yVars_rom5 = rom5[:,1]
yVars_rom10 = rom10[:,1]

xVars_lhr = lhr[:,0]  # Time
yVars_lhr = lhr[:,1] # LHR Slice 3


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(27,11)) #one row and two columns
ax1a = ax1.twinx()
ax1a.plot(xVars, yVars_sd, label='Spectral diffusion algorithm', linewidth=2)
ax1a.plot(xVars, yVars_rom10, label='Reduced order model for spherical grains', linewidth=2)
ax1a.plot(xVars[-1], 0.1441, 'o',label = 'Experimental data', color= '#050402', alpha=0.5)
ax1.plot(xVars, yVars_lhr,'--', label='Linear heat rate', color = '#b3b3b3',linewidth=2)
ax1.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=20)
ax1.set_xlabel('Time (h)',fontsize=20)
ax1a.set_ylabel('Fission gas release (/)',fontsize=20)

ax1.tick_params(axis="y", labelsize=20)
ax1a.tick_params(axis="y",labelsize=20)
ax1.tick_params(axis='x', labelsize=20)
ax1.set_ylim(0, 80)
ax1a.set_ylim(0, 0.16)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.title('peak power node | heaight = 225 mm',fontsize=20)#section 3 = 4
ax1.grid(which='both', alpha=0.3)
ax1a.grid(which='both', alpha=0.3)




ax2a = ax2.twinx()
ax2a.plot(xVars, yVars_sd, label='Spectral diffusion algorithm', linewidth=2)
ax2a.plot(xVars, yVars_rom10, label='Reduced order model for spherical grains', linewidth=2)
ax2a.plot(xVars[-1], 0.1441, 'o',label = 'Experimental FGR', color= '#050402', alpha=0.5)
ax2.plot(xVars, yVars_lhr,'--', label='Linear heat rate', color = '#b3b3b3',linewidth=2)
ax2.set_ylabel('Linear power (kW m$^{-1}$)',fontsize=20)
ax2.set_xlabel('Time (h)',fontsize=20)
ax2a.set_ylabel('Fission gas release (/)',fontsize=20)
ax2.tick_params(axis="y", labelsize=20)
ax2a.tick_params(axis="y",labelsize=20)
ax2.tick_params(axis='x', labelsize=20)
ax2.set_xlim([4.4925e4,4.495e4])
ax2.set_ylim(0, 80)
ax2a.set_ylim(0, 0.16)
plt.rcParams['figure.edgecolor'] = '#050402'
plt.rcParams['axes.edgecolor'] = '#050402'
#plt.title('peak power node | heaight = 225 mm',fontsize=20)#section 3 = 4
ax2.grid(which='both', alpha=0.3)
ax2a.grid(which='both', alpha=0.3)

ax1a.legend(loc='upper center', bbox_to_anchor=(1.2, -0.1), fancybox=True, shadow=False, ncol=3, fontsize=20)
#plt.savefig('NuFuel.pdf',bbox_inches='tight')
