# %%
# GERMINAL
# 
# Time (days). Centerline temperature (°C)
""
0, 1495.6883786289418
4.999999999999986, 2140.0587422153853
10, 2031.8246577067248
15, 2054.4783033015606
20.000000000000014, 2056.99537503432
25.000000000000014, 2026.7905142412055
29.999999999999986, 1999.1027251808505
35.00000000000004, 2016.7222273101675
40.000000000000014, 1981.483223051534
50.000000000000014, 1963.863720922217
55.00000000000004, 1953.795433991179
60.00000000000004, 1938.6930035946216
64.99999999999999, 1986.5173665170532
70.00000000000001, 1926.1076449308239
75.00000000000001, 1953.795433991179
80.00000000000001, 1900.9369276032285
84.99999999999999, 1890.8686406721904
90.00000000000001, 1916.0393579997858
94.99999999999999, 1895.9027841377097
99.99999999999999, 1749.912623637656
105.00000000000001, 1744.8784801721367
110.00000000000001, 1654.2638977927932
115.00000000000001, 1495.6883786289418
120.00000000000001, 1490.6542351634228
125.00000000000004, 1493.1713068961826
130, 1493.1713068961826
135.00000000000006, 1483.103019965144
140, 1480.585948232385
145, 1475.5518047668654
149.99999999999994, 1473.0347330341062
154.99999999999994, 1473.0347330341062
160.00000000000006, 1465.4835178358276
164.99999999999994, 1473.0347330341062
169.99999999999994, 1473.0347330341062
175, 1462.966446103068
180, 1473.0347330341062
185, 1460.4493743703083
190, 1460.4493743703083
195, 1473.0347330341062
200, 1460.4493743703083
205, 1460.4493743703083
210, 1473.0347330341062
215.00000000000006, 1457.932302637549
219.99999999999994, 1473.0347330341062
230, 1420.1762266461556
234.99999999999994, 1417.659154913396
240, 1415.1420831806367
245, 1412.625011447877
250, 1447.8640157065106
254.99999999999994, 1452.8981591720296
260, 1455.4152309047893
265, 1447.8640157065106
270, 1457.932302637549
275, 1447.8640157065106
280, 1450.3810874392702
285.00000000000006, 1457.932302637549
289.99999999999994, 1452.8981591720296
295, 1498.2054503617014
300.00000000000006, 1488.1371634306631
304.99999999999994, 1505.75666555998
310, 1495.6883786289418
315, 1498.2054503617014
320.00000000000006, 1510.7908090254991
324.99999999999994, 1503.2395938272205
330, 1513.3078807582588
335, 1518.3420242237778
340.00000000000006, 1936.175931861862
344.99999999999994, 1895.9027841377097
350, 1951.2783622584193
354.99999999999994, 1953.795433991179
365, 1951.2783622584193
375.00000000000006, 1926.1076449308239
379.99999999999994, 1948.7612905256597
385, 1931.1417883963431
390, 1956.3125057239386
394.99999999999994, 1958.8295774566982
400.00000000000006, 1946.2442187929005
405, 1956.3125057239386
409.9999999999999, 1948.7612905256597
415, 1951.2783622584193
420, 1951.2783622584193
424.9999999999999, 1951.2783622584193
434.9999999999999, 2072.0978054308775
439.9999999999999, 2067.0636619653583
445, 2054.4783033015606
454.9999999999999, 2011.6880838446486
460, 2021.7563707756867
465, 1785.1516278962895
470, 1737.3272649738583
475, 1767.5321257669725
480, 1780.1174844307702
485, 1805.288201758366
489.9999999999999, 1805.288201758366
494.9999999999999, 1810.322345223885
500, 1830.4589190859615
505.0000000000001, 1815.3564886894042
510, 1832.9759908187207
515, 1835.4930625514803
520, 1815.3564886894042
525, 1344.6640746633693
530, 1344.6640746633693
535, 1342.1470029306097
540.0000000000001, 1342.1470029306097
545.0000000000001, 1342.1470029306097
550, 1342.1470029306097
555.0000000000001, 1339.62993119785
560, 1344.6640746633693
565, 1344.6640746633693
570.0000000000001, 1342.1470029306097
579.9999999999999, 1830.4589190859615
585.0000000000001, 1817.8735604221638
590, 1815.3564886894042
595, 1835.4930625514803
600.0000000000001, 1817.8735604221638
605, 1820.3906321549232
610, 1840.5272060169996
615, 1820.3906321549232
620, 1840.5272060169996
630, 1976.449079586015
635, 1958.8295774566982
640.0000000000001, 1981.483223051534
645, 1981.483223051534
649.9999999999999, 1963.863720922217
655.0000000000001, 1981.483223051534
660, 1483.103019965144
665, 1984.0002947842936
670.0000000000001, 1981.483223051534
675, 1958.8295774566982
680, 1976.449079586015
684.9999999999999, 1953.795433991179
689.9999999999999, 1951.2783622584193
695, 1966.3807926549766
704.9999999999999, 1951.2783622584193
710, 1855.629636413557
715, 1420.1762266461556
719.9999999999999, 1417.659154913396
725, 1422.693298378915
730, 1410.1079397151173
734.9999999999999, 1415.1420831806367
740, 1412.625011447877
745, 1397.5225810513195
750.0000000000001, 1402.5567245168386
755, 1759.980910568694
759.9999999999999, 1802.7711300256065
765, 1863.1808516118354
765, 1777.600412698011
770, 1984.0002947842936
774.9999999999999, 1968.8978643877363
780, 1968.8978643877363
785, 1994.0685817153317
789.9999999999999, 1968.8978643877363
795, 1994.0685817153317
800, 1991.551509982572
815, 1986.5173665170532
820.0000000000001, 1984.0002947842936
829.9999999999999, 1976.449079586015
834.9999999999999, 1971.414936120496
845.0000000000001, 1966.3807926549766
854.9999999999999, 1928.6247166635835
""

# %%
# GERMINAL
# 
# Time (days). Pressure (bar)
""
344.99999999999994, 15.070785070785078
349.99999999999994, 16.203346203346214
354.99999999999994, 17.0123184408899
359.99999999999994, 17.98308512594228
364.99999999999994, 18.792057363485966
369.99999999999994, 19.601029601029623
374.99999999999994, 20.24820739106454
384.99999999999994, 22.108843537414984
389.99999999999994, 22.675124103695545
395, 23.40319911748484
399.99999999999994, 25.668321382607104
405, 24.85934914506344
409.99999999999994, 26.558190843905138
415, 26.153704725133302
419.99999999999994, 26.800882515168233
425, 27.852546423975
429.9999999999999, 28.01434087148374
435, 29.0660047802905
439.9999999999999, 29.794079794079806
445, 30.764846479132203
449.9999999999999, 29.955874241588532
454.9999999999999, 32.14009928295643
459.9999999999999, 32.86817429674573
470, 34.00073542930687
474.9999999999999, 34.6479132193418
480, 35.29509100937673
484.9999999999999, 35.942268799411664
490, 36.42765214193787
494.9999999999999, 37.0748299319728
500, 37.64111049825337
504.9999999999999, 38.28828828828829
510, 38.93546607832322
514.9999999999999, 39.33995219709506
520, 40.06802721088437
520, 34.80970766685053
524.9999999999999, 38.611877183305765
530, 38.77367163081449
534.9999999999999, 38.93546607832323
540, 39.097260525831956
544.9999999999999, 39.25905497334069
550, 39.42084942084942
554.9999999999999, 39.582643868358154
560, 39.74443831586689
564.9999999999999, 39.90623276337563
570, 40.06802721088435
574.9999999999999, 39.98712998712999
594.9999999999999, 44.43647729362015
599.9999999999999, 45.16455230740945
604.9999999999999, 45.73083287369001
609.9999999999999, 46.37801066372495
614.9999999999999, 46.78249678249678
619.9999999999999, 47.348777348777354
624.9999999999999, 49.128516271373414
624.9999999999999, 43.95109395109395
629.9999999999999, 48.56223570509285
634.9999999999999, 49.209413495127784
639.9999999999999, 49.93748850891709
645, 50.74646074646075
649.9999999999999, 51.31274131274132
655, 52.12171355028498
659.9999999999999, 50.746460746460755
665, 53.011583011583014
669.9999999999999, 53.658760801617944
675, 54.38683581540725
679.9999999999999, 54.95311638168781
685, 55.681191395477114
689.9999999999999, 56.247471961757675
695, 56.975546975546976
699.9999999999999, 58.59349145063431
699.9999999999999, 52.93068578782865
705, 57.70362198933627
709.9999999999999, 58.26990255561685
714.9999999999999, 56.73285530428388
719.9999999999999, 56.89464975179261
724.9999999999999, 57.05644419930135
729.9999999999999, 57.21823864681008
734.9999999999999, 57.38003309431881
739.9999999999999, 57.541827541827544
744.9999999999999, 57.70362198933628
749.9999999999999, 57.86541643684501
754.9999999999999, 59.88784703070417
759.9999999999999, 60.45412759698473
764.9999999999999, 61.18220261077404
769.9999999999999, 62.15296929582644
774.9999999999999, 62.96194153337011
779.9999999999999, 63.6900165471594
784.9999999999999, 64.25629711343997
789.9999999999999, 64.98437212722928
794.9999999999999, 65.63154991726421
799.9999999999999, 66.27872770729914
804.9999999999999, 65.63154991726421
809.9999999999999, 67.41128883986028
814.9999999999999, 67.97756940614083
820, 68.62474719617576
824.9999999999999, 69.19102776245633
830, 69.7573083287369
855.6053811659192, 72.89661859168585
855.6053811659192, 23.347069042136305
334.9775784753363, 12.92489799216257
97.86995515695067, 7.614430574071832
292.60089686098655, 10.419343109926075
226.00896860986552, 9.184745283400005
179.59641255605385, 8.842968529067178
128.1390134529148, 7.782491011190558
64.57399103139015, 5.645780309457436
31.278026905829606, 3.8573102250232267
2.017937219730939, 2.7879448955682165
""

# %%
# End of life FIMA 13.28 at%
# mean LHR 25.7 kW/m
